# %%
import numpy as np
import pandas as pd
import re

# %%
df = pd.read_csv('../TextFiles/csv/JopDataSet.csv')

# %%
# to read data from the data frame at differents indexes
print(df.head())
# Out:
#     type                                            pageurl  \
# 0  array  https://www.simplyhired.com/job/Ny79HQUAZet4Dy...
# 1  array  https://www.simplyhired.com/job/gNRtJ9_fyPkEsO...
# 2  array  https://www.simplyhired.com/job/N1azNM3D2VNGC_...
# 3  array  https://www.simplyhired.com/job/Cc3yCyLH80lt68...
# 4  array  https://www.simplyhired.com/job/jU07UpKLXqVCX3...
#
#                             uniq-id            crawl-timestamp  \
# 0  5a31cb0ee47e3cf1b5040e6c9fe9c0db  2019-09-30 16:12:44 +0000
# 1  1645b95dcd323b045e7e1733f775f582  2019-09-22 13:32:10 +0000
# 2  8624490c19ca05d1482f0084ccacdf59  2019-09-25 13:05:08 +0000
# 3  713d3a87025ff202027c7b5ba9d99580  2019-09-26 02:01:31 +0000
# 4  d788321e52ccae1c8ccc6228fee94edc  2019-09-19 16:45:36 +0000
#
#                                            employer  \
# 0                                         Giftcraft
# 1                                       Bento Group
# 2                     Burger King | Ghai Management
# ...

# %%
# to choose a specific record in the data frame(first record) 
s = df[0:1]
s=s.to_string()
print(s)
# Out:
#     type                                                                                    pageurl                           uniq-id            crawl-timestamp   employer                      ad-title                         salary-range  job-location job-country  job-city job-state                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          
# ...

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# Create a Doc object
doc = nlp(s)

# Print each token separately
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
#      SPACE
# type NOUN ROOT
#                                                                                     SPACE
# pageurl NOUN ROOT
#                            SPACE
# uniq PROPN amod
# - PUNCT punct
# id PROPN ROOT
#             SPACE
# crawl NOUN compound
# - PUNCT punct
# timestamp NOUN nmod
#    SPACE
# employer NOUN ROOT
#                       SPACE
# ad NOUN compound
# - PUNCT punct
# title NOUN nmod
#                          SPACE
# salary NOUN compound
# - PUNCT punct
# range NOUN nmod
#   SPACE
# job NOUN compound
# - PUNCT punct
# location NOUN compound
# job NOUN compound
# - PUNCT punct
# country NOUN intj
#   SPACE
# job NOUN compound
# - PUNCT punct
# city NOUN appos
# job NOUN compound
# - PUNCT punct
# state NOUN nmod
# ...

# %%
 # explore tokens
for token in doc:
    print(token.text, end=' | ')
# Out:
#      | type |                                                                                     | pageurl |                            | uniq | - | id |             | crawl | - | timestamp |    | employer |                       | ad | - | title |                          | salary | - | range |   | job | - | location | job | - | country |   | job | - | city | job | - | state |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
# ...

# %%
# MAKE NER 
for ent in doc.ents:
    print(ent.text, ent.start, ent.end, ent.start_char, ent.end_char, ent.label_)
# Out:
# 5a31cb0ee47e3cf1b5040e6c9fe9c0db 48 49 4613 4645 CARDINAL
# 2019-09-30 50 55 4647 4657 DATE
# 16:12:44 55 56 4658 4666 TIME
# $42,000 - $58,000 66 71 4726 4743 MONEY
# Richmond 74 75 4752 4760 GPE
# VA 76 77 4762 4764 GPE
# Richmond 80 81 4778 4786 GPE
# VA 82 83 4794 4796 GPE
# Richmond 84 85 4798 4806 GPE
# ||1 hour 87 89 4816 4824 TIME
# every 8 weeks 186 189 5465 5478 DATE
# daily 207 208 5584 5589 DATE
# Customer Service 228 230 5698 5714 ORG
# daily 248 249 5829 5834 DATE
# every day 269 271 5929 5938 DATE
# Giftcraft 279 280 5988 5997 ORG
# Bachelor Degree, College Diploma 286 291 6039 6071 ORG
# At least 1 year 296 300 6107 6122 DATE
# Retail 305 306 6154 6160 GPE
# Business Development 309 311 6171 6191 ORG
# Exceptional Interpersonal 354 356 6447 6472 ORG
# IOS 379 380 6620 6623 ORG
# Iphone 384 385 6639 6645 ORG
# Microsoft Office 390 392 6657 6673 ORG
# Excel 398 399 6699 6704 PRODUCT
# 1 year 430 432 6848 6854 DATE
# every 8 weeks 524 527 7437 7450 DATE
# ...

# %%
# More Specific Entities
for sent in doc.sents:
    docx = nlp(sent.text)
    if docx.ents:
        displacy.render(docx, style='ent', jupyter=True)
    else:
        print(docx.text)
# Out:
#     type
# pageurl
# uniq-id
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crawl-timestamp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# employer                      ad-title                         salary-range  job-location job-country  job-city</div></span>
# ...

# %%
## Visualizing the entity recognizer
from spacy import displacy

displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">    type                                                                                    pageurl                           uniq-id            crawl-timestamp   employer                      ad-title                         salary-range  job-location job-country  job-city job-state                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              
# ...

# %%
len([ent for ent in doc.ents ])
# Out:
# 42

# %%
# Viewing Specific Entities

options = {'ents': ['ORG', 'PRODUCT']}

displacy.render(doc, style='ent', jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">    type                                                                                    pageurl                           uniq-id            crawl-timestamp   employer                      ad-title                         salary-range  job-location job-country  job-city job-state                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              
# ...

# %%
# Import the toolkit and the full Porter Stemmer library
import nltk
from nltk.stem.porter import *
from nltk.stem.snowball import SnowballStemmer

# The Snowball Stemmer requires that you pass a language parameter
s_stemmer = SnowballStemmer(language='english')

# %%
#Stemming

for word in re.findall(r"[^!.? ]+",s):
    print(word+' --> '+s_stemmer.stem(word))
# Out:
# type --> type
# pageurl --> pageurl
# uniq-id --> uniq-id
# crawl-timestamp --> crawl-timestamp
# employer --> employ
# ad-title --> ad-titl
# salary-range --> salary-rang
# job-location --> job-loc
# job-country --> job-countri
# job-city --> job-citi
# job-state --> job-stat
# description --> descript
# email-address
# 0 --> email-address
# 0
# array --> array
# https://www --> https://www
# simplyhired --> simplyhir
# com/job/Ny79HQUAZet4Dyx-2QxibpnrcshmFI5IpoWyq4fMPoFLe3jKdZTJ-w --> com/job/ny79hquazet4dyx-2qxibpnrcshmfi5ipowyq4fmpofle3jkdztj-w
# q= --> q=
# 5a31cb0ee47e3cf1b5040e6c9fe9c0db --> 5a31cb0ee47e3cf1b5040e6c9fe9c0db
# 2019-09-30 --> 2019-09-30
# 16:12:44 --> 16:12:44
# +0000 --> +0000
# Giftcraft --> giftcraft
# Outside --> outsid
# Sales --> sale
# Representative --> repres
# Estimated: --> estimated:
# $42,000 --> $42,000
# - --> -
# $58,000 --> $58,000
# a --> a
# year --> year
# Richmond, --> richmond,
# VA --> va
# usa --> usa
# Richmond --> richmond
# VA --> va
# ...

# %%
## Lemmatization

for token in doc:
    print(f'{token.text:{10}} {token.pos_:{10}} {token.dep_:{10}} {spacy.explain(token.dep_)}')
# Out:
#            SPACE                 None
# type       NOUN       ROOT       None
#                                                                                     SPACE                 None
# pageurl    NOUN       ROOT       None
#                            SPACE                 None
# uniq       PROPN      amod       adjectival modifier
# -          PUNCT      punct      punctuation
# id         PROPN      ROOT       None
#             SPACE                 None
# crawl      NOUN       compound   compound
# -          PUNCT      punct      punctuation
# timestamp  NOUN       nmod       modifier of nominal
#            SPACE                 None
# employer   NOUN       ROOT       None
#                       SPACE                 None
# ad         NOUN       compound   compound
# -          PUNCT      punct      punctuation
# title      NOUN       nmod       modifier of nominal
#                          SPACE                 None
# salary     NOUN       compound   compound
# ...

# %%
# Now we will make filttering onDataset

# %%
import pandas as pd

# %%
df = pd.read_csv("../TextFiles/csv/JopDataSet.csv")
schema_df = pd.read_csv('../TextFiles/csv/JopDataSet.csv')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

df.head()
# Out:
#     type                                            pageurl  \
# 0  array  https://www.simplyhired.com/job/Ny79HQUAZet4Dy...
# 1  array  https://www.simplyhired.com/job/gNRtJ9_fyPkEsO...
# 2  array  https://www.simplyhired.com/job/N1azNM3D2VNGC_...
# 3  array  https://www.simplyhired.com/job/Cc3yCyLH80lt68...
# 4  array  https://www.simplyhired.com/job/jU07UpKLXqVCX3...
#
#                             uniq-id            crawl-timestamp  \
# 0  5a31cb0ee47e3cf1b5040e6c9fe9c0db  2019-09-30 16:12:44 +0000
# 1  1645b95dcd323b045e7e1733f775f582  2019-09-22 13:32:10 +0000
# 2  8624490c19ca05d1482f0084ccacdf59  2019-09-25 13:05:08 +0000
# 3  713d3a87025ff202027c7b5ba9d99580  2019-09-26 02:01:31 +0000
# 4  d788321e52ccae1c8ccc6228fee94edc  2019-09-19 16:45:36 +0000
#
#                                            employer  \
# 0                                         Giftcraft
# 1                                       Bento Group
# 2                     Burger King | Ghai Management
# ...

# %%
filt = (df['ad-title'] == 'Housekeeper')
filt
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 30025    False
# 30026    False
# 30027    False
# 30028    False
# 30029    False
# Name: ad-title, Length: 30030, dtype: bool

# %%
df.loc[filt]
# Out:
#         type                                            pageurl  \
# 16     array  https://www.simplyhired.com/job/XRwtaur_PstLpI...
# 328    array  https://www.simplyhired.com/job/fXm88dePnYXgG7...
# 706    array  https://www.simplyhired.com/job/EGDyXo3oUacsgs...
# 852    array  https://www.simplyhired.com/job/In7fECJaJsNQV5...
# 980    array  https://www.simplyhired.com/job/NJ93BQ_oM6C_Sa...
# 991    array  https://www.simplyhired.com/job/fKMvd7I-RASsSu...
# 1038   array  https://www.simplyhired.com/job/qr_SU4_EBBLefB...
# 1387   array  https://www.simplyhired.com/job/jg9aJpK4ZyXf_S...
# 1493   array  https://www.simplyhired.com/job/zIDEYKaKyfLrAG...
# 2271   array  https://www.simplyhired.com/job/kmKQjhmfHQYB1j...
# 2528   array  https://www.simplyhired.com/job/prd12qiK3aGsNK...
# 2562   array  https://www.simplyhired.com/job/YQGR7RmpdxBB_O...
# 2667   array  https://www.simplyhired.com/job/o4hkeNBpAWvKDA...
# 2808   array  https://www.simplyhired.com/job/FMLSa8k6uGmHZF...
# ...

# %%
# result of job ads that have housekeeping in their category is 249 record

filt = df['ad-title'].str.contains('Housekeeper', na=False)

housekeeping_df = df.loc[filt]

# %%
housekeeping_df
# Out:
#         type                                            pageurl  \
# 16     array  https://www.simplyhired.com/job/XRwtaur_PstLpI...
# 113    array  https://www.simplyhired.com/job/mzUgm7mS7Alii4...
# 328    array  https://www.simplyhired.com/job/fXm88dePnYXgG7...
# 369    array  https://www.simplyhired.com/job/w9Vw2P7zYUQrBj...
# 435    array  https://www.simplyhired.com/job/ubDJUC6FI4ImD8...
# ...      ...                                                ...
# 29353  array  https://www.simplyhired.com/job/AlWKp_H5-ouSG6...
# 29419  array  https://www.simplyhired.com/job/JGRA4wfFl28CrX...
# 29515  array  https://www.simplyhired.com/job/9ytRt6RMV0k1Bf...
# 29945  array  https://www.simplyhired.com/job/E6V77yTMEH5se1...
# 30025  array  https://www.simplyhired.com/job/bCvyw7_YnIAmCL...
#
#                                 uniq-id            crawl-timestamp  \
# 16     44ec38ab192b4a8c72f175929ee34df6  2019-09-17 16:37:07 +0000
# ...
