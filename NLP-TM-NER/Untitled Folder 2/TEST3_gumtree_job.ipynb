# %%
import numpy as np
import pandas as pd
import re
import spacy

# %%
df = pd.read_csv('../TextFiles/csv/gumtree_job.csv')

# %%
# to read data from the data frame at differents indexes
print(df.head())
# Out:
#                                              pageurl  \
# 0  http://www.gumtree.com.au/s-ad/heathridge/chil...
# 1  http://www.gumtree.com.au/s-ad/dandenong/wareh...
# 2  http://www.gumtree.com.au/s-ad/campbellfield/a...
# 3  http://www.gumtree.com.au/s-ad/waterford-west/...
# 4  http://www.gumtree.com.au/s-ad/broome/other/ya...
#
#                      record/uniq_id           record/job_board  \
# 0  e378872541356a7423a855b164a4b9c3  http://www.gumtree.com.au
# 1  515430026fb85cedb498e1dddb2f1751  http://www.gumtree.com.au
# 2  99d3c51a21fb3e3f99e923a0169c1e48  http://www.gumtree.com.au
# 3  425cb29cbd6cb7234ba60c012cee68cf  http://www.gumtree.com.au
# 4  418bb84350baba76c4b3f18511ff1b5b  http://www.gumtree.com.au
#
#                                      record/page_url  \
# 0  http://www.gumtree.com.au/s-ad/heathridge/chil...
# 1  http://www.gumtree.com.au/s-ad/dandenong/wareh...
# 2  http://www.gumtree.com.au/s-ad/campbellfield/a...
# ...

# %%
s = df[0:1]
s=s.to_string()
print(s)
# Out:
#                                                                                                                   pageurl                    record/uniq_id           record/job_board                                                                                                         record/page_url                        record/job_title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       record/job_description                       record/location record/country_code record/job_type record/sector           
# ...

# %%
# using spacy make Tokenization 

nlp = spacy.load('en_core_web_sm')

# Create a Doc object
doc = nlp(s)

# Print each token separately
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
#                                                                                                                    SPACE
# pageurl NOUN ROOT
#                     SPACE
# record NOUN nmod
# / SYM punct
# uniq_id PROPN nmod
#            SPACE
# record NOUN dobj
# / SYM punct
# job_board PROPN nmod
#                                                                                                          SPACE
# record NOUN nmod
# / SYM punct
# page_url PROPN nmod
#                         SPACE
# record NOUN appos
# / SYM punct
# job_title PROPN nmod
# ...

# %%
 re.findall(r"[^!.? ]+",s)
# Out:
# ['pageurl',
#  'record/uniq_id',
#  'record/job_board',
#  'record/page_url',
#  'record/job_title',
#  'record/job_description',
#  'record/location',
#  'record/country_code',
#  'record/job_type',
#  'record/sector',
#  'record/salary',
#  'record/country',
#  'record/date_added\n0',
#  'http://www',
#  'gumtree',
#  'com',
#  'au/s-ad/heathridge/childcare-after-school-care/out-of-school-care-educator-qualified/1154530185',
#  'e378872541356a7423a855b164a4b9c3',
#  'http://www',
#  'gumtree',
#  'com',
#  'au',
#  'http://www',
#  'gumtree',
#  'com',
#  'au/s-ad/heathridge/childcare-after-school-care/out-of-school-care-educator-qualified/1154530185',
#  'Out',
#  'of',
#  'School',
#  'Care',
#  'Educator-',
#  'Qualified',
#  'We',
#  'are',
#  'a',
#  'small,',
#  'family',
#  'owned',
#  'Out',
#  'of',
#  'School',
#  'Care',
#  'service',
#  'located',
#  'in',
#  'Heathridge',
#  'We',
#  'are',
#  'currently',
#  'looking',
#  'for',
#  'an',
#  'enthusiastic',
# ...

# %%
# make NER 
for chunk in doc.noun_chunks:
    print(chunk.text+' - '+chunk.root.text+' - '+chunk.root.dep_+' - '+chunk.root.head.text)
# Out:
#                                                                                                                   pageurl - pageurl - ROOT - pageurl
# record/uniq_id           record - record - dobj - pageurl
# /job_board                                                                                                         record/page_url                        record - record - appos - record
# ...

# %%
# MAKE NER 
for ent in doc.ents:
    print(ent.text, ent.start, ent.end, ent.start_char, ent.end_char, ent.label_)
# Out:
# job_type 31 32 965 973 ORG
# Out of School Care 122 126 1434 1452 ORG
# Heathridge 129 130 1472 1482 GPE
# Certificate IV Children's Services 165 170 1664 1698 ORG
# 55 215 216 1962 1964 CARDINAL
# Channel Drive 216 218 1965 1978 LOC
# AU 223 224 2016 2018 ORG
# australia 238 239 2094 2103 GPE

# %%
## Visualizing the entity recognizer
from spacy import displacy

displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">                                                                                                                  pageurl                    record/uniq_id           record/job_board                                                                                                         record/page_url                        record/job_title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       record/job_description       
# ...

# %%
# More Specific Entities
for sent in doc.sents:
    docx = nlp(sent.text)
    if docx.ents:
        displacy.render(docx,   style='ent', jupyter=True)
    else:
        print(docx.text)
# Out:
#                                                                                                                   pageurl                    record/uniq_id           record/job_board                                                                                                         record/page_url                        record/
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...

# %%
len([ent for ent in doc.ents ])
# Out:
# 8

# %%
# Viewing Specific Entities

options = {'ents': ['ORG', 'GPE']}

displacy.render(doc, style='ent', jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">                                                                                                                  pageurl                    record/uniq_id           record/job_board                                                                                                         record/page_url                        record/job_title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       record/job_description       
# ...

# %%
#Stemming

# Import the toolkit and the full Porter Stemmer library
import nltk
from nltk.stem.porter import *
from nltk.stem.snowball import SnowballStemmer

# The Snowball Stemmer requires that you pass a language parameter
s_stemmer = SnowballStemmer(language='english')
#Instead, we'll use another popular NLP tool called nltk, which stands for Natural Language Toolkit. 
for word in re.findall(r"[^!.? ]+",s):
    print(word+' --> '+s_stemmer.stem(word))
# Out:
# pageurl --> pageurl
# record/uniq_id --> record/uniq_id
# record/job_board --> record/job_board
# record/page_url --> record/page_url
# record/job_title --> record/job_titl
# record/job_description --> record/job_descript
# record/location --> record/loc
# record/country_code --> record/country_cod
# record/job_type --> record/job_typ
# record/sector --> record/sector
# record/salary --> record/salari
# record/country --> record/countri
# record/date_added
# 0 --> record/date_added
# 0
# http://www --> http://www
# gumtree --> gumtre
# com --> com
# au/s-ad/heathridge/childcare-after-school-care/out-of-school-care-educator-qualified/1154530185 --> au/s-ad/heathridge/childcare-after-school-care/out-of-school-care-educator-qualified/1154530185
# e378872541356a7423a855b164a4b9c3 --> e378872541356a7423a855b164a4b9c3
# http://www --> http://www
# gumtree --> gumtre
# com --> com
# au --> au
# http://www --> http://www
# gumtree --> gumtre
# com --> com
# ...

# %%
##Function to display lemmas
def show_lemmas(text):
    for token in text:
        print(f'{token.text:{12}} {token.pos_:{6}} {token.lemma:<{22}} {token.lemma_}')
        
show_lemmas(doc)
# Out:
#                                                                                                                    SPACE  3694873550166444206
# pageurl      NOUN   5485203307599741254    pageurl
#                     SPACE  3279268888731716531
# record       NOUN   12677120423429974351   record
# /            SYM    2466615745961202537    /
# uniq_id      PROPN  18318867001484744910   uniq_id
#              SPACE  11427293743432821961
# record       NOUN   12677120423429974351   record
# /            SYM    2466615745961202537    /
# job_board    PROPN  6352251602666443383    job_board
#                                                                                                          SPACE  103350864693194678
# record       NOUN   12677120423429974351   record
# /            SYM    2466615745961202537    /
# page_url     PROPN  8891669333025704004    page_url
#                         SPACE  18030149166957954530
# record       NOUN   12677120423429974351   record
# ...

# %%
 #start making filttering on Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("../TextFiles/csv/gumtree_job.csv")
schema_df = pd.read_csv('../TextFiles/csv/gumtree_job.csv')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

df.head()
# Out:
#                                              pageurl  \
# 0  http://www.gumtree.com.au/s-ad/heathridge/chil...
# 1  http://www.gumtree.com.au/s-ad/dandenong/wareh...
# 2  http://www.gumtree.com.au/s-ad/campbellfield/a...
# 3  http://www.gumtree.com.au/s-ad/waterford-west/...
# 4  http://www.gumtree.com.au/s-ad/broome/other/ya...
#
#                      record/uniq_id           record/job_board  \
# 0  e378872541356a7423a855b164a4b9c3  http://www.gumtree.com.au
# 1  515430026fb85cedb498e1dddb2f1751  http://www.gumtree.com.au
# 2  99d3c51a21fb3e3f99e923a0169c1e48  http://www.gumtree.com.au
# 3  425cb29cbd6cb7234ba60c012cee68cf  http://www.gumtree.com.au
# 4  418bb84350baba76c4b3f18511ff1b5b  http://www.gumtree.com.au
#
#                                      record/page_url  \
# 0  http://www.gumtree.com.au/s-ad/heathridge/chil...
# 1  http://www.gumtree.com.au/s-ad/dandenong/wareh...
# 2  http://www.gumtree.com.au/s-ad/campbellfield/a...
# ...

# %%
filt = (df['record/job_type'] == 'Full time')
filt
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4     False
# 5      True
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31     True
# 32    False
# 33     True
# 34     True
# 35    False
# 36     True
# 37    False
# 38     True
# 39    False
# 40     True
# 41    False
# 42     True
# 43     True
# 44    False
# 45    False
# 46     True
# 47    False
# 48     True
# Name: record/job_type, dtype: bool

# %%
df.loc[filt]
# Out:
#                                               pageurl  \
# 2   http://www.gumtree.com.au/s-ad/campbellfield/a...
# 3   http://www.gumtree.com.au/s-ad/waterford-west/...
# 5   http://www.gumtree.com.au/s-ad/perth/productio...
# 8   http://www.gumtree.com.au/s-ad/banyo/warehousi...
# 14  http://www.gumtree.com.au/s-ad/hallam/producti...
# 19  http://www.gumtree.com.au/s-ad/rydalmere/wareh...
# 23  http://www.gumtree.com.au/s-ad/moorabbin/wareh...
# 31  http://www.gumtree.com.au/s-ad/bondi-junction/...
# 33  http://www.gumtree.com.au/s-ad/greenacre/wareh...
# 34  http://www.gumtree.com.au/s-ad/brisbane-city/c...
# 36  http://www.gumtree.com.au/s-ad/tarneit/childca...
# 38  http://www.gumtree.com.au/s-ad/lambton/warehou...
# 40  http://www.gumtree.com.au/s-ad/waterloo/childc...
# 42  http://www.gumtree.com.au/s-ad/melton/assembly...
# 43  http://www.gumtree.com.au/s-ad/castle-hill/war...
# 46  http://www.gumtree.com.au/s-ad/canterbury/othe...
# ...

# %%
# save data after filttaring in data frame  
filt = df['record/job_type'].str.contains('Full time', na=False)

job3 = df.loc[filt]

# %%
job3
# Out:
#                                               pageurl  \
# 2   http://www.gumtree.com.au/s-ad/campbellfield/a...
# 3   http://www.gumtree.com.au/s-ad/waterford-west/...
# 5   http://www.gumtree.com.au/s-ad/perth/productio...
# 8   http://www.gumtree.com.au/s-ad/banyo/warehousi...
# 14  http://www.gumtree.com.au/s-ad/hallam/producti...
# 19  http://www.gumtree.com.au/s-ad/rydalmere/wareh...
# 23  http://www.gumtree.com.au/s-ad/moorabbin/wareh...
# 31  http://www.gumtree.com.au/s-ad/bondi-junction/...
# 33  http://www.gumtree.com.au/s-ad/greenacre/wareh...
# 34  http://www.gumtree.com.au/s-ad/brisbane-city/c...
# 36  http://www.gumtree.com.au/s-ad/tarneit/childca...
# 38  http://www.gumtree.com.au/s-ad/lambton/warehou...
# 40  http://www.gumtree.com.au/s-ad/waterloo/childc...
# 42  http://www.gumtree.com.au/s-ad/melton/assembly...
# 43  http://www.gumtree.com.au/s-ad/castle-hill/war...
# 46  http://www.gumtree.com.au/s-ad/canterbury/othe...
# ...

# %%
# new make NLP proccess agine to see the deffirent 

import spacy
nlp = spacy.load('en_core_web_sm')

# Create a Doc object
job3= nlp(s)

# Print each token separately
for token in job3:
    print(token.text, token.pos_, token.dep_)
# Out:
#                                                                                                                    SPACE
# pageurl NOUN ROOT
#                     SPACE
# record NOUN nmod
# / SYM punct
# uniq_id PROPN nmod
#            SPACE
# record NOUN dobj
# / SYM punct
# job_board PROPN nmod
#                                                                                                          SPACE
# record NOUN nmod
# / SYM punct
# page_url PROPN nmod
#                         SPACE
# record NOUN appos
# / SYM punct
# job_title PROPN nmod
# ...

# %%
# MAKE NER 

for chunk in job3.noun_chunks:
    print(chunk.text+' - '+chunk.root.text+' - '+chunk.root.dep_+' - '+chunk.root.head.text)
# Out:
#                                                                                                                   pageurl - pageurl - ROOT - pageurl
# record/uniq_id           record - record - dobj - pageurl
# /job_board                                                                                                         record/page_url                        record - record - appos - record
# ...

# %%
for ent in job3.ents:
    print(ent.text, ent.start, ent.end, ent.start_char, ent.end_char, ent.label_)
# Out:
# job_type 31 32 965 973 ORG
# Out of School Care 122 126 1434 1452 ORG
# Heathridge 129 130 1472 1482 GPE
# Certificate IV Children's Services 165 170 1664 1698 ORG
# 55 215 216 1962 1964 CARDINAL
# Channel Drive 216 218 1965 1978 LOC
# AU 223 224 2016 2018 ORG
# australia 238 239 2094 2103 GPE

# %%
# More Specific Entities
for sent in job3.sents:
    docx = nlp(sent.text)
    if docx.ents:
        displacy.render(docx, style='ent', jupyter=True)
    else:
        print(docx.text)
# Out:
#                                                                                                                   pageurl                    record/uniq_id           record/job_board                                                                                                         record/page_url                        record/
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...

# %%
len([ent for ent in job3.ents ])
# Out:
# 8
