# %%
import numpy as np
import pandas as pd
import re

# %%
df = pd.read_csv('../TextFiles/csv/amazon_jobs.csv')

# %%
# to read data from the data frame at differents indexes
print(df.head())
# Out:
#                                              pageurl  \
# 0  https://www.amazon.jobs/en/search.json?base_qu...
# 1  https://www.amazon.jobs/en/search.json?base_qu...
# 2  https://www.amazon.jobs/en/search.json?base_qu...
# 3  https://www.amazon.jobs/en/search.json?base_qu...
# 4  https://www.amazon.jobs/en/search.json?base_qu...
#
#                    record/0/uniq_id   record/0/crawl_timestamp  \
# 0  850f0199e2ce9d1d51ee5e2e11318d94  2019-11-15 00:15:23 +0000
# 1  98427294aa7c987f329ab4fdf4fb0f25  2019-11-15 00:13:36 +0000
# 2  6b745f0dfdfb8aba7d584d12bc712643  2019-11-15 00:13:07 +0000
# 3  ebbfe8e0204325a444aac97cb69d85f1  2019-11-15 00:16:13 +0000
# 4  8b53f751c33849c0f52b84aa53539387  2019-11-15 00:17:14 +0000
#
#                                     record/0/job_url  \
# 0  https://www.amazon.jobs/en/jobs/986897/softwar...
# 1  https://www.amazon.jobs/en/jobs/956579/ad-succ...
# 2  https://www.amazon.jobs/en/jobs/960293/softwar...
# 3  https://www.amazon.jobs/en/jobs/977773/sr-manu...
# 4  https://www.amazon.jobs/en/jobs/979745/busines...
#
#                                       record/0/title  \
# 0                    Software Development Engineer I
# 1                            Ad Success Team Manager
# 2                      Software Development Engineer
# 3                         Sr. Manufacturing Engineer
# 4  Business Development Manager - Training US-Sou...
#
#                                 record/0/description record/0/location  \
# 0  Amazon’s Global Logistics Technology team is c...   US, WA, Seattle
# 1  Advertising Success Team (AST) is suite of cos...  CN, 31, Shanghai
# 2  Prime Video is changing the way millions of cu...        UK, London
# 3  Are you inspired by invention? Is problem solv...   US, CO, Boulder
# 4  This role can be based in Tampa, FL or Atlanta...   US, GA, Atlanta
#
#                           record/0/category  record/0/job_id  \
# 0                      Software Development           986897
# 1  Sales, Advertising, & Account Management           956579
# 2                      Software Development           960293
# 3                      Hardware Development           977773
# 4         Leadership Development & Training           979745
#
#             record/0/company_name  ...           record/8/company_name  \
# 0       Amazon.com Services, Inc.  ...       Amazon Web Services, Inc.
# 1     AmazonInfoSrvs(BJ)-Shanghai  ...  Amazon Pay(India) Private Lmtd
# 2  Amazon Dev Centre (London) Ltd  ...       Amazon Web Services, Inc.
# 3             Amazon Robotics LLC  ...      Elemental Technologies LLC
# 4       Amazon Web Services, Inc.  ...       Amazon.com Services, Inc.
#
#                    record/9/uniq_id   record/9/crawl_timestamp  \
# 0  1b8936ec121a39e17fce9eec1e244c96  2019-11-15 00:15:23 +0000
# 1  cdd655636aa6515bd582a93ab303639b  2019-11-15 00:13:36 +0000
# 2  09742e966fa08616bc0fd0ce1dff6824  2019-11-15 00:13:07 +0000
# 3  ed759292be1f75681f073663cded2262  2019-11-15 00:16:13 +0000
# 4  19745a7b740b84943c3315ced8a2b4be  2019-11-15 00:17:14 +0000
#
#                                     record/9/job_url  \
# 0  https://www.amazon.jobs/en/jobs/986871/senior-...
# 1  https://www.amazon.jobs/en/jobs/956549/senior-...
# 2  https://www.amazon.jobs/en/jobs/960243/senior-...
# 3  https://www.amazon.jobs/en/jobs/977615/sourcin...
# 4  https://www.amazon.jobs/en/jobs/979714/softwar...
#
#                                       record/9/title  \
# 0  Senior Engagement Manager - Professional Services
# 1  Senior Technical Account Manager - Come Build ...
# 2                Senior Financial Analyst, Global IT
# 3                                 Sourcing Recruiter
# 4                   Software Development Engineer II
#
#                                 record/9/description  record/9/location  \
# 0  At Amazon Web Services (AWS), we’re hiring a t...     US, CA, Irvine
# 1  Do you have a technical background and looking...  AU, ACT, Canberra
# 2  Join the Amazon Web Services (AWS) Finance tea...    US, WA, Seattle
# 3  The Role:The Amazon Devices recruiting team is...  US, CA, Sunnyvale
# 4  The Amazon Checkout Platform team seeks a crea...    US, WA, Seattle
#
#                                record/9/category record/9/job_id  \
# 0  Project/Program/Product Management--Technical          986871
# 1                            Solutions Architect          956549
# 2                           Finance & Accounting          960243
# 3                                Human Resources          977615
# 4                           Software Development          979714
#
#        record/9/company_name
# 0  Amazon Web Services, Inc.
# 1      AWS Australia Pty Ltd
# 2  Amazon.com Services, Inc.
# 3  Amazon.com Services, Inc.
# 4  Amazon.com Services, Inc.
#
# [5 rows x 91 columns]

# %%
s = df[0:1]
s=s.to_string()
print(s)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                 pageurl                  record/0/uniq_id   record/0/crawl_timestamp                                                        record/0/job_url                   record/0/title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    record/0/description record/0/location     record/0/category  record/0/job_id      record/0/company_name                  record/1/uniq_id   record/1/crawl_timestamp                                                       record/1/job_url                  record/1/title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# 0  https://www.amazon.jobs/en/search.json?base_query=&city=&country=&county=&facets%5B%5D=location&facets%5B%5D=business_category&facets%5B%5D=category&facets%5B%5D=schedule_type_id&facets%5B%5D=employee_class&facets%5B%5D=normalized_location&facets%5B%5D=job_function_id&latitude=&loc_group_id=&loc_query=United+States&longitude=&offset=1530&query_options=&radius=24km&region=&result_limit=10&sort=relevant  850f0199e2ce9d1d51ee5e2e11318d94  2019-11-15 00:15:23 +0000  https://www.amazon.jobs/en/jobs/986897/software-development-engineer-i  Software Development Engineer I  Amazon’s Global Logistics Technology team is chartered with building solutions for international movement of shipments which can originate from any place on earth, cross the international border and be delivered in a different part of planet. There are variety of ways in which we can import shipments from vendors/sellers to our warehouses and export package from one country to another through several intermediate locations to deliver it to our international customer. There are millions of such packages, each with different attributes, delivery requirements and international commerce and customs constraints. What results is a complex graph of source, intermediate and destination nodes with their arcs crossing international borders and associated with different costs and transit times. Accounting for all these constraints and maximizing the number of shipments shipped, while minimizing cost, providing a variety of customer delivery options and maximizing delivery performance is our primary focus.We are building world class technology cutting across deep algorithmic problems, brand new tools that cater to multi-party business scenarios and challenging data models that are evolving very quickly. Our systems touch every single package that travels internationally which mandates building of highly available and scalable distributed systems. Besides technology, there are ample opportunities in the team to build domain expertise of international transportation and supply chain realms and get first-hand experience of the Amazon operations by interacting directly with our global internal and external partners, and of course the esteemed senior engineering talent pool.We are looking for highly talented software development engineers who are passionate not only about architecting and developing large scale distributed technology solutions but also innovating new ideas and providing directions to our business in the domain of imports and exports logistics. We have many key initiatives lined-up to support our rapid evolution and growth of cross border transportation network by solving some of the most challenging problems in this domain.#AGLT   US, WA, Seattle  Software Development           986897  Amazon.com Services, Inc.  9215700a26684c9dca1ad77718f33ff2  2019-11-15 00:15:23 +0000  https://www.amazon.jobs/en/jobs/986896/business-intelligence-engineer  Business Intelligence Engineer  Amazon Advertising is dedicated to driving measurable outcomes for brand advertisers, agencies, authors, and entrepreneurs. Our ad solutions—including sponsored, display, video, and custom ads—leverage Amazon’s innovations and insights to find, attract, and engage intended audiences throughout their daily journeys. With a range of flexible pricing and buying models, including self-service, managed service, and programmatic ad buying, these solutions help businesses build brand awareness, increase product sales, and more.We are seeking an exceptional Business Intelligence Engineer to join the Advertising Forecasting Science team at Palo Alto, California. You will have extremely high visibility via presenting regular business metrics to leadership on a regular basis, and work closely with a group of talented scientists and engineers. You will need to dive deep into distributed data at the Petabyte level and provide insights to guide the development of Machine Learning problems in time series and  ...

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# Create a Doc object
doc = nlp(s)

# Print each token separately
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                  SPACE
# pageurl NOUN ROOT
#                   SPACE
# record/0 PROPN nmod
# / SYM punct
# uniq_id PROPN intj
#    SPACE
# record/0 X nmod
# / SYM punct
# crawl_timestamp PROPN nmod
#                                                         SPACE
# record/0 PROPN ROOT
# / SYM punct
# job_url X ROOT
#                    SPACE
# record/0 PROPN nmod
# / SYM punct
# title NOUN nmod
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     SPACE
# record/0 PROPN nmod
# / SYM punct
# description NOUN nmod
# record/0 PROPN nmod
# / SYM punct
# location NOUN nmod
#      SPACE
# record/0 PROPN nmod
# / SYM punct
# category NOUN ROOT
#   SPACE
# record/0 PROPN nmod
# / SYM punct
# job_id PROPN ROOT
#       SPACE
# record/0 PROPN nmod
# / SYM punct
# company_name PROPN ROOT
#                   SPACE
# record/1 PROPN nmod
# / SYM punct
# uniq_id PROPN ROOT
#    SPACE
# record/1 PROPN nmod
# / SYM punct
# crawl_timestamp PROPN nmod
#                                                        SPACE
# record/1 PROPN ROOT
# / PUNCT punct
# job_url X punct
#                   SPACE
# record/1 PROPN nmod
# / SYM punct
# title NOUN ROOT
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                SPACE
# record/1 PROPN nmod
# / SYM punct
# description NOUN ROOT
#   SPACE
# record/1 PROPN nmod
# / SYM punct
# location PROPN nmod
#       SPACE
# record/1 PROPN ROOT
# / SYM punct
# category NOUN intj
#   SPACE
# record/1 PROPN nmod
# / SYM punct
# job_id PROPN intj
#       SPACE
# record/1 PROPN nmod
# / SYM punct
# company_name PROPN intj
#                   SPACE
# record/2 PROPN appos
# / SYM punct
# uniq_id PROPN ROOT
#    SPACE
# record/2 NOUN intj
# / SYM punct
# crawl_timestamp PROPN intj
#                                                        SPACE
# record/2 PROPN appos
# / SYM punct
# job_url X punct
#                   SPACE
# record/2 PROPN nmod
# / SYM punct
# title NOUN nmod
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     SPACE
# record/2 PROPN nmod
# / SYM punct
# description NOUN nmod
# record/2 NOUN nmod
# / SYM punct
# location NOUN nmod
#                        SPACE
# record/2 PROPN ROOT
# / SYM punct
# category NOUN intj
#   SPACE
# record/2 PROPN appos
# / SYM punct
# job_id PROPN npadvmod
#       SPACE
# record/2 PROPN appos
# / SYM punct
# company_name PROPN npadvmod
#                   SPACE
# record/3 PROPN dobj
# / SYM punct
# uniq_id PROPN ROOT
#    SPACE
# record/3 X nmod
# / SYM punct
# crawl_timestamp PROPN nmod
#                                         SPACE
# record/3 PROPN nmod
# / SYM punct
# job_url X punct
#    SPACE
# record/3 NOUN nmod
# / SYM punct
# title NOUN nmod
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  SPACE
# record/3 X nmod
# / SYM punct
# description NOUN nmod
# record/3 PROPN nmod
# / SYM punct
# location NOUN nmod
#                        SPACE
# record/3 PROPN nmod
# / SYM punct
# category NOUN nmod
#   SPACE
# record/3 X nmod
# / SYM punct
# job_id PROPN nmod
#       SPACE
# record/3 PROPN nmod
# / SYM punct
# company_name PROPN nmod
#                   SPACE
# record/4 PROPN intj
# / SYM punct
# uniq_id PROPN nummod
#    SPACE
# record/4 PUNCT nmod
# / SYM punct
# crawl_timestamp PROPN nmod
#                                                 SPACE
# record/4 PUNCT intj
# / SYM punct
# job_url X punct
#             SPACE
# record/4 PROPN dobj
# / SYM punct
# title NOUN nmod
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  SPACE
# record/4 NOUN nmod
# / SYM punct
# description NOUN nmod
# record/4 NOUN amod
# / SYM punct
# location NOUN nmod
#                     SPACE
# record/4 PROPN nmod
# / SYM punct
# category NOUN dobj
#   SPACE
# record/4 PUNCT intj
# / SYM punct
# job_id PROPN intj
#            SPACE
# record/4 PROPN ROOT
# / SYM punct
# company_name PROPN npadvmod
#                   SPACE
# record/5 PROPN ROOT
# / SYM punct
# uniq_id NUM ROOT
#    SPACE
# record/5 NOUN ROOT
# / SYM punct
# crawl_timestamp PROPN nmod
#                                                          SPACE
# record/5 PROPN ROOT
# / PUNCT punct
# job_url X ROOT
#                      SPACE
# record/5 PROPN nmod
# / SYM punct
# title NOUN nmod
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            SPACE
# record/5 NOUN nmod
# / SYM punct
# description NOUN nmod
# record/5 NOUN nmod
# / SYM punct
# location NOUN ROOT
#                     SPACE
# record/5 PROPN nmod
# / SYM punct
# category NOUN ROOT
#   SPACE
# record/5 PROPN nmod
# / SYM punct
# job_id PROPN ROOT
#            SPACE
# record/5 PROPN nmod
# / SYM punct
# company_name PROPN ROOT
#                   SPACE
# record/6 PROPN nmod
# / SYM punct
# uniq_id PROPN ROOT
#    SPACE
# record/6 PUNCT nmod
# / SYM punct
# crawl_timestamp PROPN nmod
#                                                SPACE
# record/6 PROPN nmod
# / SYM punct
# job_url PROPN punct
#            SPACE
# record/6 PROPN nmod
# / SYM punct
# title NOUN nmod
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           SPACE
# record/6 NOUN nmod
# / SYM punct
# description NOUN nmod
# record/6 PUNCT nmod
# / SYM punct
# location PROPN dobj
#                     SPACE
# record/6 PROPN nmod
# / SYM punct
# category NOUN nmod
#   SPACE
# record/6 PROPN nmod
# / SYM punct
# job_id PROPN conj
#            SPACE
# record/6 PROPN nmod
# / SYM punct
# company_name PROPN conj
#                   SPACE
# record/7 PROPN nmod
# / SYM punct
# uniq_id PROPN ROOT
#    SPACE
# record/7 X appos
# / SYM punct
# crawl_timestamp PROPN intj
#                                                      SPACE
# record/7 PROPN ROOT
# / SYM punct
# job_url X ROOT
#                  SPACE
# record/7 PROPN nmod
# / SYM punct
# title NOUN nmod
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          SPACE
# record/7 PROPN nmod
# / SYM punct
# description NOUN nmod
# record/7 PROPN nmod
# / SYM punct
# location PROPN intj
#       SPACE
# record/7 PROPN nmod
# / SYM punct
# category NOUN nmod
#   SPACE
# record/7 PROPN nmod
# / SYM punct
# job_id PROPN conj
#       SPACE
# record/7 PROPN nmod
# / SYM punct
# company_name PROPN ROOT
#                   SPACE
# record/8 PROPN ROOT
# / SYM punct
# uniq_id PROPN ROOT
#    SPACE
# record/8 PROPN ROOT
# / SYM punct
# crawl_timestamp PROPN intj
#                                            SPACE
# record/8 PROPN appos
# / PUNCT punct
# job_url PROPN ROOT
#       SPACE
# record/8 PROPN nmod
# / SYM punct
# title NOUN nmod
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      SPACE
# record/8 PROPN nmod
# / SYM punct
# description NOUN nmod
# record/8 PROPN nmod
# / SYM punct
# location PROPN nmod
# record/8 PROPN nmod
# / SYM punct
# category NOUN ROOT
#   SPACE
# record/8 PROPN nmod
# / SYM punct
# job_id PROPN ROOT
#       SPACE
# record/8 PROPN nmod
# / SYM punct
# company_name PROPN ROOT
#                   SPACE
# record/9 PROPN ROOT
# / SYM punct
# uniq_id PROPN ROOT
#    SPACE
# record/9 PROPN ROOT
# / SYM punct
# crawl_timestamp PROPN intj
#                                                                         SPACE
# record/9 PROPN appos
# / SYM punct
# job_url X ROOT
#                                      SPACE
# record/9 PROPN nmod
# / SYM punct
# title NOUN ROOT
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# record/9 PROPN nmod
# / SYM punct
# description NOUN nmod
# record/9 PROPN nmod
# / SYM punct
# location NOUN ROOT
#                               SPACE
# record/9 PROPN nmod
# / SYM punct
# category NOUN nmod
#   SPACE
# record/9 PUNCT ROOT
# / SYM punct
# job_id PROPN nmod
#       SPACE
# record/9 PROPN nmod
# / SYM punct
# company_name PROPN ROOT
#
#  SPACE
# 0 NUM appos
#   SPACE
# https://www.amazon.jobs/en/search.json?base_query=&city=&country=&county=&facets%5B%5D=location&facets%5B%5D=business_category&facets%5B%5D=category&facets%5B%5D=schedule_type_id&facets%5B%5D=employee_class&facets%5B%5D=normalized_location&facets%5B%5D=job_function_id&latitude=&loc_group_id=&loc_query=United+States&longitude=&offset=1530&query_options=&radius=24km&region=&result_limit=10&sort=relevant ADJ nmod
#   SPACE
# 850f0199e2ce9d1d51ee5e2e11318d94 NUM nummod
#   SPACE
# 2019 NUM nummod
# - SYM punct
# 11 NUM nummod
# - SYM punct
# 15 NUM prep
# 00:15:23 NUM punct
# +0000 PROPN intj
#   SPACE
# https://www.amazon.jobs/en/jobs/986897/software-development-engineer-i ADJ intj
#   SPACE
# Software PROPN compound
# Development PROPN compound
# Engineer PROPN nmod
# I PRON nmod
#   SPACE
# Amazon PROPN nmod
# ’s PART punct
# Global PROPN compound
# Logistics PROPN compound
# Technology PROPN compound
# team NOUN nsubjpass
# is AUX auxpass
# chartered VERB ROOT
# with ADP prep
# building NOUN compound
# solutions NOUN pobj
# for ADP prep
# international ADJ amod
# movement NOUN pobj
# of ADP prep
# shipments NOUN pobj
# which DET nsubj
# can VERB aux
# originate VERB relcl
# from ADP prep
# any DET det
# place NOUN pobj
# on ADP prep
# earth NOUN pobj
# , PUNCT punct
# cross VERB conj
# the DET det
# international ADJ amod
# border NOUN dobj
# and CCONJ cc
# be AUX auxpass
# delivered VERB conj
# in ADP prep
# a DET det
# different ADJ amod
# part NOUN pobj
# of ADP prep
# planet NOUN pobj
# . PUNCT punct
# There PRON expl
# are AUX ROOT
# variety NOUN attr
# of ADP prep
# ways NOUN pobj
# in ADP prep
# which DET pobj
# we PRON nsubj
# can VERB aux
# import VERB relcl
# shipments NOUN dobj
# from ADP prep
# vendors NOUN nmod
# / SYM punct
# sellers NOUN pobj
# to ADP prep
# our DET poss
# warehouses NOUN pobj
# and CCONJ cc
# export NOUN compound
# package NOUN conj
# from ADP prep
# one NUM nummod
# country NOUN pobj
# to ADP prep
# another DET pobj
# through ADP prep
# several ADJ amod
# intermediate ADJ amod
# locations NOUN pobj
# to PART aux
# deliver VERB advcl
# it PRON dobj
# to ADP prep
# our DET poss
# international ADJ amod
# customer NOUN pobj
# . PUNCT punct
# There PRON expl
# are AUX ROOT
# millions NOUN attr
# of ADP prep
# such ADJ amod
# packages NOUN pobj
# , PUNCT punct
# each DET appos
# with ADP prep
# different ADJ amod
# attributes NOUN pobj
# , PUNCT punct
# delivery NOUN compound
# requirements NOUN conj
# and CCONJ cc
# international ADJ amod
# commerce NOUN nmod
# and CCONJ cc
# customs PROPN conj
# constraints NOUN conj
# . PUNCT punct
# What DET det
# results VERB nsubj
# is AUX ROOT
# a DET det
# complex ADJ amod
# graph NOUN attr
# of ADP prep
# source NOUN pobj
# , PUNCT punct
# intermediate ADJ conj
# and CCONJ cc
# destination NOUN conj
# nodes NOUN npadvmod
# with ADP prep
# their DET poss
# arcs ADJ pobj
# crossing VERB pcomp
# international ADJ amod
# borders NOUN dobj
# and CCONJ cc
# associated VERB conj
# with ADP prep
# different ADJ amod
# costs NOUN pobj
# and CCONJ cc
# transit NOUN compound
# times NOUN conj
# . PUNCT punct
# Accounting VERB advcl
# for ADP prep
# all DET predet
# these DET det
# constraints NOUN pobj
# and CCONJ cc
# maximizing VERB conj
# the DET det
# number NOUN dobj
# of ADP prep
# shipments NOUN pobj
# shipped VERB acl
# , PUNCT punct
# while SCONJ mark
# minimizing VERB advcl
# cost NOUN dobj
# , PUNCT punct
# providing VERB advcl
# a DET det
# variety NOUN dobj
# of ADP prep
# customer NOUN compound
# delivery NOUN compound
# options NOUN pobj
# and CCONJ cc
# maximizing VERB conj
# delivery NOUN compound
# performance NOUN nsubj
# is AUX ROOT
# our DET poss
# primary ADJ amod
# focus NOUN attr
# . PUNCT punct
# We PRON nsubj
# are AUX aux
# building VERB ROOT
# world NOUN compound
# class NOUN compound
# technology NOUN compound
# cutting VERB dobj
# across ADP prep
# deep ADJ amod
# algorithmic ADJ compound
# problems NOUN pobj
# , PUNCT punct
# brand NOUN nmod
# new ADJ amod
# tools NOUN dobj
# that DET nsubj
# cater VERB relcl
# to ADP prep
# multi ADJ dep
# - ADJ dep
# party ADJ compound
# business NOUN compound
# scenarios NOUN pobj
# and CCONJ cc
# challenging VERB conj
# data NOUN compound
# models NOUN dobj
# that DET nsubj
# are AUX aux
# evolving VERB relcl
# very ADV advmod
# quickly ADV advmod
# . PUNCT punct
# Our DET poss
# systems NOUN compound
# touch VERB ROOT
# every DET det
# single ADJ amod
# package NOUN dobj
# that DET nsubj
# travels VERB relcl
# internationally ADV advmod
# which DET nsubj
# mandates VERB nsubj
# building VERB advcl
# of ADP prep
# highly ADV advmod
# available ADJ amod
# and CCONJ cc
# scalable ADJ conj
# distributed VERB amod
# systems NOUN pobj
# . PUNCT punct
# Besides SCONJ prep
# technology NOUN pobj
# , PUNCT punct
# there PRON expl
# are AUX ROOT
# ample ADJ amod
# opportunities NOUN attr
# in ADP prep
# the DET det
# team NOUN pobj
# to PART aux
# build VERB acl
# domain NOUN compound
# expertise NOUN dobj
# of ADP prep
# international ADJ amod
# transportation NOUN nmod
# and CCONJ cc
# supply NOUN conj
# chain NOUN compound
# realms NOUN pobj
# and CCONJ cc
# get AUX conj
# first ADJ amod
# - PUNCT punct
# hand NOUN compound
# experience NOUN dobj
# of ADP prep
# the DET det
# Amazon PROPN compound
# operations NOUN pobj
# by ADP prep
# interacting VERB pcomp
# directly ADV advmod
# with ADP prep
# our DET poss
# global ADJ amod
# internal ADJ amod
# and CCONJ cc
# external ADJ conj
# partners NOUN pobj
# , PUNCT punct
# and CCONJ cc
# of ADP prep
# course NOUN pobj
# the DET det
# esteemed VERB amod
# senior ADJ amod
# engineering NOUN compound
# talent NOUN compound
# pool NOUN conj
# . PUNCT punct
# We PRON nsubj
# are AUX aux
# looking VERB ROOT
# for ADP prep
# highly ADV advmod
# talented ADJ amod
# software NOUN compound
# development NOUN compound
# engineers NOUN pobj
# who PRON nsubj
# are AUX relcl
# passionate ADJ acomp
# not PART preconj
# only ADV advmod
# about ADP prep
# architecting VERB pcomp
# and CCONJ cc
# developing VERB conj
# large ADJ amod
# scale NOUN amod
# distributed VERB amod
# technology NOUN compound
# solutions NOUN dobj
# but CCONJ cc
# also ADV advmod
# innovating VERB conj
# new ADJ amod
# ideas NOUN dobj
# and CCONJ cc
# providing VERB conj
# directions NOUN dobj
# to ADP prep
# our DET poss
# business NOUN pobj
# in ADP prep
# the DET det
# domain NOUN pobj
# of ADP prep
# imports NOUN nmod
# and CCONJ cc
# exports VERB conj
# logistics NOUN pobj
# . PUNCT punct
# We PRON nsubj
# have AUX ROOT
# many ADJ amod
# key ADJ amod
# initiatives NOUN dobj
# lined VERB acl
# - PUNCT punct
# up NOUN prt
# to PART aux
# support VERB advcl
# our DET poss
# rapid ADJ amod
# evolution NOUN dobj
# and CCONJ cc
# growth NOUN conj
# of ADP prep
# cross NOUN compound
# border NOUN compound
# transportation NOUN compound
# network NOUN pobj
# by ADP prep
# solving VERB pcomp
# some DET dobj
# of ADP prep
# the DET det
# most ADV advmod
# challenging ADJ amod
# problems NOUN pobj
# in ADP prep
# this DET det
# domain.#AGLT PROPN amod
#    SPACE
# US PROPN pobj
# , PUNCT punct
# WA PROPN conj
# , PUNCT punct
# Seattle PROPN conj
#   SPACE
# Software PROPN compound
# Development PROPN conj
#            SPACE
# 986897 NUM ROOT
#   SPACE
# Amazon.com PROPN compound
# Services PROPN ROOT
# , PUNCT punct
# Inc. PROPN nmod
#   SPACE
# 9215700a26684c9dca1ad77718f33ff2 NUM ROOT
#   SPACE
# 2019 NUM nummod
# - SYM punct
# 11 NUM intj
# - SYM punct
# 15 NUM prep
# 00:15:23 NUM punct
# +0000 PROPN ROOT
#   SPACE
# https://www.amazon.jobs/en/jobs/986896/business-intelligence-engineer NOUN ROOT
#   SPACE
# Business PROPN compound
# Intelligence PROPN compound
# Engineer PROPN appos
#   SPACE
# Amazon PROPN compound
# Advertising PROPN nsubjpass
# is AUX auxpass
# dedicated VERB ROOT
# to ADP prep
# driving VERB pcomp
# measurable ADJ amod
# outcomes NOUN dobj
# for ADP prep
# brand NOUN compound
# advertisers NOUN pobj
# , PUNCT punct
# agencies NOUN conj
# , PUNCT punct
# authors NOUN conj
# , PUNCT punct
# and CCONJ cc
# entrepreneurs NOUN conj
# . PUNCT punct
# Our DET poss
# ad NOUN compound
# solutions NOUN ROOT
# — PUNCT punct
# including VERB prep
# sponsored VERB pobj
# , PUNCT punct
# display NOUN conj
# , PUNCT punct
# video NOUN conj
# , PUNCT punct
# and CCONJ cc
# custom NOUN compound
# ads NOUN conj
# — PUNCT punct
# leverage NOUN compound
# Amazon PROPN nmod
# ’s PART punct
# innovations NOUN pobj
# and CCONJ cc
# insights NOUN conj
# to PART aux
# find VERB acl
# , PUNCT punct
# attract VERB conj
# , PUNCT punct
# and CCONJ cc
# engage VERB conj
# intended ADJ amod
# audiences NOUN dobj
# throughout ADP prep
# their DET poss
# daily ADJ amod
# journeys NOUN pobj
# . PUNCT punct
# With ADP prep
# a DET det
# range NOUN pobj
# of ADP prep
# flexible ADJ amod
# pricing NOUN pobj
# and CCONJ cc
# buying NOUN compound
# models NOUN conj
# , PUNCT punct
# including VERB prep
# self NOUN compound
# - PUNCT punct
# service NOUN pobj
# , PUNCT punct
# managed VERB amod
# service NOUN conj
# , PUNCT punct
# and CCONJ cc
# programmatic ADJ amod
# ad NOUN compound
# buying NOUN conj
# , PUNCT punct
# these DET det
# solutions NOUN nsubj
# help VERB ROOT
# businesses NOUN nsubj
# build VERB ccomp
# brand NOUN compound
# awareness NOUN dobj
# , PUNCT punct
# increase VERB conj
# product NOUN compound
# sales NOUN dobj
# , PUNCT punct
# and CCONJ cc
# more ADV conj
# . PUNCT punct
# We PRON nsubj
# are AUX aux
# seeking VERB ROOT
# an DET det
# exceptional ADJ amod
# Business PROPN compound
# Intelligence PROPN compound
# Engineer PROPN dobj
# to PART aux
# join VERB xcomp
# the DET det
# Advertising PROPN compound
# Forecasting PROPN compound
# Science PROPN compound
# team NOUN dobj
# at ADP prep
# Palo PROPN compound
# Alto PROPN pobj
# , PUNCT punct
# California PROPN appos
# . PUNCT punct
# You PRON nsubj
# will VERB aux
# have AUX ROOT
# extremely ADV advmod
# high ADJ amod
# visibility NOUN dobj
# via ADP prep
# presenting VERB pcomp
# regular ADJ amod
# business NOUN compound
# metrics NOUN dobj
# to PART prep
# leadership NOUN pobj
# on ADP prep
# a DET det
# regular ADJ amod
# basis NOUN pobj
# , PUNCT punct
# and CCONJ cc
# work VERB conj
# closely ADV advmod
# with ADP prep
# a DET det
# group NOUN pobj
# of ADP prep
# talented ADJ amod
# scientists NOUN pobj
# and CCONJ cc
# engineers NOUN conj
# . PUNCT punct
# You PRON nsubj
# will VERB aux
# need VERB ROOT
# to PART aux
# dive VERB xcomp
# deep ADV advmod
# into ADP prep
# distributed VERB amod
# data NOUN pobj
# at ADP prep
# the DET det
# Petabyte PROPN compound
# level NOUN pobj
# and CCONJ cc
# provide VERB conj
# insights NOUN dobj
# to PART aux
# guide VERB acl
# the DET det
# development NOUN dobj
# of ADP prep
# Machine PROPN compound
# Learning PROPN compound
# problems NOUN pobj
# in ADP prep
# time NOUN compound
# series NOUN pobj
# and CCONJ cc
# revenue NOUN compound
# forecasts NOUN conj
# , PUNCT punct
# auction NOUN compound
# prediction NOUN conj
# , PUNCT punct
# and CCONJ cc
# bid NOUN conj
# optimizations NOUN dobj
# , PUNCT punct
# to PART aux
# support VERB advcl
# the DET det
# growth NOUN dobj
# of ADP prep
# Amazon PROPN nmod
# ’s PART punct
# advertising NOUN compound
# business NOUN pobj
# . PUNCT punct
# Our DET poss
# ideal ADJ amod
# candidate NOUN nsubj
# will VERB aux
# have AUX ROOT
# strong ADJ amod
# analytical ADJ amod
# skills NOUN dobj
# , PUNCT punct
# business NOUN compound
# acumen NOUN conj
# and CCONJ cc
# judgement NOUN conj
# , PUNCT punct
# intellectual ADJ amod
# curiosity NOUN conj
# , PUNCT punct
# technical ADJ amod
# skills NOUN conj
# , PUNCT punct
# and CCONJ cc
# excel VERB conj
# at ADP prep
# both CCONJ preconj
# written VERB amod
# and CCONJ cc
# verbal ADJ conj
# communications NOUN pobj
# . PUNCT punct
# S PROPN ROOT
# / SYM punct
# he PRON nsubj
# will VERB aux
# be AUX ROOT
# a DET det
# self NOUN npadvmod
# - PUNCT punct
# motivated VERB amod
# individual NOUN attr
# who PRON nsubj
# is AUX relcl
# comfortable ADJ acomp
# with ADP prep
# ambiguity NOUN pobj
# and CCONJ cc
# be AUX conj
# able ADJ acomp
# to PART aux
# think VERB xcomp
# critically ADV advmod
# about ADP prep
# a DET det
# science NOUN compound
# product NOUN pobj
# from ADP prep
# business NOUN compound
# standpoint NOUN pobj
# . PUNCT punct
# The DET det
# primary ADJ amod
# responsibilities NOUN nsubj
# of ADP prep
# this DET det
# role NOUN pobj
# include VERB ROOT
# : PUNCT punct
# · PUNCT punct
# Design NOUN npadvmod
# , PUNCT punct
# develop VERB xcomp
# , PUNCT punct
# and CCONJ cc
# maintain VERB conj
# scalable ADJ oprd
# , PUNCT punct
# automated VERB amod
# metrics NOUN compound
# reports NOUN conj
# and CCONJ cc
# dashboards NOUN conj
# to PART aux
# support VERB advcl
# our DET poss
# analytical ADJ amod
# and CCONJ cc
# business NOUN conj
# needs NOUN dobj
# · PUNCT punct
# Provide VERB nsubj
# insights NOUN dobj
# on ADP prep
# data NOUN compound
# analytics NOUN pobj
# to PART prep
# influence VERB compound
# model NOUN compound
# development NOUN compound
# roadmap PROPN pobj
# · PUNCT punct
# Work VERB nsubj
# closely ADV advmod
# with ADP prep
# stakeholders NOUN nsubj
# and CCONJ cc
# leadership NOUN conj
# to PART aux
# define VERB pcomp
# and CCONJ cc
# present VERB conj
# the DET det
# team NOUN dobj
# ’s PART punct
# business NOUN nmod
# operational ADJ amod
# metrics NOUN dobj
# · PUNCT punct
# Work VERB ROOT
# closely ADV advmod
# with ADP mark
# scientists NOUN nsubj
# to PART aux
# define VERB advcl
# and CCONJ cc
# present VERB conj
# the DET det
# team NOUN dobj
# ’s PART punct
# model NOUN npadvmod
# - PUNCT punct
# related VERB amod
# metrics NOUN dobj
# · PUNCT punct
# Recognize VERB dep
# and CCONJ cc
# adopt VERB conj
# best ADJ amod
# practices NOUN dobj
# in ADP prep
# reporting NOUN pobj
# and CCONJ cc
# analytics NOUN conj
# – PUNCT punct
# automation NOUN conj
# , PUNCT punct
# data NOUN compound
# integrity NOUN conj
# , PUNCT punct
# validation NOUN conj
# , PUNCT punct
# and CCONJ cc
# documentation NOUN conj
#   SPACE
# US PROPN conj
# , PUNCT punct
# CA PROPN conj
# , PUNCT punct
# Palo PROPN compound
# Alto PROPN npadvmod
#   SPACE
# Business PROPN compound
# Intelligence PROPN ROOT
#            SPACE
# 986896 NUM ROOT
#   SPACE
# Amazon.com PROPN compound
# Services PROPN ROOT
# , PUNCT punct
# Inc. PROPN compound
#   SPACE
# 14b00d40ced925890eb4eca458040133 NUM ROOT
#   SPACE
# 2019 NUM nummod
# - PUNCT punct
# 11 NUM intj
# - SYM punct
# 15 NUM prep
# 00:15:23 NUM punct
# +0000 NOUN ROOT
#   SPACE
# https://www.amazon.jobs/en/jobs/986894/senior-solution-design-manager NUM nmod
#   SPACE
# Senior PROPN compound
# Solution PROPN compound
# Design PROPN compound
# Manager PROPN appos
#   SPACE
# The DET det
# Amazon PROPN compound
# Cross PROPN compound
# Border PROPN compound
# Exports PROPN compound
# team NOUN nsubj
# is AUX aux
# looking VERB ROOT
# for ADP prep
# a DET det
# highly ADV advmod
# skilled ADJ amod
# and CCONJ cc
# motivated ADJ conj
# Sr PROPN dep
# . PUNCT conj
# Solution NOUN compound
# Design PROPN compound
# Manager PROPN pobj
# to PART aux
# incubate VERB advcl
# a DET det
# supply NOUN compound
# chain NOUN compound
# execution NOUN compound
# team NOUN dobj
# . PUNCT punct
# The DET det
# role NOUN nsubj
# and CCONJ cc
# the DET det
# team NOUN conj
# will VERB aux
# be AUX ROOT
# responsible ADJ acomp
# for ADP prep
# onboarding VERB pcomp
# logistics NOUN compound
# partners NOUN dobj
# as SCONJ prep
# part NOUN pobj
# of ADP prep
# our DET poss
# Cross PROPN dep
# - ADJ dep
# Border ADJ amod
# expansion NOUN compound
# plans NOUN pobj
# . PUNCT punct
# The DET det
# successful ADJ amod
# candidate NOUN nsubj
# will VERB aux
# work VERB ROOT
# closely ADV advmod
# with ADP prep
# both CCONJ det
# internal ADJ amod
# and CCONJ cc
# external ADJ conj
# stakeholders NOUN pobj
# to PART aux
# drive VERB advcl
# and CCONJ cc
# program NOUN conj
# manage VERB conj
# logistics NOUN compound
# execution NOUN compound
# programs NOUN dobj
# . PUNCT punct
# An DET det
# ideal ADJ amod
# candidate NOUN nsubj
# has AUX ROOT
# a DET det
# background NOUN dobj
# in ADP prep
# transportation NOUN nmod
# or CCONJ cc
# logistics NOUN nmod
# / SYM punct
# operations NOUN conj
# management NOUN pobj
# and CCONJ cc
# excellent ADJ amod
# data NOUN conj
# driven VERB acl
# problem NOUN compound
# resolution NOUN compound
# skills NOUN dobj
# . PUNCT punct
# This DET det
# person NOUN nsubj
# will VERB aux
# have AUX ROOT
# the DET det
# ability NOUN dobj
# to PART aux
# leverage VERB acl
# and CCONJ cc
# analyze VERB conj
# data NOUN dobj
# and CCONJ cc
# blend NOUN conj
# that DET mark
# with ADP prep
# experience NOUN pobj
# to PART aux
# lead VERB acl
# process NOUN compound
# improvements NOUN dobj
# , PUNCT punct
# standardize VERB acl
# team NOUN compound
# processes NOUN dobj
# and CCONJ cc
# eliminate VERB conj
# the DET det
# root NOUN compound
# cause NOUN dobj
# of ADP prep
# defects NOUN pobj
# . PUNCT punct
# This DET det
# job NOUN nsubj
# will VERB aux
# require VERB ROOT
# exceptional ADJ amod
# team NOUN compound
# leadership NOUN dobj
# , PUNCT punct
# communication NOUN conj
# and CCONJ cc
# interpersonal ADJ amod
# skills NOUN conj
# while SCONJ mark
# having VERB advcl
# the DET det
# ability NOUN dobj
# to ADP aux
# in ADP acl
# a DET det
# high ADJ amod
# pressure NOUN compound
# environment NOUN pobj
# and CCONJ cc
# exercise VERB conj
# sound NOUN compound
# judgment NOUN dobj
# . PUNCT punct
# The DET det
# successful ADJ amod
# candidate NOUN nsubj
# will VERB aux
# be AUX ROOT
# proficient ADJ acomp
# at ADP prep
# strategic ADJ amod
# problem NOUN pobj
# solving VERB acl
# , PUNCT punct
# prioritizing VERB conj
# logistics NOUN compound
# challenges NOUN dobj
# and CCONJ cc
# possess VERB conj
# a DET det
# bias NOUN dobj
# to PART aux
# get AUX advcl
# things NOUN nsubj
# done VERB ccomp
# and CCONJ cc
# deliver VERB conj
# results NOUN dobj
# while SCONJ mark
# attracting VERB advcl
# , PUNCT punct
# growing VERB conj
# and CCONJ cc
# retaining VERB conj
# a DET det
# highly ADV advmod
# talented ADJ amod
# team NOUN dobj
# . PUNCT punct
# Key ADJ amod
# responsibilities NOUN nsubj
# for ADP prep
# 2019/20 NUM pobj
# include VERB ROOT
# · PUNCT punct
# Work VERB dobj
# with ADP prep
# cross ADJ dep
# - ADJ dep
# functional ADJ amod
# teams NOUN pobj
# to ADP prep
# on ADP nmod
# - PUNCT punct
# board NOUN pobj
# carriers NOUN pobj
# to PART aux
# support VERB advcl
# AGL PROPN nmod
# global ADJ amod
# initiatives NOUN dobj
# · PUNCT punct
# Build VERB ROOT
# , PUNCT punct
# own ADJ conj
# and CCONJ cc
# incubate VERB conj
# a DET det
# repeatable ADJ amod
# process NOUN nmod
# / SYM punct
# function NOUN dobj
# which DET nsubjpass
# can VERB aux
# be AUX auxpass
# handed VERB relcl
# off ADP prt
# to ADP prep
# a DET det
# team NOUN pobj
# of ADP prep
# program NOUN compound
# managers NOUN pobj
# as SCONJ mark
# we PRON nsubj
# scale VERB advcl
# · PUNCT punct
# Contribute VERB conj
# to PART prep
# ...
# Analyze VERB dobj
# and CCONJ cc
# process VERB conj
# large ADJ amod
# amounts NOUN dobj
# of ADP prep
# data NOUN pobj
# and CCONJ cc
# build VERB conj
# machine NOUN compound
# learning NOUN compound
# models NOUN dobj
# to PART aux
# solve VERB relcl
# specific ADJ amod
# business NOUN compound
# problems NOUN dobj
# · PUNCT punct
# Research NOUN dobj
# and CCONJ cc
# implement VERB conj
# novel ADJ amod
# machine NOUN compound
# learning NOUN dobj
# , PUNCT punct
# AI PROPN conj
# and CCONJ cc
# statistical ADJ amod
# approaches NOUN conj
# . PUNCT punct
# · PUNCT punct
# Establish VERB acl
# scalable ADJ amod
# , PUNCT punct
# efficient ADJ amod
# , PUNCT punct
# automated VERB amod
# processes NOUN dobj
# for ADP prep
# large ADJ amod
# scale NOUN compound
# data NOUN compound
# analyses NOUN pobj
# , PUNCT punct
# and CCONJ cc
# model NOUN compound
# development NOUN conj
# , PUNCT punct
# validation NOUN conj
# and CCONJ cc
# implementation NOUN conj
# · PUNCT punct
# Work VERB ROOT
# closely ADV advmod
# with ADP prep
# software NOUN compound
# engineering NOUN compound
# teams NOUN nsubj
# to PART aux
# drive VERB pcomp
# model NOUN nmod
# / SYM punct
# solution NOUN compound
# implementations NOUN dobj
# and CCONJ cc
# new ADJ amod
# feature NOUN compound
# creation NOUN conj
# · PUNCT punct
# Develop VERB advcl
# state NOUN nmod
# - PUNCT punct
# of ADP prep
# - PUNCT punct
# the DET det
# - PUNCT punct
# art NOUN pobj
# machine NOUN compound
# learning NOUN compound
# models NOUN dobj
# that DET nsubj
# are AUX relcl
# privacy NOUN compound
# preserving VERB acomp
# and CCONJ cc
# robust ADJ conj
# against ADP prep
# adversarial ADJ amod
# attacks NOUN pobj
#   SPACE
# US PROPN appos
# , PUNCT punct
# NY PROPN conj
# , PUNCT punct
# New PROPN compound
# York PROPN intj
#   SPACE
# Research PROPN compound
# Science PROPN ROOT
#            SPACE
# 986874 NUM ROOT
#   SPACE
# Amazon PROPN compound
# Web PROPN compound
# Services PROPN ROOT
# , PUNCT punct
# Inc. PROPN compound
#   SPACE
# 1b8936ec121a39e17fce9eec1e244c96 NUM ROOT
#   SPACE
# 2019 NUM ROOT
# - SYM punct
# 11 NUM intj
# - SYM punct
# 15 NUM prep
# 00:15:23 NUM punct
# +0000 PROPN prep
#   SPACE
# https://www.amazon.jobs/en/jobs/986871/senior-engagement-manager-professional-services NOUN punct
#   SPACE
# Senior PROPN compound
# Engagement PROPN compound
# Manager PROPN compound
# - PUNCT punct
# Professional PROPN compound
# Services PROPN ROOT
#   SPACE
# At ADP prep
# Amazon PROPN compound
# Web PROPN compound
# Services PROPN pobj
# ( PUNCT punct
# AWS PROPN appos
# ) PUNCT punct
# , PUNCT punct
# we PRON nsubj
# ’re VERB aux
# hiring VERB ROOT
# a DET det
# technical ADJ amod
# Engagement PROPN compound
# Manager PROPN dobj
# to PART aux
# lead VERB xcomp
# AWS PROPN compound
# consultants NOUN dobj
# , PUNCT punct
# partner NOUN conj
# , PUNCT punct
# and CCONJ cc
# client NOUN compound
# teams NOUN conj
# . PUNCT punct
# Engagement PROPN compound
# Managers PROPN ROOT
# , PUNCT punct
# manage VERB conj
# and CCONJ cc
# deliver VERB conj
# AWS PROPN compound
# cloud NOUN compound
# products NOUN dobj
# and CCONJ cc
# services NOUN conj
# that DET nsubj
# enable VERB relcl
# our DET poss
# customers NOUN nsubj
# to PART aux
# realize VERB ccomp
# their DET poss
# business NOUN compound
# objectives NOUN dobj
# . PUNCT punct
# These DET det
# professional ADJ amod
# services NOUN compound
# engagements NOUN nsubj
# focus VERB ROOT
# on ADP prep
# the DET det
# full ADJ amod
# platform NOUN pobj
# of ADP prep
# AWS PROPN compound
# customer NOUN compound
# solutions NOUN pobj
# to PART aux
# help VERB advcl
# our DET poss
# customers NOUN nsubj
# and CCONJ cc
# partners NOUN conj
# remove VERB ccomp
# constraints NOUN dobj
# and CCONJ cc
# accelerate VERB conj
# their DET poss
# journey NOUN dobj
# to ADP prep
# AWS.AWS PROPN compound
# Professional PROPN compound
# Services PROPN pobj
# engage VERB ROOT
# in ADP prep
# a DET det
# wide ADJ amod
# variety NOUN pobj
# of ADP prep
# projects NOUN pobj
# for ADP prep
# customers NOUN pobj
# and CCONJ cc
# partners NOUN conj
# , PUNCT punct
# providing VERB advcl
# collective ADJ amod
# AWS PROPN compound
# customer NOUN compound
# experience NOUN dobj
# , PUNCT punct
# best ADJ amod
# practices NOUN conj
# , PUNCT punct
# and CCONJ cc
# obsessing VERB conj
# about ADP prep
# strong ADJ amod
# success NOUN pobj
# for ADP prep
# the DET det
# Customer PROPN pobj
# . PUNCT punct
# Our DET poss
# team NOUN nsubj
# collaborates VERB ROOT
# across ADP prep
# the DET det
# entire ADJ amod
# AWS PROPN compound
# organization NOUN pobj
# to PART aux
# bring VERB advcl
# access NOUN dobj
# to ADP prep
# product NOUN pobj
# , PUNCT punct
# service NOUN conj
# , PUNCT punct
# and CCONJ cc
# training NOUN compound
# teams NOUN conj
# , PUNCT punct
# to PART aux
# deliver VERB advcl
# the DET det
# right ADJ amod
# solutions NOUN dobj
# and CCONJ cc
# drive VERB conj
# feature NOUN compound
# innovations NOUN dobj
# for ADP prep
# our DET poss
# customers NOUN pobj
# across ADP prep
# all DET det
# industries NOUN pobj
# . PUNCT punct
# Engagement NOUN compound
# Managers NOUN nsubj
# help VERB ROOT
# Customers NOUN nsubj
# make VERB ccomp
# decisions NOUN nsubj
# to PART aux
# meet VERB ccomp
# their DET poss
# technical ADJ amod
# and CCONJ cc
# business NOUN conj
# objectives NOUN dobj
# by ADP prep
# providing VERB pcomp
# best ADJ amod
# practices NOUN dobj
# , PUNCT punct
# proactively ADV advmod
# identifying VERB conj
# and CCONJ cc
# closing VERB amod
# project NOUN compound
# gaps NOUN conj
# . PUNCT punct
# RESPONSIBILITIES NOUN nsubj
# AND CCONJ cc
# ABILITIES NOUN conj
# INCLUDE VERB ROOT
# : PUNCT punct
# EXPERTISE PROPN dobj
# · PUNCT punct
# Collaborate NOUN appos
# with ADP prep
# AWS PROPN compound
# field NOUN compound
# sales NOUN pobj
# , PUNCT punct
# pre ADJ dep
# - NOUN dep
# sales NOUN conj
# , PUNCT punct
# training NOUN conj
# and CCONJ cc
# support NOUN conj
# teams NOUN conj
# to PART aux
# seek VERB advcl
# to PART aux
# understand VERB xcomp
# our DET poss
# customer NOUN nmod
# ’s PART punct
# needs NOUN dobj
# , PUNCT punct
# their DET poss
# business NOUN dobj
# , PUNCT punct
# how ADV advmod
# success NOUN nsubjpass
# is AUX auxpass
# defined VERB conj
# , PUNCT punct
# and CCONJ cc
# ensure VERB conj
# that SCONJ mark
# we PRON nsubj
# are AUX aux
# exceeding VERB ccomp
# expectations NOUN dobj
# in ADP prep
# delivery NOUN pobj
# and CCONJ cc
# developing VERB conj
# valued VERB amod
# solutions NOUN dobj
# . PUNCT punct
# · PUNCT punct
# Experience NOUN nsubj
# leveraging VERB ROOT
# formal ADJ amod
# project NOUN nmod
# management NOUN nmod
# and CCONJ cc
# development NOUN conj
# methodologies NOUN dobj
# on ADP prep
# enterprise NOUN compound
# level NOUN compound
# engagements NOUN pobj
# . PUNCT punct
# · PUNCT punct
# Possesses VERB ROOT
# a DET det
# deep ADJ amod
# knowledge NOUN dobj
# of ADP prep
# project NOUN compound
# management NOUN pobj
# best ADJ amod
# practices NOUN dobj
# and CCONJ cc
# how ADV advmod
# to PART aux
# apply VERB xcomp
# them PRON dobj
# in ADP prep
# an DET det
# effective ADJ amod
# yet CCONJ advmod
# pragmatic ADJ conj
# way NOUN pobj
# across ADP prep
# large ADJ amod
# , PUNCT punct
# complex ADJ amod
# projects NOUN pobj
# . PUNCT punct
# · PUNCT punct
# Understanding NOUN ROOT
# of ADP prep
# technology NOUN compound
# principles NOUN pobj
# and CCONJ cc
# services NOUN conj
# including VERB prep
# infrastructure NOUN pobj
# , PUNCT punct
# business NOUN compound
# applications NOUN conj
# , PUNCT punct
# data NOUN compound
# management NOUN conj
# , PUNCT punct
# security NOUN conj
# , PUNCT punct
# application NOUN compound
# platforms NOUN conj
# and CCONJ cc
# consumer NOUN npadvmod
# facing VERB compound
# technology NOUN conj
# . PUNCT punct
# SOLUTIONS PROPN ROOT
# · PUNCT punct
# Lead NOUN compound
# individuals NOUN nsubj
# , PUNCT punct
# teams NOUN conj
# or CCONJ cc
# multiple ADJ amod
# groups NOUN conj
# and CCONJ cc
# play VERB conj
# an DET det
# active ADJ amod
# role NOUN dobj
# in ADP prep
# analyzing VERB pcomp
# project NOUN compound
# goals NOUN dobj
# , PUNCT punct
# creating VERB advcl
# a DET det
# plan NOUN dobj
# to PART aux
# achieve VERB acl
# those DET det
# goals NOUN dobj
# , PUNCT punct
# and CCONJ cc
# then ADV advmod
# driving VERB conj
# the DET det
# AWS PROPN compound
# team NOUN compound
# members NOUN dobj
# , PUNCT punct
# customer NOUN compound
# stakeholders NOUN conj
# / SYM punct
# SMEs PROPN appos
# and CCONJ cc
# potentially ADV advmod
# other ADJ amod
# third ADJ amod
# parties NOUN conj
# to PART aux
# achieve VERB advcl
# those DET det
# goals NOUN dobj
# while SCONJ mark
# understanding VERB advcl
# the DET det
# client NOUN compound
# environment NOUN dobj
# and CCONJ cc
# any DET det
# limitations NOUN conj
# to ADP prep
# execution NOUN pobj
# . PUNCT punct
# · PUNCT punct
# Actively ADV advmod
# looks VERB ROOT
# for ADP prep
# ways NOUN pobj
# to PART aux
# improve VERB relcl
# process NOUN compound
# efficiencies NOUN dobj
# and CCONJ cc
# effectiveness NOUN conj
# . PUNCT punct
# · PUNCT punct
# Ability NOUN appos
# to PART aux
# apply VERB acl
# strategic ADJ amod
# thinking NOUN dobj
# and CCONJ cc
# demonstrate VERB conj
# understanding NOUN dobj
# of ADP prep
# requirements NOUN pobj
# to PART aux
# execute VERB xcomp
# . PUNCT punct
# · PUNCT punct
# Ability NOUN appos
# to PART aux
# make VERB acl
# decisions NOUN dobj
# guided VERB acl
# by ADP agent
# policies NOUN pobj
# , PUNCT punct
# procedures NOUN conj
# and CCONJ cc
# business NOUN compound
# plan NOUN conj
# with ADP prep
# limited ADJ amod
# guidance NOUN pobj
# . PUNCT punct
# · PUNCT punct
# Business NOUN nmod
# and CCONJ cc
# financial ADJ conj
# acumen NOUN dobj
# . PUNCT punct
# · PUNCT punct
# Business NOUN compound
# case NOUN compound
# development NOUN ROOT
# . PUNCT punct
# DELIVERY NOUN nmod
# · PUNCT punct
# Plan NOUN ROOT
# , PUNCT punct
# organize VERB conj
# , PUNCT punct
# and CCONJ cc
# manage VERB conj
# all DET det
# phases NOUN dobj
# of ADP prep
# a DET det
# project NOUN compound
# lifecycle NOUN pobj
# to PART aux
# ensure VERB advcl
# successful ADJ amod
# delivery NOUN dobj
# . PUNCT punct
# This DET nsubj
# includes VERB ROOT
# developing VERB nmod
# and CCONJ cc
# managing VERB conj
# project NOUN compound
# governance NOUN compound
# plans NOUN dobj
# , PUNCT punct
# project NOUN compound
# schedules NOUN conj
# , PUNCT punct
# team NOUN compound
# goals NOUN conj
# , PUNCT punct
# defining VERB acl
# success NOUN compound
# criteria NOUN dobj
# , PUNCT punct
# project NOUN compound
# milestones NOUN conj
# , PUNCT punct
# and CCONJ cc
# budgets NOUN conj
# . PUNCT punct
# · PUNCT punct
# Plays VERB ROOT
# an DET det
# active ADJ amod
# role NOUN dobj
# in ADP prep
# managing VERB pcomp
# project NOUN compound
# goals NOUN dobj
# and CCONJ cc
# driving VERB conj
# teams NOUN dobj
# to PART aux
# achieve VERB advcl
# customers NOUN poss
# ’ PART case
# business NOUN compound
# outcomes NOUN dobj
# by ADP prep
# managing VERB pcomp
# issues NOUN dobj
# , PUNCT punct
# risks NOUN conj
# , PUNCT punct
# decisions NOUN conj
# , PUNCT punct
# and CCONJ cc
# action NOUN compound
# items NOUN conj
# . PUNCT punct
# · PUNCT punct
# Ability NOUN advcl
# to PART aux
# take VERB acl
# ownership NOUN dobj
# , PUNCT punct
# work VERB acl
# under ADP prep
# pressure NOUN pobj
# and CCONJ cc
# meet VERB conj
# deadlines NOUN dobj
# on ADP prep
# time NOUN pobj
# . PUNCT punct
# · PUNCT punct
# Ability NOUN nsubj
# to PART aux
# challenge VERB acl
# , PUNCT punct
# recommend VERB conj
# and CCONJ cc
# redirect ADJ conj
# teams NOUN dobj
# as ADV advmod
# well ADV advmod
# as SCONJ cc
# manage VERB acl
# client NOUN compound
# expectations NOUN dobj
# during ADP prep
# the DET det
# engagement NOUN pobj
# . PUNCT punct
# · PUNCT punct
# Takes VERB acl
# proactive ADJ amod
# steps NOUN dobj
# to PART aux
# ensure VERB advcl
# teams NOUN nsubj
# meet VERB ccomp
# or CCONJ cc
# exceed VERB conj
# customer NOUN compound
# expectations NOUN dobj
# . PUNCT punct
# · PUNCT punct
# Works VERB conj
# effectively ADV advmod
# in ADP prep
# a DET det
# dynamic ADJ amod
# environment NOUN pobj
# with ADP prep
# changing VERB amod
# priorities NOUN pobj
# . PUNCT punct
# · PUNCT punct
# Results NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# , PUNCT punct
# prioritizes NOUN compound
# work NOUN compound
# activities NOUN dobj
# , PUNCT punct
# plans NOUN conj
# and CCONJ cc
# stays NOUN conj
# organized VERB acl
# in ADP prep
# order NOUN pobj
# to PART aux
# meet VERB acl
# commitments NOUN dobj
# . PUNCT punct
# COMMUNICATION PROPN ROOT
# · PUNCT punct
# Outstanding PROPN amod
# written VERB dep
# and CCONJ cc
# verbal ADJ amod
# communication NOUN conj
# skills NOUN ROOT
# with ADP prep
# team NOUN compound
# members NOUN pobj
# and CCONJ cc
# audiences NOUN conj
# of ADP prep
# all DET det
# levels NOUN pobj
# . PUNCT punct
# · PUNCT punct
# Interfaces NOUN nsubj
# with ADP prep
# various ADJ amod
# customer NOUN pobj
# and CCONJ cc
# internal ADJ amod
# AWS PROPN compound
# stakeholders NOUN conj
# which DET nsubj
# consists VERB relcl
# of ADP prep
# senior ADJ amod
# leadership NOUN compound
# teams NOUN pobj
# ( PUNCT punct
# C NOUN compound
# - PUNCT punct
# level NOUN nmod
# execs NOUN nmod
# , PUNCT punct
# SVP PROPN nmod
# / SYM punct
# VP PROPN appos
# , PUNCT punct
# Directors NOUN conj
# ) PUNCT punct
# and CCONJ cc
# project NOUN compound
# level NOUN compound
# resources NOUN conj
# such ADJ amod
# as SCONJ prep
# SMEs NOUN pobj
# . PUNCT punct
# · PUNCT punct
# Plans NOUN conj
# and CCONJ cc
# oversees VERB conj
# the DET det
# preparation NOUN dobj
# and CCONJ cc
# dissemination NOUN conj
# of ADP prep
# project NOUN compound
# communications NOUN pobj
# . PUNCT punct
# · PUNCT punct
# Demonstrates VERB ROOT
# the DET det
# ability NOUN dobj
# to PART aux
# understand VERB acl
# the DET det
# operating VERB compound
# styles NOUN dobj
# of ADP prep
# others NOUN pobj
# as ADV advmod
# well ADV advmod
# as SCONJ cc
# team NOUN nmod
# / SYM punct
# client NOUN compound
# relationships NOUN conj
# , PUNCT punct
# team NOUN compound
# dynamics NOUN conj
# , PUNCT punct
# and CCONJ cc
# adjusts NOUN compound
# behavior NOUN conj
# accordingly ADV advmod
# to PART aux
# succeed VERB relcl
# . PUNCT punct
# Recognizes PROPN ROOT
# environmental ADJ amod
# or CCONJ cc
# cultural ADJ conj
# nuances NOUN dobj
# and CCONJ cc
# adapts NOUN conj
# . PUNCT punct
# · PUNCT punct
# Excellent ADJ amod
# presentation NOUN ROOT
# , PUNCT punct
# communication NOUN conj
# ( PUNCT punct
# oral PROPN amod
# & CCONJ cc
# written VERB conj
# ) PUNCT punct
# , PUNCT punct
# and CCONJ cc
# relationship NOUN compound
# building NOUN compound
# skills NOUN conj
# , PUNCT punct
# across ADP prep
# all DET det
# levels NOUN pobj
# of ADP prep
# management NOUN pobj
# . PUNCT punct
# TEAMING NOUN ROOT
# · PUNCT punct
# Proven ADJ amod
# success NOUN appos
# in ADP prep
# working VERB pcomp
# with ADP prep
# teams NOUN pobj
# and CCONJ cc
# executive ADJ amod
# leadership NOUN conj
# in ADP prep
# a DET det
# complex ADJ amod
# , PUNCT punct
# global ADJ amod
# company NOUN compound
# environment NOUN pobj
# . PUNCT punct
# · PUNCT punct
# Team NOUN compound
# player NOUN ROOT
# who PRON nsubj
# effectively ADV advmod
# integrates VERB relcl
# , PUNCT punct
# motivates NOUN conj
# and CCONJ cc
# builds VERB conj
# relationships NOUN dobj
# with ADP prep
# cross ADJ dep
# - ADJ dep
# functional ADJ amod
# team NOUN compound
# members NOUN pobj
# ( PUNCT punct
# local ADJ amod
# or CCONJ cc
# remote ADJ conj
# ) PUNCT punct
# , PUNCT punct
# sponsors NOUN conj
# , PUNCT punct
# key ADJ amod
# stakeholders NOUN conj
# , PUNCT punct
# executives NOUN conj
# , PUNCT punct
# and CCONJ cc
# other ADJ amod
# individuals NOUN conj
# or CCONJ cc
# organizations NOUN conj
# involved VERB acl
# with ADP prep
# or CCONJ cc
# affected VERB conj
# by ADP agent
# the DET det
# project NOUN pobj
# . PUNCT punct
# · PUNCT punct
# Proven ADJ amod
# experience NOUN ROOT
# working VERB acl
# in ADP prep
# a DET det
# matrix NOUN compound
# environment NOUN pobj
# , PUNCT punct
# managing VERB advcl
# multiple ADJ amod
# stakeholders NOUN dobj
# . PUNCT punct
# · PUNCT punct
# Negotiation NOUN nmod
# and CCONJ cc
# conflict NOUN compound
# resolution NOUN compound
# capabilities NOUN appos
# . PUNCT punct
# · PUNCT punct
# Excellent ADJ amod
# people NOUN compound
# management NOUN compound
# skills NOUN conj
# , PUNCT punct
# including VERB prep
# the DET det
# ability NOUN pobj
# to PART aux
# influence VERB acl
# , PUNCT punct
# negotiate VERB conj
# and CCONJ cc
# achieve VERB conj
# results NOUN dobj
# through ADP prep
# others NOUN pobj
# who PRON nsubj
# are AUX relcl
# not PART neg
# direct ADJ amod
# reports NOUN attr
# . PUNCT punct
# This DET nsubj
# is AUX ROOT
# a DET det
# customer NOUN npadvmod
# facing NOUN amod
# role NOUN attr
# . PUNCT punct
# You PRON nsubjpass
# be AUX auxpass
# required VERB ROOT
# to PART aux
# travel VERB xcomp
# to ADP prep
# client NOUN compound
# locations NOUN pobj
# to PART aux
# deliver VERB advcl
# professional ADJ amod
# services NOUN dobj
# when ADV advmod
# needed VERB advcl
# . PUNCT punct
#     SPACE
# US PROPN ROOT
# , PUNCT punct
# CA PROPN conj
# , PUNCT punct
# Irvine PROPN appos
#   SPACE
# Project PROPN nmod
# / SYM punct
# Program PROPN nmod
# / SYM punct
# Product PROPN compound
# Management PROPN conj
# -- PUNCT punct
# Technical PROPN ROOT
#            SPACE
# 986871 NUM nummod
#   SPACE
# Amazon PROPN compound
# Web PROPN compound
# Services PROPN npadvmod
# , PUNCT punct
# Inc. PROPN intj

# %%
 # explore tokens
for token in doc:
    print(token.text, end=' | ')
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                  | pageurl |                   | record/0 | / | uniq_id |    | record/0 | / | crawl_timestamp |                                                         | record/0 | / | job_url |                    | record/0 | / | title |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     | record/0 | / | description | record/0 | / | location |      | record/0 | / | category |   | record/0 | / | job_id |       | record/0 | / | company_name |                   | record/1 | / | uniq_id |    | record/1 | / | crawl_timestamp |                                                        | record/1 | / | job_url |                   | record/1 | / | title |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# / | job_url |             | record/4 | / | title |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  | record/4 | / | description | record/4 | / | location |                     | record/4 | / | category |   | record/4 | / | job_id |            | record/4 | / | company_name |                   | record/5 | / | uniq_id |    | record/5 | / | crawl_timestamp |                                                          | record/5 | / | job_url |                      | record/5 | / | title |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
#  | 0 |   | https://www.amazon.jobs/en/search.json?base_query=&city=&country=&county=&facets%5B%5D=location&facets%5B%5D=business_category&facets%5B%5D=category&facets%5B%5D=schedule_type_id&facets%5B%5D=employee_class&facets%5B%5D=normalized_location&facets%5B%5D=job_function_id&latitude=&loc_group_id=&loc_query=United+States&longitude=&offset=1530&query_options=&radius=24km&region=&result_limit=10&sort=relevant |   | 850f0199e2ce9d1d51ee5e2e11318d94 |   | 2019 | - | 11 | - | 15 | 00:15:23 | +0000 |   | https://www.amazon.jobs/en/jobs/986897/software-development-engineer-i |   | Software | Development | Engineer | I |   | Amazon | ’s | Global | Logistics | Technology | team | is | chartered | with | building | solutions | for | international | movement | of | shipments | which | can | originate | from | any | place | on | earth | , | cross | the | international | border | and | be | delivered | in | a | different | part | of | planet | . | There | are | variety | of | ways | in | which | we | can | import | shipments | from | vendors | / | sellers | to | our | warehouses | and | export | package | from | one | country | to | another | through | several | intermediate | locations | to | deliver | it | to | our | international | customer | . | There | are | millions | of | such | packages | , | each | with | different | attributes | , | delivery | requirements | and | international | commerce | and | customs | constraints | . | What | results | is | a | complex | graph | of | source | , | intermediate | and | destination | nodes | with | their | arcs | crossing | international | borders | and | associated | with | different | costs | and | transit | times | . | Accounting | for | all | these | constraints | and | maximizing | the | number | of | shipments | shipped | , | while | minimizing | cost | , | providing | a | variety | of | customer | delivery | options | and | maximizing | delivery | performance | is | our | primary | focus | . | We | are | building | world | class | technology | cutting | across | deep | algorithmic | problems | , | brand | new | tools | that | cater | to | multi | - | party | business | scenarios | and | challenging | data | models | that | are | evolving | very | quickly | . | Our | systems | touch | every | single | package | that | travels | internationally | which | mandates | building | of | highly | available | and | scalable | distributed | systems | . | Besides | technology | , | there | are | ample | opportunities | in | the | team | to | build | domain | expertise | of | international | transportation | and | supply | chain | realms | and | get | first | - | hand | experience | of | the | Amazon | operations | by | interacting | directly | with | our | global | internal | and | external | partners | , | and | of | course | the | esteemed | senior | engineering | talent | pool | . | We | are | looking | for | highly | talented | software | development | engineers | who | are | passionate | not | only | about | architecting | and | developing | large | scale | distributed | technology | solutions | but | also | innovating | new | ideas | and | providing | directions | to | our | business | in | the | domain | of | imports | and | exports | logistics | . | We | have | many | key | initiatives | lined | - | up | to | support | our | rapid | evolution | and | growth | of | cross | border | transportation | network | by | solving | some | of | the | most | challenging | problems | in | this | domain.#AGLT |    | US | , | WA | , | Seattle |   | Software | Development |            | 986897 |   | Amazon.com | Services | , | Inc. |   | 9215700a26684c9dca1ad77718f33ff2 |   | 2019 | - | 11 | - | 15 | 00:15:23 | +0000 |   | https://www.amazon.jobs/en/jobs/986896/business-intelligence-engineer |   | Business | Intelligence | Engineer |   | Amazon | Advertising | is | dedicated | to | driving | measurable | outcomes | for | brand | advertisers | , | agencies | , | authors | , | and | entrepreneurs | . | O ...
# improve | tools | and | work | flows | . | This | role | interacts | closely | with | retail | and | operations | business | partners | across | Amazon | , | and | is | pivotal | to | the | growth | of | this | strategic | initiative | . | Specific | responsibilities | include | : | · | Manage | inventory | availability | and | inventory | health | including | improved | in | - | stock | , | turns | , | vendor | operational | improvement | ( | efficiency | , | fill | rates | , | lead | time | ) | , | forecasting | , | and | shrink | · | Drive | strategic | initiatives | to | improve | customer | experience | , | enable | new | capabilities | , | and | reduce | waste | · | Answer | complex | business | questions | and | make | decisions | by | querying | and | analyzing | large | data | sets | · | Work | with | internal | teams | to | build | automated | tools | and | process | improvements | that | will | drive | scale | and | reduce | error | · | Manage | day | - | to | - | day | operational | relationships | with | vendors | and | distributors | partners | , | including | product | lifecycle | management | , | expanding | selection | and | optimize | sourcing | recommendations | / | decisions | · | Liaison | between | product | categories | teams | , | internal | operations | business | partners | and | vendor | partners | · | Maintain | vendor | relationship | and | work | on | vendor | performance | improvement | through | daily | communication | , | training | session | , | tracking | purchase | orders | , | investigating | late | deliveries | , | resolving | order | rejections | , | working | with | vendors | on | PO | automation | , | etc | . | · | Determination | of | order | quantities | by | taking | into | account | forecasts | , | historical | trends | and | inventory | targets |    | US | , | WA | , | Seattle |   | Buying | , | Planning | , | & | Instock | Management |            | 986893 |   | Amazon.com | Services | , | Inc. |   | fff278b8672d6999631c5517c081fc4d |   | 2019 | - | 11 | - | 15 | 00:15:23 | +0000 |   | https://www.amazon.jobs/en/jobs/986891/shift-manager-logistics |   | Shift | Manager | , | Logistics |   | Do | you | want | to | work | hard | , | have | fun | and | make | history | ? | If | you | do | then | Amazon | could | be | the | right | career | choice | for | you | . | Our | logistics | teams | are | changing | the | way | we | interact | with | customers | around | the | globe | every | single | day | and | solving | some | of | the | biggest | logistical | challenges | facing | not | just | Amazon | , | but | also | the | entire | industry | . | Amazon | ’s | transportation | teams | work | to | ensure | the | delivery | packages | globally | for | customers | around | the | world | . | On | its | busiest | day | , | Cyber | Monday | , | Amazon | customers | around | the | world | have | ordered | more | than | 400 | items | per | second | and | the | transportation | teams | play | a | critical | role | ensuring | packages | make | it | to | customers | ’ | doors | on | - | time | and | in | great | condition | . | Whether | its | items | large | or | small | , | we | find | solutions | to | make | sure | we | are | delivering | on | our | promise | for | customers | . | Our | Area | Managers | are | responsible | for | the | day | - | to | - | day | operations | of | delivery | stations | in | the | Amazon | network | , | including | inbound | , | outbound | , | and | sortation | operations | . | They | will | actively | engage | with | site | and | regional | operations | leadership | to | implement | new | operational | improvements | and | new | services | . | We | expect | our | managers | to | continually | identify | ways | to | improve | our | operations | . | Key | Job | Duties | · | Oversee | the | delivery | of | Amazon | orders | to | customers | · | Build | , | optimize | , | and | assign | delivery | routes | on | your | shift | · | Communicate | with | and | respond | to  ...
# . | Our | logistics | teams | are | changing | the | way | we | interact | with | customers | around | the | globe | every | single | day | and | solving | some | of | the | biggest | logistical | challenges | facing | not | just | Amazon | , | but | also | the | entire | industry | . | Amazon | ’s | transportation | teams | work | to | ensure | the | delivery | of | packages | for | customers | around | the | world | . | On | its | busiest | day | , | Cyber | Monday | , | Amazon | customers | around | the | world | have | ordered | more | than | 400 | items | per | second | and | the | transportation | teams | play | a | critical | role | ensuring | packages | make | it | to | customers | ’ | doors | on | - | time | and | in | great | condition | . | Whether | it | is | an | item | large | or | small | , | we | find | solutions | to | make | sure | we | are | delivering | on | our | promise | for | customers | . | Our | Area | Managers | are | responsible | for | management | and | supervision | over | the | day | - | to | - | day | operations | of | delivery | stations | in | the | Amazon | network | , | including | inbound | , | outbound | , | and | sortation | operations | . | Area | Managers | actively | engage | with | site | and | regional | operations | leadership | to | develop | and | implement | new | operational | improvements | and | new | services | . | We | expect | our | managers | to | continually | identify | ways | to | improve | our | operations | . | Key | Job | Duties | · | Act | as | second | - | in | - | command | to | Station | Manager | in | managing | to | achieve | station | safety | , | quality | , | productivity | and | CE | performance | and | to | include | interviewing | , | hiring | , | promotions | , | discipline | , | and | terminations | of | employment | · | Responsible | for | managing | associates | to | achieve | operational | metrics | for | areas | of | responsibility | · | Managing | to | meet | expectations | regarding | Standard | Work | , | Gemba | , | reporting | and | root | cause | defects | · | Conduct | daily | and | weekly | performance | meetings | · | Oversee | response | to | customer | / | TOC | escalations | · | Assess | and | develop | future | production | and | labor | plans | · | Interact | with | all | support | teams | ( | LP | , | quality | , | safety | , | HR | etc | . | ) | to | develop | plans | to | meet | business | objectives | · | Analyze | and | oversight | of | scheduling | and | staffing | requirements | for | area | of | responsibility | · | Volume | planning | / | contingency | planning | · | Subject | matter | expert | for | all | process | areas | in | the | station | ( | Sort | , | OnRoad | , | RTS | ) | · | Ensuring | process | compliance | and | reporting | for | areas | of | responsibility | ( | LP | , | Safety | , | Quality | , | HR | ) | · | Support | team | interaction | and | escalation | for | area | of | responsibility | · | Develop | an | environment | that | drives | performance | while | maintaining | safe | environment | and | ensure | timely | reporting | · | Point | of | contact | for | safety | / | security | issues | that | occur | on | site | , | incident | commander | in | event | of | an | issue | · | Day | - | to | - | day | management | / | supervision | , | including | coverage | and | scheduling | of | L4 | Shift | Managers | · | Oversight | and | participation | in | ensuring | appropriate | performance | management | for | Amazon | L1-L3 | associates | ( | does | not | apply | to | temporary | associates | ) | · | Occasional | work | in | direct | process | path | ( | if | needed | ) | · | Vacation | coverage | for | Station | Manager | ( | if | needed)Additional | Job | Elements | : | · | Must | be | able | to | lift | up | to | 49 | pounds | with | or | without | reasonable | accommodation | · | Must | be | willing | and | able | to | frequently | push | , | pull | , | squat | , | bend | , | and | reach | · | Must | be | ...
#  | · | Lead | individuals | , | teams | or | multiple | groups | and | play | an | active | role | in | analyzing | project | goals | , | creating | a | plan | to | achieve | those | goals | , | and | then | driving | the | AWS | team | members | , | customer | stakeholders | / | SMEs | and | potentially | other | third | parties | to | achieve | those | goals | while | understanding | the | client | environment | and | any | limitations | to | execution | . | · | Actively | looks | for | ways | to | improve | process | efficiencies | and | effectiveness | . | · | Ability | to | apply | strategic | thinking | and | demonstrate | understanding | of | requirements | to | execute | . | · | Ability | to | make | decisions | guided | by | policies | , | procedures | and | business | plan | with | limited | guidance | . | · | Business | and | financial | acumen | . | · | Business | case | development | . | DELIVERY | · | Plan | , | organize | , | and | manage | all | phases | of | a | project | lifecycle | to | ensure | successful | delivery | . | This | includes | developing | and | managing | project | governance | plans | , | project | schedules | , | team | goals | , | defining | success | criteria | , | project | milestones | , | and | budgets | . | · | Plays | an | active | role | in | managing | project | goals | and | driving | teams | to | achieve | customers | ’ | business | outcomes | by | managing | issues | , | risks | , | decisions | , | and | action | items | . | · | Ability | to | take | ownership | , | work | under | pressure | and | meet | deadlines | on | time | . | · | Ability | to | challenge | , | recommend | and | redirect | teams | as | well | as | manage | client | expectations | during | the | engagement | . | · | Takes | proactive | steps | to | ensure | teams | meet | or | exceed | customer | expectations | . | · | Works | effectively | in | a | dynamic | environment | with | changing | priorities | . | · | Results | - | oriented | , | prioritizes | work | activities | , | plans | and | stays | organized | in | order | to | meet | commitments | . | COMMUNICATION | · | Outstanding | written | and | verbal | communication | skills | with | team | members | and | audiences | of | all | levels | . | · | Interfaces | with | various | customer | and | internal | AWS | stakeholders | which | consists | of | senior | leadership | teams | ( | C | - | level | execs | , | SVP | / | VP | , | Directors | ) | and | project | level | resources | such | as | SMEs | . | · | Plans | and | oversees | the | preparation | and | dissemination | of | project | communications | . | · | Demonstrates | the | ability | to | understand | the | operating | styles | of | others | as | well | as | team | / | client | relationships | , | team | dynamics | , | and | adjusts | behavior | accordingly | to | succeed | . | Recognizes | environmental | or | cultural | nuances | and | adapts | . | · | Excellent | presentation | , | communication | ( | oral | & | written | ) | , | and | relationship | building | skills | , | across | all | levels | of | management | . | TEAMING | · | Proven | success | in | working | with | teams | and | executive | leadership | in | a | complex | , | global | company | environment | . | · | Team | player | who | effectively | integrates | , | motivates | and | builds | relationships | with | cross | - | functional | team | members | ( | local | or | remote | ) | , | sponsors | , | key | stakeholders | , | executives | , | and | other | individuals | or | organizations | involved | with | or | affected | by | the | project | . | · | Proven | experience | working | in | a | matrix | environment | , | managing | multiple | stakeholders | . | · | Negotiation | and | conflict | resolution | capabilities | . | · | Excellent | people | management | skills | , | including | the | ability | to | influence | , | negotiate | and | achieve | results | through | others | who | are | not | direct | reports | . | This | is | ...

# %%
## Visualizing the entity recognizer
from spacy import displacy

displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">                                                                                                                                                                                                                                                                                                                                                                                                                pageurl                  record/0/uniq_id   record/0/crawl_timestamp                                                        record/0/job_url                   record/0/title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    record/0/description record/0/location     record/0/category  record/0/job_id      record/0/company_name                  record/1/uniq_id   record/1/crawl_timestamp                                                       record/1/job_url                  record/1/title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...

# %%
re.findall(r"[^!.? ]+",s)
# Out:
# ['pageurl',
#  'record/0/uniq_id',
#  'record/0/crawl_timestamp',
#  'record/0/job_url',
#  'record/0/title',
#  'record/0/description',
#  'record/0/location',
#  'record/0/category',
#  'record/0/job_id',
#  'record/0/company_name',
#  'record/1/uniq_id',
#  'record/1/crawl_timestamp',
#  'record/1/job_url',
#  'record/1/title',
#  'record/1/description',
#  'record/1/location',
#  'record/1/category',
#  'record/1/job_id',
#  'record/1/company_name',
#  'record/2/uniq_id',
#  'record/2/crawl_timestamp',
#  'record/2/job_url',
#  'record/2/title',
#  'record/2/description',
#  'record/2/location',
#  'record/2/category',
#  'record/2/job_id',
#  'record/2/company_name',
#  'record/3/uniq_id',
#  'record/3/crawl_timestamp',
#  'record/3/job_url',
#  'record/3/title',
#  'record/3/description',
#  'record/3/location',
#  'record/3/category',
#  'record/3/job_id',
#  'record/3/company_name',
#  'record/4/uniq_id',
#  'record/4/crawl_timestamp',
#  'record/4/job_url',
#  'record/4/title',
#  'record/4/description',
#  'record/4/location',
#  'record/4/category',
#  'record/4/job_id',
#  'record/4/company_name',
#  'record/5/uniq_id',
#  'record/5/crawl_timestamp',
#  'record/5/job_url',
#  'record/5/title',
#  'record/5/description',
#  'record/5/location',
#  'record/5/category',
#  'record/5/job_id',
#  'record/5/company_name',
#  'record/6/uniq_id',
#  'record/6/crawl_timestamp',
#  'record/6/job_url',
#  'record/6/title',
#  'record/6/description',
#  'record/6/location',
#  'record/6/category',
#  'record/6/job_id',
#  'record/6/company_name',
#  'record/7/uniq_id',
#  'record/7/crawl_timestamp',
#  'record/7/job_url',
#  'record/7/title',
#  'record/7/description',
#  'record/7/location',
#  'record/7/category',
#  'record/7/job_id',
#  'record/7/company_name',
#  'record/8/uniq_id',
#  'record/8/crawl_timestamp',
#  'record/8/job_url',
#  'record/8/title',
#  'record/8/description',
#  'record/8/location',
#  'record/8/category',
#  'record/8/job_id',
#  'record/8/company_name',
#  'record/9/uniq_id',
#  'record/9/crawl_timestamp',
#  'record/9/job_url',
#  'record/9/title',
#  'record/9/description',
#  'record/9/location',
#  'record/9/category',
#  'record/9/job_id',
#  'record/9/company_name\n0',
#  'https://www',
#  'amazon',
#  'jobs/en/search',
#  'json',
#  'base_query=&city=&country=&county=&facets%5B%5D=location&facets%5B%5D=business_category&facets%5B%5D=category&facets%5B%5D=schedule_type_id&facets%5B%5D=employee_class&facets%5B%5D=normalized_location&facets%5B%5D=job_function_id&latitude=&loc_group_id=&loc_query=United+States&longitude=&offset=1530&query_options=&radius=24km&region=&result_limit=10&sort=relevant',
#  '850f0199e2ce9d1d51ee5e2e11318d94',
#  '2019-11-15',
#  '00:15:23',
#  '+0000',
#  'https://www',
#  'amazon',
#  'jobs/en/jobs/986897/software-development-engineer-i',
#  'Software',
#  'Development',
#  'Engineer',
#  'I',
#  'Amazon’s',
#  'Global',
#  'Logistics',
#  'Technology',
#  'team',
#  'is',
#  'chartered',
#  'with',
#  'building',
#  'solutions',
#  'for',
#  'international',
#  'movement',
#  'of',
#  'shipments',
#  'which',
#  'can',
#  'originate',
#  'from',
#  'any',
#  'place',
#  'on',
#  'earth,',
#  'cross',
#  'the',
#  'international',
#  'border',
#  'and',
#  'be',
#  'delivered',
#  'in',
#  'a',
#  'different',
#  'part',
#  'of',
#  'planet',
#  'There',
#  'are',
#  'variety',
#  'of',
#  'ways',
#  'in',
#  'which',
#  'we',
#  'can',
#  'import',
#  'shipments',
#  'from',
#  'vendors/sellers',
#  'to',
#  'our',
#  'warehouses',
#  'and',
#  'export',
#  'package',
#  'from',
#  'one',
#  'country',
#  'to',
#  'another',
#  'through',
#  'several',
#  'intermediate',
#  'locations',
#  'to',
#  'deliver',
#  'it',
#  'to',
#  'our',
#  'international',
#  'customer',
#  'There',
#  'are',
#  'millions',
#  'of',
#  'such',
#  'packages,',
#  'each',
#  'with',
#  'different',
#  'attributes,',
#  'delivery',
#  'requirements',
#  'and',
#  'international',
#  'commerce',
#  'and',
#  'customs',
#  'constraints',
#  'What',
#  'results',
#  'is',
#  'a',
#  'complex',
#  'graph',
#  'of',
#  'source,',
#  'intermediate',
#  'and',
#  'destination',
#  'nodes',
#  'with',
#  'their',
#  'arcs',
#  'crossing',
#  'international',
#  'borders',
#  'and',
#  'associated',
#  'with',
#  'different',
#  'costs',
#  'and',
#  'transit',
#  'times',
#  'Accounting',
#  'for',
#  'all',
#  'these',
#  'constraints',
#  'and',
#  'maximizing',
#  'the',
#  'number',
#  'of',
#  'shipments',
#  'shipped,',
#  'while',
#  'minimizing',
#  'cost,',
#  'providing',
#  'a',
#  'variety',
#  'of',
#  'customer',
#  'delivery',
#  'options',
#  'and',
#  'maximizing',
#  'delivery',
#  'performance',
#  'is',
#  'our',
#  'primary',
#  'focus',
#  'We',
#  'are',
#  'building',
#  'world',
#  'class',
#  'technology',
#  'cutting',
#  'across',
#  'deep',
#  'algorithmic',
#  'problems,',
#  'brand',
#  'new',
#  'tools',
#  'that',
#  'cater',
#  'to',
#  'multi-party',
#  'business',
#  'scenarios',
#  'and',
#  'challenging',
#  'data',
#  'models',
#  'that',
#  'are',
#  'evolving',
#  'very',
#  'quickly',
#  'Our',
#  'systems',
#  'touch',
#  'every',
#  'single',
#  'package',
#  'that',
#  'travels',
#  'internationally',
#  'which',
#  'mandates',
#  'building',
#  'of',
#  'highly',
#  'available',
#  'and',
#  'scalable',
#  'distributed',
#  'systems',
#  'Besides',
#  'technology,',
#  'there',
#  'are',
#  'ample',
#  'opportunities',
#  'in',
#  'the',
#  'team',
#  'to',
#  'build',
#  'domain',
#  'expertise',
#  'of',
#  'international',
#  'transportation',
#  'and',
#  'supply',
#  'chain',
#  'realms',
#  'and',
#  'get',
#  'first-hand',
#  'experience',
#  'of',
#  'the',
#  'Amazon',
#  'operations',
#  'by',
#  'interacting',
#  'directly',
#  'with',
#  'our',
#  'global',
#  'internal',
#  'and',
#  'external',
#  'partners,',
#  'and',
#  'of',
#  'course',
#  'the',
#  'esteemed',
#  'senior',
#  'engineering',
#  'talent',
#  'pool',
#  'We',
#  'are',
#  'looking',
#  'for',
#  'highly',
#  'talented',
#  'software',
#  'development',
#  'engineers',
#  'who',
#  'are',
#  'passionate',
#  'not',
#  'only',
#  'about',
#  'architecting',
#  'and',
#  'developing',
#  'large',
#  'scale',
#  'distributed',
#  'technology',
#  'solutions',
#  'but',
#  'also',
#  'innovating',
#  'new',
#  'ideas',
#  'and',
#  'providing',
#  'directions',
#  'to',
#  'our',
#  'business',
#  'in',
#  'the',
#  'domain',
#  'of',
#  'imports',
#  'and',
#  'exports',
#  'logistics',
#  'We',
#  'have',
#  'many',
#  'key',
#  'initiatives',
#  'lined-up',
#  'to',
#  'support',
#  'our',
#  'rapid',
#  'evolution',
#  'and',
#  'growth',
#  'of',
#  'cross',
#  'border',
#  'transportation',
#  'network',
#  'by',
#  'solving',
#  'some',
#  'of',
#  'the',
#  'most',
#  'challenging',
#  'problems',
#  'in',
#  'this',
#  'domain',
#  '#AGLT',
#  'US,',
#  'WA,',
#  'Seattle',
#  'Software',
#  'Development',
#  '986897',
#  'Amazon',
#  'com',
#  'Services,',
#  'Inc',
#  '9215700a26684c9dca1ad77718f33ff2',
#  '2019-11-15',
#  '00:15:23',
#  '+0000',
#  'https://www',
#  'amazon',
#  'jobs/en/jobs/986896/business-intelligence-engineer',
#  'Business',
#  'Intelligence',
#  'Engineer',
#  'Amazon',
#  'Advertising',
#  'is',
#  'dedicated',
#  'to',
#  'driving',
#  'measurable',
#  'outcomes',
#  'for',
#  'brand',
#  'advertisers,',
#  'agencies,',
#  'authors,',
#  'and',
#  'entrepreneurs',
#  'Our',
#  'ad',
#  'solutions—including',
#  'sponsored,',
#  'display,',
#  'video,',
#  'and',
#  'custom',
#  'ads—leverage',
#  'Amazon’s',
#  'innovations',
#  'and',
#  'insights',
#  'to',
#  'find,',
#  'attract,',
#  'and',
#  'engage',
#  'intended',
#  'audiences',
#  'throughout',
#  'their',
#  'daily',
#  'journeys',
#  'With',
#  'a',
#  'range',
#  'of',
#  'flexible',
#  'pricing',
#  'and',
#  'buying',
#  'models,',
#  'including',
#  'self-service,',
#  'managed',
#  'service,',
#  'and',
#  'programmatic',
#  'ad',
#  'buying,',
#  'these',
#  'solutions',
#  'help',
#  'businesses',
#  'build',
#  'brand',
#  'awareness,',
#  'increase',
#  'product',
#  'sales,',
#  'and',
#  'more',
#  'We',
#  'are',
#  'seeking',
#  'an',
#  'exceptional',
#  'Business',
#  'Intelligence',
#  'Engineer',
#  'to',
#  'join',
#  'the',
#  'Advertising',
#  'Forecasting',
#  'Science',
#  'team',
#  'at',
#  'Palo',
#  'Alto,',
#  'California',
#  'You',
#  'will',
#  'have',
#  'extremely',
#  'high',
#  'visibility',
#  'via',
#  'presenting',
#  'regular',
#  'business',
#  'metrics',
#  'to',
#  'leadership',
#  'on',
#  'a',
#  'regular',
#  'basis,',
#  'and',
#  'work',
#  'closely',
#  'with',
#  'a',
#  'group',
#  'of',
#  'talented',
#  'scientists',
#  'and',
#  'engineers',
#  'You',
#  'will',
#  'need',
#  'to',
#  'dive',
#  'deep',
#  'into',
#  'distributed',
#  'data',
#  'at',
#  'the',
#  'Petabyte',
#  'level',
#  'and',
#  'provide',
#  'insights',
#  'to',
#  'guide',
#  'the',
#  'development',
#  'of',
#  'Machine',
#  'Learning',
#  'problems',
#  'in',
#  'time',
#  'series',
#  'and',
#  'revenue',
#  'forecasts,',
#  'auction',
#  'prediction,',
#  'and',
#  'bid',
#  'optimizations,',
#  'to',
#  'support',
#  'the',
#  'growth',
#  'of',
#  'Amazon’s',
#  'advertising',
#  'business',
#  'Our',
#  'ideal',
#  'candidate',
#  'will',
#  'have',
#  'strong',
#  'analytical',
#  'skills,',
#  'business',
#  'acumen',
#  'and',
#  'judgement,',
#  'intellectual',
#  'curiosity,',
#  'technical',
#  'skills,',
#  'and',
#  'excel',
#  'at',
#  'both',
#  'written',
#  'and',
#  'verbal',
#  'communications',
#  'S/he',
#  'will',
#  'be',
#  'a',
#  'self-motivated',
#  'individual',
#  'who',
#  'is',
#  'comfortable',
#  'with',
#  'ambiguity',
#  'and',
#  'be',
#  'able',
#  'to',
#  'think',
#  'critically',
#  'about',
#  'a',
#  'science',
#  'product',
#  'from',
#  'business',
#  'standpoint',
#  'The',
#  'primary',
#  'responsibilities',
#  'of',
#  'this',
#  'role',
#  'include:·',
#  'Design,',
#  'develop,',
#  'and',
#  'maintain',
#  'scalable,',
#  'automated',
#  'metrics',
#  'reports',
#  'and',
#  'dashboards',
#  'to',
#  'support',
#  'our',
#  'analytical',
#  'and',
#  'business',
#  'needs·',
#  'Provide',
#  'insights',
#  'on',
#  'data',
#  'analytics',
#  'to',
#  'influence',
#  'model',
#  'development',
#  'roadmap·',
#  'Work',
#  'closely',
#  'with',
#  'stakeholders',
#  'and',
#  'leadership',
#  'to',
#  'define',
#  'and',
#  'present',
#  'the',
#  'team’s',
#  'business',
#  'operational',
#  'metrics·',
#  'Work',
#  'closely',
#  'with',
#  'scientists',
#  'to',
#  'define',
#  'and',
#  'present',
#  'the',
#  'team’s',
#  'model-related',
#  'metrics·',
#  'Recognize',
#  'and',
#  'adopt',
#  'best',
#  'practices',
#  'in',
#  'reporting',
#  'and',
#  'analytics',
#  '–',
#  'automation,',
#  'data',
#  'integrity,',
#  'validation,',
#  'and',
#  'documentation',
#  'US,',
#  'CA,',
#  'Palo',
#  'Alto',
#  'Business',
#  'Intelligence',
#  '986896',
#  'Amazon',
#  'com',
#  'Services,',
#  'Inc',
#  '14b00d40ced925890eb4eca458040133',
#  '2019-11-15',
#  '00:15:23',
#  '+0000',
#  'https://www',
#  'amazon',
#  'jobs/en/jobs/986894/senior-solution-design-manager',
#  'Senior',
#  'Solution',
#  'Design',
#  'Manager',
#  'The',
#  'Amazon',
#  'Cross',
#  'Border',
#  'Exports',
#  'team',
#  'is',
#  'looking',
#  'for',
#  'a',
#  'highly',
#  'skilled',
#  'and',
#  'motivated',
#  'Sr',
#  'Solution',
#  'Design',
#  'Manager',
#  'to',
#  'incubate',
#  'a',
#  'supply',
#  'chain',
#  'execution',
#  'team',
#  'The',
#  'role',
#  'and',
#  'the',
#  'team',
#  'will',
#  'be',
#  'responsible',
#  'for',
#  'onboarding',
#  'logistics',
#  'partners',
#  'as',
#  'part',
#  'of',
#  'our',
#  'Cross-Border',
#  'expansion',
#  'plans',
#  'The',
#  'successful',
#  'candidate',
#  'will',
#  'work',
#  'closely',
#  'with',
#  'both',
#  'internal',
#  'and',
#  'external',
#  'stakeholders',
#  'to',
#  'drive',
#  'and',
#  'program',
#  'manage',
#  'logistics',
#  'execution',
#  'programs',
#  'An',
#  'ideal',
#  'candidate',
#  'has',
#  'a',
#  'background',
#  'in',
#  'transportation',
#  'or',
#  'logistics/operations',
#  'management',
#  'and',
#  'excellent',
#  'data',
#  'driven',
#  'problem',
#  'resolution',
#  'skills',
#  'This',
#  'person',
#  'will',
#  'have',
#  'the',
#  'ability',
#  'to',
#  'leverage',
#  'and',
#  'analyze',
#  'data',
#  'and',
#  'blend',
#  'that',
#  'with',
#  'experience',
#  'to',
#  'lead',
#  'process',
#  'improvements,',
#  'standardize',
#  'team',
#  'processes',
#  'and',
#  'eliminate',
#  'the',
#  'root',
#  'cause',
#  'of',
#  'defects',
#  'This',
#  'job',
#  'will',
#  'require',
#  'exceptional',
#  'team',
#  'leadership,',
#  'communication',
#  'and',
#  'interpersonal',
#  'skills',
#  'while',
#  'having',
#  'the',
#  'ability',
#  'to',
#  'in',
#  'a',
#  'high',
#  'pressure',
#  'environment',
#  'and',
#  'exercise',
#  'sound',
#  'judgment',
#  'The',
#  'successful',
#  'candidate',
#  'will',
#  'be',
#  'proficient',
#  'at',
#  'strategic',
#  'problem',
#  'solving,',
#  'prioritizing',
#  'logistics',
#  'challenges',
#  'and',
#  'possess',
#  'a',
#  'bias',
#  'to',
#  'get',
#  'things',
#  'done',
#  'and',
#  'deliver',
#  'results',
#  'while',
#  'attracting,',
#  'growing',
#  'and',
#  'retaining',
#  'a',
#  'highly',
#  'talented',
#  'team',
#  'Key',
#  'responsibilities',
#  'for',
#  '2019/20',
#  'include·',
#  'Work',
#  'with',
#  'cross-functional',
#  'teams',
#  'to',
#  'on-board',
#  'carriers',
#  'to',
#  'support',
#  'AGL',
#  'global',
#  'initiatives·',
#  'Build,',
#  'own',
#  'and',
#  'incubate',
#  'a',
#  'repeatable',
#  'process/function',
#  'which',
#  'can',
#  'be',
#  'handed',
#  'off',
#  'to',
#  'a',
#  'team',
#  'of',
#  'program',
#  'managers',
#  'as',
#  'we',
#  'scale·',
#  'Contribute',
#  'to',
#  'strategic',
#  'yearly',
#  'planning',
#  'processes',
#  'US,',
#  'WA,',
#  'Bellevue',
#  'Supply',
#  'Chain/Transportation',
#  'Management',
#  '986894',
#  'Amazon',
#  'com',
#  'Services,',
#  'Inc',
#  '0c96a59282dc24bbc546bf31d42825d5',
#  '2019-11-15',
#  '00:15:23',
#  '+0000',
#  'https://www',
#  'amazon',
#  'jobs/en/jobs/986893/instock-manager',
#  'Instock',
#  'Manager',
#  'The',
#  'AmazonFresh',
#  'and',
#  'Prime',
#  'Now',
#  'organizations',
#  'are',
#  'at',
#  'the',
#  'forefront',
#  'of',
#  'developing',
#  'and',
#  'supporting',
#  'the',
#  'future',
#  'of',
#  'grocery',
#  'and',
#  'ultra-fast',
#  'delivery',
#  'services',
#  ...]

# %%
# Import the toolkit and the full Porter Stemmer library
import nltk
from nltk.stem.porter import *
from nltk.stem.snowball import SnowballStemmer

# The Snowball Stemmer requires that you pass a language parameter
s_stemmer = SnowballStemmer(language='english')

# %%
#Stemming

#Stemming is a somewhat crude method for cataloging related words; it essentially chops off letters from the end until the stem is reached. 
#This works fairly well in most cases, but unfortunately English has many exceptions where a more sophisticated process is required. 
#In fact, spaCy doesn't include a stemmer, opting instead to rely entirely on lemmatization.

#Instead, we'll use another popular NLP tool called nltk, which stands for Natural Language Toolkit. 
for word in re.findall(r"[^!.? ]+",s):
    print(word+' --> '+s_stemmer.stem(word))
# Out:
# pageurl --> pageurl
# record/0/uniq_id --> record/0/uniq_id
# record/0/crawl_timestamp --> record/0/crawl_timestamp
# record/0/job_url --> record/0/job_url
# record/0/title --> record/0/titl
# record/0/description --> record/0/descript
# record/0/location --> record/0/loc
# record/0/category --> record/0/categori
# record/0/job_id --> record/0/job_id
# record/0/company_name --> record/0/company_nam
# record/1/uniq_id --> record/1/uniq_id
# record/1/crawl_timestamp --> record/1/crawl_timestamp
# record/1/job_url --> record/1/job_url
# record/1/title --> record/1/titl
# record/1/description --> record/1/descript
# record/1/location --> record/1/loc
# record/1/category --> record/1/categori
# record/1/job_id --> record/1/job_id
# record/1/company_name --> record/1/company_nam
# record/2/uniq_id --> record/2/uniq_id
# record/2/crawl_timestamp --> record/2/crawl_timestamp
# record/2/job_url --> record/2/job_url
# record/2/title --> record/2/titl
# record/2/description --> record/2/descript
# record/2/location --> record/2/loc
# record/2/category --> record/2/categori
# record/2/job_id --> record/2/job_id
# record/2/company_name --> record/2/company_nam
# record/3/uniq_id --> record/3/uniq_id
# record/3/crawl_timestamp --> record/3/crawl_timestamp
# record/3/job_url --> record/3/job_url
# record/3/title --> record/3/titl
# record/3/description --> record/3/descript
# record/3/location --> record/3/loc
# record/3/category --> record/3/categori
# record/3/job_id --> record/3/job_id
# record/3/company_name --> record/3/company_nam
# record/4/uniq_id --> record/4/uniq_id
# record/4/crawl_timestamp --> record/4/crawl_timestamp
# record/4/job_url --> record/4/job_url
# record/4/title --> record/4/titl
# record/4/description --> record/4/descript
# record/4/location --> record/4/loc
# record/4/category --> record/4/categori
# record/4/job_id --> record/4/job_id
# record/4/company_name --> record/4/company_nam
# record/5/uniq_id --> record/5/uniq_id
# record/5/crawl_timestamp --> record/5/crawl_timestamp
# record/5/job_url --> record/5/job_url
# record/5/title --> record/5/titl
# record/5/description --> record/5/descript
# record/5/location --> record/5/loc
# record/5/category --> record/5/categori
# record/5/job_id --> record/5/job_id
# record/5/company_name --> record/5/company_nam
# record/6/uniq_id --> record/6/uniq_id
# record/6/crawl_timestamp --> record/6/crawl_timestamp
# record/6/job_url --> record/6/job_url
# record/6/title --> record/6/titl
# record/6/description --> record/6/descript
# record/6/location --> record/6/loc
# record/6/category --> record/6/categori
# record/6/job_id --> record/6/job_id
# record/6/company_name --> record/6/company_nam
# record/7/uniq_id --> record/7/uniq_id
# record/7/crawl_timestamp --> record/7/crawl_timestamp
# record/7/job_url --> record/7/job_url
# record/7/title --> record/7/titl
# record/7/description --> record/7/descript
# record/7/location --> record/7/loc
# record/7/category --> record/7/categori
# record/7/job_id --> record/7/job_id
# record/7/company_name --> record/7/company_nam
# record/8/uniq_id --> record/8/uniq_id
# record/8/crawl_timestamp --> record/8/crawl_timestamp
# record/8/job_url --> record/8/job_url
# record/8/title --> record/8/titl
# record/8/description --> record/8/descript
# record/8/location --> record/8/loc
# record/8/category --> record/8/categori
# record/8/job_id --> record/8/job_id
# record/8/company_name --> record/8/company_nam
# record/9/uniq_id --> record/9/uniq_id
# record/9/crawl_timestamp --> record/9/crawl_timestamp
# record/9/job_url --> record/9/job_url
# record/9/title --> record/9/titl
# record/9/description --> record/9/descript
# record/9/location --> record/9/loc
# record/9/category --> record/9/categori
# record/9/job_id --> record/9/job_id
# record/9/company_name
# 0 --> record/9/company_name
# 0
# https://www --> https://www
# amazon --> amazon
# jobs/en/search --> jobs/en/search
# json --> json
# base_query=&city=&country=&county=&facets%5B%5D=location&facets%5B%5D=business_category&facets%5B%5D=category&facets%5B%5D=schedule_type_id&facets%5B%5D=employee_class&facets%5B%5D=normalized_location&facets%5B%5D=job_function_id&latitude=&loc_group_id=&loc_query=United+States&longitude=&offset=1530&query_options=&radius=24km&region=&result_limit=10&sort=relevant --> base_query=&city=&country=&county=&facets%5b%5d=location&facets%5b%5d=business_category&facets%5b%5d=category&facets%5b%5d=schedule_type_id&facets%5b%5d=employee_class&facets%5b%5d=normalized_location&facets%5b%5d=job_function_id&latitude=&loc_group_id=&loc_query=united+states&longitude=&offset=1530&query_options=&radius=24km&region=&result_limit=10&sort=relev
# 850f0199e2ce9d1d51ee5e2e11318d94 --> 850f0199e2ce9d1d51ee5e2e11318d94
# 2019-11-15 --> 2019-11-15
# 00:15:23 --> 00:15:23
# +0000 --> +0000
# https://www --> https://www
# amazon --> amazon
# jobs/en/jobs/986897/software-development-engineer-i --> jobs/en/jobs/986897/software-development-engineer-i
# Software --> softwar
# Development --> develop
# Engineer --> engin
# I --> i
# Amazon’s --> amazon
# Global --> global
# Logistics --> logist
# Technology --> technolog
# team --> team
# is --> is
# chartered --> charter
# with --> with
# building --> build
# solutions --> solut
# for --> for
# international --> intern
# movement --> movement
# of --> of
# shipments --> shipment
# which --> which
# can --> can
# originate --> origin
# from --> from
# any --> ani
# place --> place
# on --> on
# earth, --> earth,
# cross --> cross
# the --> the
# international --> intern
# border --> border
# and --> and
# be --> be
# delivered --> deliv
# in --> in
# a --> a
# different --> differ
# part --> part
# of --> of
# planet --> planet
# There --> there
# are --> are
# variety --> varieti
# of --> of
# ways --> way
# in --> in
# which --> which
# we --> we
# can --> can
# import --> import
# shipments --> shipment
# from --> from
# vendors/sellers --> vendors/sel
# to --> to
# our --> our
# warehouses --> warehous
# and --> and
# export --> export
# package --> packag
# from --> from
# one --> one
# country --> countri
# to --> to
# another --> anoth
# through --> through
# several --> sever
# intermediate --> intermedi
# locations --> locat
# to --> to
# deliver --> deliv
# it --> it
# to --> to
# our --> our
# international --> intern
# customer --> custom
# There --> there
# are --> are
# millions --> million
# of --> of
# such --> such
# packages, --> packages,
# each --> each
# with --> with
# different --> differ
# attributes, --> attributes,
# delivery --> deliveri
# requirements --> requir
# and --> and
# international --> intern
# commerce --> commerc
# and --> and
# customs --> custom
# constraints --> constraint
# What --> what
# results --> result
# is --> is
# a --> a
# complex --> complex
# graph --> graph
# of --> of
# source, --> source,
# intermediate --> intermedi
# and --> and
# destination --> destin
# nodes --> node
# with --> with
# their --> their
# arcs --> arc
# crossing --> cross
# international --> intern
# borders --> border
# and --> and
# associated --> associ
# with --> with
# different --> differ
# costs --> cost
# and --> and
# transit --> transit
# times --> time
# Accounting --> account
# for --> for
# all --> all
# these --> these
# constraints --> constraint
# and --> and
# maximizing --> maxim
# the --> the
# number --> number
# of --> of
# shipments --> shipment
# shipped, --> shipped,
# while --> while
# minimizing --> minim
# cost, --> cost,
# providing --> provid
# a --> a
# variety --> varieti
# of --> of
# customer --> custom
# delivery --> deliveri
# options --> option
# and --> and
# maximizing --> maxim
# delivery --> deliveri
# performance --> perform
# is --> is
# our --> our
# primary --> primari
# focus --> focus
# We --> we
# are --> are
# building --> build
# world --> world
# class --> class
# technology --> technolog
# cutting --> cut
# across --> across
# deep --> deep
# algorithmic --> algorithm
# problems, --> problems,
# brand --> brand
# new --> new
# tools --> tool
# that --> that
# cater --> cater
# to --> to
# multi-party --> multi-parti
# business --> busi
# scenarios --> scenario
# and --> and
# challenging --> challeng
# data --> data
# models --> model
# that --> that
# are --> are
# evolving --> evolv
# very --> veri
# quickly --> quick
# Our --> our
# systems --> system
# touch --> touch
# every --> everi
# single --> singl
# package --> packag
# that --> that
# travels --> travel
# internationally --> intern
# which --> which
# mandates --> mandat
# building --> build
# of --> of
# highly --> high
# available --> avail
# and --> and
# scalable --> scalabl
# distributed --> distribut
# systems --> system
# Besides --> besid
# technology, --> technology,
# there --> there
# are --> are
# ample --> ampl
# opportunities --> opportun
# in --> in
# the --> the
# team --> team
# to --> to
# build --> build
# domain --> domain
# expertise --> expertis
# of --> of
# international --> intern
# transportation --> transport
# and --> and
# supply --> suppli
# chain --> chain
# realms --> realm
# and --> and
# get --> get
# first-hand --> first-hand
# experience --> experi
# of --> of
# the --> the
# Amazon --> amazon
# operations --> oper
# by --> by
# interacting --> interact
# directly --> direct
# with --> with
# our --> our
# global --> global
# internal --> intern
# and --> and
# external --> extern
# partners, --> partners,
# and --> and
# of --> of
# course --> cours
# the --> the
# esteemed --> esteem
# senior --> senior
# engineering --> engin
# talent --> talent
# pool --> pool
# We --> we
# are --> are
# looking --> look
# for --> for
# highly --> high
# talented --> talent
# software --> softwar
# development --> develop
# engineers --> engin
# who --> who
# are --> are
# passionate --> passion
# not --> not
# only --> onli
# about --> about
# architecting --> architect
# and --> and
# developing --> develop
# large --> larg
# scale --> scale
# distributed --> distribut
# technology --> technolog
# solutions --> solut
# but --> but
# also --> also
# innovating --> innov
# new --> new
# ideas --> idea
# and --> and
# providing --> provid
# directions --> direct
# to --> to
# our --> our
# business --> busi
# in --> in
# the --> the
# domain --> domain
# of --> of
# imports --> import
# and --> and
# exports --> export
# logistics --> logist
# We --> we
# have --> have
# many --> mani
# key --> key
# initiatives --> initi
# lined-up --> lined-up
# to --> to
# support --> support
# our --> our
# rapid --> rapid
# evolution --> evolut
# and --> and
# growth --> growth
# of --> of
# cross --> cross
# border --> border
# transportation --> transport
# network --> network
# by --> by
# solving --> solv
# some --> some
# of --> of
# the --> the
# most --> most
# challenging --> challeng
# problems --> problem
# in --> in
# this --> this
# domain --> domain
# #AGLT --> #aglt
# US, --> us,
# WA, --> wa,
# Seattle --> seattl
# Software --> softwar
# Development --> develop
# 986897 --> 986897
# Amazon --> amazon
# com --> com
# Services, --> services,
# Inc --> inc
# 9215700a26684c9dca1ad77718f33ff2 --> 9215700a26684c9dca1ad77718f33ff2
# 2019-11-15 --> 2019-11-15
# 00:15:23 --> 00:15:23
# +0000 --> +0000
# https://www --> https://www
# amazon --> amazon
# jobs/en/jobs/986896/business-intelligence-engineer --> jobs/en/jobs/986896/business-intelligence-engin
# Business --> busi
# Intelligence --> intellig
# Engineer --> engin
# Amazon --> amazon
# Advertising --> advertis
# is --> is
# dedicated --> dedic
# to --> to
# driving --> drive
# measurable --> measur
# outcomes --> outcom
# for --> for
# brand --> brand
# advertisers, --> advertisers,
# agencies, --> agencies,
# authors, --> authors,
# and --> and
# entrepreneurs --> entrepreneur
# Our --> our
# ad --> ad
# solutions—including --> solutions—includ
# sponsored, --> sponsored,
# display, --> display,
# video, --> video,
# and --> and
# custom --> custom
# ads—leverage --> ads—leverag
# Amazon’s --> amazon
# innovations --> innov
# and --> and
# insights --> insight
# to --> to
# find, --> find,
# attract, --> attract,
# and --> and
# engage --> engag
# intended --> intend
# audiences --> audienc
# throughout --> throughout
# their --> their
# daily --> daili
# journeys --> journey
# With --> with
# a --> a
# range --> rang
# of --> of
# flexible --> flexibl
# pricing --> price
# and --> and
# buying --> buy
# models, --> models,
# including --> includ
# self-service, --> self-service,
# managed --> manag
# service, --> service,
# and --> and
# programmatic --> programmat
# ad --> ad
# buying, --> buying,
# these --> these
# solutions --> solut
# help --> help
# businesses --> busi
# build --> build
# brand --> brand
# awareness, --> awareness,
# increase --> increas
# product --> product
# sales, --> sales,
# and --> and
# more --> more
# We --> we
# are --> are
# seeking --> seek
# an --> an
# exceptional --> except
# Business --> busi
# Intelligence --> intellig
# Engineer --> engin
# to --> to
# join --> join
# the --> the
# Advertising --> advertis
# Forecasting --> forecast
# Science --> scienc
# team --> team
# at --> at
# Palo --> palo
# Alto, --> alto,
# California --> california
# You --> you
# will --> will
# have --> have
# extremely --> extrem
# high --> high
# visibility --> visibl
# via --> via
# presenting --> present
# regular --> regular
# business --> busi
# metrics --> metric
# to --> to
# leadership --> leadership
# on --> on
# a --> a
# regular --> regular
# basis, --> basis,
# and --> and
# work --> work
# closely --> close
# with --> with
# a --> a
# group --> group
# of --> of
# talented --> talent
# scientists --> scientist
# and --> and
# engineers --> engin
# You --> you
# will --> will
# need --> need
# to --> to
# dive --> dive
# deep --> deep
# into --> into
# distributed --> distribut
# data --> data
# at --> at
# the --> the
# Petabyte --> petabyt
# level --> level
# and --> and
# provide --> provid
# insights --> insight
# to --> to
# guide --> guid
# the --> the
# development --> develop
# of --> of
# Machine --> machin
# Learning --> learn
# problems --> problem
# in --> in
# time --> time
# series --> seri
# and --> and
# revenue --> revenu
# forecasts, --> forecasts,
# auction --> auction
# prediction, --> prediction,
# and --> and
# bid --> bid
# optimizations, --> optimizations,
# to --> to
# support --> support
# the --> the
# growth --> growth
# of --> of
# Amazon’s --> amazon
# advertising --> advertis
# business --> busi
# Our --> our
# ideal --> ideal
# candidate --> candid
# will --> will
# have --> have
# strong --> strong
# analytical --> analyt
# skills, --> skills,
# business --> busi
# acumen --> acumen
# and --> and
# judgement, --> judgement,
# intellectual --> intellectu
# curiosity, --> curiosity,
# technical --> technic
# skills, --> skills,
# and --> and
# excel --> excel
# at --> at
# both --> both
# written --> written
# and --> and
# verbal --> verbal
# communications --> communic
# S/he --> s/he
# will --> will
# be --> be
# a --> a
# self-motivated --> self-motiv
# individual --> individu
# who --> who
# is --> is
# comfortable --> comfort
# with --> with
# ambiguity --> ambigu
# and --> and
# be --> be
# able --> abl
# to --> to
# think --> think
# critically --> critic
# about --> about
# a --> a
# science --> scienc
# product --> product
# from --> from
# business --> busi
# standpoint --> standpoint
# The --> the
# primary --> primari
# responsibilities --> respons
# of --> of
# this --> this
# role --> role
# include:· --> include:·
# Design, --> design,
# develop, --> develop,
# and --> and
# maintain --> maintain
# scalable, --> scalable,
# automated --> autom
# metrics --> metric
# reports --> report
# and --> and
# dashboards --> dashboard
# to --> to
# support --> support
# our --> our
# analytical --> analyt
# and --> and
# business --> busi
# needs· --> needs·
# Provide --> provid
# insights --> insight
# on --> on
# data --> data
# analytics --> analyt
# to --> to
# influence --> influenc
# model --> model
# development --> develop
# roadmap· --> roadmap·
# Work --> work
# closely --> close
# with --> with
# stakeholders --> stakehold
# and --> and
# leadership --> leadership
# to --> to
# define --> defin
# and --> and
# present --> present
# the --> the
# team’s --> team
# business --> busi
# operational --> oper
# metrics· --> metrics·
# Work --> work
# closely --> close
# with --> with
# scientists --> scientist
# to --> to
# define --> defin
# and --> and
# present --> present
# the --> the
# team’s --> team
# model-related --> model-rel
# metrics· --> metrics·
# Recognize --> recogn
# and --> and
# adopt --> adopt
# best --> best
# practices --> practic
# in --> in
# reporting --> report
# and --> and
# analytics --> analyt
# – --> –
# automation, --> automation,
# data --> data
# integrity, --> integrity,
# validation, --> validation,
# and --> and
# documentation --> document
# US, --> us,
# CA, --> ca,
# Palo --> palo
# Alto --> alto
# Business --> busi
# Intelligence --> intellig
# 986896 --> 986896
# Amazon --> amazon
# com --> com
# Services, --> services,
# Inc --> inc
# 14b00d40ced925890eb4eca458040133 --> 14b00d40ced925890eb4eca458040133
# 2019-11-15 --> 2019-11-15
# 00:15:23 --> 00:15:23
# +0000 --> +0000
# https://www --> https://www
# amazon --> amazon
# jobs/en/jobs/986894/senior-solution-design-manager --> jobs/en/jobs/986894/senior-solution-design-manag
# Senior --> senior
# Solution --> solut
# Design --> design
# Manager --> manag
# The --> the
# Amazon --> amazon
# Cross --> cross
# Border --> border
# Exports --> export
# team --> team
# is --> is
# looking --> look
# for --> for
# a --> a
# highly --> high
# skilled --> skill
# and --> and
# motivated --> motiv
# Sr --> sr
# Solution --> solut
# Design --> design
# Manager --> manag
# to --> to
# incubate --> incub
# a --> a
# supply --> suppli
# chain --> chain
# execution --> execut
# team --> team
# The --> the
# role --> role
# and --> and
# the --> the
# team --> team
# will --> will
# be --> be
# responsible --> respons
# for --> for
# onboarding --> onboard
# logistics --> logist
# partners --> partner
# as --> as
# part --> part
# of --> of
# our --> our
# Cross-Border --> cross-bord
# expansion --> expans
# plans --> plan
# The --> the
# successful --> success
# candidate --> candid
# will --> will
# work --> work
# closely --> close
# with --> with
# both --> both
# internal --> intern
# and --> and
# external --> extern
# stakeholders --> stakehold
# to --> to
# drive --> drive
# and --> and
# program --> program
# manage --> manag
# logistics --> logist
# execution --> execut
# programs --> program
# An --> an
# ideal --> ideal
# candidate --> candid
# has --> has
# a --> a
# background --> background
# in --> in
# transportation --> transport
# or --> or
# logistics/operations --> logistics/oper
# management --> manag
# and --> and
# excellent --> excel
# data --> data
# driven --> driven
# problem --> problem
# resolution --> resolut
# skills --> skill
# This --> this
# person --> person
# will --> will
# have --> have
# the --> the
# ability --> abil
# to --> to
# leverage --> leverag
# and --> and
# analyze --> analyz
# data --> data
# and --> and
# blend --> blend
# that --> that
# with --> with
# experience --> experi
# to --> to
# lead --> lead
# process --> process
# improvements, --> improvements,
# standardize --> standard
# team --> team
# processes --> process
# and --> and
# eliminate --> elimin
# the --> the
# root --> root
# cause --> caus
# of --> of
# defects --> defect
# This --> this
# job --> job
# will --> will
# require --> requir
# exceptional --> except
# team --> team
# leadership, --> leadership,
# communication --> communic
# and --> and
# interpersonal --> interperson
# skills --> skill
# while --> while
# having --> have
# the --> the
# ability --> abil
# to --> to
# in --> in
# a --> a
# high --> high
# pressure --> pressur
# environment --> environ
# and --> and
# exercise --> exercis
# sound --> sound
# judgment --> judgment
# The --> the
# successful --> success
# candidate --> candid
# will --> will
# be --> be
# proficient --> profici
# at --> at
# strategic --> strateg
# problem --> problem
# solving, --> solving,
# prioritizing --> priorit
# logistics --> logist
# challenges --> challeng
# and --> and
# possess --> possess
# a --> a
# bias --> bias
# to --> to
# get --> get
# things --> thing
# done --> done
# and --> and
# deliver --> deliv
# results --> result
# while --> while
# attracting, --> attracting,
# growing --> grow
# and --> and
# retaining --> retain
# a --> a
# highly --> high
# talented --> talent
# team --> team
# Key --> key
# responsibilities --> respons
# for --> for
# 2019/20 --> 2019/20
# include· --> include·
# Work --> work
# with --> with
# cross-functional --> cross-funct
# teams --> team
# to --> to
# on-board --> on-board
# carriers --> carrier
# to --> to
# support --> support
# AGL --> agl
# global --> global
# initiatives· --> initiatives·
# Build, --> build,
# own --> own
# and --> and
# incubate --> incub
# a --> a
# repeatable --> repeat
# process/function --> process/funct
# which --> which
# can --> can
# be --> be
# handed --> hand
# off --> off
# to --> to
# a --> a
# team --> team
# of --> of
# program --> program
# managers --> manag
# as --> as
# we --> we
# scale· --> scale·
# Contribute --> contribut
# to --> to
# strategic --> strateg
# yearly --> year
# planning --> plan
# processes --> process
# US, --> us,
# WA, --> wa,
# Bellevue --> bellevu
# Supply --> suppli
# Chain/Transportation --> chain/transport
# Management --> manag
# 986894 --> 986894
# Amazon --> amazon
# com --> com
# Services, --> services,
# Inc --> inc
# 0c96a59282dc24bbc546bf31d42825d5 --> 0c96a59282dc24bbc546bf31d42825d5
# 2019-11-15 --> 2019-11-15
# 00:15:23 --> 00:15:23
# +0000 --> +0000
# https://www --> https://www
# amazon --> amazon
# jobs/en/jobs/986893/instock-manager --> jobs/en/jobs/986893/instock-manag
# Instock --> instock
# Manager --> manag
# The --> the
# AmazonFresh --> amazonfresh
# and --> and
# Prime --> prime
# Now --> now
# organizations --> organ
# are --> are
# at --> at
# the --> the
# forefront --> forefront
# of --> of
# developing --> develop
# and --> and
# supporting --> support
# the --> the
# future --> futur
# of --> of
# grocery --> groceri
# and --> and
# ultra-fast --> ultra-fast
# delivery --> deliveri
# services --> servic
# at --> at
# Amazon --> amazon
# Our --> our
# passion --> passion
# is --> is
# driving --> drive
# an --> an
# excellent --> excel
# customer --> custom
# experience --> experi
# in --> in
# the --> the
# grocery --> groceri
# space --> space
# by --> by
# optimizing --> optim
# existing --> exist
# business --> busi
# functions --> function
# and --> and
# inventing --> invent
# solutions --> solut
# for --> for
# previously --> previous
# unsolved --> unsolv
# problems --> problem
# We --> we
# are --> are
# hiring --> hire
# an --> an
# Instock --> instock
# Manager --> manag
# who --> who
# invents --> invent
# and --> and
# simplifies --> simplifi
# to --> to
# solve --> solv
# complex --> complex
# problems, --> problems,
# excels --> excel
# at --> at
# querying --> queri
# and --> and
# analyzing --> analyz
# data --> data
# to --> to
# dive --> dive
# deep, --> deep,
# and --> and
# isn't --> isn't
# afraid --> afraid
# to --> to
# roll --> roll
# up --> up
# his/her --> his/her
# sleeves --> sleev
# to --> to
# deliver --> deliv
# results --> result
# The --> the
# Instock --> instock
# Manager --> manag
# will --> will
# be --> be
# responsible --> respons
# for --> for
# executing --> execut
# inventory --> inventori
# strategies --> strategi
# to --> to
# optimize --> optim
# customer --> custom
# experience, --> experience,
# sales, --> sales,
# margin --> margin
# and --> and
# turns --> turn
# They --> they
# will --> will
# be --> be
# relentlessly --> relentless
# focused --> focus
# on --> on
# delivering --> deliv
# high --> high
# in-stock --> in-stock
# rates --> rate
# in --> in
# order --> order
# to --> to
# meet --> meet
# the --> the
# needs --> need
# of --> of
# our --> our
# customers --> custom
# They --> they
# will --> will
# dive --> dive
# deep --> deep
# core --> core
# drivers --> driver
# of --> of
# in-stock --> in-stock
# performance, --> performance,
# and --> and
# proactively --> proactiv
# identify --> identifi
# opportunities --> opportun
# to --> to
# improve --> improv
# tools --> tool
# and --> and
# work --> work
# flows --> flow
# This --> this
# role --> role
# interacts --> interact
# closely --> close
# with --> with
# retail --> retail
# and --> and
# operations --> oper
# business --> busi
# partners --> partner
# across --> across
# Amazon, --> amazon,
# and --> and
# is --> is
# pivotal --> pivot
# to --> to
# the --> the
# growth --> growth
# of --> of
# this --> this
# strategic --> strateg
# initiative --> initi
# Specific --> specif
# responsibilities --> respons
# include:· --> include:·
# Manage --> manag
# inventory --> inventori
# availability --> avail
# and --> and
# inventory --> inventori
# health --> health
# including --> includ
# improved --> improv
# in-stock, --> in-stock,
# turns, --> turns,
# vendor --> vendor
# operational --> oper
# improvement --> improv
# (efficiency, --> (efficiency,
# fill --> fill
# rates, --> rates,
# lead --> lead
# time), --> time),
# forecasting, --> forecasting,
# and --> and
# shrink· --> shrink·
# Drive --> drive
# strategic --> strateg
# initiatives --> initi
# to --> to
# improve --> improv
# customer --> custom
# experience, --> experience,
# enable --> enabl
# new --> new
# capabilities, --> capabilities,
# and --> and
# reduce --> reduc
# waste· --> waste·
# Answer --> answer
# complex --> complex
# business --> busi
# questions --> question
# and --> and
# make --> make
# decisions --> decis
# by --> by
# querying --> queri
# and --> and
# analyzing --> analyz
# large --> larg
# data --> data
# sets· --> sets·
# Work --> work
# with --> with
# internal --> intern
# teams --> team
# to --> to
# build --> build
# automated --> autom
# tools --> tool
# and --> and
# process --> process
# improvements --> improv
# that --> that
# will --> will
# drive --> drive
# scale --> scale
# and --> and
# reduce --> reduc
# error· --> error·
# Manage --> manag
# day-to-day --> day-to-day
# operational --> oper
# relationships --> relationship
# with --> with
# vendors --> vendor
# and --> and
# distributors --> distributor
# partners, --> partners,
# including --> includ
# product --> product
# lifecycle --> lifecycl
# management, --> management,
# expanding --> expand
# selection --> select
# and --> and
# optimize --> optim
# sourcing --> sourc
# recommendations --> recommend
# / --> /
# decisions· --> decisions·
# Liaison --> liaison
# between --> between
# product --> product
# categories --> categori
# teams, --> teams,
# internal --> intern
# operations --> oper
# business --> busi
# partners --> partner
# and --> and
# vendor --> vendor
# partners· --> partners·
# Maintain --> maintain
# vendor --> vendor
# relationship --> relationship
# and --> and
# work --> work
# on --> on
# vendor --> vendor
# performance --> perform
# improvement --> improv
# through --> through
# daily --> daili
# communication, --> communication,
# training --> train
# session, --> session,
# tracking --> track
# purchase --> purchas
# orders, --> orders,
# investigating --> investig
# late --> late
# deliveries, --> deliveries,
# resolving --> resolv
# order --> order
# rejections, --> rejections,
# working --> work
# with --> with
# vendors --> vendor
# on --> on
# PO --> po
# automation, --> automation,
# etc --> etc
# · --> ·
# Determination --> determin
# of --> of
# order --> order
# quantities --> quantiti
# by --> by
# taking --> take
# into --> into
# account --> account
# forecasts, --> forecasts,
# historical --> histor
# trends --> trend
# and --> and
# inventory --> inventori
# targets --> target
# US, --> us,
# WA, --> wa,
# Seattle --> seattl
# Buying, --> buying,
# Planning, --> planning,
# & --> &
# Instock --> instock
# Management --> manag
# 986893 --> 986893
# Amazon --> amazon
# com --> com
# Services, --> services,
# Inc --> inc
# fff278b8672d6999631c5517c081fc4d --> fff278b8672d6999631c5517c081fc4d
# 2019-11-15 --> 2019-11-15
# 00:15:23 --> 00:15:23
# +0000 --> +0000
# https://www --> https://www
# amazon --> amazon
# jobs/en/jobs/986891/shift-manager-logistics --> jobs/en/jobs/986891/shift-manager-logist
# Shift --> shift
# Manager, --> manager,
# Logistics --> logist
# Do --> do
# you --> you
# want --> want
# to --> to
# work --> work
# hard, --> hard,
# have --> have
# fun --> fun
# and --> and
# make --> make
# history --> histori
# If --> if
# you --> you
# do --> do
# then --> then
# Amazon --> amazon
# could --> could
# be --> be
# the --> the
# right --> right
# career --> career
# choice --> choic
# for --> for
# you --> you
# Our --> our
# logistics --> logist
# teams --> team
# are --> are
# changing --> chang
# the --> the
# way --> way
# we --> we
# interact --> interact
# with --> with
# customers --> custom
# around --> around
# the --> the
# globe --> globe
# every --> everi
# single --> singl
# day --> day
# and --> and
# solving --> solv
# some --> some
# of --> of
# the --> the
# biggest --> biggest
# logistical --> logist
# challenges --> challeng
# facing --> face
# not --> not
# just --> just
# Amazon, --> amazon,
# but --> but
# also --> also
# the --> the
# entire --> entir
# industry --> industri
# Amazon’s --> amazon
# transportation --> transport
# teams --> team
# work --> work
# to --> to
# ensure --> ensur
# the --> the
# delivery --> deliveri
# packages --> packag
# globally --> global
# for --> for
# customers --> custom
# around --> around
# the --> the
# world --> world
# On --> on
# its --> it
# busiest --> busiest
# day, --> day,
# Cyber --> cyber
# Monday,Amazon --> monday,amazon
# customers --> custom
# around --> around
# the --> the
# world --> world
# have --> have
# ordered --> order
# more --> more
# than --> than
# 400 --> 400
# items --> item
# per --> per
# second --> second
# and --> and
# the --> the
# transportation --> transport
# teams --> team
# play --> play
# a --> a
# critical --> critic
# role --> role
# ensuring --> ensur
# packages --> packag
# make --> make
# it --> it
# to --> to
# customers’ --> custom
# doors --> door
# on-time --> on-tim
# and --> and
# in --> in
# great --> great
# condition --> condit
# Whether --> whether
# its --> it
# items --> item
# large --> larg
# or --> or
# small, --> small,
# we --> we
# find --> find
# solutions --> solut
# to --> to
# make --> make
# sure --> sure
# we --> we
# are --> are
# delivering --> deliv
# on --> on
# our --> our
# promise --> promis
# for --> for
# customers --> custom
# Our --> our
# Area --> area
# Managers --> manag
# are --> are
# responsible --> respons
# for --> for
# the --> the
# day-to-day --> day-to-day
# operations --> oper
# of --> of
# delivery --> deliveri
# stations --> station
# in --> in
# the --> the
# Amazon --> amazon
# network, --> network,
# including --> includ
# inbound, --> inbound,
# outbound, --> outbound,
# and --> and
# sortation --> sortat
# operations --> oper
# They --> they
# will --> will
# actively --> activ
# engage --> engag
# with --> with
# site --> site
# and --> and
# regional --> region
# operations --> oper
# leadership --> leadership
# to --> to
# implement --> implement
# new --> new
# operational --> oper
# improvements --> improv
# and --> and
# new --> new
# services --> servic
# We --> we
# expect --> expect
# our --> our
# managers --> manag
# to --> to
# continually --> continu
# identify --> identifi
# ways --> way
# to --> to
# improve --> improv
# our --> our
# operations --> oper
# Key --> key
# Job --> job
# Duties· --> duties·
# Oversee --> overse
# the --> the
# delivery --> deliveri
# of --> of
# Amazon --> amazon
# orders --> order
# to --> to
# customers· --> customers·
# Build, --> build,
# optimize, --> optimize,
# and --> and
# assign --> assign
# delivery --> deliveri
# routes --> rout
# on --> on
# your --> your
# shift· --> shift·
# Communicate --> communic
# with --> with
# and --> and
# respond --> respond
# to --> to
# Amazon --> amazon
# Customer --> custom
# Service --> servic
# associates --> associ
# on --> on
# delivery --> deliveri
# exceptions --> except
# and --> and
# requests· --> requests·
# Support --> support
# Amazon --> amazon
# operations --> oper
# leadership --> leadership
# team --> team
# in --> in
# daily --> daili
# operations --> oper
# management --> manag
# of --> of
# the --> the
# delivery --> deliveri
# station, --> station,
# including --> includ
# route --> rout
# assignment, --> assignment,
# leading --> lead
# meetings, --> meetings,
# and --> and
# communicating --> communic
# with --> with
# internal --> intern
# and --> and
# external --> extern
# suppliers --> supplier
# · --> ·
# Troubleshoot --> troubleshoot
# problems --> problem
# through --> through
# to --> to
# resolution, --> resolution,
# escalating --> escal
# as --> as
# necessary· --> necessary·
# Provide --> provid
# vacation --> vacat
# coverage --> coverag
# for --> for
# other --> other
# managers· --> managers·
# Review --> review
# and --> and
# update --> updat
# SOPs --> sop
# as --> as
# required· --> required·
# Participate --> particip
# in --> in
# Lean/Kaizen, --> lean/kaizen,
# Black --> black
# Belt, --> belt,
# and --> and
# other --> other
# Operational --> oper
# Excellence --> excel
# initiatives• --> initiatives•
# Ensure --> ensur
# compliance --> complianc
# throughout --> throughout
# the --> the
# site --> site
# to --> to
# global --> global
# process --> process
# standards --> standard
# and --> and
# work --> work
# on --> on
# continuous --> continu
# improvement --> improv
# initiativesAdditional --> initiativesaddit
# Job --> job
# Elements:• --> elements:•
# Must --> must
# be --> be
# able --> abl
# to --> to
# lift --> lift
# up --> up
# to --> to
# 49 --> 49
# pounds --> pound
# with --> with
# or --> or
# without --> without
# reasonable --> reason
# accommodation• --> accommodation•
# Must --> must
# be --> be
# willing --> will
# and --> and
# able --> abl
# to --> to
# frequently --> frequent
# push, --> push,
# pull, --> pull,
# squat, --> squat,
# bend, --> bend,
# and --> and
# reach• --> reach•
# Must --> must
# be --> be
# able --> abl
# to --> to
# stand/walk --> stand/walk
# for --> for
# up --> up
# to --> to
# 10-12 --> 10-12
# hours• --> hours•
# Must --> must
# be --> be
# able --> abl
# to --> to
# work --> work
# in --> in
# an --> an
# environment --> environ
# where --> where
# the --> the
# noise --> nois
# level --> level
# varies --> vari
# and --> and
# can --> can
# be --> be
# loud• --> loud•
# Must --> must
# be --> be
# able --> abl
# to --> to
# work --> work
# in --> in
# an --> an
# environment --> environ
# where --> where
# the --> the
# temperature --> temperatur
# may --> may
# vary --> vari
# between --> between
# 60 --> 60
# and --> and
# 90 --> 90
# degrees, --> degrees,
# and --> and
# will --> will
# occasionally --> occasion
# exceed --> exceed
# 90 --> 90
# degrees• --> degrees•
# Must --> must
# be --> be
# able --> abl
# to --> to
# continuously --> continu
# climb --> climb
# and --> and
# descend --> descend
# stairs --> stair
# safely --> safe
# (applies --> (appli
# to --> to
# sites --> site
# with --> with
# stairs)• --> stairs)•
# Must --> must
# be --> be
# able --> abl
# to --> to
# work --> work
# on --> on
# a --> a
# secure --> secur
# mezzanine --> mezzanin
# at --> at
# a --> a
# height --> height
# of --> of
# up --> up
# to --> to
# 40 --> 40
# feet --> feet
# (applies --> (appli
# to --> to
# buildings --> build
# with --> with
# mezzanines) --> mezzanines)
# CA, --> ca,
# AB, --> ab,
# Calgary --> calgari
# Fulfillment --> fulfil
# & --> &
# Operations --> oper
# Management --> manag
# 986891 --> 986891
# AMZN --> amzn
# CAN --> can
# Fulfillment --> fulfil
# Svcs, --> svcs,
# ULC --> ulc
# 78f0732c511fb6cb1e31b68a90d2df41 --> 78f0732c511fb6cb1e31b68a90d2df41
# 2019-11-15 --> 2019-11-15
# 00:15:23 --> 00:15:23
# +0000 --> +0000
# https://www --> https://www
# amazon --> amazon
# jobs/en/jobs/986888/area-manager-delivery-operations --> jobs/en/jobs/986888/area-manager-delivery-oper
# Area --> area
# Manager, --> manager,
# Delivery --> deliveri
# Operations --> oper
# Do --> do
# you --> you
# want --> want
# to --> to
# work --> work
# hard, --> hard,
# have --> have
# fun --> fun
# and --> and
# make --> make
# history --> histori
# If --> if
# you --> you
# do, --> do,
# then --> then
# Amazon --> amazon
# could --> could
# be --> be
# the --> the
# right --> right
# career --> career
# choice --> choic
# for --> for
# you --> you
# Our --> our
# logistics --> logist
# teams --> team
# are --> are
# changing --> chang
# the --> the
# way --> way
# we --> we
# interact --> interact
# with --> with
# customers --> custom
# around --> around
# the --> the
# globe --> globe
# every --> everi
# single --> singl
# day --> day
# and --> and
# solving --> solv
# some --> some
# of --> of
# the --> the
# biggest --> biggest
# logistical --> logist
# challenges --> challeng
# facing --> face
# not --> not
# just --> just
# Amazon, --> amazon,
# but --> but
# also --> also
# the --> the
# entire --> entir
# industry --> industri
# Amazon’s --> amazon
# transportation --> transport
# teams --> team
# work --> work
# to --> to
# ensure --> ensur
# the --> the
# delivery --> deliveri
# of --> of
# packages --> packag
# for --> for
# customers --> custom
# around --> around
# the --> the
# world --> world
# On --> on
# its --> it
# busiest --> busiest
# day, --> day,
# Cyber --> cyber
# Monday, --> monday,
# Amazon --> amazon
# customers --> custom
# around --> around
# the --> the
# world --> world
# have --> have
# ordered --> order
# more --> more
# than --> than
# 400 --> 400
# items --> item
# per --> per
# second --> second
# and --> and
# the --> the
# transportation --> transport
# teams --> team
# play --> play
# a --> a
# critical --> critic
# role --> role
# ensuring --> ensur
# packages --> packag
# make --> make
# it --> it
# to --> to
# customers’ --> custom
# doors --> door
# on-time --> on-tim
# and --> and
# in --> in
# great --> great
# condition --> condit
# Whether --> whether
# it --> it
# is --> is
# an --> an
# item --> item
# large --> larg
# or --> or
# small, --> small,
# we --> we
# find --> find
# solutions --> solut
# to --> to
# make --> make
# sure --> sure
# we --> we
# are --> are
# delivering --> deliv
# on --> on
# our --> our
# promise --> promis
# for --> for
# customers --> custom
# We --> we
# are --> are
# looking --> look
# for --> for
# a --> a
# Driver --> driver
# Resource --> resourc
# Manager, --> manager,
# Logistics --> logist
# who --> who
# will --> will
# be --> be
# responsible --> respons
# for --> for
# driver --> driver
# success --> success
# and --> and
# maintaining --> maintain
# a --> a
# positive --> posit
# driver --> driver
# experience --> experi
# Key --> key
# Job --> job
# Duties· --> duties·
# Cultivate --> cultiv
# and --> and
# sustain --> sustain
# a --> a
# positive --> posit
# culture, --> culture,
# quality --> qualiti
# performance, --> performance,
# safe --> safe
# environment, --> environment,
# and --> and
# a --> a
# positive, --> positive,
# professional --> profession
# driver --> driver
# experience· --> experience·
# Subject --> subject
# matter --> matter
# expert --> expert
# for --> for
# all --> all
# DA --> da
# and --> and
# DSP --> dsp
# process --> process
# areas --> area
# in --> in
# the --> the
# station --> station
# (Load --> (load
# Out, --> out,
# OnRoad --> onroad
# Execution, --> execution,
# RTS)· --> rts)·
# Manage --> manag
# two --> two
# direct --> direct
# reports --> report
# responsible --> respons
# for --> for
# DA --> da
# training --> train
# processes --> process
# and --> and
# on --> on
# road --> road
# audit --> audit
# mechanisms --> mechan
# for --> for
# DAs· --> das·
# Participate --> particip
# in --> in
# negotiations --> negoti
# for --> for
# DSP --> dsp
# dispute --> disput
# resolution, --> resolution,
# specifically --> specif
# approving --> approv
# payment, --> payment,
# determining --> determin
# payment --> payment
# adjustments --> adjust
# where --> where
# appropriate, --> appropriate,
# and --> and
# managing --> manag
# the --> the
# DSP --> dsp
# invoice --> invoic
# process· --> process·
# Conduct --> conduct
# weekly --> week
# performance --> perform
# meetings --> meet
# with --> with
# DSP --> dsp
# owners --> owner
# to --> to
# develop --> develop
# and --> and
# ensure --> ensur
# adherence --> adher
# to --> to
# action --> action
# plans --> plan
# that --> that
# meet --> meet
# business --> busi
# objectives --> object
# and --> and
# to --> to
# facilitate --> facilit
# monthly --> month
# round --> round
# tables --> tabl
# for --> for
# owner --> owner
# feedback· --> feedback·
# Drive --> drive
# continuous --> continu
# cost --> cost
# and --> and
# process --> process
# improvement --> improv
# programs --> program
# while --> while
# maintaining --> maintain
# positive --> posit
# working --> work
# relationships --> relationship
# with --> with
# DSPs --> dsps
# and --> and
# operations --> oper
# leadership·Partner --> leadership·partn
# with --> with
# regional --> region
# Fleet --> fleet
# Management --> manag
# leadership --> leadership
# to --> to
# validate --> valid
# and --> and
# confirm --> confirm
# vehicle --> vehicl
# demand --> demand
# during --> dure
# peaks --> peak
# and --> and
# ramps· --> ramps·
# Responsible --> respons
# for --> for
# DSP --> dsp
# Compliance --> complianc
# to --> to
# the --> the
# Fleet --> fleet
# Management --> manag
# Program· --> program·
# Lead --> lead
# daily --> daili
# SUMs --> sum
# with --> with
# the --> the
# DA --> da
# population --> popul
# prior --> prior
# to --> to
# load --> load
# out --> out
# to --> to
# drive --> drive
# quality --> qualiti
# and --> and
# engagement· --> engagement·
# Determine --> determin
# DA --> da
# scheduling --> schedul
# strategy --> strategi
# through --> through
# optimization --> optim
# of --> of
# delivery --> deliveri
# route --> rout
# assignment· --> assignment·
# Oversee --> overse
# response --> respons
# to --> to
# customer/TOC --> customer/toc
# escalations· --> escalations·
# Monitor --> monitor
# Driver --> driver
# staffing --> staf
# and --> and
# fleet --> fleet
# pipeline --> pipelin
# to --> to
# ensure --> ensur
# sufficient --> suffici
# capacityAdditional --> capacityaddit
# Job --> job
# Elements· --> elements·
# Must --> must
# be --> be
# able --> abl
# to --> to
# do --> do
# the --> the
# following --> follow
# with --> with
# or --> or
# without --> without
# reasonable --> reason
# accommodation:· --> accommodation:·
# Lift --> lift
# up --> up
# to --> to
# 70 --> 70
# pounds· --> pounds·
# Frequently --> frequent
# push, --> push,
# pull, --> pull,
# squat, --> squat,
# bend, --> bend,
# and --> and
# reach· --> reach·
# Stand/walk --> stand/walk
# for --> for
# up --> up
# to --> to
# 12 --> 12
# hours· --> hours·
# Push --> push
# and --> and
# pull --> pull
# wheeled --> wheel
# dollies --> dolli
# loaded --> load
# with --> with
# products --> product
# up --> up
# to --> to
# 100 --> 100
# pounds· --> pounds·
# Engage --> engag
# in --> in
# full --> full
# manual --> manual
# dexterity --> dexter
# in --> in
# both --> both
# hands --> hand
# and --> and
# wrists· --> wrists·
# Work --> work
# in --> in
# an --> an
# environment --> environ
# where --> where
# the --> the
# noise --> nois
# level --> level
# varies --> vari
# and --> and
# can --> can
# be --> be
# loud· --> loud·
# Work --> work
# in --> in
# an --> an
# environment --> environ
# where --> where
# the --> the
# temperature --> temperatur
# may --> may
# vary --> vari
# between --> between
# 60 --> 60
# and --> and
# 90 --> 90
# degrees, --> degrees,
# occasionally --> occasion
# exceeding --> exceed
# 90 --> 90
# degrees· --> degrees·
# Continuously --> continu
# climb --> climb
# and --> and
# descend --> descend
# stairs --> stair
# safely· --> safely·
# Must --> must
# be --> be
# able --> abl
# to --> to
# work --> work
# flexible --> flexibl
# schedules/shifts/areas, --> schedules/shifts/areas,
# including --> includ
# weekends, --> weekends,
# nights, --> nights,
# and --> and
# holidays --> holiday
# CA, --> ca,
# AB, --> ab,
# Calgary --> calgari
# Fulfillment --> fulfil
# & --> &
# Operations --> oper
# Management --> manag
# 986888 --> 986888
# AMZN --> amzn
# CAN --> can
# Fulfillment --> fulfil
# Svcs, --> svcs,
# ULC --> ulc
# b4385894d48d5041a92d8b7f4432e2f6 --> b4385894d48d5041a92d8b7f4432e2f6
# 2019-11-15 --> 2019-11-15
# 00:15:23 --> 00:15:23
# +0000 --> +0000
# https://www --> https://www
# amazon --> amazon
# jobs/en/jobs/986886/area-manager-logistics --> jobs/en/jobs/986886/area-manager-logist
# Area --> area
# Manager, --> manager,
# Logistics --> logist
# Do --> do
# you --> you
# want --> want
# to --> to
# work --> work
# hard, --> hard,
# have --> have
# fun --> fun
# and --> and
# make --> make
# history --> histori
# If --> if
# you --> you
# do, --> do,
# then --> then
# Amazon --> amazon
# could --> could
# be --> be
# the --> the
# right --> right
# career --> career
# choice --> choic
# for --> for
# you --> you
# Our --> our
# logistics --> logist
# teams --> team
# are --> are
# changing --> chang
# the --> the
# way --> way
# we --> we
# interact --> interact
# with --> with
# customers --> custom
# around --> around
# the --> the
# globe --> globe
# every --> everi
# single --> singl
# day --> day
# and --> and
# solving --> solv
# some --> some
# of --> of
# the --> the
# biggest --> biggest
# logistical --> logist
# challenges --> challeng
# facing --> face
# not --> not
# just --> just
# Amazon, --> amazon,
# but --> but
# also --> also
# the --> the
# entire --> entir
# industry --> industri
# Amazon’s --> amazon
# transportation --> transport
# teams --> team
# work --> work
# to --> to
# ensure --> ensur
# the --> the
# delivery --> deliveri
# of --> of
# packages --> packag
# for --> for
# customers --> custom
# around --> around
# the --> the
# world --> world
# On --> on
# its --> it
# busiest --> busiest
# day, --> day,
# Cyber --> cyber
# Monday, --> monday,
# Amazon --> amazon
# customers --> custom
# around --> around
# the --> the
# world --> world
# have --> have
# ordered --> order
# more --> more
# than --> than
# 400 --> 400
# items --> item
# per --> per
# second --> second
# and --> and
# the --> the
# transportation --> transport
# teams --> team
# play --> play
# a --> a
# critical --> critic
# role --> role
# ensuring --> ensur
# packages --> packag
# make --> make
# it --> it
# to --> to
# customers’ --> custom
# doors --> door
# on-time --> on-tim
# and --> and
# in --> in
# great --> great
# condition --> condit
# Whether --> whether
# it --> it
# is --> is
# an --> an
# item --> item
# large --> larg
# or --> or
# small, --> small,
# we --> we
# find --> find
# solutions --> solut
# to --> to
# make --> make
# sure --> sure
# we --> we
# are --> are
# delivering --> deliv
# on --> on
# our --> our
# promise --> promis
# for --> for
# customers --> custom
# Our --> our
# Area --> area
# Managers --> manag
# are --> are
# responsible --> respons
# for --> for
# management --> manag
# and --> and
# supervision --> supervis
# over --> over
# the --> the
# day-to-day --> day-to-day
# operations --> oper
# of --> of
# delivery --> deliveri
# stations --> station
# in --> in
# the --> the
# Amazon --> amazon
# network, --> network,
# including --> includ
# inbound, --> inbound,
# outbound, --> outbound,
# and --> and
# sortation --> sortat
# operations --> oper
# Area --> area
# Managers --> manag
# actively --> activ
# engage --> engag
# with --> with
# site --> site
# and --> and
# regional --> region
# operations --> oper
# leadership --> leadership
# to --> to
# develop --> develop
# and --> and
# implement --> implement
# new --> new
# operational --> oper
# improvements --> improv
# and --> and
# new --> new
# services --> servic
# We --> we
# expect --> expect
# our --> our
# managers --> manag
# to --> to
# continually --> continu
# identify --> identifi
# ways --> way
# to --> to
# improve --> improv
# our --> our
# operations --> oper
# Key --> key
# Job --> job
# Duties· --> duties·
# Act --> act
# as --> as
# second-in-command --> second-in-command
# to --> to
# Station --> station
# Manager --> manag
# in --> in
# managing --> manag
# to --> to
# achieve --> achiev
# station --> station
# safety, --> safety,
# quality, --> quality,
# productivity --> product
# and --> and
# CE --> ce
# performance --> perform
# and --> and
# to --> to
# include --> includ
# interviewing, --> interviewing,
# hiring, --> hiring,
# promotions, --> promotions,
# discipline, --> discipline,
# and --> and
# terminations --> termin
# of --> of
# employment· --> employment·
# Responsible --> respons
# for --> for
# managing --> manag
# associates --> associ
# to --> to
# achieve --> achiev
# operational --> oper
# metrics --> metric
# for --> for
# areas --> area
# of --> of
# responsibility· --> responsibility·
# Managing --> manag
# to --> to
# meet --> meet
# expectations --> expect
# regarding --> regard
# Standard --> standard
# Work, --> work,
# Gemba, --> gemba,
# reporting --> report
# and --> and
# root --> root
# cause --> caus
# defects· --> defects·
# Conduct --> conduct
# daily --> daili
# and --> and
# weekly --> week
# performance --> perform
# meetings· --> meetings·
# Oversee --> overse
# response --> respons
# to --> to
# customer/TOC --> customer/toc
# escalations· --> escalations·
# Assess --> assess
# and --> and
# develop --> develop
# future --> futur
# production --> product
# and --> and
# labor --> labor
# plans· --> plans·
# Interact --> interact
# with --> with
# all --> all
# support --> support
# teams --> team
# (LP, --> (lp,
# quality, --> quality,
# safety, --> safety,
# HR --> hr
# etc --> etc
# ) --> )
# to --> to
# develop --> develop
# plans --> plan
# to --> to
# meet --> meet
# business --> busi
# objectives· --> objectives·
# Analyze --> analyz
# and --> and
# oversight --> oversight
# of --> of
# scheduling --> schedul
# and --> and
# staffing --> staf
# requirements --> requir
# for --> for
# area --> area
# of --> of
# responsibility· --> responsibility·
# Volume --> volum
# planning/contingency --> planning/conting
# planning· --> planning·
# Subject --> subject
# matter --> matter
# expert --> expert
# for --> for
# all --> all
# process --> process
# areas --> area
# in --> in
# the --> the
# station --> station
# (Sort, --> (sort,
# OnRoad, --> onroad,
# RTS)· --> rts)·
# Ensuring --> ensur
# process --> process
# compliance --> complianc
# and --> and
# reporting --> report
# for --> for
# areas --> area
# of --> of
# responsibility --> respons
# (LP, --> (lp,
# Safety, --> safety,
# Quality, --> quality,
# HR)· --> hr)·
# Support --> support
# team --> team
# interaction --> interact
# and --> and
# escalation --> escal
# for --> for
# area --> area
# of --> of
# responsibility· --> responsibility·
# Develop --> develop
# an --> an
# environment --> environ
# that --> that
# drives --> drive
# performance --> perform
# while --> while
# maintaining --> maintain
# safe --> safe
# environment --> environ
# and --> and
# ensure --> ensur
# timely --> time
# reporting· --> reporting·
# Point --> point
# of --> of
# contact --> contact
# for --> for
# safety/security --> safety/secur
# issues --> issu
# that --> that
# occur --> occur
# on --> on
# site, --> site,
# incident --> incid
# commander --> command
# in --> in
# event --> event
# of --> of
# an --> an
# issue· --> issue·
# Day-to-day --> day-to-day
# management/supervision, --> management/supervision,
# including --> includ
# coverage --> coverag
# and --> and
# scheduling --> schedul
# of --> of
# L4 --> l4
# Shift --> shift
# Managers· --> managers·
# Oversight --> oversight
# and --> and
# participation --> particip
# in --> in
# ensuring --> ensur
# appropriate --> appropri
# performance --> perform
# management --> manag
# for --> for
# Amazon --> amazon
# L1-L3 --> l1-l3
# associates --> associ
# (does --> (doe
# not --> not
# apply --> appli
# to --> to
# temporary --> temporari
# associates)· --> associates)·
# Occasional --> occasion
# work --> work
# in --> in
# direct --> direct
# process --> process
# path --> path
# (if --> (if
# needed)· --> needed)·
# Vacation --> vacat
# coverage --> coverag
# for --> for
# Station --> station
# Manager --> manag
# (if --> (if
# needed)Additional --> needed)addit
# Job --> job
# Elements:· --> elements:·
# Must --> must
# be --> be
# able --> abl
# to --> to
# lift --> lift
# up --> up
# to --> to
# 49 --> 49
# ...
# Scientist --> scientist
# Want --> want
# to --> to
# stop --> stop
# fraudsters --> fraudster
# and --> and
# make --> make
# a --> a
# direct --> direct
# multi-million --> multi-million
# dollar --> dollar
# impact --> impact
# to --> to
# Amazon's --> amazon
# bottom --> bottom
# line --> line
# Come --> come
# join --> join
# the --> the
# AWS --> aw
# Fraud --> fraud
# Prevention --> prevent
# team --> team
# and --> and
# help --> help
# us --> us
# prevent --> prevent
# fraud --> fraud
# and --> and
# abuse --> abus
# on --> on
# AWS, --> aws,
# the --> the
# largest --> largest
# and --> and
# fastest --> fastest
# growing --> grow
# public --> public
# cloud --> cloud
# provider --> provid
# Fraudsters --> fraudster
# are --> are
# continually --> continu
# looking --> look
# for --> for
# new --> new
# ways --> way
# to --> to
# steal --> steal
# from --> from
# companies --> compani
# doing --> do
# business --> busi
# online --> onlin
# We --> we
# invent --> invent
# new --> new
# techniques --> techniqu
# to --> to
# detect --> detect
# and --> and
# stop --> stop
# these --> these
# bad --> bad
# actors, --> actors,
# leveraging --> leverag
# the --> the
# latest --> latest
# in --> in
# data --> data
# mining, --> mining,
# predictive --> predict
# modeling, --> modeling,
# and --> and
# enforcement --> enforc
# Our --> our
# team, --> team,
# AWS --> aw
# Fraud --> fraud
# Prevention, --> prevention,
# is --> is
# a --> a
# centralized --> central
# team --> team
# within --> within
# AWS --> aw
# that --> that
# protects --> protect
# all --> all
# AWS --> aw
# services --> servic
# from --> from
# fraud --> fraud
# and --> and
# abuse, --> abuse,
# and --> and
# ensures --> ensur
# the --> the
# experience --> experi
# of --> of
# legitimate --> legitim
# AWS --> aw
# customers --> custom
# is --> is
# not --> not
# negatively --> negat
# impacted --> impact
# by --> by
# a --> a
# few --> few
# bad --> bad
# actors --> actor
# As --> as
# a --> a
# Research --> research
# Scientist --> scientist
# at --> at
# Amazon, --> amazon,
# you’ll:· --> you'll:·
# Gather --> gather
# and --> and
# formulate --> formul
# business --> busi
# problems --> problem
# into --> into
# technical --> technic
# framework --> framework
# to --> to
# solve --> solv
# such --> such
# problems --> problem
# using --> use
# Machine --> machin
# Learning --> learn
# and --> and
# Statistical --> statist
# modeling --> model
# approaches· --> approaches·
# Analyze --> analyz
# and --> and
# process --> process
# large --> larg
# amounts --> amount
# of --> of
# data --> data
# and --> and
# build --> build
# machine --> machin
# learning --> learn
# models --> model
# to --> to
# solve --> solv
# specific --> specif
# business --> busi
# problems· --> problems·
# Research --> research
# and --> and
# implement --> implement
# novel --> novel
# machine --> machin
# learning, --> learning,
# AI --> ai
# and --> and
# statistical --> statist
# approaches --> approach
# · --> ·
# Establish --> establish
# scalable, --> scalable,
# efficient, --> efficient,
# automated --> autom
# processes --> process
# for --> for
# large --> larg
# scale --> scale
# data --> data
# analyses, --> analyses,
# and --> and
# model --> model
# development, --> development,
# validation --> valid
# and --> and
# implementation· --> implementation·
# Work --> work
# closely --> close
# with --> with
# software --> softwar
# engineering --> engin
# teams --> team
# to --> to
# drive --> drive
# model/solution --> model/solut
# implementations --> implement
# and --> and
# new --> new
# feature --> featur
# creation· --> creation·
# Develop --> develop
# state-of-the-art --> state-of-the-art
# machine --> machin
# learning --> learn
# models --> model
# that --> that
# are --> are
# privacy --> privaci
# preserving --> preserv
# and --> and
# robust --> robust
# against --> against
# adversarial --> adversari
# attacks --> attack
# US, --> us,
# NY, --> ny,
# New --> new
# York --> york
# Research --> research
# Science --> scienc
# 986874 --> 986874
# Amazon --> amazon
# Web --> web
# Services, --> services,
# Inc --> inc
# 1b8936ec121a39e17fce9eec1e244c96 --> 1b8936ec121a39e17fce9eec1e244c96
# 2019-11-15 --> 2019-11-15
# 00:15:23 --> 00:15:23
# +0000 --> +0000
# https://www --> https://www
# amazon --> amazon
# jobs/en/jobs/986871/senior-engagement-manager-professional-services --> jobs/en/jobs/986871/senior-engagement-manager-professional-servic
# Senior --> senior
# Engagement --> engag
# Manager --> manag
# - --> -
# Professional --> profession
# Services --> servic
# At --> at
# Amazon --> amazon
# Web --> web
# Services --> servic
# (AWS), --> (aws),
# we’re --> we'r
# hiring --> hire
# a --> a
# technical --> technic
# Engagement --> engag
# Manager --> manag
# to --> to
# lead --> lead
# AWS --> aw
# consultants, --> consultants,
# partner, --> partner,
# and --> and
# client --> client
# teams --> team
# Engagement --> engag
# Managers, --> managers,
# manage --> manag
# and --> and
# deliver --> deliv
# AWS --> aw
# cloud --> cloud
# products --> product
# and --> and
# services --> servic
# that --> that
# enable --> enabl
# our --> our
# customers --> custom
# to --> to
# realize --> realiz
# their --> their
# business --> busi
# objectives --> object
# These --> these
# professional --> profession
# services --> servic
# engagements --> engag
# focus --> focus
# on --> on
# the --> the
# full --> full
# platform --> platform
# of --> of
# AWS --> aw
# customer --> custom
# solutions --> solut
# to --> to
# help --> help
# our --> our
# customers --> custom
# and --> and
# partners --> partner
# remove --> remov
# constraints --> constraint
# and --> and
# accelerate --> acceler
# their --> their
# journey --> journey
# to --> to
# AWS --> aw
# AWS --> aw
# Professional --> profession
# Services --> servic
# engage --> engag
# in --> in
# a --> a
# wide --> wide
# variety --> varieti
# of --> of
# projects --> project
# for --> for
# customers --> custom
# and --> and
# partners, --> partners,
# providing --> provid
# collective --> collect
# AWS --> aw
# customer --> custom
# experience, --> experience,
# best --> best
# practices, --> practices,
# and --> and
# obsessing --> obsess
# about --> about
# strong --> strong
# success --> success
# for --> for
# the --> the
# Customer --> custom
# Our --> our
# team --> team
# collaborates --> collabor
# across --> across
# the --> the
# entire --> entir
# AWS --> aw
# organization --> organ
# to --> to
# bring --> bring
# access --> access
# to --> to
# product, --> product,
# service, --> service,
# and --> and
# training --> train
# teams, --> teams,
# to --> to
# deliver --> deliv
# the --> the
# right --> right
# solutions --> solut
# and --> and
# drive --> drive
# feature --> featur
# innovations --> innov
# for --> for
# our --> our
# customers --> custom
# across --> across
# all --> all
# industries --> industri
# Engagement --> engag
# Managers --> manag
# help --> help
# Customers --> custom
# make --> make
# decisions --> decis
# to --> to
# meet --> meet
# their --> their
# technical --> technic
# and --> and
# business --> busi
# objectives --> object
# by --> by
# providing --> provid
# best --> best
# practices, --> practices,
# proactively --> proactiv
# identifying --> identifi
# and --> and
# closing --> close
# project --> project
# gaps --> gap
# RESPONSIBILITIES --> respons
# AND --> and
# ABILITIES --> abil
# INCLUDE:EXPERTISE· --> include:expertise·
# Collaborate --> collabor
# with --> with
# AWS --> aw
# field --> field
# sales, --> sales,
# pre-sales, --> pre-sales,
# training --> train
# and --> and
# support --> support
# teams --> team
# to --> to
# seek --> seek
# to --> to
# understand --> understand
# our --> our
# customer’s --> custom
# needs, --> needs,
# their --> their
# business, --> business,
# how --> how
# success --> success
# is --> is
# defined, --> defined,
# and --> and
# ensure --> ensur
# that --> that
# we --> we
# are --> are
# exceeding --> exceed
# expectations --> expect
# in --> in
# delivery --> deliveri
# and --> and
# developing --> develop
# valued --> valu
# solutions --> solut
# · --> ·
# Experience --> experi
# leveraging --> leverag
# formal --> formal
# project --> project
# management --> manag
# and --> and
# development --> develop
# methodologies --> methodolog
# on --> on
# enterprise --> enterpris
# level --> level
# engagements --> engag
# · --> ·
# Possesses --> possess
# a --> a
# deep --> deep
# knowledge --> knowledg
# of --> of
# project --> project
# management --> manag
# best --> best
# practices --> practic
# and --> and
# how --> how
# to --> to
# apply --> appli
# them --> them
# in --> in
# an --> an
# effective --> effect
# yet --> yet
# pragmatic --> pragmat
# way --> way
# across --> across
# large, --> large,
# complex --> complex
# projects --> project
# · --> ·
# Understanding --> understand
# of --> of
# technology --> technolog
# principles --> principl
# and --> and
# services --> servic
# including --> includ
# infrastructure, --> infrastructure,
# business --> busi
# applications, --> applications,
# data --> data
# management, --> management,
# security, --> security,
# application --> applic
# platforms --> platform
# and --> and
# consumer --> consum
# facing --> face
# technology --> technolog
# SOLUTIONS· --> solutions·
# Lead --> lead
# individuals, --> individuals,
# teams --> team
# or --> or
# multiple --> multipl
# groups --> group
# and --> and
# play --> play
# an --> an
# active --> activ
# role --> role
# in --> in
# analyzing --> analyz
# project --> project
# goals, --> goals,
# creating --> creat
# a --> a
# plan --> plan
# to --> to
# achieve --> achiev
# those --> those
# goals, --> goals,
# and --> and
# then --> then
# driving --> drive
# the --> the
# AWS --> aw
# team --> team
# members, --> members,
# customer --> custom
# stakeholders/SMEs --> stakeholders/sm
# and --> and
# potentially --> potenti
# other --> other
# third --> third
# parties --> parti
# to --> to
# achieve --> achiev
# those --> those
# goals --> goal
# while --> while
# understanding --> understand
# the --> the
# client --> client
# environment --> environ
# and --> and
# any --> ani
# limitations --> limit
# to --> to
# execution --> execut
# · --> ·
# Actively --> activ
# looks --> look
# for --> for
# ways --> way
# to --> to
# improve --> improv
# process --> process
# efficiencies --> effici
# and --> and
# effectiveness --> effect
# · --> ·
# Ability --> abil
# to --> to
# apply --> appli
# strategic --> strateg
# thinking --> think
# and --> and
# demonstrate --> demonstr
# understanding --> understand
# of --> of
# requirements --> requir
# to --> to
# execute --> execut
# · --> ·
# Ability --> abil
# to --> to
# make --> make
# decisions --> decis
# guided --> guid
# by --> by
# policies, --> policies,
# procedures --> procedur
# and --> and
# business --> busi
# plan --> plan
# with --> with
# limited --> limit
# guidance --> guidanc
# · --> ·
# Business --> busi
# and --> and
# financial --> financi
# acumen --> acumen
# · --> ·
# Business --> busi
# case --> case
# development --> develop
# DELIVERY· --> delivery·
# Plan, --> plan,
# organize, --> organize,
# and --> and
# manage --> manag
# all --> all
# phases --> phase
# of --> of
# a --> a
# project --> project
# lifecycle --> lifecycl
# to --> to
# ensure --> ensur
# successful --> success
# delivery --> deliveri
# This --> this
# includes --> includ
# developing --> develop
# and --> and
# managing --> manag
# project --> project
# governance --> govern
# plans, --> plans,
# project --> project
# schedules, --> schedules,
# team --> team
# goals, --> goals,
# defining --> defin
# success --> success
# criteria, --> criteria,
# project --> project
# milestones, --> milestones,
# and --> and
# budgets --> budget
# · --> ·
# Plays --> play
# an --> an
# active --> activ
# role --> role
# in --> in
# managing --> manag
# project --> project
# goals --> goal
# and --> and
# driving --> drive
# teams --> team
# to --> to
# achieve --> achiev
# customers’ --> custom
# business --> busi
# outcomes --> outcom
# by --> by
# managing --> manag
# issues, --> issues,
# risks, --> risks,
# decisions, --> decisions,
# and --> and
# action --> action
# items --> item
# · --> ·
# Ability --> abil
# to --> to
# take --> take
# ownership, --> ownership,
# work --> work
# under --> under
# pressure --> pressur
# and --> and
# meet --> meet
# deadlines --> deadlin
# on --> on
# time --> time
# · --> ·
# Ability --> abil
# to --> to
# challenge, --> challenge,
# recommend --> recommend
# and --> and
# redirect --> redirect
# teams --> team
# as --> as
# well --> well
# as --> as
# manage --> manag
# client --> client
# expectations --> expect
# during --> dure
# the --> the
# engagement --> engag
# · --> ·
# Takes --> take
# proactive --> proactiv
# steps --> step
# to --> to
# ensure --> ensur
# teams --> team
# meet --> meet
# or --> or
# exceed --> exceed
# customer --> custom
# expectations --> expect
# · --> ·
# Works --> work
# effectively --> effect
# in --> in
# a --> a
# dynamic --> dynam
# environment --> environ
# with --> with
# changing --> chang
# priorities --> prioriti
# · --> ·
# Results-oriented, --> results-oriented,
# prioritizes --> priorit
# work --> work
# activities, --> activities,
# plans --> plan
# and --> and
# stays --> stay
# organized --> organ
# in --> in
# order --> order
# to --> to
# meet --> meet
# commitments --> commit
# COMMUNICATION· --> communication·
# Outstanding --> outstand
# written --> written
# and --> and
# verbal --> verbal
# communication --> communic
# skills --> skill
# with --> with
# team --> team
# members --> member
# and --> and
# audiences --> audienc
# of --> of
# all --> all
# levels --> level
# · --> ·
# Interfaces --> interfac
# with --> with
# various --> various
# customer --> custom
# and --> and
# internal --> intern
# AWS --> aw
# stakeholders --> stakehold
# which --> which
# consists --> consist
# of --> of
# senior --> senior
# leadership --> leadership
# teams --> team
# (C-level --> (c-level
# execs, --> execs,
# SVP/VP, --> svp/vp,
# Directors) --> directors)
# and --> and
# project --> project
# level --> level
# resources --> resourc
# such --> such
# as --> as
# SMEs --> smes
# · --> ·
# Plans --> plan
# and --> and
# oversees --> overse
# the --> the
# preparation --> prepar
# and --> and
# dissemination --> dissemin
# of --> of
# project --> project
# communications --> communic
# · --> ·
# Demonstrates --> demonstr
# the --> the
# ability --> abil
# to --> to
# understand --> understand
# the --> the
# operating --> oper
# styles --> style
# of --> of
# others --> other
# as --> as
# well --> well
# as --> as
# team/client --> team/client
# relationships, --> relationships,
# team --> team
# dynamics, --> dynamics,
# and --> and
# adjusts --> adjust
# behavior --> behavior
# accordingly --> accord
# to --> to
# succeed --> succeed
# Recognizes --> recogn
# environmental --> environment
# or --> or
# cultural --> cultur
# nuances --> nuanc
# and --> and
# adapts --> adapt
# · --> ·
# Excellent --> excel
# presentation, --> presentation,
# communication --> communic
# (oral --> (oral
# & --> &
# written), --> written),
# and --> and
# relationship --> relationship
# building --> build
# skills, --> skills,
# across --> across
# all --> all
# levels --> level
# of --> of
# management --> manag
# TEAMING· --> teaming·
# Proven --> proven
# success --> success
# in --> in
# working --> work
# with --> with
# teams --> team
# and --> and
# executive --> execut
# leadership --> leadership
# in --> in
# a --> a
# complex, --> complex,
# global --> global
# company --> compani
# environment --> environ
# · --> ·
# Team --> team
# player --> player
# who --> who
# effectively --> effect
# integrates, --> integrates,
# motivates --> motiv
# and --> and
# builds --> build
# relationships --> relationship
# with --> with
# cross-functional --> cross-funct
# team --> team
# members --> member
# (local --> (local
# or --> or
# remote), --> remote),
# sponsors, --> sponsors,
# key --> key
# stakeholders, --> stakeholders,
# executives, --> executives,
# and --> and
# other --> other
# individuals --> individu
# or --> or
# organizations --> organ
# involved --> involv
# with --> with
# or --> or
# affected --> affect
# by --> by
# the --> the
# project --> project
# · --> ·
# Proven --> proven
# experience --> experi
# working --> work
# in --> in
# a --> a
# matrix --> matrix
# environment, --> environment,
# managing --> manag
# multiple --> multipl
# stakeholders --> stakehold
# · --> ·
# Negotiation --> negoti
# and --> and
# conflict --> conflict
# resolution --> resolut
# capabilities --> capabl
# · --> ·
# Excellent --> excel
# people --> peopl
# management --> manag
# skills, --> skills,
# including --> includ
# the --> the
# ability --> abil
# to --> to
# influence, --> influence,
# negotiate --> negoti
# and --> and
# achieve --> achiev
# results --> result
# through --> through
# others --> other
# who --> who
# are --> are
# not --> not
# direct --> direct
# reports --> report
# This --> this
# is --> is
# a --> a
# customer --> custom
# facing --> face
# role --> role
# You --> you
# be --> be
# required --> requir
# to --> to
# travel --> travel
# to --> to
# client --> client
# locations --> locat
# to --> to
# deliver --> deliv
# professional --> profession
# services --> servic
# when --> when
# needed --> need
# US, --> us,
# CA, --> ca,
# Irvine --> irvin
# Project/Program/Product --> project/program/product
# Management--Technical --> management--techn
# 986871 --> 986871
# Amazon --> amazon
# Web --> web
# Services, --> services,
# Inc --> inc

# %%
## Lemmatization

#In contrast to stemming, 
#lemmatization looks beyond word reduction, and considers a language's full vocabulary to apply a morphological analysis to words. 
#The lemma of 'was' is 'be' and the lemma of 'mice' is 'mouse'. Further, the lemma of 'meeting' might be 'meet' or 'meeting' depending on its use in a sentence

# %%
##Function to display lemmas
def show_lemmas(text):
    for token in text:
        print(f'{token.text:{12}} {token.pos_:{6}} {token.lemma:<{22}} {token.lemma_}')

# %%
show_lemmas(doc)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                  SPACE  3208317858860871289
# pageurl      NOUN   5485203307599741254    pageurl
#                   SPACE  9687856286444532230
# record/0     PROPN  7706950813061305857    record/0
# /            SYM    2466615745961202537    /
# uniq_id      PROPN  18318867001484744910   uniq_id
#              SPACE  12127836336259238092
# record/0     X      7706950813061305857    record/0
# /            SYM    2466615745961202537    /
# crawl_timestamp PROPN  2177531639090775180    crawl_timestamp
#                                                         SPACE  15186086939463859429
# record/0     PROPN  7706950813061305857    record/0
# /            SYM    2466615745961202537    /
# job_url      X      3899865007845437402    job_url
#                    SPACE  372830584939022714
# record/0     PROPN  7706950813061305857    record/0
# /            SYM    2466615745961202537    /
# title        NOUN   4059498964464840598    title
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     SPACE  13018181886397729800                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# record/0     PROPN  7706950813061305857    record/0
# /            SYM    2466615745961202537    /
# description  NOUN   15699362302781265145   description
# record/0     PROPN  7706950813061305857    record/0
# /            SYM    2466615745961202537    /
# location     NOUN   4272944830542554761    location
#              SPACE  3518396686757337811
# record/0     PROPN  7706950813061305857    record/0
# /            SYM    2466615745961202537    /
# category     NOUN   12545855305924804326   category
#              SPACE  8532415787641010193
# record/0     PROPN  7706950813061305857    record/0
# /            SYM    2466615745961202537    /
# job_id       PROPN  11543310256069391702   job_id
#              SPACE  17579141535385064505
# record/0     PROPN  7706950813061305857    record/0
# /            SYM    2466615745961202537    /
# company_name PROPN  4949911190484699260    company_name
#                   SPACE  9687856286444532230
# record/1     PROPN  9021362760763132401    record/1
# /            SYM    2466615745961202537    /
# uniq_id      PROPN  18318867001484744910   uniq_id
#              SPACE  12127836336259238092
# record/1     PROPN  9021362760763132401    record/1
# /            SYM    2466615745961202537    /
# crawl_timestamp PROPN  2177531639090775180    crawl_timestamp
#                                                        SPACE  16482185863778234133
# record/1     PROPN  9021362760763132401    record/1
# /            PUNCT  2466615745961202537    /
# job_url      X      3899865007845437402    job_url
#                   SPACE  9687856286444532230
# record/1     PROPN  9021362760763132401    record/1
# /            SYM    2466615745961202537    /
# title        NOUN   4059498964464840598    title
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                SPACE  2048347992764222388                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# record/1     PROPN  9021362760763132401    record/1
# /            SYM    2466615745961202537    /
# description  NOUN   15699362302781265145   description
#              SPACE  8532415787641010193
# record/1     PROPN  9021362760763132401    record/1
# /            SYM    2466615745961202537    /
# location     PROPN  4272944830542554761    location
#              SPACE  17579141535385064505
# record/1     PROPN  9021362760763132401    record/1
# /            SYM    2466615745961202537    /
# category     NOUN   12545855305924804326   category
#              SPACE  8532415787641010193
# record/1     PROPN  9021362760763132401    record/1
# /            SYM    2466615745961202537    /
# job_id       PROPN  11543310256069391702   job_id
#              SPACE  17579141535385064505
# record/1     PROPN  9021362760763132401    record/1
# /            SYM    2466615745961202537    /
# company_name PROPN  4949911190484699260    company_name
#                   SPACE  9687856286444532230
# record/2     PROPN  15173292460903718120   record/2
# /            SYM    2466615745961202537    /
# uniq_id      PROPN  18318867001484744910   uniq_id
#              SPACE  12127836336259238092
# record/2     NOUN   15173292460903718120   record/2
# /            SYM    2466615745961202537    /
# crawl_timestamp PROPN  2177531639090775180    crawl_timestamp
#                                                        SPACE  16482185863778234133
# record/2     PROPN  15173292460903718120   record/2
# /            SYM    2466615745961202537    /
# job_url      X      3899865007845437402    job_url
#                   SPACE  9687856286444532230
# record/2     PROPN  15173292460903718120   record/2
# /            SYM    2466615745961202537    /
# title        NOUN   4059498964464840598    title
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     SPACE  7491762519203936930
# record/2     PROPN  15173292460903718120   record/2
# /            SYM    2466615745961202537    /
# description  NOUN   15699362302781265145   description
# record/2     NOUN   15173292460903718120   record/2
# /            SYM    2466615745961202537    /
# location     NOUN   4272944830542554761    location
#                        SPACE  15641042832978725572
# record/2     PROPN  15173292460903718120   record/2
# /            SYM    2466615745961202537    /
# category     NOUN   12545855305924804326   category
#              SPACE  8532415787641010193
# record/2     PROPN  15173292460903718120   record/2
# /            SYM    2466615745961202537    /
# job_id       PROPN  11543310256069391702   job_id
#              SPACE  17579141535385064505
# record/2     PROPN  15173292460903718120   record/2
# /            SYM    2466615745961202537    /
# company_name PROPN  4949911190484699260    company_name
#                   SPACE  9687856286444532230
# record/3     PROPN  8372902930140136488    record/3
# /            SYM    2466615745961202537    /
# uniq_id      PROPN  18318867001484744910   uniq_id
#              SPACE  12127836336259238092
# record/3     X      8372902930140136488    record/3
# /            SYM    2466615745961202537    /
# crawl_timestamp PROPN  2177531639090775180    crawl_timestamp
#                                         SPACE  12825308331802534044
# record/3     PROPN  8372902930140136488    record/3
# /            SYM    2466615745961202537    /
# job_url      X      3899865007845437402    job_url
#              SPACE  12127836336259238092
# record/3     NOUN   8372902930140136488    record/3
# /            SYM    2466615745961202537    /
# title        NOUN   4059498964464840598    title
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  SPACE  3022532534158112321                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# record/3     X      8372902930140136488    record/3
# /            SYM    2466615745961202537    /
# description  NOUN   15699362302781265145   description
# record/3     PROPN  8372902930140136488    record/3
# /            SYM    2466615745961202537    /
# location     NOUN   4272944830542554761    location
#                        SPACE  15641042832978725572
# record/3     PROPN  8372902930140136488    record/3
# /            SYM    2466615745961202537    /
# category     NOUN   12545855305924804326   category
#              SPACE  8532415787641010193
# record/3     X      8372902930140136488    record/3
# /            SYM    2466615745961202537    /
# job_id       PROPN  11543310256069391702   job_id
#              SPACE  17579141535385064505
# record/3     PROPN  8372902930140136488    record/3
# /            SYM    2466615745961202537    /
# company_name PROPN  4949911190484699260    company_name
#                   SPACE  9687856286444532230
# record/4     PROPN  7631418976736226495    record/4
# /            SYM    2466615745961202537    /
# uniq_id      PROPN  18318867001484744910   uniq_id
#              SPACE  12127836336259238092
# record/4     PUNCT  7631418976736226495    record/4
# /            SYM    2466615745961202537    /
# crawl_timestamp PROPN  2177531639090775180    crawl_timestamp
#                                                 SPACE  18238821423149713435
# record/4     PUNCT  7631418976736226495    record/4
# /            SYM    2466615745961202537    /
# job_url      X      3899865007845437402    job_url
#              SPACE  14267765035303216250
# record/4     PROPN  7631418976736226495    record/4
# /            SYM    2466615745961202537    /
# title        NOUN   4059498964464840598    title
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  SPACE  9474822926421247557                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# record/4     NOUN   7631418976736226495    record/4
# /            SYM    2466615745961202537    /
# description  NOUN   15699362302781265145   description
# record/4     NOUN   7631418976736226495    record/4
# /            SYM    2466615745961202537    /
# location     NOUN   4272944830542554761    location
#                     SPACE  3279268888731716531
# record/4     PROPN  7631418976736226495    record/4
# /            SYM    2466615745961202537    /
# category     NOUN   12545855305924804326   category
#              SPACE  8532415787641010193
# record/4     PUNCT  7631418976736226495    record/4
# /            SYM    2466615745961202537    /
# job_id       PROPN  11543310256069391702   job_id
#              SPACE  11427293743432821961
# record/4     PROPN  7631418976736226495    record/4
# /            SYM    2466615745961202537    /
# company_name PROPN  4949911190484699260    company_name
#                   SPACE  9687856286444532230
# record/5     PROPN  3929411870428732994    record/5
# /            SYM    2466615745961202537    /
# uniq_id      NUM    18318867001484744910   uniq_id
#              SPACE  12127836336259238092
# record/5     NOUN   3929411870428732994    record/5
# /            SYM    2466615745961202537    /
# crawl_timestamp PROPN  2177531639090775180    crawl_timestamp
#                                                          SPACE  15678592580573368695
# record/5     PROPN  3929411870428732994    record/5
# /            PUNCT  2466615745961202537    /
# job_url      X      3899865007845437402    job_url
#                      SPACE  7673489056978492252
# record/5     PROPN  3929411870428732994    record/5
# /            SYM    2466615745961202537    /
# title        NOUN   4059498964464840598    title
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            SPACE  3726190834242507141                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# record/5     NOUN   3929411870428732994    record/5
# /            SYM    2466615745961202537    /
# description  NOUN   15699362302781265145   description
# record/5     NOUN   3929411870428732994    record/5
# /            SYM    2466615745961202537    /
# location     NOUN   4272944830542554761    location
#                     SPACE  3279268888731716531
# record/5     PROPN  3929411870428732994    record/5
# /            SYM    2466615745961202537    /
# category     NOUN   12545855305924804326   category
#              SPACE  8532415787641010193
# record/5     PROPN  3929411870428732994    record/5
# /            SYM    2466615745961202537    /
# job_id       PROPN  11543310256069391702   job_id
#              SPACE  11427293743432821961
# record/5     PROPN  3929411870428732994    record/5
# /            SYM    2466615745961202537    /
# company_name PROPN  4949911190484699260    company_name
#                   SPACE  9687856286444532230
# record/6     PROPN  9389122415142509300    record/6
# /            SYM    2466615745961202537    /
# uniq_id      PROPN  18318867001484744910   uniq_id
#              SPACE  12127836336259238092
# record/6     PUNCT  9389122415142509300    record/6
# /            SYM    2466615745961202537    /
# crawl_timestamp PROPN  2177531639090775180    crawl_timestamp
#                                                SPACE  8393971429755204367
# record/6     PROPN  9389122415142509300    record/6
# /            SYM    2466615745961202537    /
# job_url      PROPN  3899865007845437402    job_url
#              SPACE  11427293743432821961
# record/6     PROPN  9389122415142509300    record/6
# /            SYM    2466615745961202537    /
# title        NOUN   4059498964464840598    title
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           SPACE  4133763047620830112                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# record/6     NOUN   9389122415142509300    record/6
# /            SYM    2466615745961202537    /
# description  NOUN   15699362302781265145   description
# record/6     PUNCT  9389122415142509300    record/6
# /            SYM    2466615745961202537    /
# location     PROPN  4272944830542554761    location
#                     SPACE  3279268888731716531
# record/6     PROPN  9389122415142509300    record/6
# /            SYM    2466615745961202537    /
# category     NOUN   12545855305924804326   category
#              SPACE  8532415787641010193
# record/6     PROPN  9389122415142509300    record/6
# /            SYM    2466615745961202537    /
# job_id       PROPN  11543310256069391702   job_id
#              SPACE  11427293743432821961
# record/6     PROPN  9389122415142509300    record/6
# /            SYM    2466615745961202537    /
# company_name PROPN  4949911190484699260    company_name
#                   SPACE  9687856286444532230
# record/7     PROPN  11787185413474961486   record/7
# /            SYM    2466615745961202537    /
# uniq_id      PROPN  18318867001484744910   uniq_id
#              SPACE  12127836336259238092
# record/7     X      11787185413474961486   record/7
# /            SYM    2466615745961202537    /
# crawl_timestamp PROPN  2177531639090775180    crawl_timestamp
#                                                      SPACE  7706328773537405150
# record/7     PROPN  11787185413474961486   record/7
# /            SYM    2466615745961202537    /
# job_url      X      3899865007845437402    job_url
#                  SPACE  18141116546261537062
# record/7     PROPN  11787185413474961486   record/7
# /            SYM    2466615745961202537    /
# title        NOUN   4059498964464840598    title
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          SPACE  17617759029641844863
# record/7     PROPN  11787185413474961486   record/7
# /            SYM    2466615745961202537    /
# description  NOUN   15699362302781265145   description
# record/7     PROPN  11787185413474961486   record/7
# /            SYM    2466615745961202537    /
# location     PROPN  4272944830542554761    location
#              SPACE  17579141535385064505
# record/7     PROPN  11787185413474961486   record/7
# /            SYM    2466615745961202537    /
# category     NOUN   12545855305924804326   category
#              SPACE  8532415787641010193
# record/7     PROPN  11787185413474961486   record/7
# /            SYM    2466615745961202537    /
# job_id       PROPN  11543310256069391702   job_id
#              SPACE  17579141535385064505
# record/7     PROPN  11787185413474961486   record/7
# /            SYM    2466615745961202537    /
# company_name PROPN  4949911190484699260    company_name
#                   SPACE  9687856286444532230
# record/8     PROPN  13893748529658577671   record/8
# /            SYM    2466615745961202537    /
# uniq_id      PROPN  18318867001484744910   uniq_id
#              SPACE  12127836336259238092
# record/8     PROPN  13893748529658577671   record/8
# /            SYM    2466615745961202537    /
# crawl_timestamp PROPN  2177531639090775180    crawl_timestamp
#                                            SPACE  16616940001321289713
# record/8     PROPN  13893748529658577671   record/8
# /            PUNCT  2466615745961202537    /
# job_url      PROPN  3899865007845437402    job_url
#              SPACE  17579141535385064505
# record/8     PROPN  13893748529658577671   record/8
# /            SYM    2466615745961202537    /
# title        NOUN   4059498964464840598    title
# ...
# as           ADV    7437575085468336610    as
# well         ADV    4525988469032889948    well
# as           SCONJ  7437575085468336610    as
# manage       VERB   16342131796647358051   manage
# client       NOUN   10852021146411011557   client
# expectations NOUN   14115759321026111728   expectation
# during       ADP    16172899360071598086   during
# the          DET    7425985699627899538    the
# engagement   NOUN   10272974437208788339   engagement
# .            PUNCT  12646065887601541794   .
# ·            PUNCT  658638836119262832     ·
# Takes        VERB   6789454535283781228    take
# proactive    ADJ    11019961304058235489   proactive
# steps        NOUN   4645701992108298564    step
# to           PART   3791531372978436496    to
# ensure       VERB   15159758025291269046   ensure
# teams        NOUN   4303356597303500170    team
# meet         VERB   6880656908171229526    meet
# or           CCONJ  3740602843040177340    or
# exceed       VERB   10325036181672007798   exceed
# customer     NOUN   14759225161440374483   customer
# expectations NOUN   14115759321026111728   expectation
# .            PUNCT  12646065887601541794   .
# ·            PUNCT  658638836119262832     ·
# Works        VERB   10038440415813069799   work
# effectively  ADV    6784290887568980553    effectively
# in           ADP    3002984154512732771    in
# a            DET    11901859001352538922   a
# dynamic      ADJ    3506062363670148130    dynamic
# environment  NOUN   16709044843282783534   environment
# with         ADP    12510949447758279278   with
# changing     VERB   3979101002134440957    change
# priorities   NOUN   9968779605669014735    priority
# .            PUNCT  12646065887601541794   .
# ·            PUNCT  658638836119262832     ·
# Results      NOUN   16479863421078305451   result
# -            PUNCT  9153284864653046197    -
# oriented     VERB   16915394698671438349   orient
# ,            PUNCT  2593208677638477497    ,
# prioritizes  NOUN   7394390246409488321    prioritize
# work         NOUN   10038440415813069799   work
# activities   NOUN   14741564733023616354   activity
# ,            PUNCT  2593208677638477497    ,
# plans        NOUN   6610255016299222351    plan
# and          CCONJ  2283656566040971221    and
# stays        NOUN   15684468530116715331   stay
# organized    VERB   5723289482389263840    organize
# in           ADP    3002984154512732771    in
# order        NOUN   13136985495629980461   order
# to           PART   3791531372978436496    to
# meet         VERB   6880656908171229526    meet
# commitments  NOUN   15101176271007702840   commitment
# .            PUNCT  12646065887601541794   .
# COMMUNICATION PROPN  14496752287410108423   COMMUNICATION
# ·            PUNCT  658638836119262832     ·
# Outstanding  PROPN  1290281167296812434    Outstanding
# written      VERB   15597474948775060119   write
# and          CCONJ  2283656566040971221    and
# verbal       ADJ    3137397719575896324    verbal
# communication NOUN   3997826077466872131    communication
# skills       NOUN   15048162888359431889   skill
# with         ADP    12510949447758279278   with
# team         NOUN   4303356597303500170    team
# members      NOUN   14721843519903598875   member
# and          CCONJ  2283656566040971221    and
# audiences    NOUN   1887105629196476915    audience
# of           ADP    886050111519832510     of
# all          DET    13409319323822384369   all
# levels       NOUN   15060127769916968652   level
# .            PUNCT  12646065887601541794   .
# ·            PUNCT  658638836119262832     ·
# Interfaces   NOUN   10918538201279686601   interface
# with         ADP    12510949447758279278   with
# various      ADJ    15505458595570984623   various
# customer     NOUN   14759225161440374483   customer
# and          CCONJ  2283656566040971221    and
# internal     ADJ    6956465441722722121    internal
# AWS          PROPN  3858756788708896167    AWS
# stakeholders NOUN   7143813683338293920    stakeholder
# which        DET    7063653163634019529    which
# consists     VERB   13300951158337658757   consist
# of           ADP    886050111519832510     of
# senior       ADJ    17934676104927248284   senior
# leadership   NOUN   12348383610936207933   leadership
# teams        NOUN   4303356597303500170    team
# (            PUNCT  12638816674900267446   (
# C            NOUN   16900879642891266615   c
# -            PUNCT  9153284864653046197    -
# level        NOUN   15060127769916968652   level
# execs        NOUN   128316955046734635     execs
# ,            PUNCT  2593208677638477497    ,
# SVP          PROPN  1514606616856833997    SVP
# /            SYM    2466615745961202537    /
# VP           PROPN  4971034725327601250    VP
# ,            PUNCT  2593208677638477497    ,
# Directors    NOUN   269131395021514181     director
# )            PUNCT  3842344029291005339    )
# and          CCONJ  2283656566040971221    and
# project      NOUN   10994073736148868485   project
# level        NOUN   15060127769916968652   level
# resources    NOUN   18066197654291781363   resource
# such         ADJ    13040105543478938413   such
# as           SCONJ  7437575085468336610    as
# SMEs         NOUN   7849908647976580842    sme
# .            PUNCT  12646065887601541794   .
# ·            PUNCT  658638836119262832     ·
# Plans        NOUN   6610255016299222351    plan
# and          CCONJ  2283656566040971221    and
# oversees     VERB   4593634169573578677    oversee
# the          DET    7425985699627899538    the
# preparation  NOUN   11893607816483184616   preparation
# and          CCONJ  2283656566040971221    and
# dissemination NOUN   13909457812695262391   dissemination
# of           ADP    886050111519832510     of
# project      NOUN   10994073736148868485   project
# communications NOUN   3997826077466872131    communication
# .            PUNCT  12646065887601541794   .
# ·            PUNCT  658638836119262832     ·
# Demonstrates VERB   5547305781669311980    demonstrate
# the          DET    7425985699627899538    the
# ability      NOUN   11565809527369121409   ability
# to           PART   3791531372978436496    to
# understand   VERB   2256871070683278179    understand
# the          DET    7425985699627899538    the
# operating    VERB   9854540405589975553    operate
# styles       NOUN   11923606697255677998   style
# of           ADP    886050111519832510     of
# others       NOUN   1176656782636220709    other
# as           ADV    7437575085468336610    as
# well         ADV    4525988469032889948    well
# as           SCONJ  7437575085468336610    as
# team         NOUN   4303356597303500170    team
# /            SYM    2466615745961202537    /
# client       NOUN   10852021146411011557   client
# relationships NOUN   3329440288606200168    relationship
# ,            PUNCT  2593208677638477497    ,
# team         NOUN   4303356597303500170    team
# dynamics     NOUN   3506062363670148130    dynamic
# ,            PUNCT  2593208677638477497    ,
# and          CCONJ  2283656566040971221    and
# adjusts      NOUN   12254408354648292678   adjust
# behavior     NOUN   12571187882446423527   behavior
# accordingly  ADV    8255362438685088826    accordingly
# to           PART   3791531372978436496    to
# succeed      VERB   8588752623551235015    succeed
# .            PUNCT  12646065887601541794   .
# Recognizes   PROPN  18125366910276118081   Recognizes
# environmental ADJ    15091995114702057010   environmental
# or           CCONJ  3740602843040177340    or
# cultural     ADJ    14167363690842711897   cultural
# nuances      NOUN   13163337371923817971   nuance
# and          CCONJ  2283656566040971221    and
# adapts       NOUN   4490312319112527657    adapt
# .            PUNCT  12646065887601541794   .
# ·            PUNCT  658638836119262832     ·
# Excellent    ADJ    11137614687254113498   excellent
# presentation NOUN   12296841845045627053   presentation
# ,            PUNCT  2593208677638477497    ,
# communication NOUN   3997826077466872131    communication
# (            PUNCT  12638816674900267446   (
# oral         PROPN  10806071269752920667   oral
# &            CCONJ  15473034735919704609   &
# written      VERB   15597474948775060119   write
# )            PUNCT  3842344029291005339    )
# ,            PUNCT  2593208677638477497    ,
# and          CCONJ  2283656566040971221    and
# relationship NOUN   3329440288606200168    relationship
# building     NOUN   12544948182236414430   building
# skills       NOUN   15048162888359431889   skill
# ,            PUNCT  2593208677638477497    ,
# across       ADP    12865022372469924430   across
# all          DET    13409319323822384369   all
# levels       NOUN   15060127769916968652   level
# of           ADP    886050111519832510     of
# management   NOUN   1454996307668600469    management
# .            PUNCT  12646065887601541794   .
# TEAMING      NOUN   18026710229660598184   teaming
# ·            PUNCT  658638836119262832     ·
# Proven       ADJ    3820635118947225009    proven
# success      NOUN   16089821935113899987   success
# in           ADP    3002984154512732771    in
# working      VERB   10038440415813069799   work
# with         ADP    12510949447758279278   with
# teams        NOUN   4303356597303500170    team
# and          CCONJ  2283656566040971221    and
# executive    ADJ    14727885303214594713   executive
# leadership   NOUN   12348383610936207933   leadership
# in           ADP    3002984154512732771    in
# a            DET    11901859001352538922   a
# complex      ADJ    11125307656307208867   complex
# ,            PUNCT  2593208677638477497    ,
# global       ADJ    17053192215331816304   global
# company      NOUN   6905553075311563409    company
# environment  NOUN   16709044843282783534   environment
# .            PUNCT  12646065887601541794   .
# ·            PUNCT  658638836119262832     ·
# Team         NOUN   4303356597303500170    team
# player       NOUN   3885285634180617021    player
# who          PRON   3876862883474502309    who
# effectively  ADV    6784290887568980553    effectively
# integrates   VERB   14935986945223263592   integrate
# ,            PUNCT  2593208677638477497    ,
# motivates    NOUN   2427514414050757706    motivate
# and          CCONJ  2283656566040971221    and
# builds       VERB   15542623189494043735   build
# relationships NOUN   3329440288606200168    relationship
# with         ADP    12510949447758279278   with
# cross        ADJ    8734324568794052990    cross
# -            ADJ    9153284864653046197    -
# functional   ADJ    8749041279847911972    functional
# team         NOUN   4303356597303500170    team
# members      NOUN   14721843519903598875   member
# (            PUNCT  12638816674900267446   (
# local        ADJ    16319852998319793599   local
# or           CCONJ  3740602843040177340    or
# remote       ADJ    3009338867599940128    remote
# )            PUNCT  3842344029291005339    )
# ,            PUNCT  2593208677638477497    ,
# sponsors     NOUN   9913921232984826988    sponsor
# ,            PUNCT  2593208677638477497    ,
# key          ADJ    12247610008914253561   key
# stakeholders NOUN   7143813683338293920    stakeholder
# ,            PUNCT  2593208677638477497    ,
# executives   NOUN   14727885303214594713   executive
# ,            PUNCT  2593208677638477497    ,
# and          CCONJ  2283656566040971221    and
# other        ADJ    1176656782636220709    other
# individuals  NOUN   15424120832172538961   individual
# or           CCONJ  3740602843040177340    or
# organizations NOUN   15435089905045195647   organization
# involved     VERB   10316718014565377194   involve
# with         ADP    12510949447758279278   with
# or           CCONJ  3740602843040177340    or
# affected     VERB   17543419487618836897   affect
# by           ADP    16764210730586636600   by
# the          DET    7425985699627899538    the
# project      NOUN   10994073736148868485   project
# .            PUNCT  12646065887601541794   .
# ·            PUNCT  658638836119262832     ·
# Proven       ADJ    3820635118947225009    proven
# experience   NOUN   12090100147684300169   experience
# working      VERB   10038440415813069799   work
# in           ADP    3002984154512732771    in
# a            DET    11901859001352538922   a
# matrix       NOUN   11345786522433259331   matrix
# environment  NOUN   16709044843282783534   environment
# ,            PUNCT  2593208677638477497    ,
# managing     VERB   16342131796647358051   manage
# multiple     ADJ    16628341085578573424   multiple
# stakeholders NOUN   7143813683338293920    stakeholder
# .            PUNCT  12646065887601541794   .
# ·            PUNCT  658638836119262832     ·
# Negotiation  NOUN   4898394642952175633    negotiation
# and          CCONJ  2283656566040971221    and
# conflict     NOUN   1656665257010592753    conflict
# resolution   NOUN   12218664377615122786   resolution
# capabilities NOUN   10129303448580826007   capability
# .            PUNCT  12646065887601541794   .
# ·            PUNCT  658638836119262832     ·
# Excellent    ADJ    11137614687254113498   excellent
# people       NOUN   7593739049417968140    people
# management   NOUN   1454996307668600469    management
# skills       NOUN   15048162888359431889   skill
# ,            PUNCT  2593208677638477497    ,
# including    VERB   14049642289933595219   include
# the          DET    7425985699627899538    the
# ability      NOUN   11565809527369121409   ability
# to           PART   3791531372978436496    to
# influence    VERB   6113139012427377515    influence
# ,            PUNCT  2593208677638477497    ,
# negotiate    VERB   13817489830196363743   negotiate
# and          CCONJ  2283656566040971221    and
# achieve      VERB   1478592441673796122    achieve
# results      NOUN   16479863421078305451   result
# through      ADP    18216413589307435838   through
# others       NOUN   1176656782636220709    other
# who          PRON   3876862883474502309    who
# are          AUX    10382539506755952630   be
# not          PART   447765159362469301     not
# direct       ADJ    3396428638438620601    direct
# reports      NOUN   2729752284408055516    report
# .            PUNCT  12646065887601541794   .
# This         DET    1995909169258310477    this
# is           AUX    10382539506755952630   be
# a            DET    11901859001352538922   a
# customer     NOUN   14759225161440374483   customer
# facing       NOUN   3797421210655036452    facing
# role         NOUN   15289190992820506615   role
# .            PUNCT  12646065887601541794   .
# You          PRON   561228191312463089     -PRON-
# be           AUX    10382539506755952630   be
# required     VERB   9094995078650759376    require
# to           PART   3791531372978436496    to
# travel       VERB   9016120516514741834    travel
# to           ADP    3791531372978436496    to
# client       NOUN   10852021146411011557   client
# locations    NOUN   4272944830542554761    location
# to           PART   3791531372978436496    to
# deliver      VERB   9306182646126209050    deliver
# professional ADJ    1628340908579922823    professional
# services     NOUN   208172016153456603     service
# when         ADV    15807309897752499399   when
# needed       VERB   478886015463313967     need
# .            PUNCT  12646065887601541794   .
#              SPACE  6718839663412986256
# US           PROPN  15397641858402276818   US
# ,            PUNCT  2593208677638477497    ,
# CA           PROPN  8902657483871908647    CA
# ,            PUNCT  2593208677638477497    ,
# Irvine       PROPN  15294118415578089826   Irvine
#              SPACE  8532415787641010193
# Project      PROPN  5641902175427286826    Project
# /            SYM    2466615745961202537    /
# Program      PROPN  5553474545235520872    Program
# /            SYM    2466615745961202537    /
# Product      PROPN  16898055450696666743   Product
# Management   PROPN  11401798372640567787   Management
# --           PUNCT  10501404726543969396   --
# Technical    PROPN  17150435118023439842   Technical
#              SPACE  11427293743432821961
# 986871       NUM    14018198514096163487   986871
#              SPACE  8532415787641010193
# Amazon       PROPN  7854762596996286480    Amazon
# Web          PROPN  4796059894154151487    Web
# Services     PROPN  16271719928879294026   Services
# ,            PUNCT  2593208677638477497    ,
# Inc.         PROPN  11367013928689839740   Inc.

# %%
for token in doc:
    print(f'{token.text:{10}} {token.pos_:{10}} {token.dep_:{10}} {spacy.explain(token.dep_)}')
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                  SPACE                 None
# pageurl    NOUN       ROOT       None
#                   SPACE                 None
# record/0   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# uniq_id    PROPN      intj       interjection
#            SPACE                 None
# record/0   X          nmod       modifier of nominal
# /          SYM        punct      punctuation
# crawl_timestamp PROPN      nmod       modifier of nominal
#                                                         SPACE                 None
# record/0   PROPN      ROOT       None
# /          SYM        punct      punctuation
# job_url    X          ROOT       None
#                    SPACE                 None
# record/0   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# title      NOUN       nmod       modifier of nominal
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     SPACE                 None
# record/0   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# description NOUN       nmod       modifier of nominal
# record/0   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# location   NOUN       nmod       modifier of nominal
#            SPACE                 None
# record/0   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# category   NOUN       ROOT       None
#            SPACE                 None
# record/0   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# job_id     PROPN      ROOT       None
#            SPACE                 None
# record/0   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# company_name PROPN      ROOT       None
#                   SPACE                 None
# record/1   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# uniq_id    PROPN      ROOT       None
#            SPACE                 None
# record/1   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# crawl_timestamp PROPN      nmod       modifier of nominal
#                                                        SPACE                 None
# record/1   PROPN      ROOT       None
# /          PUNCT      punct      punctuation
# job_url    X          punct      punctuation
#                   SPACE                 None
# record/1   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# title      NOUN       ROOT       None
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                SPACE                 None
# record/1   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# description NOUN       ROOT       None
#            SPACE                 None
# record/1   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# location   PROPN      nmod       modifier of nominal
#            SPACE                 None
# record/1   PROPN      ROOT       None
# /          SYM        punct      punctuation
# category   NOUN       intj       interjection
#            SPACE                 None
# record/1   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# job_id     PROPN      intj       interjection
#            SPACE                 None
# record/1   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# company_name PROPN      intj       interjection
#                   SPACE                 None
# record/2   PROPN      appos      appositional modifier
# /          SYM        punct      punctuation
# uniq_id    PROPN      ROOT       None
#            SPACE                 None
# record/2   NOUN       intj       interjection
# /          SYM        punct      punctuation
# crawl_timestamp PROPN      intj       interjection
#                                                        SPACE                 None
# record/2   PROPN      appos      appositional modifier
# /          SYM        punct      punctuation
# job_url    X          punct      punctuation
#                   SPACE                 None
# record/2   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# title      NOUN       nmod       modifier of nominal
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     SPACE                 None
# record/2   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# description NOUN       nmod       modifier of nominal
# record/2   NOUN       nmod       modifier of nominal
# /          SYM        punct      punctuation
# location   NOUN       nmod       modifier of nominal
#                        SPACE                 None
# record/2   PROPN      ROOT       None
# /          SYM        punct      punctuation
# category   NOUN       intj       interjection
#            SPACE                 None
# record/2   PROPN      appos      appositional modifier
# /          SYM        punct      punctuation
# job_id     PROPN      npadvmod   noun phrase as adverbial modifier
#            SPACE                 None
# record/2   PROPN      appos      appositional modifier
# /          SYM        punct      punctuation
# company_name PROPN      npadvmod   noun phrase as adverbial modifier
#                   SPACE                 None
# record/3   PROPN      dobj       direct object
# /          SYM        punct      punctuation
# uniq_id    PROPN      ROOT       None
#            SPACE                 None
# record/3   X          nmod       modifier of nominal
# /          SYM        punct      punctuation
# crawl_timestamp PROPN      nmod       modifier of nominal
#                                         SPACE                 None
# record/3   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# job_url    X          punct      punctuation
#            SPACE                 None
# record/3   NOUN       nmod       modifier of nominal
# /          SYM        punct      punctuation
# title      NOUN       nmod       modifier of nominal
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  SPACE                 None
# record/3   X          nmod       modifier of nominal
# /          SYM        punct      punctuation
# description NOUN       nmod       modifier of nominal
# record/3   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# location   NOUN       nmod       modifier of nominal
#                        SPACE                 None
# record/3   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# category   NOUN       nmod       modifier of nominal
#            SPACE                 None
# record/3   X          nmod       modifier of nominal
# /          SYM        punct      punctuation
# job_id     PROPN      nmod       modifier of nominal
#            SPACE                 None
# record/3   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# company_name PROPN      nmod       modifier of nominal
#                   SPACE                 None
# record/4   PROPN      intj       interjection
# /          SYM        punct      punctuation
# uniq_id    PROPN      nummod     numeric modifier
#            SPACE                 None
# record/4   PUNCT      nmod       modifier of nominal
# /          SYM        punct      punctuation
# crawl_timestamp PROPN      nmod       modifier of nominal
#                                                 SPACE                 None
# record/4   PUNCT      intj       interjection
# /          SYM        punct      punctuation
# job_url    X          punct      punctuation
#             SPACE                 None
# record/4   PROPN      dobj       direct object
# /          SYM        punct      punctuation
# title      NOUN       nmod       modifier of nominal
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  SPACE                 None
# record/4   NOUN       nmod       modifier of nominal
# /          SYM        punct      punctuation
# description NOUN       nmod       modifier of nominal
# record/4   NOUN       amod       adjectival modifier
# /          SYM        punct      punctuation
# location   NOUN       nmod       modifier of nominal
#                     SPACE                 None
# record/4   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# category   NOUN       dobj       direct object
#            SPACE                 None
# record/4   PUNCT      intj       interjection
# /          SYM        punct      punctuation
# job_id     PROPN      intj       interjection
#            SPACE                 None
# record/4   PROPN      ROOT       None
# /          SYM        punct      punctuation
# company_name PROPN      npadvmod   noun phrase as adverbial modifier
#                   SPACE                 None
# record/5   PROPN      ROOT       None
# /          SYM        punct      punctuation
# uniq_id    NUM        ROOT       None
#            SPACE                 None
# record/5   NOUN       ROOT       None
# /          SYM        punct      punctuation
# crawl_timestamp PROPN      nmod       modifier of nominal
#                                                          SPACE                 None
# record/5   PROPN      ROOT       None
# /          PUNCT      punct      punctuation
# job_url    X          ROOT       None
#                      SPACE                 None
# record/5   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# title      NOUN       nmod       modifier of nominal
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            SPACE                 None
# record/5   NOUN       nmod       modifier of nominal
# /          SYM        punct      punctuation
# description NOUN       nmod       modifier of nominal
# record/5   NOUN       nmod       modifier of nominal
# /          SYM        punct      punctuation
# location   NOUN       ROOT       None
#                     SPACE                 None
# record/5   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# category   NOUN       ROOT       None
#            SPACE                 None
# record/5   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# job_id     PROPN      ROOT       None
#            SPACE                 None
# record/5   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# company_name PROPN      ROOT       None
#                   SPACE                 None
# record/6   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# uniq_id    PROPN      ROOT       None
#            SPACE                 None
# record/6   PUNCT      nmod       modifier of nominal
# /          SYM        punct      punctuation
# crawl_timestamp PROPN      nmod       modifier of nominal
#                                                SPACE                 None
# record/6   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# job_url    PROPN      punct      punctuation
#            SPACE                 None
# record/6   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# title      NOUN       nmod       modifier of nominal
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           SPACE                 None
# record/6   NOUN       nmod       modifier of nominal
# /          SYM        punct      punctuation
# description NOUN       nmod       modifier of nominal
# record/6   PUNCT      nmod       modifier of nominal
# /          SYM        punct      punctuation
# location   PROPN      dobj       direct object
#                     SPACE                 None
# record/6   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# category   NOUN       nmod       modifier of nominal
#            SPACE                 None
# record/6   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# job_id     PROPN      conj       conjunct
#            SPACE                 None
# record/6   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# company_name PROPN      conj       conjunct
#                   SPACE                 None
# record/7   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# uniq_id    PROPN      ROOT       None
#            SPACE                 None
# record/7   X          appos      appositional modifier
# /          SYM        punct      punctuation
# crawl_timestamp PROPN      intj       interjection
#                                                      SPACE                 None
# record/7   PROPN      ROOT       None
# /          SYM        punct      punctuation
# job_url    X          ROOT       None
#                  SPACE                 None
# record/7   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# title      NOUN       nmod       modifier of nominal
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          SPACE                 None
# record/7   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# description NOUN       nmod       modifier of nominal
# record/7   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# location   PROPN      intj       interjection
#            SPACE                 None
# record/7   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# category   NOUN       nmod       modifier of nominal
#            SPACE                 None
# record/7   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# job_id     PROPN      conj       conjunct
#            SPACE                 None
# record/7   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# company_name PROPN      ROOT       None
#                   SPACE                 None
# record/8   PROPN      ROOT       None
# /          SYM        punct      punctuation
# uniq_id    PROPN      ROOT       None
#            SPACE                 None
# record/8   PROPN      ROOT       None
# /          SYM        punct      punctuation
# crawl_timestamp PROPN      intj       interjection
#                                            SPACE                 None
# record/8   PROPN      appos      appositional modifier
# /          PUNCT      punct      punctuation
# job_url    PROPN      ROOT       None
#            SPACE                 None
# record/8   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# title      NOUN       nmod       modifier of nominal
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      SPACE                 None
# record/8   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# description NOUN       nmod       modifier of nominal
# record/8   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# location   PROPN      nmod       modifier of nominal
# record/8   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# category   NOUN       ROOT       None
#            SPACE                 None
# record/8   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# job_id     PROPN      ROOT       None
#            SPACE                 None
# record/8   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# company_name PROPN      ROOT       None
#                   SPACE                 None
# record/9   PROPN      ROOT       None
# /          SYM        punct      punctuation
# uniq_id    PROPN      ROOT       None
#            SPACE                 None
# record/9   PROPN      ROOT       None
# /          SYM        punct      punctuation
# crawl_timestamp PROPN      intj       interjection
#                                                                         SPACE                 None
# record/9   PROPN      appos      appositional modifier
# /          SYM        punct      punctuation
# job_url    X          ROOT       None
#                                      SPACE                 None
# record/9   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# title      NOUN       ROOT       None
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# record/9   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# description NOUN       nmod       modifier of nominal
# record/9   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# location   NOUN       ROOT       None
#                               SPACE                 None
# record/9   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# category   NOUN       nmod       modifier of nominal
#            SPACE                 None
# record/9   PUNCT      ROOT       None
# /          SYM        punct      punctuation
# job_id     PROPN      nmod       modifier of nominal
#            SPACE                 None
# record/9   PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# company_name PROPN      ROOT       None
#
#           SPACE                 None
# 0          NUM        appos      appositional modifier
#            SPACE                 None
# https://www.amazon.jobs/en/search.json?base_query=&city=&country=&county=&facets%5B%5D=location&facets%5B%5D=business_category&facets%5B%5D=category&facets%5B%5D=schedule_type_id&facets%5B%5D=employee_class&facets%5B%5D=normalized_location&facets%5B%5D=job_function_id&latitude=&loc_group_id=&loc_query=United+States&longitude=&offset=1530&query_options=&radius=24km&region=&result_limit=10&sort=relevant ADJ        nmod       modifier of nominal
#            SPACE                 None
# 850f0199e2ce9d1d51ee5e2e11318d94 NUM        nummod     numeric modifier
#            SPACE                 None
# 2019       NUM        nummod     numeric modifier
# -          SYM        punct      punctuation
# 11         NUM        nummod     numeric modifier
# -          SYM        punct      punctuation
# 15         NUM        prep       prepositional modifier
# 00:15:23   NUM        punct      punctuation
# +0000      PROPN      intj       interjection
#            SPACE                 None
# https://www.amazon.jobs/en/jobs/986897/software-development-engineer-i ADJ        intj       interjection
#            SPACE                 None
# Software   PROPN      compound   compound
# Development PROPN      compound   compound
# Engineer   PROPN      nmod       modifier of nominal
# I          PRON       nmod       modifier of nominal
#            SPACE                 None
# Amazon     PROPN      nmod       modifier of nominal
# ’s         PART       punct      punctuation
# Global     PROPN      compound   compound
# Logistics  PROPN      compound   compound
# Technology PROPN      compound   compound
# team       NOUN       nsubjpass  nominal subject (passive)
# is         AUX        auxpass    auxiliary (passive)
# chartered  VERB       ROOT       None
# with       ADP        prep       prepositional modifier
# building   NOUN       compound   compound
# solutions  NOUN       pobj       object of preposition
# for        ADP        prep       prepositional modifier
# international ADJ        amod       adjectival modifier
# movement   NOUN       pobj       object of preposition
# of         ADP        prep       prepositional modifier
# shipments  NOUN       pobj       object of preposition
# which      DET        nsubj      nominal subject
# can        VERB       aux        auxiliary
# originate  VERB       relcl      relative clause modifier
# from       ADP        prep       prepositional modifier
# any        DET        det        determiner
# place      NOUN       pobj       object of preposition
# on         ADP        prep       prepositional modifier
# earth      NOUN       pobj       object of preposition
# ,          PUNCT      punct      punctuation
# cross      VERB       conj       conjunct
# the        DET        det        determiner
# international ADJ        amod       adjectival modifier
# border     NOUN       dobj       direct object
# and        CCONJ      cc         coordinating conjunction
# be         AUX        auxpass    auxiliary (passive)
# delivered  VERB       conj       conjunct
# in         ADP        prep       prepositional modifier
# a          DET        det        determiner
# different  ADJ        amod       adjectival modifier
# part       NOUN       pobj       object of preposition
# of         ADP        prep       prepositional modifier
# planet     NOUN       pobj       object of preposition
# .          PUNCT      punct      punctuation
# There      PRON       expl       expletive
# are        AUX        ROOT       None
# variety    NOUN       attr       attribute
# of         ADP        prep       prepositional modifier
# ways       NOUN       pobj       object of preposition
# in         ADP        prep       prepositional modifier
# which      DET        pobj       object of preposition
# we         PRON       nsubj      nominal subject
# can        VERB       aux        auxiliary
# import     VERB       relcl      relative clause modifier
# shipments  NOUN       dobj       direct object
# from       ADP        prep       prepositional modifier
# vendors    NOUN       nmod       modifier of nominal
# /          SYM        punct      punctuation
# sellers    NOUN       pobj       object of preposition
# to         ADP        prep       prepositional modifier
# our        DET        poss       possession modifier
# warehouses NOUN       pobj       object of preposition
# and        CCONJ      cc         coordinating conjunction
# export     NOUN       compound   compound
# package    NOUN       conj       conjunct
# from       ADP        prep       prepositional modifier
# one        NUM        nummod     numeric modifier
# country    NOUN       pobj       object of preposition
# to         ADP        prep       prepositional modifier
# another    DET        pobj       object of preposition
# through    ADP        prep       prepositional modifier
# several    ADJ        amod       adjectival modifier
# intermediate ADJ        amod       adjectival modifier
# locations  NOUN       pobj       object of preposition
# to         PART       aux        auxiliary
# deliver    VERB       advcl      adverbial clause modifier
# it         PRON       dobj       direct object
# to         ADP        prep       prepositional modifier
# our        DET        poss       possession modifier
# international ADJ        amod       adjectival modifier
# customer   NOUN       pobj       object of preposition
# .          PUNCT      punct      punctuation
# There      PRON       expl       expletive
# are        AUX        ROOT       None
# millions   NOUN       attr       attribute
# of         ADP        prep       prepositional modifier
# such       ADJ        amod       adjectival modifier
# packages   NOUN       pobj       object of preposition
# ,          PUNCT      punct      punctuation
# each       DET        appos      appositional modifier
# with       ADP        prep       prepositional modifier
# different  ADJ        amod       adjectival modifier
# attributes NOUN       pobj       object of preposition
# ,          PUNCT      punct      punctuation
# delivery   NOUN       compound   compound
# requirements NOUN       conj       conjunct
# and        CCONJ      cc         coordinating conjunction
# international ADJ        amod       adjectival modifier
# commerce   NOUN       nmod       modifier of nominal
# and        CCONJ      cc         coordinating conjunction
# customs    PROPN      conj       conjunct
# constraints NOUN       conj       conjunct
# .          PUNCT      punct      punctuation
# What       DET        det        determiner
# results    VERB       nsubj      nominal subject
# is         AUX        ROOT       None
# a          DET        det        determiner
# complex    ADJ        amod       adjectival modifier
# graph      NOUN       attr       attribute
# of         ADP        prep       prepositional modifier
# source     NOUN       pobj       object of preposition
# ,          PUNCT      punct      punctuation
# intermediate ADJ        conj       conjunct
# and        CCONJ      cc         coordinating conjunction
# destination NOUN       conj       conjunct
# nodes      NOUN       npadvmod   noun phrase as adverbial modifier
# with       ADP        prep       prepositional modifier
# ...
# manage     VERB       acl        clausal modifier of noun (adjectival clause)
# client     NOUN       compound   compound
# expectations NOUN       dobj       direct object
# during     ADP        prep       prepositional modifier
# the        DET        det        determiner
# engagement NOUN       pobj       object of preposition
# .          PUNCT      punct      punctuation
# ·          PUNCT      punct      punctuation
# Takes      VERB       acl        clausal modifier of noun (adjectival clause)
# proactive  ADJ        amod       adjectival modifier
# steps      NOUN       dobj       direct object
# to         PART       aux        auxiliary
# ensure     VERB       advcl      adverbial clause modifier
# teams      NOUN       nsubj      nominal subject
# meet       VERB       ccomp      clausal complement
# or         CCONJ      cc         coordinating conjunction
# exceed     VERB       conj       conjunct
# customer   NOUN       compound   compound
# expectations NOUN       dobj       direct object
# .          PUNCT      punct      punctuation
# ·          PUNCT      punct      punctuation
# Works      VERB       conj       conjunct
# effectively ADV        advmod     adverbial modifier
# in         ADP        prep       prepositional modifier
# a          DET        det        determiner
# dynamic    ADJ        amod       adjectival modifier
# environment NOUN       pobj       object of preposition
# with       ADP        prep       prepositional modifier
# changing   VERB       amod       adjectival modifier
# priorities NOUN       pobj       object of preposition
# .          PUNCT      punct      punctuation
# ·          PUNCT      punct      punctuation
# Results    NOUN       npadvmod   noun phrase as adverbial modifier
# -          PUNCT      punct      punctuation
# oriented   VERB       amod       adjectival modifier
# ,          PUNCT      punct      punctuation
# prioritizes NOUN       compound   compound
# work       NOUN       compound   compound
# activities NOUN       dobj       direct object
# ,          PUNCT      punct      punctuation
# plans      NOUN       conj       conjunct
# and        CCONJ      cc         coordinating conjunction
# stays      NOUN       conj       conjunct
# organized  VERB       acl        clausal modifier of noun (adjectival clause)
# in         ADP        prep       prepositional modifier
# order      NOUN       pobj       object of preposition
# to         PART       aux        auxiliary
# meet       VERB       acl        clausal modifier of noun (adjectival clause)
# commitments NOUN       dobj       direct object
# .          PUNCT      punct      punctuation
# COMMUNICATION PROPN      ROOT       None
# ·          PUNCT      punct      punctuation
# Outstanding PROPN      amod       adjectival modifier
# written    VERB       dep        unclassified dependent
# and        CCONJ      cc         coordinating conjunction
# verbal     ADJ        amod       adjectival modifier
# communication NOUN       conj       conjunct
# skills     NOUN       ROOT       None
# with       ADP        prep       prepositional modifier
# team       NOUN       compound   compound
# members    NOUN       pobj       object of preposition
# and        CCONJ      cc         coordinating conjunction
# audiences  NOUN       conj       conjunct
# of         ADP        prep       prepositional modifier
# all        DET        det        determiner
# levels     NOUN       pobj       object of preposition
# .          PUNCT      punct      punctuation
# ·          PUNCT      punct      punctuation
# Interfaces NOUN       nsubj      nominal subject
# with       ADP        prep       prepositional modifier
# various    ADJ        amod       adjectival modifier
# customer   NOUN       pobj       object of preposition
# and        CCONJ      cc         coordinating conjunction
# internal   ADJ        amod       adjectival modifier
# AWS        PROPN      compound   compound
# stakeholders NOUN       conj       conjunct
# which      DET        nsubj      nominal subject
# consists   VERB       relcl      relative clause modifier
# of         ADP        prep       prepositional modifier
# senior     ADJ        amod       adjectival modifier
# leadership NOUN       compound   compound
# teams      NOUN       pobj       object of preposition
# (          PUNCT      punct      punctuation
# C          NOUN       compound   compound
# -          PUNCT      punct      punctuation
# level      NOUN       nmod       modifier of nominal
# execs      NOUN       nmod       modifier of nominal
# ,          PUNCT      punct      punctuation
# SVP        PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# VP         PROPN      appos      appositional modifier
# ,          PUNCT      punct      punctuation
# Directors  NOUN       conj       conjunct
# )          PUNCT      punct      punctuation
# and        CCONJ      cc         coordinating conjunction
# project    NOUN       compound   compound
# level      NOUN       compound   compound
# resources  NOUN       conj       conjunct
# such       ADJ        amod       adjectival modifier
# as         SCONJ      prep       prepositional modifier
# SMEs       NOUN       pobj       object of preposition
# .          PUNCT      punct      punctuation
# ·          PUNCT      punct      punctuation
# Plans      NOUN       conj       conjunct
# and        CCONJ      cc         coordinating conjunction
# oversees   VERB       conj       conjunct
# the        DET        det        determiner
# preparation NOUN       dobj       direct object
# and        CCONJ      cc         coordinating conjunction
# dissemination NOUN       conj       conjunct
# of         ADP        prep       prepositional modifier
# project    NOUN       compound   compound
# communications NOUN       pobj       object of preposition
# .          PUNCT      punct      punctuation
# ·          PUNCT      punct      punctuation
# Demonstrates VERB       ROOT       None
# the        DET        det        determiner
# ability    NOUN       dobj       direct object
# to         PART       aux        auxiliary
# understand VERB       acl        clausal modifier of noun (adjectival clause)
# the        DET        det        determiner
# operating  VERB       compound   compound
# styles     NOUN       dobj       direct object
# of         ADP        prep       prepositional modifier
# others     NOUN       pobj       object of preposition
# as         ADV        advmod     adverbial modifier
# well       ADV        advmod     adverbial modifier
# as         SCONJ      cc         coordinating conjunction
# team       NOUN       nmod       modifier of nominal
# /          SYM        punct      punctuation
# client     NOUN       compound   compound
# relationships NOUN       conj       conjunct
# ,          PUNCT      punct      punctuation
# team       NOUN       compound   compound
# dynamics   NOUN       conj       conjunct
# ,          PUNCT      punct      punctuation
# and        CCONJ      cc         coordinating conjunction
# adjusts    NOUN       compound   compound
# behavior   NOUN       conj       conjunct
# accordingly ADV        advmod     adverbial modifier
# to         PART       aux        auxiliary
# succeed    VERB       relcl      relative clause modifier
# .          PUNCT      punct      punctuation
# Recognizes PROPN      ROOT       None
# environmental ADJ        amod       adjectival modifier
# or         CCONJ      cc         coordinating conjunction
# cultural   ADJ        conj       conjunct
# nuances    NOUN       dobj       direct object
# and        CCONJ      cc         coordinating conjunction
# adapts     NOUN       conj       conjunct
# .          PUNCT      punct      punctuation
# ·          PUNCT      punct      punctuation
# Excellent  ADJ        amod       adjectival modifier
# presentation NOUN       ROOT       None
# ,          PUNCT      punct      punctuation
# communication NOUN       conj       conjunct
# (          PUNCT      punct      punctuation
# oral       PROPN      amod       adjectival modifier
# &          CCONJ      cc         coordinating conjunction
# written    VERB       conj       conjunct
# )          PUNCT      punct      punctuation
# ,          PUNCT      punct      punctuation
# and        CCONJ      cc         coordinating conjunction
# relationship NOUN       compound   compound
# building   NOUN       compound   compound
# skills     NOUN       conj       conjunct
# ,          PUNCT      punct      punctuation
# across     ADP        prep       prepositional modifier
# all        DET        det        determiner
# levels     NOUN       pobj       object of preposition
# of         ADP        prep       prepositional modifier
# management NOUN       pobj       object of preposition
# .          PUNCT      punct      punctuation
# TEAMING    NOUN       ROOT       None
# ·          PUNCT      punct      punctuation
# Proven     ADJ        amod       adjectival modifier
# success    NOUN       appos      appositional modifier
# in         ADP        prep       prepositional modifier
# working    VERB       pcomp      complement of preposition
# with       ADP        prep       prepositional modifier
# teams      NOUN       pobj       object of preposition
# and        CCONJ      cc         coordinating conjunction
# executive  ADJ        amod       adjectival modifier
# leadership NOUN       conj       conjunct
# in         ADP        prep       prepositional modifier
# a          DET        det        determiner
# complex    ADJ        amod       adjectival modifier
# ,          PUNCT      punct      punctuation
# global     ADJ        amod       adjectival modifier
# company    NOUN       compound   compound
# environment NOUN       pobj       object of preposition
# .          PUNCT      punct      punctuation
# ·          PUNCT      punct      punctuation
# Team       NOUN       compound   compound
# player     NOUN       ROOT       None
# who        PRON       nsubj      nominal subject
# effectively ADV        advmod     adverbial modifier
# integrates VERB       relcl      relative clause modifier
# ,          PUNCT      punct      punctuation
# motivates  NOUN       conj       conjunct
# and        CCONJ      cc         coordinating conjunction
# builds     VERB       conj       conjunct
# relationships NOUN       dobj       direct object
# with       ADP        prep       prepositional modifier
# cross      ADJ        dep        unclassified dependent
# -          ADJ        dep        unclassified dependent
# functional ADJ        amod       adjectival modifier
# team       NOUN       compound   compound
# members    NOUN       pobj       object of preposition
# (          PUNCT      punct      punctuation
# local      ADJ        amod       adjectival modifier
# or         CCONJ      cc         coordinating conjunction
# remote     ADJ        conj       conjunct
# )          PUNCT      punct      punctuation
# ,          PUNCT      punct      punctuation
# sponsors   NOUN       conj       conjunct
# ,          PUNCT      punct      punctuation
# key        ADJ        amod       adjectival modifier
# stakeholders NOUN       conj       conjunct
# ,          PUNCT      punct      punctuation
# executives NOUN       conj       conjunct
# ,          PUNCT      punct      punctuation
# and        CCONJ      cc         coordinating conjunction
# other      ADJ        amod       adjectival modifier
# individuals NOUN       conj       conjunct
# or         CCONJ      cc         coordinating conjunction
# organizations NOUN       conj       conjunct
# involved   VERB       acl        clausal modifier of noun (adjectival clause)
# with       ADP        prep       prepositional modifier
# or         CCONJ      cc         coordinating conjunction
# affected   VERB       conj       conjunct
# by         ADP        agent      agent
# the        DET        det        determiner
# project    NOUN       pobj       object of preposition
# .          PUNCT      punct      punctuation
# ·          PUNCT      punct      punctuation
# Proven     ADJ        amod       adjectival modifier
# experience NOUN       ROOT       None
# working    VERB       acl        clausal modifier of noun (adjectival clause)
# in         ADP        prep       prepositional modifier
# a          DET        det        determiner
# matrix     NOUN       compound   compound
# environment NOUN       pobj       object of preposition
# ,          PUNCT      punct      punctuation
# managing   VERB       advcl      adverbial clause modifier
# multiple   ADJ        amod       adjectival modifier
# stakeholders NOUN       dobj       direct object
# .          PUNCT      punct      punctuation
# ·          PUNCT      punct      punctuation
# Negotiation NOUN       nmod       modifier of nominal
# and        CCONJ      cc         coordinating conjunction
# conflict   NOUN       compound   compound
# resolution NOUN       compound   compound
# capabilities NOUN       appos      appositional modifier
# .          PUNCT      punct      punctuation
# ·          PUNCT      punct      punctuation
# Excellent  ADJ        amod       adjectival modifier
# people     NOUN       compound   compound
# management NOUN       compound   compound
# skills     NOUN       conj       conjunct
# ,          PUNCT      punct      punctuation
# including  VERB       prep       prepositional modifier
# the        DET        det        determiner
# ability    NOUN       pobj       object of preposition
# to         PART       aux        auxiliary
# influence  VERB       acl        clausal modifier of noun (adjectival clause)
# ,          PUNCT      punct      punctuation
# negotiate  VERB       conj       conjunct
# and        CCONJ      cc         coordinating conjunction
# achieve    VERB       conj       conjunct
# results    NOUN       dobj       direct object
# through    ADP        prep       prepositional modifier
# others     NOUN       pobj       object of preposition
# who        PRON       nsubj      nominal subject
# are        AUX        relcl      relative clause modifier
# not        PART       neg        negation modifier
# direct     ADJ        amod       adjectival modifier
# reports    NOUN       attr       attribute
# .          PUNCT      punct      punctuation
# This       DET        nsubj      nominal subject
# is         AUX        ROOT       None
# a          DET        det        determiner
# customer   NOUN       npadvmod   noun phrase as adverbial modifier
# facing     NOUN       amod       adjectival modifier
# role       NOUN       attr       attribute
# .          PUNCT      punct      punctuation
# You        PRON       nsubjpass  nominal subject (passive)
# be         AUX        auxpass    auxiliary (passive)
# required   VERB       ROOT       None
# to         PART       aux        auxiliary
# travel     VERB       xcomp      open clausal complement
# to         ADP        prep       prepositional modifier
# client     NOUN       compound   compound
# locations  NOUN       pobj       object of preposition
# to         PART       aux        auxiliary
# deliver    VERB       advcl      adverbial clause modifier
# professional ADJ        amod       adjectival modifier
# services   NOUN       dobj       direct object
# when       ADV        advmod     adverbial modifier
# needed     VERB       advcl      adverbial clause modifier
# .          PUNCT      punct      punctuation
#            SPACE                 None
# US         PROPN      ROOT       None
# ,          PUNCT      punct      punctuation
# CA         PROPN      conj       conjunct
# ,          PUNCT      punct      punctuation
# Irvine     PROPN      appos      appositional modifier
#            SPACE                 None
# Project    PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# Program    PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# Product    PROPN      compound   compound
# Management PROPN      conj       conjunct
# --         PUNCT      punct      punctuation
# Technical  PROPN      ROOT       None
#            SPACE                 None
# 986871     NUM        nummod     numeric modifier
#            SPACE                 None
# Amazon     PROPN      compound   compound
# Web        PROPN      compound   compound
# Services   PROPN      npadvmod   noun phrase as adverbial modifier
# ,          PUNCT      punct      punctuation
# Inc.       PROPN      intj       interjection
