# %%
import numpy as np
import pandas as pd
import re

# %%
df = pd.read_csv('../TextFiles/csv/nyc-jobs.csv')

# %%
# to read data from the data frame at differents indexes
print(df.head())
# Out:
#    Job ID                          Agency Posting Type  # Of Positions  \
# 0   87990    DEPARTMENT OF BUSINESS SERV.     Internal               1
# 1   97899    DEPARTMENT OF BUSINESS SERV.     Internal               1
# 2  102221  DEPT OF ENVIRONMENT PROTECTION     External               1
# 3  102221  DEPT OF ENVIRONMENT PROTECTION     Internal               1
# 4  114352  DEPT OF ENVIRONMENT PROTECTION     Internal               5
#
#                              Business Title             Civil Service Title  \
# 0                           Account Manager  CONTRACT REVIEWER (OFFICE OF L
# 1  EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT  ADMINISTRATIVE BUSINESS PROMOT
# 2                        Project Specialist  ENVIRONMENTAL ENGINEERING INTE
# 3                        Project Specialist  ENVIRONMENTAL ENGINEERING INTE
# 4                        Deputy Plant Chief  SENIOR STATIONARY ENGINEER (EL
#
#   Title Code No Level Job Category Full-Time/Part-Time indicator  ...  \
# ...

# %%
s = df[0:1]
s=s.to_string()
print(s)
# Out:
#    Job ID                        Agency Posting Type  # Of Positions   Business Title             Civil Service Title Title Code No Level Job Category Full-Time/Part-Time indicator Salary Range From  Salary Range To Salary Frequency        Work Location    Division/Work Unit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   
# ...

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# Create a Doc object
doc = nlp(s)

# Print each token separately
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
#     SPACE
# Job PROPN compound
# ID PROPN ROOT
#                         SPACE
# Agency PROPN ROOT
# Posting PROPN compound
# Type PROPN compound
#   SPACE
# # NOUN ROOT
# Of ADP prep
# Positions PROPN pobj
#    SPACE
# Business PROPN compound
# Title PROPN pobj
#              SPACE
# Civil PROPN compound
# Service PROPN appos
# Title PROPN compound
# Title PROPN compound
# Code PROPN appos
# No INTJ det
# Level PROPN ROOT
# Job PROPN compound
# Category NOUN compound
# Full PROPN amod
# - PUNCT punct
# Time PROPN nmod
# / SYM punct
# Part PROPN compound
# - PUNCT punct
# Time PROPN compound
# indicator NOUN ROOT
# Salary PROPN compound
# Range PROPN appos
# From ADP prep
#   SPACE
# Salary PROPN compound
# Range PROPN pobj
# To ADP prep
# Salary PROPN compound
# Frequency PROPN nmod
#         SPACE
# Work PROPN compound
# Location PROPN nmod
#     SPACE
# Division PROPN nmod
# / SYM punct
# Work PROPN compound
# Unit PROPN pobj
# ...

# %%
 # explore tokens
for token in doc:
    print(token.text, end=' | ')
# Out:
#     | Job | ID |                         | Agency | Posting | Type |   | # | Of | Positions |    | Business | Title |              | Civil | Service | Title | Title | Code | No | Level | Job | Category | Full | - | Time | / | Part | - | Time | indicator | Salary | Range | From |   | Salary | Range | To | Salary | Frequency |         | Work | Location |     | Division | / | Work | Unit |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 
# ...

# %%
re.findall(r"[^!.? ]+",s)
# Out:
# ['Job',
#  'ID',
#  'Agency',
#  'Posting',
#  'Type',
#  '#',
#  'Of',
#  'Positions',
#  'Business',
#  'Title',
#  'Civil',
#  'Service',
#  'Title',
#  'Title',
#  'Code',
#  'No',
#  'Level',
#  'Job',
#  'Category',
#  'Full-Time/Part-Time',
#  'indicator',
#  'Salary',
#  'Range',
#  'From',
#  'Salary',
#  'Range',
#  'To',
#  'Salary',
#  'Frequency',
#  'Work',
#  'Location',
#  'Division/Work',
#  'Unit',
#  'Job',
#  'Description',
#  'Minimum',
#  'Qual',
#  'Requirements',
#  'Preferred',
#  'Skills',
#  'Additional',
#  'Information',
#  'To',
#  'Apply',
#  'Hours/Shift',
#  'Work',
#  'Location',
#  '1',
#  'Recruitment',
#  'Contact',
#  'Residency',
#  'Requirement',
#  'Posting',
#  'Date',
#  'Post',
#  'Until',
#  'Posting',
#  'Updated',
#  'Process',
#  'Date\n0',
#  '87990',
#  'DEPARTMENT',
#  'OF',
#  'BUSINESS',
#  'SERV',
#  'Internal',
#  '1',
#  'Account',
#  'Manager',
#  'CONTRACT',
#  'REVIEWER',
#  '(OFFICE',
#  'OF',
#  'L',
#  '40563',
#  '1',
# ...

# %%
# MAKE NER 
for ent in doc.ents:
    print(ent.text, ent.start, ent.end, ent.start_char, ent.end_char, ent.label_)
# Out:
# Civil Service Title 15 18 98 117 ORG
# ...

# %%
## Visualizing the entity recognizer
from spacy import displacy

displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">   Job ID                        Agency Posting Type  # Of Positions   Business Title
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Civil Service Title
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Title Code No Level Job Category Full-Time/Part-Time indicator Salary Range From  Salary Range To Salary Frequency        Work Location
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...

# %%
# More Specific Entities
for sent in doc.sents:
    docx = nlp(sent.text)
    if docx.ents:
        displacy.render(docx, style='ent', jupyter=True)
    else:
        print(docx.text)
# Out:
#    Job ID
# Agency
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Posting Type  # Of Positions   Business Title
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Civil Service Title
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Title Code</div></span>
# No Level
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Job Category Full-Time/Part-Time indicator
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Salary Range
# ...

# %%
len([ent for ent in doc.ents ])
# Out:
# 61

# %%
# Viewing Specific Entities

options = {'ents': ['ORG', 'PRODUCT']}

displacy.render(doc, style='ent', jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">   Job ID                        Agency Posting Type  # Of Positions   Business Title
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Civil Service Title
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Title Code No Level Job Category Full-Time/Part-Time indicator Salary Range From  Salary Range To Salary Frequency        Work Location
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...

# %%
# Import the toolkit and the full Porter Stemmer library
import nltk
from nltk.stem.porter import *
from nltk.stem.snowball import SnowballStemmer

# The Snowball Stemmer requires that you pass a language parameter
s_stemmer = SnowballStemmer(language='english')

# %%
#Stemming

for word in re.findall(r"[^!.? ]+",s):
    print(word+' --> '+s_stemmer.stem(word))
# Out:
# Job --> job
# ID --> id
# Agency --> agenc
# Posting --> post
# Type --> type
# # --> #
# Of --> of
# Positions --> posit
# Business --> busi
# Title --> titl
# Civil --> civil
# Service --> servic
# Title --> titl
# Title --> titl
# Code --> code
# No --> no
# Level --> level
# Job --> job
# Category --> categori
# Full-Time/Part-Time --> full-time/part-tim
# indicator --> indic
# Salary --> salari
# Range --> rang
# From --> from
# Salary --> salari
# Range --> rang
# To --> to
# Salary --> salari
# Frequency --> frequenc
# Work --> work
# Location --> locat
# Division/Work --> division/work
# Unit --> unit
# Job --> job
# Description --> descript
# Minimum --> minimum
# Qual --> qual
# Requirements --> requir
# Preferred --> prefer
# Skills --> skill
# Additional --> addit
# Information --> inform
# To --> to
# Apply --> appli
# Hours/Shift --> hours/shift
# Work --> work
# Location --> locat
# 1 --> 1
# Recruitment --> recruit
# Contact --> contact
# Residency --> resid
# ...

# %%
## Lemmatization

for token in doc:
    print(f'{token.text:{10}} {token.pos_:{10}} {token.dep_:{10}} {spacy.explain(token.dep_)}')
# Out:
#            SPACE                 None
# Job        PROPN      compound   compound
# ID         PROPN      ROOT       None
#                         SPACE                 None
# Agency     PROPN      ROOT       None
# Posting    PROPN      compound   compound
# Type       PROPN      compound   compound
#            SPACE                 None
# #          NOUN       ROOT       None
# Of         ADP        prep       prepositional modifier
# Positions  PROPN      pobj       object of preposition
#            SPACE                 None
# Business   PROPN      compound   compound
# Title      PROPN      pobj       object of preposition
#              SPACE                 None
# Civil      PROPN      compound   compound
# Service    PROPN      appos      appositional modifier
# Title      PROPN      compound   compound
# Title      PROPN      compound   compound
# Code       PROPN      appos      appositional modifier
# No         INTJ       det        determiner
# ...

# %%
 #start making filttering on Dataset 
import pandas as pd

# %%
df = pd.read_csv("../TextFiles/csv/nyc-jobs.csv")
schema_df = pd.read_csv('../TextFiles/csv/nyc-jobs.csv')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

df.head()
# Out:
#    Job ID                          Agency Posting Type  # Of Positions  \
# 0   87990    DEPARTMENT OF BUSINESS SERV.     Internal               1
# 1   97899    DEPARTMENT OF BUSINESS SERV.     Internal               1
# 2  102221  DEPT OF ENVIRONMENT PROTECTION     External               1
# 3  102221  DEPT OF ENVIRONMENT PROTECTION     Internal               1
# 4  114352  DEPT OF ENVIRONMENT PROTECTION     Internal               5
#
#                              Business Title             Civil Service Title  \
# 0                           Account Manager  CONTRACT REVIEWER (OFFICE OF L
# 1  EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT  ADMINISTRATIVE BUSINESS PROMOT
# 2                        Project Specialist  ENVIRONMENTAL ENGINEERING INTE
# 3                        Project Specialist  ENVIRONMENTAL ENGINEERING INTE
# 4                        Deputy Plant Chief  SENIOR STATIONARY ENGINEER (EL
#
#   Title Code No Level Job Category Full-Time/Part-Time indicator  \
# ...

# %%
filt = (df[' LocatWorkion'] == 'New York')
filt
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3415    False
# 3416    False
# 3417    False
# 3418    False
# 3419    False
# Name: Work Location, Length: 3420, dtype: bool

# %%
df.loc[filt]
# Out:
# Empty DataFrame
# Columns: [Job ID, Agency, Posting Type, # Of Positions, Business Title, Civil Service Title, Title Code No, Level, Job Category, Full-Time/Part-Time indicator, Salary Range From, Salary Range To, Salary Frequency, Work Location, Division/Work Unit, Job Description, Minimum Qual Requirements, Preferred Skills, Additional Information, To Apply, Hours/Shift, Work Location 1, Recruitment Contact, Residency Requirement, Posting Date, Post Until, Posting Updated, Process Date]
# Index: []

# %%
# save data after filttaring in data frame  
filt = df['Job Category'].str.contains('Information Technology', na=False)

job_5 = df.loc[filt]

# %%
job_5
