# %%
import numpy as np
import pandas as pd
import re

# %%
df = pd.read_csv('../TextFiles/csv/jobs_ca_sample.csv')

# %%
# to read data from the data frame at differents indexes
print(df.head())
# Out:
#                                              pageurl  \
# 0  https://www.jobs.ca/offer/senior-engineer-inst...
# 1  https://www.jobs.ca/offer/account-executive-me...
#
#                      record/uniq_id     record/job_board  \
# 0  3808ba4110a7663d046d9b2dff60d9de  https://www.jobs.ca
# 1  8acd32dd33c5282875f3fcd2fdc160d4  https://www.jobs.ca
#
#                                      record/page_url  \
# 0  https://www.jobs.ca/offer/senior-engineer-inst...
# 1  https://www.jobs.ca/offer/account-executive-me...
#
#                                 record/job_title  \
# 0  Senior Engineer, Instrumentation and Controls
# 1                      Account Executive, Medium
#
#                               record/job_description record/location  \
# 0  Français Careers View Profile Français View al...          Canada
# 1  Bell.ca Français Home Featured Jobs Business I...          Canada
#
#   record/country_code
# 0                  CA
# 1                  CA

# %%
s = df[0:1]
s=s.to_string()
print(s)
# Out:
#                                                                           pageurl                    record/uniq_id     record/job_board                                                                 record/page_url                               record/job_title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# 0  https://www.jobs.ca/offer/senior-engineer-instrumentation-and-controls/873334/  3808ba4110a7663d046d9b2dff60d9de  https://www.jobs.ca  https://www.jobs.ca/offer/senior-engineer-instrumentation-and-controls/873334/  Senior Engineer, Instrumentation and Controls  Français Careers View Profile Français View all jobs Filter by category Engineers Business professionals Trades & operators Students & new grads Search by location Join our community View Profile Search by Keyword Search by Location Search jobs × Send me alerts every days Create Alert × Send me alerts every days Share this Job var searchString = ''; var siteName = "Suncor Energy Services"; $(function() { $('.rsslink-jobs2web').unbind('click').click(function(e){ TrackGoogleAnalytics('/feed/rss/0', 0, 0, searchString, 'RSSFeed', siteName); }); $('.rsslink-google').unbind('click').click(function(){ TrackGoogleAnalytics('/feed/google/0', 0, 0, searchString, 'GoogleFeed', siteName); }); $('.rsslink-yahoo').unbind('click').click(function(){ TrackGoogleAnalytics('/feed/yahoo/0', 0, 0, searchString, 'YahooFeed', siteName); }); $('.rsslink-msn').unbind('click').click(function(){ TrackGoogleAnalytics('/feed/msn/0', 0, 0, searchString, 'MSNFeed', siteName); }); }); //<![CDATA[ var trackVars = {"refid":""}; var lang = "en"; var gaPropertyId = ""; var httpProtocol = "https"; //]]> var addthis_config = { username:'addthisj2w' ,ui_open_windows: true ,ui_click: true ,ui_508_compliant: true ,data_track_clickback: false ,ui_language: "en" ,data_ga_property: "" ,data_ga_social: true }; var calledsfshorturl = false; $(function(){ $('.addthis_toolbox').mouseover(function(e){ if (!calledsfshorturl) { calledsfshorturl = true; $(this).sfshorturl({ callback:addthisCallback ,event:e ,track: trackVars }); } }); function addthisCallback(data){ $(data.event.target).attr('addthis:url',data.shorturl); addthis.update('share', 'url', data.shorturl); } }); Senior Engineer, Instrumentation and Controls Apply now » Apply now Apply Now Start apply with LinkedIn Start Please wait... Date: Jul 18, 2017 LOCATION: Edmonton, Alberta (CA-AB) JOB NUMBER: 16130   Job Overview Reporting to the team leader, instrumentation, electrical and controls area projects, you will help support and lead the refinery wide instrumentation and controls projects and long-term plans to ensure safe and reliable operations within the Edmonton refinery. Key Accountabilities Develop detailed engineering work packages in accordance with project specifications and provide construction, commissioning and start-up support Develop control narratives for new and existing DCS control and safety systems; investigate and troubleshoot control system configuration problems and recommend quick and reliable solutions Review work packages for error free and consistent engineering deliverables as per applicable codes and approved engineering standards Design, configure, validate (offline simulation) and optimize controls software packages to provide accurate and reliable software deliverables for safe refinery operations; test systems thoroughly in an offline environment with key stakeholders to address valid concerns Provide continuous improvement and standardization feedback towards improved controls configuration processes, project efficiencies, quality and cost effectiveness Exercise cost control when providing engineering solutions, review and maintain project schedules, track engineering tasks and deliverables in conjunction with project management Prepare material requisitions and complete technical evaluations by reviewing vendor or subcontractor quotations, drawings and specifications in conformance with project requirements Participate in design reviews, process hazard analysis, management of change, layers of protection analysis (LOPA) and safety integrity level (SIL) analysis  Use resources effectively and offer coaching to junior staff and contractor resources Required Qualifications Experience and Education: Eight or more years of co ...

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# Create a Doc object
doc = nlp(s)

# Print each token separately
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
#                                                                            SPACE
# pageurl NOUN ROOT
#                     SPACE
# record NOUN dobj
# / SYM punct
# uniq_id PROPN appos
#      SPACE
# record NOUN npadvmod
# / SYM punct
# job_board PROPN nmod
#                                                                  SPACE
# record NOUN nmod
# / SYM punct
# page_url PROPN ROOT
#                                SPACE
# record PROPN appos
# / SYM punct
# job_title PROPN nmod
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# record NOUN nmod
# / SYM punct
# job_description PROPN nmod
# record NOUN nmod
# / SYM punct
# location NOUN nmod
# record NOUN nmod
# / SYM punct
# country_code PROPN ROOT
#
#  SPACE
# 0 NUM ROOT
#   SPACE
# https://www.jobs.ca/offer/senior-engineer-instrumentation-and-controls/873334/ PROPN ROOT
#   SPACE
# 3808ba4110a7663d046d9b2dff60d9de NUM ROOT
#   SPACE
# https://www.jobs.ca X ROOT
#   SPACE
# https://www.jobs.ca/offer/senior-engineer-instrumentation-and-controls/873334/ PROPN ROOT
#   SPACE
# Senior PROPN compound
# Engineer PROPN ROOT
# , PUNCT punct
# Instrumentation PROPN conj
# and CCONJ cc
# Controls PROPN conj
#   SPACE
# Français PROPN compound
# Careers NOUN compound
# View VERB compound
# Profile PROPN compound
# Français PROPN compound
# View VERB ROOT
# all DET det
# jobs NOUN compound
# Filter PROPN nsubj
# by ADP prep
# category NOUN compound
# Engineers PROPN compound
# Business PROPN compound
# professionals NOUN compound
# Trades PROPN pobj
# & CCONJ cc
# operators NOUN compound
# Students PROPN conj
# & CCONJ cc
# new ADJ amod
# grads NOUN conj
# Search VERB acl
# by ADP prep
# location NOUN pobj
# Join VERB ROOT
# our DET poss
# community NOUN compound
# View NOUN compound
# Profile PROPN compound
# Search NOUN dobj
# by ADP prep
# Keyword PROPN compound
# Search PROPN pobj
# by ADP prep
# Location PROPN compound
# Search PROPN compound
# jobs NOUN compound
# × PUNCT pobj
# Send VERB ROOT
# me PRON dative
# alerts NOUN dobj
# every DET det
# days NOUN npadvmod
# Create VERB compound
# Alert NOUN compound
# × PUNCT nsubj
# Send VERB ROOT
# me PRON dative
# alerts NOUN dobj
# every DET det
# days NOUN npadvmod
# Share PROPN ROOT
# this DET det
# Job PROPN compound
# var NOUN compound
# searchString NOUN dobj
# = SYM punct
# '' PUNCT punct
# ; PUNCT punct
# var PROPN compound
# siteName PROPN conj
# = SYM punct
# " PUNCT punct
# Suncor PROPN compound
# Energy PROPN compound
# Services PROPN ROOT
# " PUNCT punct
# ; PUNCT punct
# $ SYM dep
# ( PUNCT punct
# function NOUN appos
# ( PUNCT punct
# ) PUNCT punct
# { PUNCT punct
# $ SYM prep
# ( PUNCT punct
# ' PUNCT punct
# .rsslink PUNCT compound
# - PUNCT punct
# jobs2web').unbind('click').click(function(e PROPN pobj
# ) PUNCT punct
# { PUNCT punct
# TrackGoogleAnalytics('/feed PROPN nmod
# / SYM punct
# rss/0 PROPN appos
# ' PUNCT punct
# , PUNCT punct
# 0 NUM nummod
# , PUNCT punct
# 0 NUM nummod
# , PUNCT punct
# searchString VERB appos
# , PUNCT punct
# ' PUNCT punct
# RSSFeed PROPN intj
# ' PUNCT punct
# , PUNCT punct
# siteName PROPN appos
# ) PUNCT punct
# ; PUNCT punct
# } PUNCT punct
# ) PUNCT punct
# ; PUNCT punct
# $ SYM nmod
# ( PUNCT punct
# ' PUNCT punct
# .rsslink PUNCT nmod
# - PUNCT punct
# google').unbind('click').click(function NOUN nmod
# ( PUNCT punct
# ) PUNCT punct
# { PUNCT punct
# TrackGoogleAnalytics('/feed PROPN nmod
# / SYM punct
# google/0 PROPN pobj
# ' PUNCT punct
# , PUNCT punct
# 0 NUM punct
# , PUNCT punct
# 0 NUM punct
# , PUNCT punct
# searchString VERB conj
# , PUNCT punct
# ' PUNCT punct
# GoogleFeed PROPN appos
# ' PUNCT punct
# , PUNCT punct
# siteName PROPN npadvmod
# ) PUNCT punct
# ; PUNCT punct
# } PUNCT punct
# ) PUNCT punct
# ; PUNCT punct
# $ SYM intj
# ( PUNCT punct
# ' PUNCT punct
# .rsslink PUNCT punct
# - PUNCT punct
# yahoo').unbind('click').click(function NOUN conj
# ( PUNCT punct
# ) PUNCT punct
# { PUNCT punct
# TrackGoogleAnalytics('/feed PROPN nmod
# / SYM punct
# yahoo/0 PROPN parataxis
# ' PUNCT punct
# , PUNCT punct
# 0 NUM nummod
# , PUNCT punct
# 0 NUM appos
# , PUNCT punct
# searchString VERB appos
# , PUNCT punct
# ' PUNCT punct
# YahooFeed PROPN nmod
# ' PUNCT punct
# , PUNCT punct
# siteName PROPN appos
# ) PUNCT punct
# ; PUNCT punct
# } PUNCT punct
# ) PUNCT punct
# ; PUNCT punct
# $ SYM appos
# ( PUNCT punct
# ' PUNCT punct
# .rsslink PUNCT nmod
# - PUNCT punct
# msn').unbind('click').click(function NUM appos
# ( PUNCT punct
# ) PUNCT punct
# { PUNCT punct
# TrackGoogleAnalytics('/feed PROPN nmod
# / SYM punct
# msn/0 PROPN appos
# ' PUNCT punct
# , PUNCT punct
# 0 NUM nummod
# , PUNCT punct
# 0 NUM punct
# , PUNCT punct
# searchString VERB appos
# , PUNCT punct
# ' PUNCT punct
# MSNFeed NOUN dobj
# ' PUNCT punct
# , PUNCT punct
# siteName PROPN appos
# ) PUNCT punct
# ; PUNCT punct
# } PUNCT punct
# ) PUNCT punct
# ; PUNCT punct
# } PUNCT punct
# ) PUNCT punct
# ; PUNCT punct
# //<![CDATA PUNCT punct
# [ PUNCT punct
# var NOUN compound
# trackVars NOUN meta
# = NOUN punct
# { PUNCT punct
# " PUNCT punct
# refid NOUN ROOT
# " PUNCT punct
# : PUNCT punct
# " PUNCT punct
# " PUNCT punct
# } PUNCT punct
# ; PUNCT punct
# var PROPN compound
# lang PROPN appos
# = PUNCT punct
# " PUNCT punct
# en X ROOT
# " PUNCT punct
# ; PUNCT punct
# var NOUN compound
# gaPropertyId X punct
# = VERB punct
# " PUNCT punct
# " PUNCT punct
# ; PUNCT punct
# var PROPN compound
# httpProtocol PROPN nsubj
# = SYM punct
# " PUNCT punct
# https NOUN ROOT
# " PUNCT punct
# ; PUNCT punct
# // X punct
# ] PUNCT punct
# ] PUNCT punct
# > PROPN ROOT
# var NOUN compound
# addthis_config PROPN ROOT
# = SYM punct
# { PUNCT punct
# username:'addthisj2w NOUN meta
# ' PUNCT punct
# , PUNCT punct
# ui_open_windows NOUN ROOT
# : PUNCT punct
# true ADJ ROOT
# , PUNCT punct
# ui_click PROPN dep
# : PUNCT punct
# true ADJ intj
# , PUNCT punct
# ui_508_compliant ADJ intj
# : PUNCT punct
# true ADJ advmod
# , PUNCT punct
# data_track_clickback NOUN dep
# : PUNCT punct
# false ADJ ROOT
# , PUNCT punct
# ui_language VERB intj
# : PUNCT punct
# " PUNCT punct
# en X intj
# " PUNCT punct
# , PUNCT punct
# data_ga_property PROPN appos
# : PUNCT punct
# " PUNCT punct
# " PUNCT punct
# , PUNCT punct
# data_ga_social PROPN intj
# : PUNCT punct
# true ADJ advmod
# } PUNCT punct
# ; PUNCT punct
# var NOUN compound
# calledsfshorturl NOUN npadvmod
# = SYM punct
# false ADJ ROOT
# ; PUNCT punct
# $ SYM dep
# ( PUNCT punct
# function NOUN intj
# ( PUNCT punct
# ) PUNCT punct
# { PUNCT punct
# $ SYM amod
# ( PUNCT punct
# ' PUNCT punct
# .addthis_toolbox').mouseover(function(e PROPN punct
# ) PUNCT punct
# { PUNCT punct
# if SCONJ mark
# ( PUNCT punct
# ! PUNCT punct
# calledsfshorturl PROPN nsubj
# ) PUNCT punct
# { PUNCT punct
# calledsfshorturl NOUN advcl
# = VERB punct
# true ADJ dobj
# ; PUNCT punct
# $ SYM punct
# ( PUNCT punct
# this).sfshorturl CCONJ ROOT
# ( PUNCT punct
# { PUNCT punct
# callback NOUN parataxis
# : PUNCT punct
# addthisCallback NOUN appos
# , PUNCT punct
# event NOUN ROOT
# : PUNCT punct
# e X appos
# , PUNCT punct
# track NOUN appos
# : PUNCT punct
# trackVars NOUN appos
# } PUNCT punct
# ) PUNCT punct
# ; PUNCT punct
# } PUNCT punct
# } PUNCT punct
# ) PUNCT punct
# ; PUNCT punct
# function VERB conj
# addthisCallback(data PROPN nummod
# ) PUNCT punct
# { PUNCT punct
# $ SYM aux
# ( PUNCT punct
# data.event.target).attr('addthis DET ROOT
# : PUNCT punct
# url',data.shorturl NUM appos
# ) PUNCT punct
# ; PUNCT punct
# addthis.update('share PROPN appos
# ' PUNCT punct
# , PUNCT punct
# ' PUNCT punct
# url PROPN conj
# ' PUNCT punct
# , PUNCT punct
# data.shorturl PROPN appos
# ) PUNCT punct
# ; PUNCT punct
# } PUNCT punct
# } PUNCT punct
# ) PUNCT punct
# ; PUNCT punct
# Senior PROPN compound
# Engineer PROPN nsubj
# , PUNCT punct
# Instrumentation PROPN conj
# and CCONJ cc
# Controls PROPN conj
# Apply VERB ROOT
# now ADV advmod
# » INTJ punct
# Apply VERB dep
# now ADV advmod
# Apply VERB dep
# Now ADV advmod
# Start PROPN nsubj
# apply VERB advcl
# with ADP prep
# LinkedIn PROPN pobj
# Start NOUN nsubj
# Please INTJ intj
# wait VERB ROOT
# ... PUNCT punct
# Date NOUN ROOT
# : PUNCT punct
# Jul PROPN appos
# 18 NUM nummod
# , PUNCT punct
# 2017 NUM nummod
# LOCATION NOUN appos
# : PUNCT punct
# Edmonton PROPN appos
# , PUNCT punct
# Alberta PROPN appos
# ( PUNCT punct
# CA PROPN compound
# - PUNCT punct
# AB PROPN ROOT
# ) PUNCT punct
# JOB NOUN compound
# NUMBER NOUN ROOT
# : PUNCT punct
# 16130 NUM ROOT
#    SPACE
# Job PROPN compound
# Overview PROPN compound
# Reporting VERB advcl
# to ADP prep
# the DET det
# team NOUN compound
# leader NOUN pobj
# , PUNCT punct
# instrumentation NOUN conj
# , PUNCT punct
# electrical ADJ amod
# and CCONJ cc
# controls NOUN conj
# area NOUN compound
# projects NOUN appos
# , PUNCT punct
# you PRON nsubj
# will VERB aux
# help VERB ROOT
# support VERB xcomp
# and CCONJ cc
# lead VERB conj
# the DET det
# refinery NOUN nmod
# wide ADJ amod
# instrumentation NOUN nmod
# and CCONJ cc
# controls NOUN conj
# projects NOUN dobj
# and CCONJ cc
# long ADJ amod
# - PUNCT punct
# term NOUN compound
# plans NOUN conj
# to PART aux
# ensure VERB acl
# safe ADJ amod
# and CCONJ cc
# reliable ADJ conj
# operations NOUN dobj
# within ADP prep
# the DET det
# Edmonton PROPN compound
# refinery NOUN pobj
# . PUNCT punct
# Key ADJ compound
# Accountabilities NOUN nsubj
# Develop VERB ccomp
# detailed ADJ amod
# engineering NOUN compound
# work NOUN compound
# packages NOUN dobj
# in ADP prep
# accordance NOUN pobj
# with ADP prep
# project NOUN compound
# specifications NOUN pobj
# and CCONJ cc
# provide VERB conj
# construction NOUN dobj
# , PUNCT punct
# commissioning NOUN conj
# and CCONJ cc
# start VERB amod
# - PUNCT punct
# up ADP prt
# support NOUN conj
# Develop VERB conj
# control NOUN compound
# narratives NOUN dobj
# for ADP prep
# new ADJ amod
# and CCONJ cc
# existing VERB conj
# DCS PROPN compound
# control NOUN nmod
# and CCONJ cc
# safety NOUN conj
# systems NOUN pobj
# ; PUNCT punct
# investigate VERB amod
# and CCONJ cc
# troubleshoot VERB compound
# control NOUN conj
# system NOUN compound
# configuration NOUN compound
# problems NOUN nsubj
# and CCONJ cc
# recommend VERB conj
# quick ADJ amod
# and CCONJ cc
# reliable ADJ conj
# solutions NOUN compound
# Review PROPN compound
# work NOUN compound
# packages NOUN dobj
# for ADP prep
# error NOUN nmod
# free ADJ amod
# and CCONJ cc
# consistent ADJ conj
# engineering NOUN compound
# deliverables NOUN pobj
# as SCONJ prep
# per ADP prep
# applicable ADJ amod
# codes NOUN pobj
# and CCONJ cc
# approved VERB amod
# engineering NOUN compound
# standards NOUN compound
# Design PROPN conj
# , PUNCT punct
# configure NOUN conj
# , PUNCT punct
# validate NOUN conj
# ( PUNCT punct
# offline ADJ compound
# simulation NOUN conj
# ) PUNCT punct
# and CCONJ cc
# optimize VERB conj
# controls NOUN compound
# software NOUN compound
# packages NOUN dobj
# to PART aux
# provide VERB xcomp
# accurate ADJ amod
# and CCONJ cc
# reliable ADJ conj
# software NOUN compound
# deliverables NOUN dobj
# for ADP prep
# safe ADJ amod
# refinery NOUN compound
# operations NOUN pobj
# ; PUNCT punct
# test NOUN compound
# systems NOUN appos
# thoroughly ADV advmod
# in ADP prep
# an DET det
# offline ADJ amod
# environment NOUN pobj
# with ADP prep
# key ADJ amod
# stakeholders NOUN pobj
# to PART aux
# address VERB relcl
# valid ADJ amod
# concerns NOUN dobj
# Provide VERB ROOT
# continuous ADJ amod
# improvement NOUN dobj
# and CCONJ cc
# standardization NOUN compound
# feedback NOUN conj
# towards ADP prep
# improved ADJ amod
# controls NOUN compound
# configuration NOUN compound
# processes NOUN pobj
# , PUNCT punct
# project NOUN compound
# efficiencies NOUN conj
# , PUNCT punct
# quality NOUN nmod
# and CCONJ cc
# cost VERB compound
# effectiveness NOUN conj
# Exercise NOUN compound
# cost NOUN compound
# control NOUN conj
# when ADV advmod
# providing VERB advcl
# engineering NOUN compound
# solutions NOUN dobj
# , PUNCT punct
# review VERB conj
# and CCONJ cc
# maintain VERB conj
# project NOUN compound
# schedules NOUN dobj
# , PUNCT punct
# track VERB compound
# engineering NOUN compound
# tasks NOUN conj
# and CCONJ cc
# deliverables NOUN conj
# in ADP prep
# conjunction NOUN pobj
# with ADP prep
# project NOUN compound
# management NOUN compound
# Prepare PROPN compound
# material NOUN compound
# requisitions NOUN pobj
# and CCONJ cc
# complete VERB amod
# technical ADJ amod
# evaluations NOUN conj
# by ADP prep
# reviewing VERB pcomp
# vendor NOUN dobj
# or CCONJ cc
# subcontractor NOUN compound
# quotations NOUN conj
# , PUNCT punct
# drawings NOUN conj
# and CCONJ cc
# specifications NOUN conj
# in ADP prep
# conformance NOUN pobj
# with ADP prep
# project NOUN compound
# requirements NOUN pobj
# Participate VERB acl
# in ADP prep
# design NOUN compound
# reviews NOUN pobj
# , PUNCT punct
# process VERB compound
# hazard PROPN compound
# analysis NOUN conj
# , PUNCT punct
# management NOUN conj
# of ADP prep
# change NOUN pobj
# , PUNCT punct
# layers NOUN conj
# of ADP prep
# protection NOUN compound
# analysis NOUN pobj
# ( PUNCT punct
# LOPA PROPN appos
# ) PUNCT punct
# and CCONJ cc
# safety NOUN compound
# integrity NOUN compound
# level NOUN appos
# ( PUNCT punct
# SIL PROPN nmod
# ) PUNCT punct
# analysis NOUN appos
#    SPACE
# Use PROPN ccomp
# resources NOUN dobj
# effectively ADV advmod
# and CCONJ cc
# offer VERB conj
# coaching VERB dobj
# to ADP prep
# junior ADJ amod
# staff NOUN nmod
# and CCONJ cc
# contractor NOUN conj
# resources NOUN pobj
# Required VERB compound
# Qualifications PROPN compound
# Experience PROPN appos
# and CCONJ cc
# Education NOUN conj
# : PUNCT punct
# Eight NUM nummod
# or CCONJ cc
# more ADJ conj
# years NOUN intj
# of ADP prep
# control NOUN compound
# systems NOUN compound
# experience NOUN pobj
#    SPACE
# Demonstrated VERB amod
# experience NOUN conj
# in ADP prep
# developing VERB pcomp
# engineering NOUN compound
# work NOUN compound
# packages NOUN dobj
# and CCONJ cc
# hands NOUN nmod
# - PUNCT punct
# on ADP prt
# control NOUN compound
# systems NOUN compound
# programming NOUN compound
# experience NOUN conj
# in ADP prep
# an DET det
# oil NOUN compound
# refinery NOUN pobj
# for ADP prep
# at ADV advmod
# least ADV advmod
# two NUM nummod
# years NOUN pobj
# ; PUNCT punct
# experience NOUN nsubjpass
# at ADP prep
# the DET det
# Edmonton PROPN compound
# refinery NOUN pobj
# is AUX auxpass
# considered VERB ccomp
# an DET det
# asset NOUN nmod
# Demonstrated VERB amod
# experience NOUN oprd
# on ADP prep
# interfacing VERB pcomp
# near SCONJ prep
# infrared ADJ amod
# analyzer PROPN nmod
# , PUNCT punct
# nuclear ADJ amod
# magnetic ADJ amod
# resonance NOUN nmod
# and CCONJ cc
# sample NOUN compound
# conditioning NOUN conj
# systems NOUN pobj
# with ADP prep
# Honeywell PROPN compound
# Experion PROPN pobj
# and CCONJ cc
# TDC3000 VERB compound
# DCS PROPN conj
# in ADP prep
# a DET det
# refinery NOUN compound
# environment NOUN pobj
# ; PUNCT punct
# advanced ADJ amod
# competency NOUN ccomp
# with ADP prep
# Triconex PROPN compound
# PLC PROPN compound
# programming NOUN pobj
# and CCONJ cc
# Unity PROPN compound
# Pro PROPN conj
# for ADP prep
# Modicon PROPN compound
# PLC PROPN compound
# Bachelor PROPN pobj
# ’s PART punct
# degree NOUN appos
# in ADP prep
# engineering NOUN pobj
# ; PUNCT punct
# post NOUN compound
# graduate ADJ compound
# qualifications NOUN nsubj
# will VERB aux
# be AUX ROOT
# an DET det
# asset NOUN compound
# Registered VERB attr
# as SCONJ prep
# a DET det
# professional ADJ amod
# engineer NOUN pobj
# with ADP prep
# the DET det
# Association PROPN nmod
# of ADP prep
# Professional PROPN compound
# Engineers PROPN pobj
# and CCONJ cc
# Geoscientists PROPN conj
# of ADP prep
# Alberta PROPN pobj
# ( PUNCT punct
# APEGA PROPN appos
# ) PUNCT punct
# Skills NOUN pobj
# and CCONJ cc
# Knowledge NOUN conj
# : PUNCT punct
# Hands NOUN nmod
# - PUNCT punct
# on ADP prt
# maintenance NOUN nmod
# and CCONJ cc
# configuration NOUN conj
# experience NOUN ROOT
# with ADP prep
# distributed VERB amod
# control NOUN compound
# system NOUN pobj
# ( PUNCT punct
# Experion PROPN appos
# , PUNCT punct
# C300 PROPN conj
# , PUNCT punct
# C200 PROPN conj
# , PUNCT punct
# TDC3000 PROPN appos
# , PUNCT punct
# SCADA PROPN appos
# ) PUNCT punct
# , PUNCT punct
# safety NOUN npadvmod
# instrumented VERB amod
# systems NOUN conj
# ( PUNCT punct
# Triconex PROPN appos
# ) PUNCT punct
# , PUNCT punct
# and CCONJ cc
# programmable ADJ amod
# logic NOUN compound
# controllers NOUN conj
# ( PUNCT punct
# Modicon PROPN appos
# ) PUNCT punct
# Strong ADJ amod
# technical ADJ amod
# knowledge NOUN nsubj
# of ADP prep
# applicable ADJ amod
# automation NOUN compound
# industry NOUN compound
# standards NOUN pobj
# , PUNCT punct
# SIL PROPN compound
# assessment NOUN appos
# , PUNCT punct
# LOPA PROPN compound
# methodologies NOUN conj
# , PUNCT punct
# and CCONJ cc
# alarm NOUN compound
# management NOUN compound
# guidelines NOUN compound
# Experience NOUN conj
# on ADP prep
# Burner PROPN compound
# Management PROPN compound
# System PROPN pobj
# ( PUNCT punct
# BMS PROPN appos
# ) PUNCT punct
# , PUNCT punct
# compressor NOUN conj
# , PUNCT punct
#   SPACE
# fire NOUN conj
# and CCONJ cc
# gas NOUN compound
# detection NOUN compound
# system NOUN conj
# and CCONJ cc
# Triconex PROPN conj
# upgrade VERB ROOT
# Strong ADJ amod
# interpersonal ADJ amod
# skills NOUN dobj
# to PART aux
# work VERB advcl
# with ADP prep
# the DET det
# engineering NOUN compound
# contractors NOUN pobj
# , PUNCT punct
# vendors NOUN conj
# and CCONJ cc
# project NOUN compound
# teams NOUN conj
# , PUNCT punct
# in ADP prep
# a DET det
# multi ADJ dep
# - ADJ dep
# discipline ADJ amod
# work NOUN compound
# environment NOUN pobj
# Self NOUN npadvmod
# - PUNCT punct
# motivated VERB amod
# individual NOUN appos
# with ADP prep
# excellent ADJ amod
# communication NOUN pobj
# , PUNCT punct
# analytical ADJ conj
# , PUNCT punct
# and CCONJ cc
# organizational ADJ amod
# skills NOUN conj
# Working PROPN compound
# Conditions PROPN compound
# Potential PROPN conj
# to PART aux
# work VERB advcl
# extended ADJ amod
# hours NOUN dobj
# to PART aux
# support VERB relcl
# turnaround NOUN npadvmod
# related ADJ amod
# shift NOUN compound
# roles NOUN dobj
# as SCONJ mark
# required VERB advcl
# Why ADV advmod
# Suncor PROPN nsubj
# Go VERB ccomp
# ahead ADV advmod
# . PUNCT punct
# Expect VERB ROOT
# growth NOUN dobj
# . PUNCT punct
# We PRON nsubj
# want VERB ROOT
# you PRON nsubj
# to PART aux
# have AUX ccomp
# a DET det
# job NOUN dobj
# you PRON nsubj
# 're AUX relcl
# genuinely ADV advmod
# excited ADJ acomp
# about ADP prep
# - PUNCT punct
# as ADV advmod
# well ADV advmod
# as SCONJ cc
# opportunities NOUN conj
# to PART aux
# learn VERB acl
# and CCONJ cc
# challenge VERB conj
# yourself PRON dobj
# or CCONJ cc
# mentor VERB conj
# others NOUN dobj
# . PUNCT punct
# Plus CCONJ cc
# , PUNCT punct
# Suncor PROPN compound
# Energy PROPN nsubj
# offers VERB ROOT
# a DET det
# flexible ADJ amod
# employee NOUN compound
# package NOUN dobj
# that DET nsubjpass
# can VERB aux
# be AUX auxpass
# adjusted VERB relcl
# to PART aux
# suit VERB advcl
# the DET det
# changing VERB amod
# needs NOUN dobj
# of ADP prep
# your DET poss
# life NOUN pobj
# , PUNCT punct
# including VERB prep
# : PUNCT punct
# Competitive ADJ amod
# base NOUN compound
# salary NOUN pobj
# and CCONJ cc
# compensation NOUN compound
# programs NOUN conj
# Attractive ADJ ROOT
# annual ADJ amod
# incentive NOUN compound
# program NOUN dobj
# Flexible PROPN amod
# benefits NOUN nsubj
# package NOUN conj
# Rewarding NOUN nmod
# pension NOUN nmod
# and CCONJ cc
# savings NOUN conj
# plans NOUN dobj
# Business PROPN compound
# Overview PROPN compound
# Suncor PROPN compound
# Energy PROPN nsubj
# is AUX ROOT
# Canada PROPN poss
# 's PART case
# energy NOUN compound
# company NOUN attr
# - PUNCT punct
# meaning VERB advcl
# rewarding NOUN amod
# opportunities NOUN dobj
# for ADP mark
# you PRON nsubj
# to PART aux
# apply VERB advcl
# your DET poss
# knowledge NOUN dobj
# , PUNCT punct
# contribute VERB conj
# and CCONJ cc
# grow VERB conj
# in ADP prep
# a DET det
# variety NOUN pobj
# of ADP prep
# career NOUN compound
# - PUNCT punct
# building NOUN compound
# positions NOUN pobj
# . PUNCT punct
# Our DET poss
# business NOUN compound
# portfolio NOUN nsubj
# spans VERB ROOT
# the DET det
# entire ADJ amod
# energy NOUN compound
# sector NOUN dobj
# , PUNCT punct
# from ADP prep
# a DET det
# leadership NOUN compound
# position NOUN pobj
# in ADP prep
# oil NOUN compound
# sands NOUN compound
# development NOUN pobj
# , PUNCT punct
# to ADP prep
# refining NOUN nmod
# and CCONJ cc
# marketing NOUN conj
# operations NOUN pobj
# , PUNCT punct
# natural ADJ amod
# gas NOUN conj
# , PUNCT punct
# and CCONJ cc
# conventional ADJ amod
# oil NOUN compound
# production NOUN conj
# , PUNCT punct
# internationally ADV advmod
# and CCONJ cc
# offshore ADJ conj
# East PROPN compound
# Coast PROPN compound
# Canada PROPN appos
# . PUNCT punct
# And CCONJ cc
# while SCONJ mark
# we PRON nsubj
# are AUX aux
# working VERB advcl
# to PART aux
# responsibly ADV advmod
# develop VERB xcomp
# petroleum NOUN compound
# resources NOUN dobj
# and CCONJ cc
# contribute VERB conj
# to ADP prep
# the DET det
# communities NOUN pobj
# where ADV advmod
# we PRON nsubj
# live VERB relcl
# and CCONJ cc
# work VERB conj
# , PUNCT punct
# we PRON nsubj
# are AUX aux
# also ADV advmod
# developing VERB ROOT
# our DET poss
# renewable ADJ amod
# energy NOUN compound
# portfolio NOUN dobj
# , PUNCT punct
# which DET nsubj
# includes VERB relcl
# wind NOUN compound
# power NOUN dobj
# and CCONJ cc
# biofuels NOUN conj
# . PUNCT punct
# As SCONJ prep
# part NOUN pobj
# of ADP prep
# Suncor PROPN poss
# 's PART case
# team NOUN pobj
# , PUNCT punct
# you PRON nsubj
# 'll VERB aux
# contribute VERB ROOT
# to ADP prep
# the DET det
# ongoing ADJ amod
# success NOUN pobj
# of ADP prep
# Canada PROPN poss
# 's PART case
# largest ADJ amod
# energy NOUN compound
# company NOUN pobj
# - PUNCT punct
# one NUM appos
# with ADP prep
# a DET det
# solid ADJ amod
# track NOUN compound
# record NOUN pobj
# of ADP prep
# growth NOUN pobj
# , PUNCT punct
# a DET det
# focus NOUN appos
# on ADP prep
# safety NOUN pobj
# and CCONJ cc
# sustainability NOUN conj
# and CCONJ cc
# tremendous ADJ amod
# potential NOUN conj
# for ADP prep
# the DET det
# future NOUN pobj
# . PUNCT punct
# And CCONJ cc
# you PRON nsubj
# 'll VERB aux
# have AUX ROOT
# the DET det
# opportunity NOUN dobj
# to PART aux
# learn VERB acl
# from ADP prep
# experts NOUN pobj
# in ADP prep
# the DET det
# industry NOUN pobj
# and CCONJ cc
# build VERB conj
# on ADP prep
# your DET poss
# skills NOUN pobj
# every DET det
# day NOUN npadvmod
# . PUNCT punct
# Suncor PROPN nsubj
# promotes VERB ROOT
# diversity NOUN dobj
# and CCONJ cc
# inclusion NOUN conj
# in ADP prep
# the DET det
# workplace NOUN pobj
# . PUNCT punct
# Suncor PROPN nsubj
# is AUX ROOT
# an DET det
# equal ADJ amod
# opportunity NOUN compound
# employer NOUN attr
# and CCONJ cc
# encourages VERB conj
# applications NOUN dobj
# from ADP prep
# all DET det
# qualified ADJ amod
# individuals NOUN pobj
# . PUNCT punct
# At ADP prep
# Suncor PROPN pobj
# , PUNCT punct
# we PRON nsubjpass
# are AUX auxpass
# dedicated ADJ ROOT
# to ADP prep
# building VERB pcomp
# a DET det
# workforce NOUN dobj
# that DET nsubj
# reflects VERB relcl
# the DET det
# diversity NOUN dobj
# of ADP prep
# the DET det
# communitities NOUN pobj
# in ADP prep
# which DET pobj
# we PRON nsubj
# live VERB relcl
# , PUNCT punct
# and CCONJ cc
# where ADV advmod
# every DET det
# team NOUN compound
# member NOUN nsubj
# has AUX conj
# the DET det
# opportunity NOUN dobj
# to PART aux
# reach VERB acl
# their DET poss
# full ADJ amod
# potential NOUN dobj
# . PUNCT punct
# Not PART neg
# sure ADJ ROOT
# if SCONJ mark
# this DET det
# particular ADJ amod
# listing NOUN nsubj
# is AUX ccomp
# the DET det
# right ADJ amod
# opportunity NOUN attr
# for ADP prep
# you PRON pobj
# ? PUNCT punct
# Please INTJ intj
# join VERB ROOT
# our DET poss
# Talent PROPN compound
# Community PROPN dobj
# at ADP prep
# www.suncor.com X pobj
# and CCONJ cc
# click VERB conj
# on ADP prep
# Careers NOUN pobj
# , PUNCT punct
# or CCONJ cc
# follow VERB conj
# us PRON dobj
# on ADP prep
# LinkedIn PROPN pobj
# , PUNCT punct
# Facebook PROPN conj
# and CCONJ cc
# Twitter PROPN conj
# for ADP prep
# the DET det
# latest ADJ amod
# job NOUN compound
# listings NOUN pobj
# and CCONJ cc
# employment NOUN compound
# news NOUN conj
# . PUNCT punct
# Please INTJ intj
# note VERB ROOT
# that SCONJ mark
# our DET poss
# job NOUN compound
# postings NOUN nsubj
# are AUX ccomp
# typically ADV advmod
# open ADJ acomp
# for ADP prep
# two NUM nummod
# weeks NOUN pobj
# , PUNCT punct
# so CCONJ cc
# if SCONJ mark
# you PRON nsubj
# are AUX advcl
# interested ADJ acomp
# and CCONJ cc
# qualified ADJ conj
# , PUNCT punct
# apply VERB conj
# now ADV advmod
# . PUNCT punct
# JOB PROPN compound
# CATEGORY PROPN ROOT
# : PUNCT punct
# Engineering NOUN compound
# Job PROPN compound
# Segment NOUN ROOT
# : PUNCT punct
# Controls PROPN compound
# Engineer PROPN nsubj
# , PUNCT punct
# Construction PROPN conj
# , PUNCT punct
# Instrumentation PROPN conj
# , PUNCT punct
# Engineer PROPN conj
# , PUNCT punct
# Electrical PROPN conj
# , PUNCT punct
# Engineering PROPN compound
# Apply PROPN appos
# now ADV advmod
# » INTJ punct
# Apply VERB nsubj
# now ADV advmod
# Apply VERB ROOT
# Now ADV advmod
# Start PROPN nsubj
# apply VERB ccomp
# with ADP prep
# LinkedIn PROPN pobj
# Start NOUN aux
# Please INTJ intj
# wait VERB ROOT
# ... PUNCT punct
# Find VERB ROOT
# similar ADJ amod
# jobs NOUN dobj
# : PUNCT punct
# Energy NOUN compound
# Jobs NOUN appos
# in ADP prep
# Edmonton PROPN compound
# Connect PROPN pobj
# with ADP prep
# Suncor PROPN pobj
# Our DET poss
# social ADJ amod
# media NOUN compound
# channels NOUN ROOT
# Related ADJ amod
# links NOUN dobj
# Careers NOUN compound
# home ADV compound
# View VERB ROOT
# all DET det
# jobs NOUN compound
# Search NOUN ROOT
# by ADP prep
# location NOUN pobj
# Top ADJ amod
# job NOUN compound
# searches VERB ROOT
# Suncor.com PROPN ROOT
# About ADP prep
# us PRON pobj
# Accessibility PROPN compound
# policy NOUN compound
# Legal PROPN ROOT
# & CCONJ cc
# privacy NOUN conj
# Français PROPN compound
# © PROPN ROOT
# 2017 NUM nummod
# Suncor PROPN compound
# Energy PROPN compound
# Inc. PROPN compound
# All DET det
# Rights PROPN nsubj
# Reserved PROPN ROOT
#           SPACE
# Canada PROPN conj
#                   SPACE
# CA PROPN dobj

# %%
## Visualizing the entity recognizer
from spacy import displacy

displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">                                                                          pageurl                    record/uniq_id     record/job_board                                                                 record/page_url                               record/job_title

# %%
re.findall(r"[^!.? ]+",s)
# Out:
# ['pageurl',
#  'record/uniq_id',
#  'record/job_board',
#  'record/page_url',
#  'record/job_title',
#  'record/job_description',
#  'record/location',
#  'record/country_code\n0',
#  'https://www',
#  'jobs',
#  'ca/offer/senior-engineer-instrumentation-and-controls/873334/',
#  '3808ba4110a7663d046d9b2dff60d9de',
#  'https://www',
#  'jobs',
#  'ca',
#  'https://www',
#  'jobs',
#  'ca/offer/senior-engineer-instrumentation-and-controls/873334/',
#  'Senior',
#  'Engineer,',
#  'Instrumentation',
#  'and',
#  'Controls',
#  'Français',
#  'Careers',
#  'View',
#  'Profile',
#  'Français',
#  'View',
#  'all',
#  'jobs',
#  'Filter',
#  'by',
#  'category',
#  'Engineers',
#  'Business',
#  'professionals',
#  'Trades',
#  '&',
#  'operators',
#  'Students',
#  '&',
#  'new',
#  'grads',
#  'Search',
#  'by',
#  'location',
#  'Join',
#  'our',
#  'community',
#  'View',
#  'Profile',
#  'Search',
#  'by',
#  'Keyword',
#  'Search',
#  'by',
#  'Location',
#  'Search',
#  'jobs',
#  '×',
#  'Send',
#  'me',
#  'alerts',
#  'every',
#  'days',
#  'Create',
#  'Alert',
#  '×',
#  'Send',
#  'me',
#  'alerts',
#  'every',
#  'days',
#  'Share',
#  'this',
#  'Job',
#  'var',
#  'searchString',
#  '=',
#  "'';",
#  'var',
#  'siteName',
#  '=',
#  '"Suncor',
#  'Energy',
#  'Services";',
#  '$(function()',
#  '{',
#  "$('",
#  "rsslink-jobs2web')",
#  "unbind('click')",
#  'click(function(e){',
#  "TrackGoogleAnalytics('/feed/rss/0',",
#  '0,',
#  '0,',
#  'searchString,',
#  "'RSSFeed',",
#  'siteName);',
#  '});',
#  "$('",
#  "rsslink-google')",
#  "unbind('click')",
#  'click(function(){',
#  "TrackGoogleAnalytics('/feed/google/0',",
#  '0,',
#  '0,',
#  'searchString,',
#  "'GoogleFeed',",
#  'siteName);',
#  '});',
#  "$('",
#  "rsslink-yahoo')",
#  "unbind('click')",
#  'click(function(){',
#  "TrackGoogleAnalytics('/feed/yahoo/0',",
#  '0,',
#  '0,',
#  'searchString,',
#  "'YahooFeed',",
#  'siteName);',
#  '});',
#  "$('",
#  "rsslink-msn')",
#  "unbind('click')",
#  'click(function(){',
#  "TrackGoogleAnalytics('/feed/msn/0',",
#  '0,',
#  '0,',
#  'searchString,',
#  "'MSNFeed',",
#  'siteName);',
#  '});',
#  '});',
#  '//<',
#  '[CDATA[',
#  'var',
#  'trackVars',
#  '=',
#  '{"refid":""};',
#  'var',
#  'lang',
#  '=',
#  '"en";',
#  'var',
#  'gaPropertyId',
#  '=',
#  '"";',
#  'var',
#  'httpProtocol',
#  '=',
#  '"https";',
#  '//]]>',
#  'var',
#  'addthis_config',
#  '=',
#  '{',
#  "username:'addthisj2w'",
#  ',ui_open_windows:',
#  'true',
#  ',ui_click:',
#  'true',
#  ',ui_508_compliant:',
#  'true',
#  ',data_track_clickback:',
#  'false',
#  ',ui_language:',
#  '"en"',
#  ',data_ga_property:',
#  '""',
#  ',data_ga_social:',
#  'true',
#  '};',
#  'var',
#  'calledsfshorturl',
#  '=',
#  'false;',
#  '$(function(){',
#  "$('",
#  "addthis_toolbox')",
#  'mouseover(function(e){',
#  'if',
#  '(',
#  'calledsfshorturl)',
#  '{',
#  'calledsfshorturl',
#  '=',
#  'true;',
#  '$(this)',
#  'sfshorturl({',
#  'callback:addthisCallback',
#  ',event:e',
#  ',track:',
#  'trackVars',
#  '});',
#  '}',
#  '});',
#  'function',
#  'addthisCallback(data){',
#  '$(data',
#  'event',
#  'target)',
#  "attr('addthis:url',data",
#  'shorturl);',
#  'addthis',
#  "update('share',",
#  "'url',",
#  'data',
#  'shorturl);',
#  '}',
#  '});',
#  'Senior',
#  'Engineer,',
#  'Instrumentation',
#  'and',
#  'Controls',
#  'Apply',
#  'now',
#  '»',
#  'Apply',
#  'now',
#  'Apply',
#  'Now',
#  'Start',
#  'apply',
#  'with',
#  'LinkedIn',
#  'Start',
#  'Please',
#  'wait',
#  'Date:',
#  'Jul',
#  '18,',
#  '2017',
#  'LOCATION:',
#  'Edmonton,',
#  'Alberta',
#  '(CA-AB)',
#  'JOB',
#  'NUMBER:',
#  '16130',
#  '\xa0',
#  'Job',
#  'Overview',
#  'Reporting',
#  'to',
#  'the',
#  'team',
#  'leader,',
#  'instrumentation,',
#  'electrical',
#  'and',
#  'controls',
#  'area',
#  'projects,',
#  'you',
#  'will',
#  'help',
#  'support',
#  'and',
#  'lead',
#  'the',
#  'refinery',
#  'wide',
#  'instrumentation',
#  'and',
#  'controls',
#  'projects',
#  'and',
#  'long-term',
#  'plans',
#  'to',
#  'ensure',
#  'safe',
#  'and',
#  'reliable',
#  'operations',
#  'within',
#  'the',
#  'Edmonton',
#  'refinery',
#  'Key',
#  'Accountabilities',
#  'Develop',
#  'detailed',
#  'engineering',
#  'work',
#  'packages',
#  'in',
#  'accordance',
#  'with',
#  'project',
#  'specifications',
#  'and',
#  'provide',
#  'construction,',
#  'commissioning',
#  'and',
#  'start-up',
#  'support',
#  'Develop',
#  'control',
#  'narratives',
#  'for',
#  'new',
#  'and',
#  'existing',
#  'DCS',
#  'control',
#  'and',
#  'safety',
#  'systems;',
#  'investigate',
#  'and',
#  'troubleshoot',
#  'control',
#  'system',
#  'configuration',
#  'problems',
#  'and',
#  'recommend',
#  'quick',
#  'and',
#  'reliable',
#  'solutions',
#  'Review',
#  'work',
#  'packages',
#  'for',
#  'error',
#  'free',
#  'and',
#  'consistent',
#  'engineering',
#  'deliverables',
#  'as',
#  'per',
#  'applicable',
#  'codes',
#  'and',
#  'approved',
#  'engineering',
#  'standards',
#  'Design,',
#  'configure,',
#  'validate',
#  '(offline',
#  'simulation)',
#  'and',
#  'optimize',
#  'controls',
#  'software',
#  'packages',
#  'to',
#  'provide',
#  'accurate',
#  'and',
#  'reliable',
#  'software',
#  'deliverables',
#  'for',
#  'safe',
#  'refinery',
#  'operations;',
#  'test',
#  'systems',
#  'thoroughly',
#  'in',
#  'an',
#  'offline',
#  'environment',
#  'with',
#  'key',
#  'stakeholders',
#  'to',
#  'address',
#  'valid',
#  'concerns',
#  'Provide',
#  'continuous',
#  'improvement',
#  'and',
#  'standardization',
#  'feedback',
#  'towards',
#  'improved',
#  'controls',
#  'configuration',
#  'processes,',
#  'project',
#  'efficiencies,',
#  'quality',
#  'and',
#  'cost',
#  'effectiveness',
#  'Exercise',
#  'cost',
#  'control',
#  'when',
#  'providing',
#  'engineering',
#  'solutions,',
#  'review',
#  'and',
#  'maintain',
#  'project',
#  'schedules,',
#  'track',
#  'engineering',
#  'tasks',
#  'and',
#  'deliverables',
#  'in',
#  'conjunction',
#  'with',
#  'project',
#  'management',
#  'Prepare',
#  'material',
#  'requisitions',
#  'and',
#  'complete',
#  'technical',
#  'evaluations',
#  'by',
#  'reviewing',
#  'vendor',
#  'or',
#  'subcontractor',
#  'quotations,',
#  'drawings',
#  'and',
#  'specifications',
#  'in',
#  'conformance',
#  'with',
#  'project',
#  'requirements',
#  'Participate',
#  'in',
#  'design',
#  'reviews,',
#  'process',
#  'hazard',
#  'analysis,',
#  'management',
#  'of',
#  'change,',
#  'layers',
#  'of',
#  'protection',
#  'analysis',
#  '(LOPA)',
#  'and',
#  'safety',
#  'integrity',
#  'level',
#  '(SIL)',
#  'analysis\xa0',
#  'Use',
#  'resources',
#  'effectively',
#  'and',
#  'offer',
#  'coaching',
#  'to',
#  'junior',
#  'staff',
#  'and',
#  'contractor',
#  'resources',
#  'Required',
#  'Qualifications',
#  'Experience',
#  'and',
#  'Education:',
#  'Eight',
#  'or',
#  'more',
#  'years',
#  'of',
#  'control',
#  'systems',
#  'experience\xa0',
#  'Demonstrated',
#  'experience',
#  'in',
#  'developing',
#  'engineering',
#  'work',
#  'packages',
#  'and',
#  'hands-on',
#  'control',
#  'systems',
#  'programming',
#  'experience',
#  'in',
#  'an',
#  'oil',
#  'refinery',
#  'for',
#  'at',
#  'least',
#  'two',
#  'years;',
#  'experience',
#  'at',
#  'the',
#  'Edmonton',
#  'refinery',
#  'is',
#  'considered',
#  'an',
#  'asset',
#  'Demonstrated',
#  'experience',
#  'on',
#  'interfacing',
#  'near',
#  'infrared',
#  'analyzer,',
#  'nuclear',
#  'magnetic',
#  'resonance',
#  'and',
#  'sample',
#  'conditioning',
#  'systems',
#  'with',
#  'Honeywell',
#  'Experion',
#  'and',
#  'TDC3000',
#  'DCS',
#  'in',
#  'a',
#  'refinery',
#  'environment;',
#  'advanced',
#  'competency',
#  'with',
#  'Triconex',
#  'PLC',
#  'programming',
#  'and',
#  'Unity',
#  'Pro',
#  'for',
#  'Modicon',
#  'PLC',
#  'Bachelor’s',
#  'degree',
#  'in',
#  'engineering;',
#  'post',
#  'graduate',
#  'qualifications',
#  'will',
#  'be',
#  'an',
#  'asset',
#  'Registered',
#  'as',
#  'a',
#  'professional',
#  'engineer',
#  'with',
#  'the',
#  'Association',
#  'of',
#  'Professional',
#  'Engineers',
#  'and',
#  'Geoscientists',
#  'of',
#  'Alberta',
#  '(APEGA)',
#  'Skills',
#  'and',
#  'Knowledge:',
#  'Hands-on',
#  'maintenance',
#  'and',
#  'configuration',
#  'experience',
#  'with',
#  'distributed',
#  'control',
#  'system',
#  '(Experion,',
#  'C300,',
#  'C200,',
#  'TDC3000,',
#  'SCADA),',
#  'safety',
#  'instrumented',
#  'systems',
#  '(Triconex),',
#  'and',
#  'programmable',
#  'logic',
#  'controllers',
#  '(Modicon)',
#  'Strong',
#  'technical',
#  'knowledge',
#  'of',
#  'applicable',
#  'automation',
#  'industry',
#  'standards,',
#  'SIL',
#  'assessment,',
#  'LOPA',
#  'methodologies,',
#  'and',
#  'alarm',
#  'management',
#  'guidelines',
#  'Experience',
#  'on',
#  'Burner',
#  'Management',
#  'System',
#  '(BMS),',
#  'compressor,',
#  '\xa0fire',
#  'and',
#  'gas',
#  'detection',
#  'system',
#  'and',
#  'Triconex',
#  'upgrade',
#  'Strong',
#  'interpersonal',
#  'skills',
#  'to',
#  'work',
#  'with',
#  'the',
#  'engineering',
#  'contractors,',
#  'vendors',
#  'and',
#  'project',
#  'teams,',
#  'in',
#  'a',
#  'multi-discipline',
#  'work',
#  'environment',
#  'Self-motivated',
#  'individual',
#  'with',
#  'excellent',
#  'communication,',
#  'analytical,',
#  'and',
#  'organizational',
#  'skills',
#  'Working',
#  'Conditions',
#  'Potential',
#  'to',
#  'work',
#  'extended',
#  'hours',
#  'to',
#  'support',
#  'turnaround',
#  'related',
#  'shift',
#  'roles',
#  'as',
#  'required',
#  'Why',
#  'Suncor',
#  'Go',
#  'ahead',
#  'Expect',
#  'growth',
#  'We',
#  'want',
#  'you',
#  'to',
#  'have',
#  'a',
#  'job',
#  "you're",
#  'genuinely',
#  'excited',
#  'about',
#  '-',
#  'as',
#  'well',
#  'as',
#  'opportunities',
#  'to',
#  'learn',
#  'and',
#  'challenge',
#  'yourself',
#  'or',
#  'mentor',
#  'others',
#  'Plus,',
#  'Suncor',
#  'Energy',
#  'offers',
#  'a',
#  'flexible',
#  'employee',
#  'package',
#  'that',
#  'can',
#  'be',
#  'adjusted',
#  'to',
#  'suit',
#  'the',
#  'changing',
#  'needs',
#  'of',
#  'your',
#  'life,',
#  'including:',
#  'Competitive',
#  'base',
#  'salary',
#  'and',
#  'compensation',
#  'programs',
#  'Attractive',
#  'annual',
#  'incentive',
#  'program',
#  'Flexible',
#  'benefits',
#  'package',
#  'Rewarding',
#  'pension',
#  'and',
#  'savings',
#  'plans',
#  'Business',
#  'Overview',
#  'Suncor',
#  'Energy',
#  'is',
#  "Canada's",
#  'energy',
#  'company',
#  '-',
#  'meaning',
#  'rewarding',
#  'opportunities',
#  'for',
#  'you',
#  'to',
#  'apply',
#  'your',
#  'knowledge,',
#  'contribute',
#  'and',
#  'grow',
#  'in',
#  'a',
#  'variety',
#  'of',
#  'career-building',
#  'positions',
#  'Our',
#  'business',
#  'portfolio',
#  'spans',
#  'the',
#  'entire',
#  'energy',
#  'sector,',
#  'from',
#  'a',
#  'leadership',
#  'position',
#  'in',
#  'oil',
#  'sands',
#  'development,',
#  'to',
#  'refining',
#  'and',
#  'marketing',
#  'operations,',
#  'natural',
#  'gas,',
#  'and',
#  'conventional',
#  'oil',
#  'production,',
#  'internationally',
#  'and',
#  'offshore',
#  'East',
#  'Coast',
#  'Canada',
#  'And',
#  'while',
#  'we',
#  'are',
#  'working',
#  'to',
#  'responsibly',
#  'develop',
#  'petroleum',
#  'resources',
#  'and',
#  'contribute',
#  'to',
#  'the',
#  'communities',
#  'where',
#  'we',
#  'live',
#  'and',
#  'work,',
#  'we',
#  'are',
#  'also',
#  'developing',
#  'our',
#  'renewable',
#  'energy',
#  'portfolio,',
#  'which',
#  'includes',
#  'wind',
#  'power',
#  'and',
#  'biofuels',
#  'As',
#  'part',
#  'of',
#  "Suncor's",
#  'team,',
#  "you'll",
#  'contribute',
#  'to',
#  'the',
#  'ongoing',
#  'success',
#  'of',
#  "Canada's",
#  'largest',
#  'energy',
#  'company',
#  '-',
#  'one',
#  'with',
#  'a',
#  'solid',
#  'track',
#  'record',
#  'of',
#  'growth,',
#  'a',
#  'focus',
#  'on',
#  'safety',
#  'and',
#  'sustainability',
#  'and',
#  'tremendous',
#  'potential',
#  'for',
#  'the',
#  'future',
#  'And',
#  "you'll",
#  'have',
#  'the',
#  'opportunity',
#  'to',
#  'learn',
#  'from',
#  'experts',
#  'in',
#  'the',
#  'industry',
#  'and',
#  'build',
#  'on',
#  'your',
#  'skills',
#  'every',
#  'day',
#  'Suncor',
#  'promotes',
#  'diversity',
#  'and',
#  'inclusion',
#  'in',
#  'the',
#  'workplace',
#  'Suncor',
#  'is',
#  'an',
#  'equal',
#  'opportunity',
#  'employer',
#  'and',
#  'encourages',
#  'applications',
#  'from',
#  'all',
#  'qualified',
#  'individuals',
#  'At',
#  'Suncor,',
#  'we',
#  'are',
#  'dedicated',
#  'to',
#  'building',
#  'a',
#  'workforce',
#  'that',
#  'reflects',
#  'the',
#  'diversity',
#  'of',
#  'the',
#  'communitities',
#  'in',
#  'which',
#  'we',
#  'live,',
#  'and',
#  'where',
#  'every',
#  'team',
#  'member',
#  'has',
#  'the',
#  'opportunity',
#  'to',
#  'reach',
#  'their',
#  'full',
#  'potential',
#  'Not',
#  'sure',
#  'if',
#  'this',
#  'particular',
#  'listing',
#  'is',
#  'the',
#  'right',
#  'opportunity',
#  'for',
#  'you',
#  'Please',
#  'join',
#  'our',
#  'Talent',
#  'Community',
#  'at',
#  'www',
#  'suncor',
#  'com',
#  'and',
#  'click',
#  'on',
#  'Careers,',
#  'or',
#  'follow',
#  'us',
#  'on',
#  'LinkedIn,',
#  'Facebook',
#  'and',
#  'Twitter',
#  'for',
#  'the',
#  'latest',
#  'job',
#  'listings',
#  'and',
#  'employment',
#  'news',
#  'Please',
#  'note',
#  'that',
#  'our',
#  'job',
#  'postings',
#  'are',
#  'typically',
#  'open',
#  ...]

# %%
# Import the toolkit and the full Porter Stemmer library
import nltk
from nltk.stem.porter import *
from nltk.stem.snowball import SnowballStemmer

# The Snowball Stemmer requires that you pass a language parameter
s_stemmer = SnowballStemmer(language='english')

# %%
#Stemming

for word in re.findall(r"[^!.? ]+",s):
    print(word+' --> '+s_stemmer.stem(word))
# Out:
# pageurl --> pageurl
# record/uniq_id --> record/uniq_id
# record/job_board --> record/job_board
# record/page_url --> record/page_url
# record/job_title --> record/job_titl
# record/job_description --> record/job_descript
# record/location --> record/loc
# record/country_code
# 0 --> record/country_code
# 0
# https://www --> https://www
# jobs --> job
# ca/offer/senior-engineer-instrumentation-and-controls/873334/ --> ca/offer/senior-engineer-instrumentation-and-controls/873334/
# 3808ba4110a7663d046d9b2dff60d9de --> 3808ba4110a7663d046d9b2dff60d9d
# https://www --> https://www
# jobs --> job
# ca --> ca
# https://www --> https://www
# jobs --> job
# ca/offer/senior-engineer-instrumentation-and-controls/873334/ --> ca/offer/senior-engineer-instrumentation-and-controls/873334/
# Senior --> senior
# Engineer, --> engineer,
# Instrumentation --> instrument
# and --> and
# Controls --> control
# Français --> françai
# Careers --> career
# View --> view
# Profile --> profil
# Français --> françai
# View --> view
# all --> all
# jobs --> job
# Filter --> filter
# by --> by
# category --> categori
# Engineers --> engin
# Business --> busi
# professionals --> profession
# Trades --> trade
# & --> &
# operators --> oper
# Students --> student
# & --> &
# new --> new
# grads --> grad
# Search --> search
# by --> by
# location --> locat
# Join --> join
# our --> our
# community --> communiti
# View --> view
# Profile --> profil
# Search --> search
# by --> by
# Keyword --> keyword
# Search --> search
# by --> by
# Location --> locat
# Search --> search
# jobs --> job
# × --> ×
# Send --> send
# me --> me
# alerts --> alert
# every --> everi
# days --> day
# Create --> creat
# Alert --> alert
# × --> ×
# Send --> send
# me --> me
# alerts --> alert
# every --> everi
# days --> day
# Share --> share
# this --> this
# Job --> job
# var --> var
# searchString --> searchstr
# = --> =
# ''; --> ';
# var --> var
# siteName --> sitenam
# = --> =
# "Suncor --> "suncor
# Energy --> energi
# Services"; --> services";
# $(function() --> $(function()
# { --> {
# $(' --> $(
# rsslink-jobs2web') --> rsslink-jobs2web')
# unbind('click') --> unbind('click')
# click(function(e){ --> click(function(e){
# TrackGoogleAnalytics('/feed/rss/0', --> trackgoogleanalytics('/feed/rss/0',
# 0, --> 0,
# 0, --> 0,
# searchString, --> searchstring,
# 'RSSFeed', --> rssfeed',
# siteName); --> sitename);
# }); --> });
# $(' --> $(
# rsslink-google') --> rsslink-google')
# unbind('click') --> unbind('click')
# click(function(){ --> click(function(){
# TrackGoogleAnalytics('/feed/google/0', --> trackgoogleanalytics('/feed/google/0',
# 0, --> 0,
# 0, --> 0,
# searchString, --> searchstring,
# 'GoogleFeed', --> googlefeed',
# siteName); --> sitename);
# }); --> });
# $(' --> $(
# rsslink-yahoo') --> rsslink-yahoo')
# unbind('click') --> unbind('click')
# click(function(){ --> click(function(){
# TrackGoogleAnalytics('/feed/yahoo/0', --> trackgoogleanalytics('/feed/yahoo/0',
# 0, --> 0,
# 0, --> 0,
# searchString, --> searchstring,
# 'YahooFeed', --> yahoofeed',
# siteName); --> sitename);
# }); --> });
# $(' --> $(
# rsslink-msn') --> rsslink-msn')
# unbind('click') --> unbind('click')
# click(function(){ --> click(function(){
# TrackGoogleAnalytics('/feed/msn/0', --> trackgoogleanalytics('/feed/msn/0',
# 0, --> 0,
# 0, --> 0,
# searchString, --> searchstring,
# 'MSNFeed', --> msnfeed',
# siteName); --> sitename);
# }); --> });
# }); --> });
# //< --> //<
# [CDATA[ --> [cdata[
# var --> var
# trackVars --> trackvar
# = --> =
# {"refid":""}; --> {"refid":""};
# var --> var
# lang --> lang
# = --> =
# "en"; --> "en";
# var --> var
# gaPropertyId --> gapropertyid
# = --> =
# ""; --> "";
# var --> var
# httpProtocol --> httpprotocol
# = --> =
# "https"; --> "https";
# //]]> --> //]]>
# var --> var
# addthis_config --> addthis_config
# = --> =
# { --> {
# username:'addthisj2w' --> username:'addthisj2w
# ,ui_open_windows: --> ,ui_open_windows:
# true --> true
# ,ui_click: --> ,ui_click:
# true --> true
# ,ui_508_compliant: --> ,ui_508_compliant:
# true --> true
# ,data_track_clickback: --> ,data_track_clickback:
# false --> fals
# ,ui_language: --> ,ui_language:
# "en" --> "en"
# ,data_ga_property: --> ,data_ga_property:
# "" --> ""
# ,data_ga_social: --> ,data_ga_social:
# true --> true
# }; --> };
# var --> var
# calledsfshorturl --> calledsfshorturl
# = --> =
# false; --> false;
# $(function(){ --> $(function(){
# $(' --> $(
# addthis_toolbox') --> addthis_toolbox')
# mouseover(function(e){ --> mouseover(function(e){
# if --> if
# ( --> (
# calledsfshorturl) --> calledsfshorturl)
# { --> {
# calledsfshorturl --> calledsfshorturl
# = --> =
# true; --> true;
# $(this) --> $(this)
# sfshorturl({ --> sfshorturl({
# callback:addthisCallback --> callback:addthiscallback
# ,event:e --> ,event:
# ,track: --> ,track:
# trackVars --> trackvar
# }); --> });
# } --> }
# }); --> });
# function --> function
# addthisCallback(data){ --> addthiscallback(data){
# $(data --> $(data
# event --> event
# target) --> target)
# attr('addthis:url',data --> attr('addthis:url',data
# shorturl); --> shorturl);
# addthis --> addthi
# update('share', --> update('share',
# 'url', --> url',
# data --> data
# shorturl); --> shorturl);
# } --> }
# }); --> });
# Senior --> senior
# Engineer, --> engineer,
# Instrumentation --> instrument
# and --> and
# Controls --> control
# Apply --> appli
# now --> now
# » --> »
# Apply --> appli
# now --> now
# Apply --> appli
# Now --> now
# Start --> start
# apply --> appli
# with --> with
# LinkedIn --> linkedin
# Start --> start
# Please --> pleas
# wait --> wait
# Date: --> date:
# Jul --> jul
# 18, --> 18,
# 2017 --> 2017
# LOCATION: --> location:
# Edmonton, --> edmonton,
# Alberta --> alberta
# (CA-AB) --> (ca-ab)
# JOB --> job
# NUMBER: --> number:
# 16130 --> 16130
#   -->
# Job --> job
# Overview --> overview
# Reporting --> report
# to --> to
# the --> the
# team --> team
# leader, --> leader,
# instrumentation, --> instrumentation,
# electrical --> electr
# and --> and
# controls --> control
# area --> area
# projects, --> projects,
# you --> you
# will --> will
# help --> help
# support --> support
# and --> and
# lead --> lead
# the --> the
# refinery --> refineri
# wide --> wide
# instrumentation --> instrument
# and --> and
# controls --> control
# projects --> project
# and --> and
# long-term --> long-term
# plans --> plan
# to --> to
# ensure --> ensur
# safe --> safe
# and --> and
# reliable --> reliabl
# operations --> oper
# within --> within
# the --> the
# Edmonton --> edmonton
# refinery --> refineri
# Key --> key
# Accountabilities --> account
# Develop --> develop
# detailed --> detail
# engineering --> engin
# work --> work
# packages --> packag
# in --> in
# accordance --> accord
# with --> with
# project --> project
# specifications --> specif
# and --> and
# provide --> provid
# construction, --> construction,
# commissioning --> commiss
# and --> and
# start-up --> start-up
# support --> support
# Develop --> develop
# control --> control
# narratives --> narrat
# for --> for
# new --> new
# and --> and
# existing --> exist
# DCS --> dcs
# control --> control
# and --> and
# safety --> safeti
# systems; --> systems;
# investigate --> investig
# and --> and
# troubleshoot --> troubleshoot
# control --> control
# system --> system
# configuration --> configur
# problems --> problem
# and --> and
# recommend --> recommend
# quick --> quick
# and --> and
# reliable --> reliabl
# solutions --> solut
# Review --> review
# work --> work
# packages --> packag
# for --> for
# error --> error
# free --> free
# and --> and
# consistent --> consist
# engineering --> engin
# deliverables --> deliver
# as --> as
# per --> per
# applicable --> applic
# codes --> code
# and --> and
# approved --> approv
# engineering --> engin
# standards --> standard
# Design, --> design,
# configure, --> configure,
# validate --> valid
# (offline --> (offlin
# simulation) --> simulation)
# and --> and
# optimize --> optim
# controls --> control
# software --> softwar
# packages --> packag
# to --> to
# provide --> provid
# accurate --> accur
# and --> and
# reliable --> reliabl
# software --> softwar
# deliverables --> deliver
# for --> for
# safe --> safe
# refinery --> refineri
# operations; --> operations;
# test --> test
# systems --> system
# thoroughly --> thorough
# in --> in
# an --> an
# offline --> offlin
# environment --> environ
# with --> with
# key --> key
# stakeholders --> stakehold
# to --> to
# address --> address
# valid --> valid
# concerns --> concern
# Provide --> provid
# continuous --> continu
# improvement --> improv
# and --> and
# standardization --> standard
# feedback --> feedback
# towards --> toward
# improved --> improv
# controls --> control
# configuration --> configur
# processes, --> processes,
# project --> project
# efficiencies, --> efficiencies,
# quality --> qualiti
# and --> and
# cost --> cost
# effectiveness --> effect
# Exercise --> exercis
# cost --> cost
# control --> control
# when --> when
# providing --> provid
# engineering --> engin
# solutions, --> solutions,
# review --> review
# and --> and
# maintain --> maintain
# project --> project
# schedules, --> schedules,
# track --> track
# engineering --> engin
# tasks --> task
# and --> and
# deliverables --> deliver
# in --> in
# conjunction --> conjunct
# with --> with
# project --> project
# management --> manag
# Prepare --> prepar
# material --> materi
# requisitions --> requisit
# and --> and
# complete --> complet
# technical --> technic
# evaluations --> evalu
# by --> by
# reviewing --> review
# vendor --> vendor
# or --> or
# subcontractor --> subcontractor
# quotations, --> quotations,
# drawings --> draw
# and --> and
# specifications --> specif
# in --> in
# conformance --> conform
# with --> with
# project --> project
# requirements --> requir
# Participate --> particip
# in --> in
# design --> design
# reviews, --> reviews,
# process --> process
# hazard --> hazard
# analysis, --> analysis,
# management --> manag
# of --> of
# change, --> change,
# layers --> layer
# of --> of
# protection --> protect
# analysis --> analysi
# (LOPA) --> (lopa)
# and --> and
# safety --> safeti
# integrity --> integr
# level --> level
# (SIL) --> (sil)
# analysis  --> analysis
# Use --> use
# resources --> resourc
# effectively --> effect
# and --> and
# offer --> offer
# coaching --> coach
# to --> to
# junior --> junior
# staff --> staff
# and --> and
# contractor --> contractor
# resources --> resourc
# Required --> requir
# Qualifications --> qualif
# Experience --> experi
# and --> and
# Education: --> education:
# Eight --> eight
# or --> or
# more --> more
# years --> year
# of --> of
# control --> control
# systems --> system
# experience  --> experience
# Demonstrated --> demonstr
# experience --> experi
# in --> in
# developing --> develop
# engineering --> engin
# work --> work
# packages --> packag
# and --> and
# hands-on --> hands-on
# control --> control
# systems --> system
# programming --> program
# experience --> experi
# in --> in
# an --> an
# oil --> oil
# refinery --> refineri
# for --> for
# at --> at
# least --> least
# two --> two
# years; --> years;
# experience --> experi
# at --> at
# the --> the
# Edmonton --> edmonton
# refinery --> refineri
# is --> is
# considered --> consid
# an --> an
# asset --> asset
# Demonstrated --> demonstr
# experience --> experi
# on --> on
# interfacing --> interfac
# near --> near
# infrared --> infrar
# analyzer, --> analyzer,
# nuclear --> nuclear
# magnetic --> magnet
# resonance --> reson
# and --> and
# sample --> sampl
# conditioning --> condit
# systems --> system
# with --> with
# Honeywell --> honeywel
# Experion --> experion
# and --> and
# TDC3000 --> tdc3000
# DCS --> dcs
# in --> in
# a --> a
# refinery --> refineri
# environment; --> environment;
# advanced --> advanc
# competency --> compet
# with --> with
# Triconex --> triconex
# PLC --> plc
# programming --> program
# and --> and
# Unity --> uniti
# Pro --> pro
# for --> for
# Modicon --> modicon
# PLC --> plc
# Bachelor’s --> bachelor
# degree --> degre
# in --> in
# engineering; --> engineering;
# post --> post
# graduate --> graduat
# qualifications --> qualif
# will --> will
# be --> be
# an --> an
# asset --> asset
# Registered --> regist
# as --> as
# a --> a
# professional --> profession
# engineer --> engin
# with --> with
# the --> the
# Association --> associ
# of --> of
# Professional --> profession
# Engineers --> engin
# and --> and
# Geoscientists --> geoscientist
# of --> of
# Alberta --> alberta
# (APEGA) --> (apega)
# Skills --> skill
# and --> and
# Knowledge: --> knowledge:
# Hands-on --> hands-on
# maintenance --> mainten
# and --> and
# configuration --> configur
# experience --> experi
# with --> with
# distributed --> distribut
# control --> control
# system --> system
# (Experion, --> (experion,
# C300, --> c300,
# C200, --> c200,
# TDC3000, --> tdc3000,
# SCADA), --> scada),
# safety --> safeti
# instrumented --> instrument
# systems --> system
# (Triconex), --> (triconex),
# and --> and
# programmable --> programm
# logic --> logic
# controllers --> control
# (Modicon) --> (modicon)
# Strong --> strong
# technical --> technic
# knowledge --> knowledg
# of --> of
# applicable --> applic
# automation --> autom
# industry --> industri
# standards, --> standards,
# SIL --> sil
# assessment, --> assessment,
# LOPA --> lopa
# methodologies, --> methodologies,
# and --> and
# alarm --> alarm
# management --> manag
# guidelines --> guidelin
# Experience --> experi
# on --> on
# Burner --> burner
# Management --> manag
# System --> system
# (BMS), --> (bms),
# compressor, --> compressor,
#  fire -->  fire
# and --> and
# gas --> gas
# detection --> detect
# system --> system
# and --> and
# Triconex --> triconex
# upgrade --> upgrad
# Strong --> strong
# interpersonal --> interperson
# skills --> skill
# to --> to
# work --> work
# with --> with
# the --> the
# engineering --> engin
# contractors, --> contractors,
# vendors --> vendor
# and --> and
# project --> project
# teams, --> teams,
# in --> in
# a --> a
# multi-discipline --> multi-disciplin
# work --> work
# environment --> environ
# Self-motivated --> self-motiv
# individual --> individu
# with --> with
# excellent --> excel
# communication, --> communication,
# analytical, --> analytical,
# and --> and
# organizational --> organiz
# skills --> skill
# Working --> work
# Conditions --> condit
# Potential --> potenti
# to --> to
# work --> work
# extended --> extend
# hours --> hour
# to --> to
# support --> support
# turnaround --> turnaround
# related --> relat
# shift --> shift
# roles --> role
# as --> as
# required --> requir
# Why --> whi
# Suncor --> suncor
# Go --> go
# ahead --> ahead
# Expect --> expect
# growth --> growth
# We --> we
# want --> want
# you --> you
# to --> to
# have --> have
# a --> a
# job --> job
# you're --> you'r
# genuinely --> genuin
# excited --> excit
# about --> about
# - --> -
# as --> as
# well --> well
# as --> as
# opportunities --> opportun
# to --> to
# learn --> learn
# and --> and
# challenge --> challeng
# yourself --> yourself
# or --> or
# mentor --> mentor
# others --> other
# Plus, --> plus,
# Suncor --> suncor
# Energy --> energi
# offers --> offer
# a --> a
# flexible --> flexibl
# employee --> employe
# package --> packag
# that --> that
# can --> can
# be --> be
# adjusted --> adjust
# to --> to
# suit --> suit
# the --> the
# changing --> chang
# needs --> need
# of --> of
# your --> your
# life, --> life,
# including: --> including:
# Competitive --> competit
# base --> base
# salary --> salari
# and --> and
# compensation --> compens
# programs --> program
# Attractive --> attract
# annual --> annual
# incentive --> incent
# program --> program
# Flexible --> flexibl
# benefits --> benefit
# package --> packag
# Rewarding --> reward
# pension --> pension
# and --> and
# savings --> save
# plans --> plan
# Business --> busi
# Overview --> overview
# Suncor --> suncor
# Energy --> energi
# is --> is
# Canada's --> canada
# energy --> energi
# company --> compani
# - --> -
# meaning --> mean
# rewarding --> reward
# opportunities --> opportun
# for --> for
# you --> you
# to --> to
# apply --> appli
# your --> your
# knowledge, --> knowledge,
# contribute --> contribut
# and --> and
# grow --> grow
# in --> in
# a --> a
# variety --> varieti
# of --> of
# career-building --> career-build
# positions --> posit
# Our --> our
# business --> busi
# portfolio --> portfolio
# spans --> span
# the --> the
# entire --> entir
# energy --> energi
# sector, --> sector,
# from --> from
# a --> a
# leadership --> leadership
# position --> posit
# in --> in
# oil --> oil
# sands --> sand
# development, --> development,
# to --> to
# refining --> refin
# and --> and
# marketing --> market
# operations, --> operations,
# natural --> natur
# gas, --> gas,
# and --> and
# conventional --> convent
# oil --> oil
# production, --> production,
# internationally --> intern
# and --> and
# offshore --> offshor
# East --> east
# Coast --> coast
# Canada --> canada
# And --> and
# while --> while
# we --> we
# are --> are
# working --> work
# to --> to
# responsibly --> respons
# develop --> develop
# petroleum --> petroleum
# resources --> resourc
# and --> and
# contribute --> contribut
# to --> to
# the --> the
# communities --> communiti
# where --> where
# we --> we
# live --> live
# and --> and
# work, --> work,
# we --> we
# are --> are
# also --> also
# developing --> develop
# our --> our
# renewable --> renew
# energy --> energi
# portfolio, --> portfolio,
# which --> which
# includes --> includ
# wind --> wind
# power --> power
# and --> and
# biofuels --> biofuel
# As --> as
# part --> part
# of --> of
# Suncor's --> suncor
# team, --> team,
# you'll --> you'll
# contribute --> contribut
# to --> to
# the --> the
# ongoing --> ongo
# success --> success
# of --> of
# Canada's --> canada
# largest --> largest
# energy --> energi
# company --> compani
# - --> -
# one --> one
# with --> with
# a --> a
# solid --> solid
# track --> track
# record --> record
# of --> of
# growth, --> growth,
# a --> a
# focus --> focus
# on --> on
# safety --> safeti
# and --> and
# sustainability --> sustain
# and --> and
# tremendous --> tremend
# potential --> potenti
# for --> for
# the --> the
# future --> futur
# And --> and
# you'll --> you'll
# have --> have
# the --> the
# opportunity --> opportun
# to --> to
# learn --> learn
# from --> from
# experts --> expert
# in --> in
# the --> the
# industry --> industri
# and --> and
# build --> build
# on --> on
# your --> your
# skills --> skill
# every --> everi
# day --> day
# Suncor --> suncor
# promotes --> promot
# diversity --> divers
# and --> and
# inclusion --> inclus
# in --> in
# the --> the
# workplace --> workplac
# Suncor --> suncor
# is --> is
# an --> an
# equal --> equal
# opportunity --> opportun
# employer --> employ
# and --> and
# encourages --> encourag
# applications --> applic
# from --> from
# all --> all
# qualified --> qualifi
# individuals --> individu
# At --> at
# Suncor, --> suncor,
# we --> we
# are --> are
# dedicated --> dedic
# to --> to
# building --> build
# a --> a
# workforce --> workforc
# that --> that
# reflects --> reflect
# the --> the
# diversity --> divers
# of --> of
# the --> the
# communitities --> communit
# in --> in
# which --> which
# we --> we
# live, --> live,
# and --> and
# where --> where
# every --> everi
# team --> team
# member --> member
# has --> has
# the --> the
# opportunity --> opportun
# to --> to
# reach --> reach
# their --> their
# full --> full
# potential --> potenti
# Not --> not
# sure --> sure
# if --> if
# this --> this
# particular --> particular
# listing --> list
# is --> is
# the --> the
# right --> right
# opportunity --> opportun
# for --> for
# you --> you
# Please --> pleas
# join --> join
# our --> our
# Talent --> talent
# Community --> communiti
# at --> at
# www --> www
# suncor --> suncor
# com --> com
# and --> and
# click --> click
# on --> on
# Careers, --> careers,
# or --> or
# follow --> follow
# us --> us
# on --> on
# LinkedIn, --> linkedin,
# Facebook --> facebook
# and --> and
# Twitter --> twitter
# for --> for
# the --> the
# latest --> latest
# job --> job
# listings --> list
# and --> and
# employment --> employ
# news --> news
# Please --> pleas
# note --> note
# that --> that
# our --> our
# job --> job
# postings --> post
# are --> are
# typically --> typic
# open --> open
# for --> for
# two --> two
# weeks, --> weeks,
# so --> so
# if --> if
# you --> you
# are --> are
# interested --> interest
# and --> and
# qualified, --> qualified,
# apply --> appli
# now --> now
# JOB --> job
# CATEGORY: --> category:
# Engineering --> engin
# Job --> job
# Segment: --> segment:
# Controls --> control
# Engineer, --> engineer,
# Construction, --> construction,
# Instrumentation, --> instrumentation,
# Engineer, --> engineer,
# Electrical, --> electrical,
# Engineering --> engin
# Apply --> appli
# now --> now
# » --> »
# Apply --> appli
# now --> now
# Apply --> appli
# Now --> now
# Start --> start
# apply --> appli
# with --> with
# LinkedIn --> linkedin
# Start --> start
# Please --> pleas
# wait --> wait
# Find --> find
# similar --> similar
# jobs: --> jobs:
# Energy --> energi
# Jobs --> job
# in --> in
# Edmonton --> edmonton
# Connect --> connect
# with --> with
# Suncor --> suncor
# Our --> our
# social --> social
# media --> media
# channels --> channel
# Related --> relat
# links --> link
# Careers --> career
# home --> home
# View --> view
# all --> all
# jobs --> job
# Search --> search
# by --> by
# location --> locat
# Top --> top
# job --> job
# searches --> search
# Suncor --> suncor
# com --> com
# About --> about
# us --> us
# Accessibility --> access
# policy --> polici
# Legal --> legal
# & --> &
# privacy --> privaci
# Français --> françai
# © --> ©
# 2017 --> 2017
# Suncor --> suncor
# Energy --> energi
# Inc --> inc
# All --> all
# Rights --> right
# Reserved --> reserv
# Canada --> canada
# CA --> ca

# %%
##Function to display lemmas
def show_lemmas(text):
    for token in text:
        print(f'{token.text:{12}} {token.pos_:{6}} {token.lemma:<{22}} {token.lemma_}')

show_lemmas(doc)
# Out:
#                                                                            SPACE  17905419371157318882
# pageurl      NOUN   5485203307599741254    pageurl
#                     SPACE  3279268888731716531
# record       NOUN   12677120423429974351   record
# /            SYM    2466615745961202537    /
# uniq_id      PROPN  18318867001484744910   uniq_id
#              SPACE  3518396686757337811
# record       NOUN   12677120423429974351   record
# /            SYM    2466615745961202537    /
# job_board    PROPN  6352251602666443383    job_board
#                                                                  SPACE  1056688691105161902
# record       NOUN   12677120423429974351   record
# /            SYM    2466615745961202537    /
# page_url     PROPN  8891669333025704004    page_url
#                                SPACE  15724937611771062671
# record       PROPN  12677120423429974351   record
# /            SYM    2466615745961202537    /
# job_title    PROPN  6437943120659355126    job_title
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# record       NOUN   12677120423429974351   record
# /            SYM    2466615745961202537    /
# job_description PROPN  17074869836917015389   job_description
# record       NOUN   12677120423429974351   record
# /            SYM    2466615745961202537    /
# location     NOUN   4272944830542554761    location
# record       NOUN   12677120423429974351   record
# /            SYM    2466615745961202537    /
# country_code PROPN  15530586354196778051   country_code
#
#             SPACE  962983613142996970
#
# 0            NUM    746762829127501960     0
#              SPACE  8532415787641010193
# https://www.jobs.ca/offer/senior-engineer-instrumentation-and-controls/873334/ PROPN  13349819232335800689   https://www.jobs.ca/offer/senior-engineer-instrumentation-and-controls/873334/
#              SPACE  8532415787641010193
# 3808ba4110a7663d046d9b2dff60d9de NUM    2945337387070638710    3808ba4110a7663d046d9b2dff60d9de
#              SPACE  8532415787641010193
# https://www.jobs.ca X      764346249780892630     https://www.jobs.ca
#              SPACE  8532415787641010193
# https://www.jobs.ca/offer/senior-engineer-instrumentation-and-controls/873334/ PROPN  13349819232335800689   https://www.jobs.ca/offer/senior-engineer-instrumentation-and-controls/873334/
#              SPACE  8532415787641010193
# Senior       PROPN  9245954753952281271    Senior
# Engineer     PROPN  7029714065625710103    Engineer
# ,            PUNCT  2593208677638477497    ,
# Instrumentation PROPN  13948505819021949443   Instrumentation
# and          CCONJ  2283656566040971221    and
# Controls     PROPN  4550962452679798064    Controls
#              SPACE  8532415787641010193
# Français     PROPN  9661990699563991850    Français
# Careers      NOUN   16267834800013645067   career
# View         VERB   2608925738682777778    view
# Profile      PROPN  9059844313381461979    Profile
# Français     PROPN  9661990699563991850    Français
# View         VERB   2608925738682777778    view
# all          DET    13409319323822384369   all
# jobs         NOUN   18425606103329785088   job
# Filter       PROPN  12123680012006107910   Filter
# by           ADP    16764210730586636600   by
# category     NOUN   12545855305924804326   category
# Engineers    PROPN  4651764717593651265    Engineers
# Business     PROPN  3189656277002229662    Business
# professionals NOUN   1628340908579922823    professional
# Trades       PROPN  11706662568748791842   Trades
# &            CCONJ  15473034735919704609   &
# operators    NOUN   17230732322542086018   operator
# Students     PROPN  282904489848776904     Students
# &            CCONJ  15473034735919704609   &
# new          ADJ    4753564829687343602    new
# grads        NOUN   7525770801321979608    grad
# Search       VERB   295895373269394349     search
# by           ADP    16764210730586636600   by
# location     NOUN   4272944830542554761    location
# Join         VERB   16238441731120403936   join
# our          DET    561228191312463089     -PRON-
# community    NOUN   17822516981717808594   community
# View         NOUN   2608925738682777778    view
# Profile      PROPN  9059844313381461979    Profile
# Search       NOUN   295895373269394349     search
# by           ADP    16764210730586636600   by
# Keyword      PROPN  16123176905679438791   Keyword
# Search       PROPN  10439048276818773896   Search
# by           ADP    16764210730586636600   by
# Location     PROPN  6406047268281013305    Location
# Search       PROPN  10439048276818773896   Search
# jobs         NOUN   18425606103329785088   job
# ×            PUNCT  17530996820747916165   ×
# Send         VERB   6965176418496841198    send
# me           PRON   561228191312463089     -PRON-
# alerts       NOUN   4670405151688538211    alert
# every        DET    2739543297294151269    every
# days         NOUN   1608482186128794349    day
# Create       VERB   10217138629343254602   create
# Alert        NOUN   4670405151688538211    alert
# ×            PUNCT  17530996820747916165   ×
# Send         VERB   6965176418496841198    send
# me           PRON   561228191312463089     -PRON-
# alerts       NOUN   4670405151688538211    alert
# every        DET    2739543297294151269    every
# days         NOUN   1608482186128794349    day
# Share        PROPN  13039745931883698050   Share
# this         DET    1995909169258310477    this
# Job          PROPN  16842181437347778509   Job
# var          NOUN   17242580614136787773   var
# searchString NOUN   16056463499536457581   searchstring
# =            SYM    11162055469987148383   =
# ''           PUNCT  14143520107006108953   ''
# ;            PUNCT  631425121691394544     ;
# var          PROPN  17242580614136787773   var
# siteName     PROPN  10743273190323828847   siteName
# =            SYM    11162055469987148383   =
# "            PUNCT  15884554869126768810   "
# Suncor       PROPN  6214342204459202591    Suncor
# Energy       PROPN  16711491770240427610   Energy
# Services     PROPN  16271719928879294026   Services
# "            PUNCT  15884554869126768810   "
# ;            PUNCT  631425121691394544     ;
# $            SYM    11283501755624150392   $
# (            PUNCT  12638816674900267446   (
# function     NOUN   598416036538124536     function
# (            PUNCT  12638816674900267446   (
# )            PUNCT  3842344029291005339    )
# {            PUNCT  9847161165854524911    {
# $            SYM    11283501755624150392   $
# (            PUNCT  12638816674900267446   (
# '            PUNCT  11221368173670222813   '
# .rsslink     PUNCT  1593537841110700541    .rsslink
# -            PUNCT  9153284864653046197    -
# jobs2web').unbind('click').click(function(e PROPN  16958669039322663842   jobs2web').unbind('click').click(function(e
# )            PUNCT  3842344029291005339    )
# {            PUNCT  9847161165854524911    {
# TrackGoogleAnalytics('/feed PROPN  10801294017189175671   TrackGoogleAnalytics('/feed
# /            SYM    2466615745961202537    /
# rss/0        PROPN  10441982179678796225   rss/0
# '            PUNCT  11221368173670222813   '
# ,            PUNCT  2593208677638477497    ,
# 0            NUM    746762829127501960     0
# ,            PUNCT  2593208677638477497    ,
# 0            NUM    746762829127501960     0
# ,            PUNCT  2593208677638477497    ,
# searchString VERB   14551237581606183599   searchstre
# ,            PUNCT  2593208677638477497    ,
# '            PUNCT  11221368173670222813   '
# RSSFeed      PROPN  17611859679398459614   RSSFeed
# '            PUNCT  11221368173670222813   '
# ,            PUNCT  2593208677638477497    ,
# siteName     PROPN  10743273190323828847   siteName
# )            PUNCT  3842344029291005339    )
# ;            PUNCT  631425121691394544     ;
# }            PUNCT  7137162147818573492    }
# )            PUNCT  3842344029291005339    )
# ;            PUNCT  631425121691394544     ;
# $            SYM    11283501755624150392   $
# (            PUNCT  12638816674900267446   (
# '            PUNCT  11221368173670222813   '
# .rsslink     PUNCT  1593537841110700541    .rsslink
# -            PUNCT  9153284864653046197    -
# google').unbind('click').click(function NOUN   16828490533656335937   google').unbind('click').click(function
# (            PUNCT  12638816674900267446   (
# )            PUNCT  3842344029291005339    )
# {            PUNCT  9847161165854524911    {
# TrackGoogleAnalytics('/feed PROPN  10801294017189175671   TrackGoogleAnalytics('/feed
# /            SYM    2466615745961202537    /
# google/0     PROPN  6847525476679078060    google/0
# '            PUNCT  11221368173670222813   '
# ,            PUNCT  2593208677638477497    ,
# 0            NUM    746762829127501960     0
# ,            PUNCT  2593208677638477497    ,
# 0            NUM    746762829127501960     0
# ,            PUNCT  2593208677638477497    ,
# searchString VERB   14551237581606183599   searchstre
# ,            PUNCT  2593208677638477497    ,
# '            PUNCT  11221368173670222813   '
# GoogleFeed   PROPN  2967850546735928847    GoogleFeed
# '            PUNCT  11221368173670222813   '
# ,            PUNCT  2593208677638477497    ,
# siteName     PROPN  10743273190323828847   siteName
# )            PUNCT  3842344029291005339    )
# ;            PUNCT  631425121691394544     ;
# }            PUNCT  7137162147818573492    }
# )            PUNCT  3842344029291005339    )
# ;            PUNCT  631425121691394544     ;
# $            SYM    11283501755624150392   $
# (            PUNCT  12638816674900267446   (
# '            PUNCT  11221368173670222813   '
# .rsslink     PUNCT  1593537841110700541    .rsslink
# -            PUNCT  9153284864653046197    -
# yahoo').unbind('click').click(function NOUN   10547005354691791757   yahoo').unbind('click').click(function
# (            PUNCT  12638816674900267446   (
# )            PUNCT  3842344029291005339    )
# {            PUNCT  9847161165854524911    {
# TrackGoogleAnalytics('/feed PROPN  10801294017189175671   TrackGoogleAnalytics('/feed
# /            SYM    2466615745961202537    /
# yahoo/0      PROPN  13409739943482146772   yahoo/0
# '            PUNCT  11221368173670222813   '
# ,            PUNCT  2593208677638477497    ,
# 0            NUM    746762829127501960     0
# ,            PUNCT  2593208677638477497    ,
# 0            NUM    746762829127501960     0
# ,            PUNCT  2593208677638477497    ,
# searchString VERB   14551237581606183599   searchstre
# ,            PUNCT  2593208677638477497    ,
# '            PUNCT  11221368173670222813   '
# YahooFeed    PROPN  10804337399357169081   YahooFeed
# '            PUNCT  11221368173670222813   '
# ,            PUNCT  2593208677638477497    ,
# siteName     PROPN  10743273190323828847   siteName
# )            PUNCT  3842344029291005339    )
# ;            PUNCT  631425121691394544     ;
# }            PUNCT  7137162147818573492    }
# )            PUNCT  3842344029291005339    )
# ;            PUNCT  631425121691394544     ;
# $            SYM    11283501755624150392   $
# (            PUNCT  12638816674900267446   (
# '            PUNCT  11221368173670222813   '
# .rsslink     PUNCT  1593537841110700541    .rsslink
# -            PUNCT  9153284864653046197    -
# msn').unbind('click').click(function NUM    8840556763582275684    msn').unbind('click').click(function
# (            PUNCT  12638816674900267446   (
# )            PUNCT  3842344029291005339    )
# {            PUNCT  9847161165854524911    {
# TrackGoogleAnalytics('/feed PROPN  10801294017189175671   TrackGoogleAnalytics('/feed
# /            SYM    2466615745961202537    /
# msn/0        PROPN  7183536896770849490    msn/0
# '            PUNCT  11221368173670222813   '
# ,            PUNCT  2593208677638477497    ,
# 0            NUM    746762829127501960     0
# ,            PUNCT  2593208677638477497    ,
# 0            NUM    746762829127501960     0
# ,            PUNCT  2593208677638477497    ,
# searchString VERB   14551237581606183599   searchstre
# ,            PUNCT  2593208677638477497    ,
# '            PUNCT  11221368173670222813   '
# MSNFeed      NOUN   13720374044702819080   msnfeed
# '            PUNCT  11221368173670222813   '
# ,            PUNCT  2593208677638477497    ,
# siteName     PROPN  10743273190323828847   siteName
# )            PUNCT  3842344029291005339    )
# ;            PUNCT  631425121691394544     ;
# }            PUNCT  7137162147818573492    }
# )            PUNCT  3842344029291005339    )
# ;            PUNCT  631425121691394544     ;
# }            PUNCT  7137162147818573492    }
# )            PUNCT  3842344029291005339    )
# ;            PUNCT  631425121691394544     ;
# //<![CDATA   PUNCT  11160153913485875452   //<![CDATA
# [            PUNCT  4398759943034541363    [
# var          NOUN   17242580614136787773   var
# trackVars    NOUN   514757526427171306     trackvar
# =            NOUN   11162055469987148383   =
# {            PUNCT  9847161165854524911    {
# "            PUNCT  15884554869126768810   "
# refid        NOUN   12745403508197489013   refid
# "            PUNCT  15884554869126768810   "
# :            PUNCT  11532473245541075862   :
# "            PUNCT  15884554869126768810   "
# "            PUNCT  15884554869126768810   "
# }            PUNCT  7137162147818573492    }
# ;            PUNCT  631425121691394544     ;
# var          PROPN  17242580614136787773   var
# lang         PROPN  18436992917927619747   lang
# =            PUNCT  11162055469987148383   =
# "            PUNCT  15884554869126768810   "
# en           X      14626626061804382878   en
# "            PUNCT  15884554869126768810   "
# ;            PUNCT  631425121691394544     ;
# var          NOUN   17242580614136787773   var
# gaPropertyId X      15912595861893081074   gapropertyid
# =            VERB   11162055469987148383   =
# "            PUNCT  15884554869126768810   "
# "            PUNCT  15884554869126768810   "
# ;            PUNCT  631425121691394544     ;
# var          PROPN  17242580614136787773   var
# httpProtocol PROPN  9377660021418637304    httpProtocol
# =            SYM    11162055469987148383   =
# "            PUNCT  15884554869126768810   "
# https        NOUN   11579458050060195386   http
# "            PUNCT  15884554869126768810   "
# ;            PUNCT  631425121691394544     ;
# //           X      4873291044675205323    //
# ]            PUNCT  3806482680584466996    ]
# ]            PUNCT  3806482680584466996    ]
# >            PROPN  5924344943059983899    >
# var          NOUN   17242580614136787773   var
# addthis_config PROPN  4592196478853276801    addthis_config
# =            SYM    11162055469987148383   =
# {            PUNCT  9847161165854524911    {
# username:'addthisj2w NOUN   4429087553759371080    username:'addthisj2w
# '            PUNCT  11221368173670222813   '
# ,            PUNCT  2593208677638477497    ,
# ui_open_windows NOUN   4270793846414292743    ui_open_window
# :            PUNCT  11532473245541075862   :
# true         ADJ    7434368892455186804    true
# ,            PUNCT  2593208677638477497    ,
# ui_click     PROPN  8230616161587445263    ui_click
# :            PUNCT  11532473245541075862   :
# true         ADJ    7434368892455186804    true
# ,            PUNCT  2593208677638477497    ,
# ui_508_compliant ADJ    14533201978638194365   ui_508_compliant
# :            PUNCT  11532473245541075862   :
# true         ADJ    7434368892455186804    true
# ,            PUNCT  2593208677638477497    ,
# data_track_clickback NOUN   7842224594421445111    data_track_clickback
# :            PUNCT  11532473245541075862   :
# false        ADJ    17550068587262304638   false
# ,            PUNCT  2593208677638477497    ,
# ui_language  VERB   18362799863895473187   ui_language
# :            PUNCT  11532473245541075862   :
# "            PUNCT  15884554869126768810   "
# en           X      14626626061804382878   en
# "            PUNCT  15884554869126768810   "
# ,            PUNCT  2593208677638477497    ,
# data_ga_property PROPN  2569458902033565307    data_ga_property
# :            PUNCT  11532473245541075862   :
# "            PUNCT  15884554869126768810   "
# "            PUNCT  15884554869126768810   "
# ,            PUNCT  2593208677638477497    ,
# data_ga_social PROPN  6452537425741726122    data_ga_social
# :            PUNCT  11532473245541075862   :
# true         ADJ    7434368892455186804    true
# }            PUNCT  7137162147818573492    }
# ;            PUNCT  631425121691394544     ;
# var          NOUN   17242580614136787773   var
# calledsfshorturl NOUN   4360176064204820569    calledsfshorturl
# =            SYM    11162055469987148383   =
# false        ADJ    17550068587262304638   false
# ;            PUNCT  631425121691394544     ;
# $            SYM    11283501755624150392   $
# (            PUNCT  12638816674900267446   (
# function     NOUN   598416036538124536     function
# (            PUNCT  12638816674900267446   (
# )            PUNCT  3842344029291005339    )
# {            PUNCT  9847161165854524911    {
# $            SYM    11283501755624150392   $
# (            PUNCT  12638816674900267446   (
# '            PUNCT  11221368173670222813   '
# .addthis_toolbox').mouseover(function(e PROPN  14916883688628415773   .addthis_toolbox').mouseover(function(e
# )            PUNCT  3842344029291005339    )
# {            PUNCT  9847161165854524911    {
# if           SCONJ  12446819118446800910   if
# (            PUNCT  12638816674900267446   (
# !            PUNCT  17494803046312582752   !
# calledsfshorturl PROPN  4360176064204820569    calledsfshorturl
# )            PUNCT  3842344029291005339    )
# {            PUNCT  9847161165854524911    {
# calledsfshorturl NOUN   4360176064204820569    calledsfshorturl
# =            VERB   11162055469987148383   =
# true         ADJ    7434368892455186804    true
# ;            PUNCT  631425121691394544     ;
# $            SYM    11283501755624150392   $
# (            PUNCT  12638816674900267446   (
# this).sfshorturl CCONJ  9830053426427079403    this).sfshorturl
# (            PUNCT  12638816674900267446   (
# {            PUNCT  9847161165854524911    {
# callback     NOUN   12929472921216324353   callback
# :            PUNCT  11532473245541075862   :
# addthisCallback NOUN   5208074755715962621    addthiscallback
# ,            PUNCT  2593208677638477497    ,
# event        NOUN   16065740214838660377   event
# :            PUNCT  11532473245541075862   :
# e            X      1720370409040345145    e
# ,            PUNCT  2593208677638477497    ,
# track        NOUN   13353920538491180942   track
# :            PUNCT  11532473245541075862   :
# trackVars    NOUN   514757526427171306     trackvar
# }            PUNCT  7137162147818573492    }
# )            PUNCT  3842344029291005339    )
# ;            PUNCT  631425121691394544     ;
# }            PUNCT  7137162147818573492    }
# }            PUNCT  7137162147818573492    }
# )            PUNCT  3842344029291005339    )
# ;            PUNCT  631425121691394544     ;
# function     VERB   598416036538124536     function
# addthisCallback(data PROPN  8044612765674781162    addthisCallback(data
# )            PUNCT  3842344029291005339    )
# {            PUNCT  9847161165854524911    {
# $            SYM    11283501755624150392   $
# (            PUNCT  12638816674900267446   (
# data.event.target).attr('addthis DET    16703665309497424339   data.event.target).attr('addthis
# :            PUNCT  11532473245541075862   :
# url',data.shorturl NUM    15582704084403949475   url',data.shorturl
# )            PUNCT  3842344029291005339    )
# ;            PUNCT  631425121691394544     ;
# addthis.update('share PROPN  3089169061521465082    addthis.update('share
# '            PUNCT  11221368173670222813   '
# ,            PUNCT  2593208677638477497    ,
# '            PUNCT  11221368173670222813   '
# url          PROPN  13939090002020869547   url
# '            PUNCT  11221368173670222813   '
# ,            PUNCT  2593208677638477497    ,
# data.shorturl PROPN  15945103178747916294   data.shorturl
# )            PUNCT  3842344029291005339    )
# ;            PUNCT  631425121691394544     ;
# }            PUNCT  7137162147818573492    }
# }            PUNCT  7137162147818573492    }
# )            PUNCT  3842344029291005339    )
# ;            PUNCT  631425121691394544     ;
# Senior       PROPN  9245954753952281271    Senior
# Engineer     PROPN  7029714065625710103    Engineer
# ,            PUNCT  2593208677638477497    ,
# Instrumentation PROPN  13948505819021949443   Instrumentation
# and          CCONJ  2283656566040971221    and
# Controls     PROPN  4550962452679798064    Controls
# Apply        VERB   8841002517919878551    apply
# now          ADV    17157488710739566268   now
# »            INTJ   5342463183827332990    »
# Apply        VERB   8841002517919878551    apply
# now          ADV    17157488710739566268   now
# Apply        VERB   8841002517919878551    apply
# Now          ADV    17157488710739566268   now
# Start        PROPN  6653903367463496184    Start
# apply        VERB   8841002517919878551    apply
# with         ADP    12510949447758279278   with
# LinkedIn     PROPN  7219308988357715914    LinkedIn
# Start        NOUN   6480458294193393462    start
# Please       INTJ   99974891130002844      please
# wait         VERB   6203382976377178934    wait
# ...          PUNCT  10875615029400813363   ...
# Date         NOUN   15387552459474943870   date
# :            PUNCT  11532473245541075862   :
# Jul          PROPN  10294979432185667223   Jul
# 18           NUM    3049302120552557844    18
# ,            PUNCT  2593208677638477497    ,
# 2017         NUM    12587536829529815270   2017
# LOCATION     NOUN   4272944830542554761    location
# :            PUNCT  11532473245541075862   :
# Edmonton     PROPN  5494770740298034170    Edmonton
# ,            PUNCT  2593208677638477497    ,
# Alberta      PROPN  15137336096181088614   Alberta
# (            PUNCT  12638816674900267446   (
# CA           PROPN  8902657483871908647    CA
# -            PUNCT  9153284864653046197    -
# AB           PROPN  3916325639175504915    AB
# )            PUNCT  3842344029291005339    )
# JOB          NOUN   18425606103329785088   job
# NUMBER       NOUN   432                    number
# :            PUNCT  11532473245541075862   :
# 16130        NUM    7515700566349510701    16130
#              SPACE  9205076007239783027
# Job          PROPN  16842181437347778509   Job
# Overview     PROPN  11634391522534410362   Overview
# Reporting    VERB   2729752284408055516    report
# to           ADP    3791531372978436496    to
# the          DET    7425985699627899538    the
# team         NOUN   4303356597303500170    team
# leader       NOUN   12541414842550961509   leader
# ,            PUNCT  2593208677638477497    ,
# instrumentation NOUN   14273039053985598836   instrumentation
# ,            PUNCT  2593208677638477497    ,
# electrical   ADJ    16580780000321802414   electrical
# and          CCONJ  2283656566040971221    and
# controls     NOUN   572204754761179701     control
# area         NOUN   5961633188818984298    area
# projects     NOUN   10994073736148868485   project
# ,            PUNCT  2593208677638477497    ,
# you          PRON   561228191312463089     -PRON-
# will         VERB   18307573501153647118   will
# help         VERB   17461235395181654430   help
# support      VERB   5147005412574305164    support
# and          CCONJ  2283656566040971221    and
# lead         VERB   82546335403996757      lead
# the          DET    7425985699627899538    the
# refinery     NOUN   16605614721838495449   refinery
# wide         ADJ    1472532298972223094    wide
# instrumentation NOUN   14273039053985598836   instrumentation
# and          CCONJ  2283656566040971221    and
# controls     NOUN   572204754761179701     control
# projects     NOUN   10994073736148868485   project
# and          CCONJ  2283656566040971221    and
# long         ADJ    12965068231793614765   long
# -            PUNCT  9153284864653046197    -
# term         NOUN   4519742297340331040    term
# plans        NOUN   6610255016299222351    plan
# to           PART   3791531372978436496    to
# ensure       VERB   15159758025291269046   ensure
# safe         ADJ    1295616215629480030    safe
# and          CCONJ  2283656566040971221    and
# reliable     ADJ    10751479260089776908   reliable
# operations   NOUN   7076768087566493292    operation
# within       ADP    7666004699573636134    within
# the          DET    7425985699627899538    the
# Edmonton     PROPN  5494770740298034170    Edmonton
# refinery     NOUN   16605614721838495449   refinery
# .            PUNCT  12646065887601541794   .
# Key          ADJ    12247610008914253561   key
# Accountabilities NOUN   4363136251652055266    accountability
# Develop      VERB   16473443321107972938   develop
# detailed     ADJ    8214554006204516643    detailed
# engineering  NOUN   5835438034023771766    engineering
# work         NOUN   10038440415813069799   work
# packages     NOUN   3355784113702652033    package
# in           ADP    3002984154512732771    in
# accordance   NOUN   3885711098126517920    accordance
# with         ADP    12510949447758279278   with
# project      NOUN   10994073736148868485   project
# specifications NOUN   6887287302594700872    specification
# and          CCONJ  2283656566040971221    and
# provide      VERB   3805418597433244348    provide
# construction NOUN   8723451358872656344    construction
# ,            PUNCT  2593208677638477497    ,
# commissioning NOUN   12444288103284152253   commissioning
# and          CCONJ  2283656566040971221    and
# start        VERB   6480458294193393462    start
# -            PUNCT  9153284864653046197    -
# up           ADP    2199259611705938403    up
# support      NOUN   5147005412574305164    support
# Develop      VERB   16473443321107972938   develop
# control      NOUN   572204754761179701     control
# narratives   NOUN   3030168271351040345    narrative
# for          ADP    16037325823156266367   for
# new          ADJ    4753564829687343602    new
# and          CCONJ  2283656566040971221    and
# existing     VERB   2808794269826886559    exist
# DCS          PROPN  9198040740695468409    DCS
# control      NOUN   572204754761179701     control
# and          CCONJ  2283656566040971221    and
# safety       NOUN   1869645994878888584    safety
# systems      NOUN   16001232513058686804   system
# ;            PUNCT  631425121691394544     ;
# investigate  VERB   9327029060991632983    investigate
# and          CCONJ  2283656566040971221    and
# troubleshoot VERB   12687435774125623959   troubleshoot
# control      NOUN   572204754761179701     control
# system       NOUN   16001232513058686804   system
# configuration NOUN   2918034760958352161    configuration
# problems     NOUN   4473158105997569131    problem
# and          CCONJ  2283656566040971221    and
# recommend    VERB   5869997465047222503    recommend
# quick        ADJ    12442504647632856847   quick
# and          CCONJ  2283656566040971221    and
# reliable     ADJ    10751479260089776908   reliable
# solutions    NOUN   8054865091517299512    solution
# Review       PROPN  3722860919861639894    Review
# work         NOUN   10038440415813069799   work
# packages     NOUN   3355784113702652033    package
# for          ADP    16037325823156266367   for
# error        NOUN   5141748423479617815    error
# free         ADJ    17712913731469760764   free
# and          CCONJ  2283656566040971221    and
# consistent   ADJ    3990210200209757162    consistent
# engineering  NOUN   5835438034023771766    engineering
# deliverables NOUN   7086179188628728521    deliverable
# as           SCONJ  7437575085468336610    as
# per          ADP    799935474406865112     per
# applicable   ADJ    15717441996292838248   applicable
# codes        NOUN   3084953006211575075    code
# and          CCONJ  2283656566040971221    and
# approved     VERB   17226491798356777785   approve
# engineering  NOUN   5835438034023771766    engineering
# standards    NOUN   4892528069537811086    standard
# Design       PROPN  15658042274746311269   Design
# ,            PUNCT  2593208677638477497    ,
# configure    NOUN   3178153796074937268    configure
# ,            PUNCT  2593208677638477497    ,
# validate     NOUN   6029945374264985009    validate
# (            PUNCT  12638816674900267446   (
# offline      ADJ    11502586501647542770   offline
# simulation   NOUN   2711838063871469217    simulation
# )            PUNCT  3842344029291005339    )
# and          CCONJ  2283656566040971221    and
# optimize     VERB   9470301821735104089    optimize
# controls     NOUN   572204754761179701     control
# software     NOUN   8212201967714533330    software
# packages     NOUN   3355784113702652033    package
# to           PART   3791531372978436496    to
# provide      VERB   3805418597433244348    provide
# accurate     ADJ    15743158639254386803   accurate
# and          CCONJ  2283656566040971221    and
# reliable     ADJ    10751479260089776908   reliable
# software     NOUN   8212201967714533330    software
# deliverables NOUN   7086179188628728521    deliverable
# for          ADP    16037325823156266367   for
# safe         ADJ    1295616215629480030    safe
# refinery     NOUN   16605614721838495449   refinery
# operations   NOUN   7076768087566493292    operation
# ;            PUNCT  631425121691394544     ;
# test         NOUN   1618900948208871284    test
# systems      NOUN   16001232513058686804   system
# thoroughly   ADV    4170951894343133518    thoroughly
# in           ADP    3002984154512732771    in
# an           DET    15099054000809333061   an
# offline      ADJ    11502586501647542770   offline
# environment  NOUN   16709044843282783534   environment
# with         ADP    12510949447758279278   with
# key          ADJ    12247610008914253561   key
# stakeholders NOUN   7143813683338293920    stakeholder
# to           PART   3791531372978436496    to
# address      VERB   14349763737243715186   address
# valid        ADJ    14566126149644487813   valid
# concerns     NOUN   16371372851814722007   concern
# Provide      VERB   3805418597433244348    provide
# continuous   ADJ    12054918354443567014   continuous
# improvement  NOUN   14582354607007172868   improvement
# and          CCONJ  2283656566040971221    and
# standardization NOUN   16104579923345710757   standardization
# feedback     NOUN   7472266814318447235    feedback
# towards      ADP    9315050841437086371    towards
# improved     ADJ    3813719572866565009    improved
# controls     NOUN   572204754761179701     control
# configuration NOUN   2918034760958352161    configuration
# processes    NOUN   1020421249059553464    process
# ,            PUNCT  2593208677638477497    ,
# project      NOUN   10994073736148868485   project
# efficiencies NOUN   5828582720301055712    efficiency
# ,            PUNCT  2593208677638477497    ,
# quality      NOUN   8617680374120575546    quality
# and          CCONJ  2283656566040971221    and
# cost         VERB   7764511969837601066    cost
# effectiveness NOUN   7340851527471535203    effectiveness
# Exercise     NOUN   9652663489128248624    exercise
# cost         NOUN   7764511969837601066    cost
# control      NOUN   572204754761179701     control
# when         ADV    15807309897752499399   when
# providing    VERB   3805418597433244348    provide
# engineering  NOUN   5835438034023771766    engineering
# solutions    NOUN   8054865091517299512    solution
# ,            PUNCT  2593208677638477497    ,
# review       VERB   6618089098118556736    review
# and          CCONJ  2283656566040971221    and
# maintain     VERB   5164400239252635879    maintain
# project      NOUN   10994073736148868485   project
# schedules    NOUN   2631550253888566099    schedule
# ,            PUNCT  2593208677638477497    ,
# track        VERB   13353920538491180942   track
# engineering  NOUN   5835438034023771766    engineering
# tasks        NOUN   1048061966900118739    task
# and          CCONJ  2283656566040971221    and
# deliverables NOUN   7086179188628728521    deliverable
# in           ADP    3002984154512732771    in
# conjunction  NOUN   17128743588502102545   conjunction
# with         ADP    12510949447758279278   with
# project      NOUN   10994073736148868485   project
# management   NOUN   1454996307668600469    management
# Prepare      PROPN  15223200768390864627   Prepare
# material     NOUN   8984464104423655975    material
# requisitions NOUN   4244175193517507563    requisition
# and          CCONJ  2283656566040971221    and
# complete     VERB   13052011348260247525   complete
# technical    ADJ    8300455124106275346    technical
# evaluations  NOUN   9756991778312366021    evaluation
# by           ADP    16764210730586636600   by
# reviewing    VERB   6618089098118556736    review
# vendor       NOUN   2160998316008163669    vendor
# or           CCONJ  3740602843040177340    or
# subcontractor NOUN   12705534537288833567   subcontractor
# quotations   NOUN   6842054802442660858    quotation
# ,            PUNCT  2593208677638477497    ,
# drawings     NOUN   11457009927309531798   drawing
# and          CCONJ  2283656566040971221    and
# specifications NOUN   6887287302594700872    specification
# in           ADP    3002984154512732771    in
# conformance  NOUN   4537926855954927494    conformance
# with         ADP    12510949447758279278   with
# project      NOUN   10994073736148868485   project
# requirements NOUN   7763941561646261851    requirement
# Participate  VERB   4176336786957309062    participate
# in           ADP    3002984154512732771    in
# design       NOUN   4105053907530138126    design
# reviews      NOUN   6618089098118556736    review
# ,            PUNCT  2593208677638477497    ,
# process      VERB   1020421249059553464    process
# hazard       PROPN  14273250932394618362   hazard
# analysis     NOUN   5753914399162559562    analysis
# ,            PUNCT  2593208677638477497    ,
# management   NOUN   1454996307668600469    management
# of           ADP    886050111519832510     of
# change       NOUN   3979101002134440957    change
# ,            PUNCT  2593208677638477497    ,
# layers       NOUN   7486875045419418034    layer
# of           ADP    886050111519832510     of
# protection   NOUN   9357963436562240989    protection
# analysis     NOUN   5753914399162559562    analysis
# (            PUNCT  12638816674900267446   (
# LOPA         PROPN  14045990493790070068   LOPA
# )            PUNCT  3842344029291005339    )
# and          CCONJ  2283656566040971221    and
# safety       NOUN   1869645994878888584    safety
# integrity    NOUN   3316129791918973396    integrity
# level        NOUN   15060127769916968652   level
# (            PUNCT  12638816674900267446   (
# SIL          PROPN  17045594284471811043   SIL
# )            PUNCT  3842344029291005339    )
# analysis     NOUN   5753914399162559562    analysis
#              SPACE  9205076007239783027
# Use          PROPN  9570226570207762279    Use
# resources    NOUN   18066197654291781363   resource
# effectively  ADV    6784290887568980553    effectively
# and          CCONJ  2283656566040971221    and
# offer        VERB   6502919589296598169    offer
# coaching     VERB   5220333855730036458    coach
# to           ADP    3791531372978436496    to
# junior       ADJ    13640542721211991018   junior
# staff        NOUN   850430561872953815     staff
# and          CCONJ  2283656566040971221    and
# contractor   NOUN   8034257837210266917    contractor
# resources    NOUN   18066197654291781363   resource
# Required     VERB   9094995078650759376    require
# Qualifications PROPN  5218609432499644339    Qualifications
# Experience   PROPN  13723185953024897186   Experience
# and          CCONJ  2283656566040971221    and
# Education    NOUN   11255438928975991251   education
# :            PUNCT  11532473245541075862   :
# Eight        NUM    3823348673703431224    eight
# or           CCONJ  3740602843040177340    or
# more         ADJ    2160362229054775535    more
# years        NOUN   14889849580704678361   year
# of           ADP    886050111519832510     of
# control      NOUN   572204754761179701     control
# systems      NOUN   16001232513058686804   system
# experience   NOUN   12090100147684300169   experience
#              SPACE  9205076007239783027
# Demonstrated VERB   5547305781669311980    demonstrate
# experience   NOUN   12090100147684300169   experience
# in           ADP    3002984154512732771    in
# developing   VERB   16473443321107972938   develop
# engineering  NOUN   5835438034023771766    engineering
# work         NOUN   10038440415813069799   work
# packages     NOUN   3355784113702652033    package
# and          CCONJ  2283656566040971221    and
# hands        NOUN   10690717480206833971   hand
# -            PUNCT  9153284864653046197    -
# on           ADP    5640369432778651323    on
# control      NOUN   572204754761179701     control
# systems      NOUN   16001232513058686804   system
# programming  NOUN   17860067660221736314   programming
# experience   NOUN   12090100147684300169   experience
# in           ADP    3002984154512732771    in
# an           DET    15099054000809333061   an
# oil          NOUN   7110413584720537022    oil
# refinery     NOUN   16605614721838495449   refinery
# for          ADP    16037325823156266367   for
# at           ADV    11667289587015813222   at
# least        ADV    12059514183285037132   least
# two          NUM    11711838292424000352   two
# years        NOUN   14889849580704678361   year
# ;            PUNCT  631425121691394544     ;
# experience   NOUN   12090100147684300169   experience
# at           ADP    11667289587015813222   at
# the          DET    7425985699627899538    the
# Edmonton     PROPN  5494770740298034170    Edmonton
# refinery     NOUN   16605614721838495449   refinery
# is           AUX    10382539506755952630   be
# considered   VERB   17360727451542821422   consider
# an           DET    15099054000809333061   an
# asset        NOUN   706148391318671201     asset
# Demonstrated VERB   5547305781669311980    demonstrate
# experience   NOUN   12090100147684300169   experience
# on           ADP    5640369432778651323    on
# interfacing  VERB   10918538201279686601   interface
# near         SCONJ  4578410152339589874    near
# infrared     ADJ    14052270866719131364   infrared
# analyzer     PROPN  16225656928976092274   analyzer
# ,            PUNCT  2593208677638477497    ,
# nuclear      ADJ    7856404996111361519    nuclear
# magnetic     ADJ    2776355729302838858    magnetic
# resonance    NOUN   9320093679226970524    resonance
# and          CCONJ  2283656566040971221    and
# sample       NOUN   10528961229637103608   sample
# conditioning NOUN   8604656501178304778    conditioning
# systems      NOUN   16001232513058686804   system
# with         ADP    12510949447758279278   with
# Honeywell    PROPN  3279654194929343952    Honeywell
# Experion     PROPN  12620508496305106832   Experion
# and          CCONJ  2283656566040971221    and
# TDC3000      VERB   12630629196573205231   tdc3000
# DCS          PROPN  9198040740695468409    DCS
# in           ADP    3002984154512732771    in
# a            DET    11901859001352538922   a
# refinery     NOUN   16605614721838495449   refinery
# environment  NOUN   16709044843282783534   environment
# ;            PUNCT  631425121691394544     ;
# advanced     ADJ    3943929226210916060    advanced
# competency   NOUN   3913075740827003212    competency
# with         ADP    12510949447758279278   with
# Triconex     PROPN  11270921235969043857   Triconex
# PLC          PROPN  13236996994757583783   PLC
# programming  NOUN   17860067660221736314   programming
# and          CCONJ  2283656566040971221    and
# Unity        PROPN  13801780760350177599   Unity
# Pro          PROPN  6423552085730545928    Pro
# for          ADP    16037325823156266367   for
# Modicon      PROPN  5843529000911298375    Modicon
# PLC          PROPN  13236996994757583783   PLC
# Bachelor     PROPN  11228932861633861105   Bachelor
# ’s           PART   614914527630368944     ’s
# degree       NOUN   8862567407865235748    degree
# in           ADP    3002984154512732771    in
# engineering  NOUN   5835438034023771766    engineering
# ;            PUNCT  631425121691394544     ;
# post         NOUN   6601561424492272668    post
# graduate     ADJ    10720099673868162185   graduate
# qualifications NOUN   13321716309044988300   qualification
# will         VERB   18307573501153647118   will
# be           AUX    10382539506755952630   be
# an           DET    15099054000809333061   an
# asset        NOUN   706148391318671201     asset
# Registered   VERB   507029484556359861     register
# as           SCONJ  7437575085468336610    as
# a            DET    11901859001352538922   a
# professional ADJ    1628340908579922823    professional
# engineer     NOUN   2945926927285067412    engineer
# with         ADP    12510949447758279278   with
# the          DET    7425985699627899538    the
# Association  PROPN  5900517078187878729    Association
# of           ADP    886050111519832510     of
# Professional PROPN  8576307612935132458    Professional
# Engineers    PROPN  4651764717593651265    Engineers
# and          CCONJ  2283656566040971221    and
# Geoscientists PROPN  5390711615877531518    Geoscientists
# of           ADP    886050111519832510     of
# Alberta      PROPN  15137336096181088614   Alberta
# (            PUNCT  12638816674900267446   (
# APEGA        PROPN  15480695076518545198   APEGA
# )            PUNCT  3842344029291005339    )
# Skills       NOUN   15048162888359431889   skill
# and          CCONJ  2283656566040971221    and
# Knowledge    NOUN   841909098595075712     knowledge
# :            PUNCT  11532473245541075862   :
# Hands        NOUN   10690717480206833971   hand
# -            PUNCT  9153284864653046197    -
# on           ADP    5640369432778651323    on
# maintenance  NOUN   10383753245402158063   maintenance
# and          CCONJ  2283656566040971221    and
# configuration NOUN   2918034760958352161    configuration
# experience   NOUN   12090100147684300169   experience
# with         ADP    12510949447758279278   with
# distributed  VERB   13396760555283733449   distribute
# control      NOUN   572204754761179701     control
# system       NOUN   16001232513058686804   system
# (            PUNCT  12638816674900267446   (
# Experion     PROPN  12620508496305106832   Experion
# ,            PUNCT  2593208677638477497    ,
# C300         PROPN  1130872723318701992    C300
# ,            PUNCT  2593208677638477497    ,
# C200         PROPN  15610941005710597302   C200
# ,            PUNCT  2593208677638477497    ,
# TDC3000      PROPN  12626523148295153943   TDC3000
# ,            PUNCT  2593208677638477497    ,
# SCADA        PROPN  5255286143261743553    SCADA
# )            PUNCT  3842344029291005339    )
# ,            PUNCT  2593208677638477497    ,
# safety       NOUN   1869645994878888584    safety
# instrumented VERB   779358824639843206     instrument
# systems      NOUN   16001232513058686804   system
# (            PUNCT  12638816674900267446   (
# Triconex     PROPN  11270921235969043857   Triconex
# )            PUNCT  3842344029291005339    )
# ,            PUNCT  2593208677638477497    ,
# and          CCONJ  2283656566040971221    and
# programmable ADJ    11670743437371350924   programmable
# logic        NOUN   9471218585867826525    logic
# controllers  NOUN   16650080625828954626   controller
# (            PUNCT  12638816674900267446   (
# Modicon      PROPN  5843529000911298375    Modicon
# )            PUNCT  3842344029291005339    )
# Strong       ADJ    12618292361406372890   strong
# technical    ADJ    8300455124106275346    technical
# knowledge    NOUN   841909098595075712     knowledge
# of           ADP    886050111519832510     of
# applicable   ADJ    15717441996292838248   applicable
# automation   NOUN   6947835642356966710    automation
# industry     NOUN   16409696763006672153   industry
# standards    NOUN   4892528069537811086    standard
# ,            PUNCT  2593208677638477497    ,
# SIL          PROPN  17045594284471811043   SIL
# assessment   NOUN   16732015447806033820   assessment
# ,            PUNCT  2593208677638477497    ,
# LOPA         PROPN  14045990493790070068   LOPA
# methodologies NOUN   15060625784721160660   methodology
# ,            PUNCT  2593208677638477497    ,
# and          CCONJ  2283656566040971221    and
# alarm        NOUN   5909822024562114235    alarm
# management   NOUN   1454996307668600469    management
# guidelines   NOUN   4094532758491801704    guideline
# Experience   NOUN   12090100147684300169   experience
# on           ADP    5640369432778651323    on
# Burner       PROPN  8391078781543452218    Burner
# Management   PROPN  11401798372640567787   Management
# System       PROPN  2700347774471333846    System
# (            PUNCT  12638816674900267446   (
# BMS          PROPN  17050772254461138320   BMS
# ...
# ,            PUNCT  2593208677638477497    ,
# natural      ADJ    3743574233330547430    natural
# gas          NOUN   18003131564902911959   gas
# ,            PUNCT  2593208677638477497    ,
# and          CCONJ  2283656566040971221    and
# conventional ADJ    2879468130908510152    conventional
# oil          NOUN   7110413584720537022    oil
# production   NOUN   2074510144522970299    production
# ,            PUNCT  2593208677638477497    ,
# internationally ADV    11070640195767574431   internationally
# and          CCONJ  2283656566040971221    and
# offshore     ADJ    9338344535451985975    offshore
# East         PROPN  10680342869134655390   East
# Coast        PROPN  10636233284199440354   Coast
# Canada       PROPN  12493166723054806753   Canada
# .            PUNCT  12646065887601541794   .
# And          CCONJ  2283656566040971221    and
# while        SCONJ  1039541750886098100    while
# we           PRON   561228191312463089     -PRON-
# are          AUX    10382539506755952630   be
# working      VERB   10038440415813069799   work
# to           PART   3791531372978436496    to
# responsibly  ADV    7219681877595319698    responsibly
# develop      VERB   16473443321107972938   develop
# petroleum    NOUN   345334109227758051     petroleum
# resources    NOUN   18066197654291781363   resource
# and          CCONJ  2283656566040971221    and
# contribute   VERB   4511972451533797185    contribute
# to           ADP    3791531372978436496    to
# the          DET    7425985699627899538    the
# communities  NOUN   17822516981717808594   community
# where        ADV    16318918034475841628   where
# we           PRON   561228191312463089     -PRON-
# live         VERB   13874798850131827181   live
# and          CCONJ  2283656566040971221    and
# work         VERB   10038440415813069799   work
# ,            PUNCT  2593208677638477497    ,
# we           PRON   561228191312463089     -PRON-
# are          AUX    10382539506755952630   be
# also         ADV    12084876542534825196   also
# developing   VERB   16473443321107972938   develop
# our          DET    561228191312463089     -PRON-
# renewable    ADJ    15791900611853284392   renewable
# energy       NOUN   13079260030086073766   energy
# portfolio    NOUN   8616133700242567300    portfolio
# ,            PUNCT  2593208677638477497    ,
# which        DET    7063653163634019529    which
# includes     VERB   14049642289933595219   include
# wind         NOUN   15362367693071454124   wind
# power        NOUN   10405720708504167118   power
# and          CCONJ  2283656566040971221    and
# biofuels     NOUN   1321305670687977834    biofuel
# .            PUNCT  12646065887601541794   .
# As           SCONJ  7437575085468336610    as
# part         NOUN   4485934323942657167    part
# of           ADP    886050111519832510     of
# Suncor       PROPN  6214342204459202591    Suncor
# 's           PART   16428057658620181782   's
# team         NOUN   4303356597303500170    team
# ,            PUNCT  2593208677638477497    ,
# you          PRON   561228191312463089     -PRON-
# 'll          VERB   18307573501153647118   will
# contribute   VERB   4511972451533797185    contribute
# to           ADP    3791531372978436496    to
# the          DET    7425985699627899538    the
# ongoing      ADJ    9563847219062609030    ongoing
# success      NOUN   16089821935113899987   success
# of           ADP    886050111519832510     of
# Canada       PROPN  12493166723054806753   Canada
# 's           PART   16428057658620181782   's
# largest      ADJ    2751841902330220293    large
# energy       NOUN   13079260030086073766   energy
# company      NOUN   6905553075311563409    company
# -            PUNCT  9153284864653046197    -
# one          NUM    17454115351911680600   one
# with         ADP    12510949447758279278   with
# a            DET    11901859001352538922   a
# solid        ADJ    11674165167217260271   solid
# track        NOUN   13353920538491180942   track
# record       NOUN   12677120423429974351   record
# of           ADP    886050111519832510     of
# growth       NOUN   15397529643674191988   growth
# ,            PUNCT  2593208677638477497    ,
# a            DET    11901859001352538922   a
# focus        NOUN   12460925685579008443   focus
# on           ADP    5640369432778651323    on
# safety       NOUN   1869645994878888584    safety
# and          CCONJ  2283656566040971221    and
# sustainability NOUN   7060043067088244767    sustainability
# and          CCONJ  2283656566040971221    and
# tremendous   ADJ    5922451142185288652    tremendous
# potential    NOUN   15822686403977818401   potential
# for          ADP    16037325823156266367   for
# the          DET    7425985699627899538    the
# future       NOUN   17783898315335276456   future
# .            PUNCT  12646065887601541794   .
# And          CCONJ  2283656566040971221    and
# you          PRON   561228191312463089     -PRON-
# 'll          VERB   18307573501153647118   will
# have         AUX    14692702688101715474   have
# the          DET    7425985699627899538    the
# opportunity  NOUN   9751084440329135938    opportunity
# to           PART   3791531372978436496    to
# learn        VERB   9664905639869093544    learn
# from         ADP    7831658034963690409    from
# experts      NOUN   11183332174366369515   expert
# in           ADP    3002984154512732771    in
# the          DET    7425985699627899538    the
# industry     NOUN   16409696763006672153   industry
# and          CCONJ  2283656566040971221    and
# build        VERB   15542623189494043735   build
# on           ADP    5640369432778651323    on
# your         DET    561228191312463089     -PRON-
# skills       NOUN   15048162888359431889   skill
# every        DET    2739543297294151269    every
# day          NOUN   1608482186128794349    day
# .            PUNCT  12646065887601541794   .
# Suncor       PROPN  6214342204459202591    Suncor
# promotes     VERB   11790474613361244676   promote
# diversity    NOUN   12338549936519405788   diversity
# and          CCONJ  2283656566040971221    and
# inclusion    NOUN   190713507892190644     inclusion
# in           ADP    3002984154512732771    in
# the          DET    7425985699627899538    the
# workplace    NOUN   15021158800524586387   workplace
# .            PUNCT  12646065887601541794   .
# Suncor       PROPN  6214342204459202591    Suncor
# is           AUX    10382539506755952630   be
# an           DET    15099054000809333061   an
# equal        ADJ    5161393307412082313    equal
# opportunity  NOUN   9751084440329135938    opportunity
# employer     NOUN   10831503532707336449   employer
# and          CCONJ  2283656566040971221    and
# encourages   VERB   18244613377274813947   encourage
# applications NOUN   10482388013215715563   application
# from         ADP    7831658034963690409    from
# all          DET    13409319323822384369   all
# qualified    ADJ    4416020510660890727    qualified
# individuals  NOUN   15424120832172538961   individual
# .            PUNCT  12646065887601541794   .
# At           ADP    11667289587015813222   at
# Suncor       PROPN  6214342204459202591    Suncor
# ,            PUNCT  2593208677638477497    ,
# we           PRON   561228191312463089     -PRON-
# are          AUX    10382539506755952630   be
# dedicated    ADJ    16539447307374229163   dedicated
# to           ADP    3791531372978436496    to
# building     VERB   15542623189494043735   build
# a            DET    11901859001352538922   a
# workforce    NOUN   16397189618196315449   workforce
# that         DET    4380130941430378203    that
# reflects     VERB   9317338246392712140    reflect
# the          DET    7425985699627899538    the
# diversity    NOUN   12338549936519405788   diversity
# of           ADP    886050111519832510     of
# the          DET    7425985699627899538    the
# communitities NOUN   2514714309144799022    communititie
# in           ADP    3002984154512732771    in
# which        DET    7063653163634019529    which
# we           PRON   561228191312463089     -PRON-
# live         VERB   13874798850131827181   live
# ,            PUNCT  2593208677638477497    ,
# and          CCONJ  2283656566040971221    and
# where        ADV    16318918034475841628   where
# every        DET    2739543297294151269    every
# team         NOUN   4303356597303500170    team
# member       NOUN   14721843519903598875   member
# has          AUX    14692702688101715474   have
# the          DET    7425985699627899538    the
# opportunity  NOUN   9751084440329135938    opportunity
# to           PART   3791531372978436496    to
# reach        VERB   16043492340495565256   reach
# their        DET    561228191312463089     -PRON-
# full         ADJ    6605652555683495965    full
# potential    NOUN   15822686403977818401   potential
# .            PUNCT  12646065887601541794   .
# Not          PART   447765159362469301     not
# sure         ADJ    2985827712170516640    sure
# if           SCONJ  12446819118446800910   if
# this         DET    1995909169258310477    this
# particular   ADJ    15677032745291991228   particular
# listing      NOUN   13920802585481064911   listing
# is           AUX    10382539506755952630   be
# the          DET    7425985699627899538    the
# right        ADJ    5943797630011647483    right
# opportunity  NOUN   9751084440329135938    opportunity
# for          ADP    16037325823156266367   for
# you          PRON   561228191312463089     -PRON-
# ?            PUNCT  8205403955989537350    ?
# Please       INTJ   99974891130002844      please
# join         VERB   16238441731120403936   join
# our          DET    561228191312463089     -PRON-
# Talent       PROPN  14197491248763580184   Talent
# Community    PROPN  9430724964002758144    Community
# at           ADP    11667289587015813222   at
# www.suncor.com X      12418902049328573543   www.suncor.com
# and          CCONJ  2283656566040971221    and
# click        VERB   16737171721823744534   click
# on           ADP    5640369432778651323    on
# Careers      NOUN   16267834800013645067   career
# ,            PUNCT  2593208677638477497    ,
# or           CCONJ  3740602843040177340    or
# follow       VERB   14462500713227930305   follow
# us           PRON   561228191312463089     -PRON-
# on           ADP    5640369432778651323    on
# LinkedIn     PROPN  7219308988357715914    LinkedIn
# ,            PUNCT  2593208677638477497    ,
# Facebook     PROPN  8081970590932371665    Facebook
# and          CCONJ  2283656566040971221    and
# Twitter      PROPN  7346769842919679806    Twitter
# for          ADP    16037325823156266367   for
# the          DET    7425985699627899538    the
# latest       ADJ    7199752172782760331    late
# job          NOUN   18425606103329785088   job
# listings     NOUN   13920802585481064911   listing
# and          CCONJ  2283656566040971221    and
# employment   NOUN   10954873364127974648   employment
# news         NOUN   7614825220766900367    news
# .            PUNCT  12646065887601541794   .
# Please       INTJ   99974891130002844      please
# note         VERB   5316588462688733335    note
# that         SCONJ  4380130941430378203    that
# our          DET    561228191312463089     -PRON-
# job          NOUN   18425606103329785088   job
# postings     NOUN   16116065691468183615   posting
# are          AUX    10382539506755952630   be
# typically    ADV    4127424922989833796    typically
# open         ADJ    8092125317261700160    open
# for          ADP    16037325823156266367   for
# two          NUM    11711838292424000352   two
# weeks        NOUN   14249255431398666181   week
# ,            PUNCT  2593208677638477497    ,
# so           CCONJ  9781598966686434415    so
# if           SCONJ  12446819118446800910   if
# you          PRON   561228191312463089     -PRON-
# are          AUX    10382539506755952630   be
# interested   ADJ    207255285173834361     interested
# and          CCONJ  2283656566040971221    and
# qualified    ADJ    4416020510660890727    qualified
# ,            PUNCT  2593208677638477497    ,
# apply        VERB   8841002517919878551    apply
# now          ADV    17157488710739566268   now
# .            PUNCT  12646065887601541794   .
# JOB          PROPN  14184922800057448138   JOB
# CATEGORY     PROPN  17876119707536889636   CATEGORY
# :            PUNCT  11532473245541075862   :
# Engineering  NOUN   5835438034023771766    engineering
# Job          PROPN  16842181437347778509   Job
# Segment      NOUN   6184502641974542471    segment
# :            PUNCT  11532473245541075862   :
# Controls     PROPN  4550962452679798064    Controls
# Engineer     PROPN  7029714065625710103    Engineer
# ,            PUNCT  2593208677638477497    ,
# Construction PROPN  17308949030296157929   Construction
# ,            PUNCT  2593208677638477497    ,
# Instrumentation PROPN  13948505819021949443   Instrumentation
# ,            PUNCT  2593208677638477497    ,
# Engineer     PROPN  7029714065625710103    Engineer
# ,            PUNCT  2593208677638477497    ,
# Electrical   PROPN  4992211033226602308    Electrical
# ,            PUNCT  2593208677638477497    ,
# Engineering  PROPN  17806784801972435463   Engineering
# Apply        PROPN  9239136590248024966    Apply
# now          ADV    17157488710739566268   now
# »            INTJ   5342463183827332990    »
# Apply        VERB   8841002517919878551    apply
# now          ADV    17157488710739566268   now
# Apply        VERB   8841002517919878551    apply
# Now          ADV    17157488710739566268   now
# Start        PROPN  6653903367463496184    Start
# apply        VERB   8841002517919878551    apply
# with         ADP    12510949447758279278   with
# LinkedIn     PROPN  7219308988357715914    LinkedIn
# Start        NOUN   6480458294193393462    start
# Please       INTJ   99974891130002844      please
# wait         VERB   6203382976377178934    wait
# ...          PUNCT  10875615029400813363   ...
# Find         VERB   16574616920585318162   find
# similar      ADJ    18166476740537071113   similar
# jobs         NOUN   18425606103329785088   job
# :            PUNCT  11532473245541075862   :
# Energy       NOUN   13079260030086073766   energy
# Jobs         NOUN   18425606103329785088   job
# in           ADP    3002984154512732771    in
# Edmonton     PROPN  5494770740298034170    Edmonton
# Connect      PROPN  17391954754219945945   Connect
# with         ADP    12510949447758279278   with
# Suncor       PROPN  6214342204459202591    Suncor
# Our          DET    561228191312463089     -PRON-
# social       ADJ    7479279373136274171    social
# media        NOUN   4199598185158715671    medium
# channels     NOUN   7635442270831496872    channel
# Related      ADJ    9648789318421011716    related
# links        NOUN   6902681366591422880    link
# Careers      NOUN   16267834800013645067   career
# home         ADV    12006852138382633966   home
# View         VERB   2608925738682777778    view
# all          DET    13409319323822384369   all
# jobs         NOUN   18425606103329785088   job
# Search       NOUN   295895373269394349     search
# by           ADP    16764210730586636600   by
# location     NOUN   4272944830542554761    location
# Top          ADJ    8328343100126676325    top
# job          NOUN   18425606103329785088   job
# searches     VERB   295895373269394349     search
# Suncor.com   PROPN  13347722493541375684   Suncor.com
# About        ADP    942632335873952620     about
# us           PRON   561228191312463089     -PRON-
# Accessibility PROPN  6823738461467692481    Accessibility
# policy       NOUN   1913136496811477923    policy
# Legal        PROPN  14921842820012838811   Legal
# &            CCONJ  15473034735919704609   &
# privacy      NOUN   9394217028216858347    privacy
# Français     PROPN  9661990699563991850    Français
# ©            PROPN  18195260988191342947   ©
# 2017         NUM    12587536829529815270   2017
# Suncor       PROPN  6214342204459202591    Suncor
# Energy       PROPN  16711491770240427610   Energy
# Inc.         PROPN  11367013928689839740   Inc.
# All          DET    13409319323822384369   all
# Rights       PROPN  3844296817047681997    Rights
# Reserved     PROPN  9106961084643197739    Reserved
#              SPACE  7263008856362461915
# Canada       PROPN  12493166723054806753   Canada
#                   SPACE  9687856286444532230
# CA           PROPN  8902657483871908647    CA

# %%
for token in doc:
    print(f'{token.text:{10}} {token.pos_:{10}} {token.dep_:{10}} {spacy.explain(token.dep_)}')
# Out:
#                                                                            SPACE                 None
# pageurl    NOUN       ROOT       None
#                     SPACE                 None
# record     NOUN       dobj       direct object
# /          SYM        punct      punctuation
# uniq_id    PROPN      appos      appositional modifier
#            SPACE                 None
# record     NOUN       npadvmod   noun phrase as adverbial modifier
# /          SYM        punct      punctuation
# job_board  PROPN      nmod       modifier of nominal
#                                                                  SPACE                 None
# record     NOUN       nmod       modifier of nominal
# /          SYM        punct      punctuation
# page_url   PROPN      ROOT       None
#                                SPACE                 None
# record     PROPN      appos      appositional modifier
# /          SYM        punct      punctuation
# job_title  PROPN      nmod       modifier of nominal
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# record     NOUN       nmod       modifier of nominal
# /          SYM        punct      punctuation
# job_description PROPN      nmod       modifier of nominal
# record     NOUN       nmod       modifier of nominal
# /          SYM        punct      punctuation
# location   NOUN       nmod       modifier of nominal
# record     NOUN       nmod       modifier of nominal
# /          SYM        punct      punctuation
# country_code PROPN      ROOT       None
#
#           SPACE                 None
# 0          NUM        ROOT       None
#            SPACE                 None
# https://www.jobs.ca/offer/senior-engineer-instrumentation-and-controls/873334/ PROPN      ROOT       None
#            SPACE                 None
# 3808ba4110a7663d046d9b2dff60d9de NUM        ROOT       None
#            SPACE                 None
# https://www.jobs.ca X          ROOT       None
#            SPACE                 None
# https://www.jobs.ca/offer/senior-engineer-instrumentation-and-controls/873334/ PROPN      ROOT       None
#            SPACE                 None
# Senior     PROPN      compound   compound
# Engineer   PROPN      ROOT       None
# ,          PUNCT      punct      punctuation
# Instrumentation PROPN      conj       conjunct
# and        CCONJ      cc         coordinating conjunction
# Controls   PROPN      conj       conjunct
#            SPACE                 None
# Français   PROPN      compound   compound
# Careers    NOUN       compound   compound
# View       VERB       compound   compound
# Profile    PROPN      compound   compound
# Français   PROPN      compound   compound
# View       VERB       ROOT       None
# all        DET        det        determiner
# jobs       NOUN       compound   compound
# Filter     PROPN      nsubj      nominal subject
# by         ADP        prep       prepositional modifier
# category   NOUN       compound   compound
# Engineers  PROPN      compound   compound
# Business   PROPN      compound   compound
# professionals NOUN       compound   compound
# Trades     PROPN      pobj       object of preposition
# &          CCONJ      cc         coordinating conjunction
# operators  NOUN       compound   compound
# Students   PROPN      conj       conjunct
# &          CCONJ      cc         coordinating conjunction
# new        ADJ        amod       adjectival modifier
# grads      NOUN       conj       conjunct
# Search     VERB       acl        clausal modifier of noun (adjectival clause)
# by         ADP        prep       prepositional modifier
# location   NOUN       pobj       object of preposition
# Join       VERB       ROOT       None
# our        DET        poss       possession modifier
# community  NOUN       compound   compound
# View       NOUN       compound   compound
# Profile    PROPN      compound   compound
# Search     NOUN       dobj       direct object
# by         ADP        prep       prepositional modifier
# Keyword    PROPN      compound   compound
# Search     PROPN      pobj       object of preposition
# by         ADP        prep       prepositional modifier
# Location   PROPN      compound   compound
# Search     PROPN      compound   compound
# jobs       NOUN       compound   compound
# ×          PUNCT      pobj       object of preposition
# Send       VERB       ROOT       None
# me         PRON       dative     dative
# alerts     NOUN       dobj       direct object
# every      DET        det        determiner
# days       NOUN       npadvmod   noun phrase as adverbial modifier
# Create     VERB       compound   compound
# Alert      NOUN       compound   compound
# ×          PUNCT      nsubj      nominal subject
# Send       VERB       ROOT       None
# me         PRON       dative     dative
# alerts     NOUN       dobj       direct object
# every      DET        det        determiner
# days       NOUN       npadvmod   noun phrase as adverbial modifier
# Share      PROPN      ROOT       None
# this       DET        det        determiner
# Job        PROPN      compound   compound
# var        NOUN       compound   compound
# searchString NOUN       dobj       direct object
# =          SYM        punct      punctuation
# ''         PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# var        PROPN      compound   compound
# siteName   PROPN      conj       conjunct
# =          SYM        punct      punctuation
# "          PUNCT      punct      punctuation
# Suncor     PROPN      compound   compound
# Energy     PROPN      compound   compound
# Services   PROPN      ROOT       None
# "          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# $          SYM        dep        unclassified dependent
# (          PUNCT      punct      punctuation
# function   NOUN       appos      appositional modifier
# (          PUNCT      punct      punctuation
# )          PUNCT      punct      punctuation
# {          PUNCT      punct      punctuation
# $          SYM        prep       prepositional modifier
# (          PUNCT      punct      punctuation
# '          PUNCT      punct      punctuation
# .rsslink   PUNCT      compound   compound
# -          PUNCT      punct      punctuation
# jobs2web').unbind('click').click(function(e PROPN      pobj       object of preposition
# )          PUNCT      punct      punctuation
# {          PUNCT      punct      punctuation
# TrackGoogleAnalytics('/feed PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# rss/0      PROPN      appos      appositional modifier
# '          PUNCT      punct      punctuation
# ,          PUNCT      punct      punctuation
# 0          NUM        nummod     numeric modifier
# ,          PUNCT      punct      punctuation
# 0          NUM        nummod     numeric modifier
# ,          PUNCT      punct      punctuation
# searchString VERB       appos      appositional modifier
# ,          PUNCT      punct      punctuation
# '          PUNCT      punct      punctuation
# RSSFeed    PROPN      intj       interjection
# '          PUNCT      punct      punctuation
# ,          PUNCT      punct      punctuation
# siteName   PROPN      appos      appositional modifier
# )          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# }          PUNCT      punct      punctuation
# )          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# $          SYM        nmod       modifier of nominal
# (          PUNCT      punct      punctuation
# '          PUNCT      punct      punctuation
# .rsslink   PUNCT      nmod       modifier of nominal
# -          PUNCT      punct      punctuation
# google').unbind('click').click(function NOUN       nmod       modifier of nominal
# (          PUNCT      punct      punctuation
# )          PUNCT      punct      punctuation
# {          PUNCT      punct      punctuation
# TrackGoogleAnalytics('/feed PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# google/0   PROPN      pobj       object of preposition
# '          PUNCT      punct      punctuation
# ,          PUNCT      punct      punctuation
# 0          NUM        punct      punctuation
# ,          PUNCT      punct      punctuation
# 0          NUM        punct      punctuation
# ,          PUNCT      punct      punctuation
# searchString VERB       conj       conjunct
# ,          PUNCT      punct      punctuation
# '          PUNCT      punct      punctuation
# GoogleFeed PROPN      appos      appositional modifier
# '          PUNCT      punct      punctuation
# ,          PUNCT      punct      punctuation
# siteName   PROPN      npadvmod   noun phrase as adverbial modifier
# )          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# }          PUNCT      punct      punctuation
# )          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# $          SYM        intj       interjection
# (          PUNCT      punct      punctuation
# '          PUNCT      punct      punctuation
# .rsslink   PUNCT      punct      punctuation
# -          PUNCT      punct      punctuation
# yahoo').unbind('click').click(function NOUN       conj       conjunct
# (          PUNCT      punct      punctuation
# )          PUNCT      punct      punctuation
# {          PUNCT      punct      punctuation
# TrackGoogleAnalytics('/feed PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# yahoo/0    PROPN      parataxis  parataxis
# '          PUNCT      punct      punctuation
# ,          PUNCT      punct      punctuation
# 0          NUM        nummod     numeric modifier
# ,          PUNCT      punct      punctuation
# 0          NUM        appos      appositional modifier
# ,          PUNCT      punct      punctuation
# searchString VERB       appos      appositional modifier
# ,          PUNCT      punct      punctuation
# '          PUNCT      punct      punctuation
# YahooFeed  PROPN      nmod       modifier of nominal
# '          PUNCT      punct      punctuation
# ,          PUNCT      punct      punctuation
# siteName   PROPN      appos      appositional modifier
# )          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# }          PUNCT      punct      punctuation
# )          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# $          SYM        appos      appositional modifier
# (          PUNCT      punct      punctuation
# '          PUNCT      punct      punctuation
# .rsslink   PUNCT      nmod       modifier of nominal
# -          PUNCT      punct      punctuation
# msn').unbind('click').click(function NUM        appos      appositional modifier
# (          PUNCT      punct      punctuation
# )          PUNCT      punct      punctuation
# {          PUNCT      punct      punctuation
# TrackGoogleAnalytics('/feed PROPN      nmod       modifier of nominal
# /          SYM        punct      punctuation
# msn/0      PROPN      appos      appositional modifier
# '          PUNCT      punct      punctuation
# ,          PUNCT      punct      punctuation
# 0          NUM        nummod     numeric modifier
# ,          PUNCT      punct      punctuation
# 0          NUM        punct      punctuation
# ,          PUNCT      punct      punctuation
# searchString VERB       appos      appositional modifier
# ,          PUNCT      punct      punctuation
# '          PUNCT      punct      punctuation
# MSNFeed    NOUN       dobj       direct object
# '          PUNCT      punct      punctuation
# ,          PUNCT      punct      punctuation
# siteName   PROPN      appos      appositional modifier
# )          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# }          PUNCT      punct      punctuation
# )          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# }          PUNCT      punct      punctuation
# )          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# //<![CDATA PUNCT      punct      punctuation
# [          PUNCT      punct      punctuation
# var        NOUN       compound   compound
# trackVars  NOUN       meta       meta modifier
# =          NOUN       punct      punctuation
# {          PUNCT      punct      punctuation
# "          PUNCT      punct      punctuation
# refid      NOUN       ROOT       None
# "          PUNCT      punct      punctuation
# :          PUNCT      punct      punctuation
# "          PUNCT      punct      punctuation
# "          PUNCT      punct      punctuation
# }          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# var        PROPN      compound   compound
# lang       PROPN      appos      appositional modifier
# =          PUNCT      punct      punctuation
# "          PUNCT      punct      punctuation
# en         X          ROOT       None
# "          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# var        NOUN       compound   compound
# gaPropertyId X          punct      punctuation
# =          VERB       punct      punctuation
# "          PUNCT      punct      punctuation
# "          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# var        PROPN      compound   compound
# httpProtocol PROPN      nsubj      nominal subject
# =          SYM        punct      punctuation
# "          PUNCT      punct      punctuation
# https      NOUN       ROOT       None
# "          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# //         X          punct      punctuation
# ]          PUNCT      punct      punctuation
# ]          PUNCT      punct      punctuation
# >          PROPN      ROOT       None
# var        NOUN       compound   compound
# addthis_config PROPN      ROOT       None
# =          SYM        punct      punctuation
# {          PUNCT      punct      punctuation
# username:'addthisj2w NOUN       meta       meta modifier
# '          PUNCT      punct      punctuation
# ,          PUNCT      punct      punctuation
# ui_open_windows NOUN       ROOT       None
# :          PUNCT      punct      punctuation
# true       ADJ        ROOT       None
# ,          PUNCT      punct      punctuation
# ui_click   PROPN      dep        unclassified dependent
# :          PUNCT      punct      punctuation
# true       ADJ        intj       interjection
# ,          PUNCT      punct      punctuation
# ui_508_compliant ADJ        intj       interjection
# :          PUNCT      punct      punctuation
# true       ADJ        advmod     adverbial modifier
# ,          PUNCT      punct      punctuation
# data_track_clickback NOUN       dep        unclassified dependent
# :          PUNCT      punct      punctuation
# false      ADJ        ROOT       None
# ,          PUNCT      punct      punctuation
# ui_language VERB       intj       interjection
# :          PUNCT      punct      punctuation
# "          PUNCT      punct      punctuation
# en         X          intj       interjection
# "          PUNCT      punct      punctuation
# ,          PUNCT      punct      punctuation
# data_ga_property PROPN      appos      appositional modifier
# :          PUNCT      punct      punctuation
# "          PUNCT      punct      punctuation
# "          PUNCT      punct      punctuation
# ,          PUNCT      punct      punctuation
# data_ga_social PROPN      intj       interjection
# :          PUNCT      punct      punctuation
# true       ADJ        advmod     adverbial modifier
# }          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# var        NOUN       compound   compound
# calledsfshorturl NOUN       npadvmod   noun phrase as adverbial modifier
# =          SYM        punct      punctuation
# false      ADJ        ROOT       None
# ;          PUNCT      punct      punctuation
# $          SYM        dep        unclassified dependent
# (          PUNCT      punct      punctuation
# function   NOUN       intj       interjection
# (          PUNCT      punct      punctuation
# )          PUNCT      punct      punctuation
# {          PUNCT      punct      punctuation
# $          SYM        amod       adjectival modifier
# (          PUNCT      punct      punctuation
# '          PUNCT      punct      punctuation
# .addthis_toolbox').mouseover(function(e PROPN      punct      punctuation
# )          PUNCT      punct      punctuation
# {          PUNCT      punct      punctuation
# if         SCONJ      mark       marker
# (          PUNCT      punct      punctuation
# !          PUNCT      punct      punctuation
# calledsfshorturl PROPN      nsubj      nominal subject
# )          PUNCT      punct      punctuation
# {          PUNCT      punct      punctuation
# calledsfshorturl NOUN       advcl      adverbial clause modifier
# =          VERB       punct      punctuation
# true       ADJ        dobj       direct object
# ;          PUNCT      punct      punctuation
# $          SYM        punct      punctuation
# (          PUNCT      punct      punctuation
# this).sfshorturl CCONJ      ROOT       None
# (          PUNCT      punct      punctuation
# {          PUNCT      punct      punctuation
# callback   NOUN       parataxis  parataxis
# :          PUNCT      punct      punctuation
# addthisCallback NOUN       appos      appositional modifier
# ,          PUNCT      punct      punctuation
# event      NOUN       ROOT       None
# :          PUNCT      punct      punctuation
# e          X          appos      appositional modifier
# ,          PUNCT      punct      punctuation
# track      NOUN       appos      appositional modifier
# :          PUNCT      punct      punctuation
# trackVars  NOUN       appos      appositional modifier
# }          PUNCT      punct      punctuation
# )          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# }          PUNCT      punct      punctuation
# }          PUNCT      punct      punctuation
# )          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# function   VERB       conj       conjunct
# addthisCallback(data PROPN      nummod     numeric modifier
# )          PUNCT      punct      punctuation
# {          PUNCT      punct      punctuation
# $          SYM        aux        auxiliary
# (          PUNCT      punct      punctuation
# data.event.target).attr('addthis DET        ROOT       None
# :          PUNCT      punct      punctuation
# url',data.shorturl NUM        appos      appositional modifier
# )          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# addthis.update('share PROPN      appos      appositional modifier
# '          PUNCT      punct      punctuation
# ,          PUNCT      punct      punctuation
# '          PUNCT      punct      punctuation
# url        PROPN      conj       conjunct
# '          PUNCT      punct      punctuation
# ,          PUNCT      punct      punctuation
# data.shorturl PROPN      appos      appositional modifier
# )          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# }          PUNCT      punct      punctuation
# }          PUNCT      punct      punctuation
# )          PUNCT      punct      punctuation
# ;          PUNCT      punct      punctuation
# Senior     PROPN      compound   compound
# Engineer   PROPN      nsubj      nominal subject
# ,          PUNCT      punct      punctuation
# Instrumentation PROPN      conj       conjunct
# and        CCONJ      cc         coordinating conjunction
# Controls   PROPN      conj       conjunct
# Apply      VERB       ROOT       None
# now        ADV        advmod     adverbial modifier
# »          INTJ       punct      punctuation
# Apply      VERB       dep        unclassified dependent
# now        ADV        advmod     adverbial modifier
# Apply      VERB       dep        unclassified dependent
# Now        ADV        advmod     adverbial modifier
# Start      PROPN      nsubj      nominal subject
# apply      VERB       advcl      adverbial clause modifier
# with       ADP        prep       prepositional modifier
# LinkedIn   PROPN      pobj       object of preposition
# Start      NOUN       nsubj      nominal subject
# Please     INTJ       intj       interjection
# wait       VERB       ROOT       None
# ...        PUNCT      punct      punctuation
# Date       NOUN       ROOT       None
# :          PUNCT      punct      punctuation
# Jul        PROPN      appos      appositional modifier
# 18         NUM        nummod     numeric modifier
# ,          PUNCT      punct      punctuation
# 2017       NUM        nummod     numeric modifier
# LOCATION   NOUN       appos      appositional modifier
# :          PUNCT      punct      punctuation
# Edmonton   PROPN      appos      appositional modifier
# ,          PUNCT      punct      punctuation
# Alberta    PROPN      appos      appositional modifier
# (          PUNCT      punct      punctuation
# CA         PROPN      compound   compound
# -          PUNCT      punct      punctuation
# AB         PROPN      ROOT       None
# )          PUNCT      punct      punctuation
# JOB        NOUN       compound   compound
# NUMBER     NOUN       ROOT       None
# :          PUNCT      punct      punctuation
# 16130      NUM        ROOT       None
#            SPACE                 None
# Job        PROPN      compound   compound
# Overview   PROPN      compound   compound
# Reporting  VERB       advcl      adverbial clause modifier
# to         ADP        prep       prepositional modifier
# the        DET        det        determiner
# team       NOUN       compound   compound
# leader     NOUN       pobj       object of preposition
# ,          PUNCT      punct      punctuation
# instrumentation NOUN       conj       conjunct
# ,          PUNCT      punct      punctuation
# electrical ADJ        amod       adjectival modifier
# and        CCONJ      cc         coordinating conjunction
# controls   NOUN       conj       conjunct
# area       NOUN       compound   compound
# projects   NOUN       appos      appositional modifier
# ,          PUNCT      punct      punctuation
# you        PRON       nsubj      nominal subject
# will       VERB       aux        auxiliary
# help       VERB       ROOT       None
# support    VERB       xcomp      open clausal complement
# and        CCONJ      cc         coordinating conjunction
# lead       VERB       conj       conjunct
# the        DET        det        determiner
# refinery   NOUN       nmod       modifier of nominal
# wide       ADJ        amod       adjectival modifier
# instrumentation NOUN       nmod       modifier of nominal
# and        CCONJ      cc         coordinating conjunction
# controls   NOUN       conj       conjunct
# projects   NOUN       dobj       direct object
# and        CCONJ      cc         coordinating conjunction
# long       ADJ        amod       adjectival modifier
# -          PUNCT      punct      punctuation
# term       NOUN       compound   compound
# plans      NOUN       conj       conjunct
# to         PART       aux        auxiliary
# ensure     VERB       acl        clausal modifier of noun (adjectival clause)
# safe       ADJ        amod       adjectival modifier
# and        CCONJ      cc         coordinating conjunction
# reliable   ADJ        conj       conjunct
# operations NOUN       dobj       direct object
# within     ADP        prep       prepositional modifier
# the        DET        det        determiner
# Edmonton   PROPN      compound   compound
# refinery   NOUN       pobj       object of preposition
# .          PUNCT      punct      punctuation
# Key        ADJ        compound   compound
# Accountabilities NOUN       nsubj      nominal subject
# Develop    VERB       ccomp      clausal complement
# detailed   ADJ        amod       adjectival modifier
# engineering NOUN       compound   compound
# work       NOUN       compound   compound
# packages   NOUN       dobj       direct object
# in         ADP        prep       prepositional modifier
# accordance NOUN       pobj       object of preposition
# with       ADP        prep       prepositional modifier
# project    NOUN       compound   compound
# specifications NOUN       pobj       object of preposition
# and        CCONJ      cc         coordinating conjunction
# provide    VERB       conj       conjunct
# construction NOUN       dobj       direct object
# ,          PUNCT      punct      punctuation
# commissioning NOUN       conj       conjunct
# and        CCONJ      cc         coordinating conjunction
# start      VERB       amod       adjectival modifier
# -          PUNCT      punct      punctuation
# up         ADP        prt        particle
# support    NOUN       conj       conjunct
# Develop    VERB       conj       conjunct
# control    NOUN       compound   compound
# narratives NOUN       dobj       direct object
# for        ADP        prep       prepositional modifier
# new        ADJ        amod       adjectival modifier
# and        CCONJ      cc         coordinating conjunction
# existing   VERB       conj       conjunct
# DCS        PROPN      compound   compound
# control    NOUN       nmod       modifier of nominal
# and        CCONJ      cc         coordinating conjunction
# safety     NOUN       conj       conjunct
# systems    NOUN       pobj       object of preposition
# ;          PUNCT      punct      punctuation
# investigate VERB       amod       adjectival modifier
# and        CCONJ      cc         coordinating conjunction
# troubleshoot VERB       compound   compound
# control    NOUN       conj       conjunct
# system     NOUN       compound   compound
# configuration NOUN       compound   compound
# problems   NOUN       nsubj      nominal subject
# and        CCONJ      cc         coordinating conjunction
# recommend  VERB       conj       conjunct
# quick      ADJ        amod       adjectival modifier
# and        CCONJ      cc         coordinating conjunction
# reliable   ADJ        conj       conjunct
# solutions  NOUN       compound   compound
# Review     PROPN      compound   compound
# work       NOUN       compound   compound
# packages   NOUN       dobj       direct object
# for        ADP        prep       prepositional modifier
# error      NOUN       nmod       modifier of nominal
# free       ADJ        amod       adjectival modifier
# and        CCONJ      cc         coordinating conjunction
# consistent ADJ        conj       conjunct
# engineering NOUN       compound   compound
# deliverables NOUN       pobj       object of preposition
# as         SCONJ      prep       prepositional modifier
# per        ADP        prep       prepositional modifier
# applicable ADJ        amod       adjectival modifier
# codes      NOUN       pobj       object of preposition
# and        CCONJ      cc         coordinating conjunction
# approved   VERB       amod       adjectival modifier
# engineering NOUN       compound   compound
# standards  NOUN       compound   compound
# Design     PROPN      conj       conjunct
# ,          PUNCT      punct      punctuation
# configure  NOUN       conj       conjunct
# ,          PUNCT      punct      punctuation
# validate   NOUN       conj       conjunct
# (          PUNCT      punct      punctuation
# offline    ADJ        compound   compound
# simulation NOUN       conj       conjunct
# )          PUNCT      punct      punctuation
# and        CCONJ      cc         coordinating conjunction
# optimize   VERB       conj       conjunct
# controls   NOUN       compound   compound
# software   NOUN       compound   compound
# packages   NOUN       dobj       direct object
# to         PART       aux        auxiliary
# provide    VERB       xcomp      open clausal complement
# accurate   ADJ        amod       adjectival modifier
# and        CCONJ      cc         coordinating conjunction
# reliable   ADJ        conj       conjunct
# software   NOUN       compound   compound
# deliverables NOUN       dobj       direct object
# for        ADP        prep       prepositional modifier
# safe       ADJ        amod       adjectival modifier
# refinery   NOUN       compound   compound
# operations NOUN       pobj       object of preposition
# ;          PUNCT      punct      punctuation
# test       NOUN       compound   compound
# systems    NOUN       appos      appositional modifier
# thoroughly ADV        advmod     adverbial modifier
# in         ADP        prep       prepositional modifier
# an         DET        det        determiner
# offline    ADJ        amod       adjectival modifier
# environment NOUN       pobj       object of preposition
# with       ADP        prep       prepositional modifier
# key        ADJ        amod       adjectival modifier
# stakeholders NOUN       pobj       object of preposition
# to         PART       aux        auxiliary
# address    VERB       relcl      relative clause modifier
# valid      ADJ        amod       adjectival modifier
# concerns   NOUN       dobj       direct object
# Provide    VERB       ROOT       None
# continuous ADJ        amod       adjectival modifier
# improvement NOUN       dobj       direct object
# and        CCONJ      cc         coordinating conjunction
# standardization NOUN       compound   compound
# feedback   NOUN       conj       conjunct
# towards    ADP        prep       prepositional modifier
# improved   ADJ        amod       adjectival modifier
# controls   NOUN       compound   compound
# configuration NOUN       compound   compound
# processes  NOUN       pobj       object of preposition
# ,          PUNCT      punct      punctuation
# project    NOUN       compound   compound
# efficiencies NOUN       conj       conjunct
# ,          PUNCT      punct      punctuation
# quality    NOUN       nmod       modifier of nominal
# and        CCONJ      cc         coordinating conjunction
# cost       VERB       compound   compound
# effectiveness NOUN       conj       conjunct
# Exercise   NOUN       compound   compound
# cost       NOUN       compound   compound
# control    NOUN       conj       conjunct
# when       ADV        advmod     adverbial modifier
# providing  VERB       advcl      adverbial clause modifier
# engineering NOUN       compound   compound
# solutions  NOUN       dobj       direct object
# ,          PUNCT      punct      punctuation
# review     VERB       conj       conjunct
# and        CCONJ      cc         coordinating conjunction
# maintain   VERB       conj       conjunct
# project    NOUN       compound   compound
# schedules  NOUN       dobj       direct object
# ,          PUNCT      punct      punctuation
# track      VERB       compound   compound
# engineering NOUN       compound   compound
# tasks      NOUN       conj       conjunct
# and        CCONJ      cc         coordinating conjunction
# deliverables NOUN       conj       conjunct
# in         ADP        prep       prepositional modifier
# conjunction NOUN       pobj       object of preposition
# with       ADP        prep       prepositional modifier
# project    NOUN       compound   compound
# management NOUN       compound   compound
# Prepare    PROPN      compound   compound
# material   NOUN       compound   compound
# requisitions NOUN       pobj       object of preposition
# and        CCONJ      cc         coordinating conjunction
# complete   VERB       amod       adjectival modifier
# technical  ADJ        amod       adjectival modifier
# evaluations NOUN       conj       conjunct
# by         ADP        prep       prepositional modifier
# reviewing  VERB       pcomp      complement of preposition
# vendor     NOUN       dobj       direct object
# or         CCONJ      cc         coordinating conjunction
# subcontractor NOUN       compound   compound
# quotations NOUN       conj       conjunct
# ,          PUNCT      punct      punctuation
# drawings   NOUN       conj       conjunct
# and        CCONJ      cc         coordinating conjunction
# specifications NOUN       conj       conjunct
# in         ADP        prep       prepositional modifier
# conformance NOUN       pobj       object of preposition
# with       ADP        prep       prepositional modifier
# project    NOUN       compound   compound
# requirements NOUN       pobj       object of preposition
# Participate VERB       acl        clausal modifier of noun (adjectival clause)
# in         ADP        prep       prepositional modifier
# design     NOUN       compound   compound
# reviews    NOUN       pobj       object of preposition
# ,          PUNCT      punct      punctuation
# process    VERB       compound   compound
# hazard     PROPN      compound   compound
# analysis   NOUN       conj       conjunct
# ,          PUNCT      punct      punctuation
# management NOUN       conj       conjunct
# of         ADP        prep       prepositional modifier
# change     NOUN       pobj       object of preposition
# ,          PUNCT      punct      punctuation
# layers     NOUN       conj       conjunct
# of         ADP        prep       prepositional modifier
# protection NOUN       compound   compound
# analysis   NOUN       pobj       object of preposition
# (          PUNCT      punct      punctuation
# LOPA       PROPN      appos      appositional modifier
# )          PUNCT      punct      punctuation
# and        CCONJ      cc         coordinating conjunction
# safety     NOUN       compound   compound
# integrity  NOUN       compound   compound
# level      NOUN       appos      appositional modifier
# (          PUNCT      punct      punctuation
# SIL        PROPN      nmod       modifier of nominal
# )          PUNCT      punct      punctuation
# analysis   NOUN       appos      appositional modifier
#            SPACE                 None
# Use        PROPN      ccomp      clausal complement
# resources  NOUN       dobj       direct object
# effectively ADV        advmod     adverbial modifier
# and        CCONJ      cc         coordinating conjunction
# offer      VERB       conj       conjunct
# coaching   VERB       dobj       direct object
# to         ADP        prep       prepositional modifier
# junior     ADJ        amod       adjectival modifier
# staff      NOUN       nmod       modifier of nominal
# and        CCONJ      cc         coordinating conjunction
# contractor NOUN       conj       conjunct
# resources  NOUN       pobj       object of preposition
# Required   VERB       compound   compound
# Qualifications PROPN      compound   compound
# Experience PROPN      appos      appositional modifier
# and        CCONJ      cc         coordinating conjunction
# Education  NOUN       conj       conjunct
# :          PUNCT      punct      punctuation
# Eight      NUM        nummod     numeric modifier
# or         CCONJ      cc         coordinating conjunction
# more       ADJ        conj       conjunct
# years      NOUN       intj       interjection
# of         ADP        prep       prepositional modifier
# control    NOUN       compound   compound
# systems    NOUN       compound   compound
# experience NOUN       pobj       object of preposition
#            SPACE                 None
# Demonstrated VERB       amod       adjectival modifier
# experience NOUN       conj       conjunct
# in         ADP        prep       prepositional modifier
# developing VERB       pcomp      complement of preposition
# engineering NOUN       compound   compound
# work       NOUN       compound   compound
# packages   NOUN       dobj       direct object
# and        CCONJ      cc         coordinating conjunction
# hands      NOUN       nmod       modifier of nominal
# -          PUNCT      punct      punctuation
# on         ADP        prt        particle
# control    NOUN       compound   compound
# systems    NOUN       compound   compound
# programming NOUN       compound   compound
# experience NOUN       conj       conjunct
# in         ADP        prep       prepositional modifier
# an         DET        det        determiner
# oil        NOUN       compound   compound
# refinery   NOUN       pobj       object of preposition
# for        ADP        prep       prepositional modifier
# at         ADV        advmod     adverbial modifier
# least      ADV        advmod     adverbial modifier
# two        NUM        nummod     numeric modifier
# years      NOUN       pobj       object of preposition
# ;          PUNCT      punct      punctuation
# experience NOUN       nsubjpass  nominal subject (passive)
# at         ADP        prep       prepositional modifier
# the        DET        det        determiner
# Edmonton   PROPN      compound   compound
# refinery   NOUN       pobj       object of preposition
# is         AUX        auxpass    auxiliary (passive)
# considered VERB       ccomp      clausal complement
# an         DET        det        determiner
# asset      NOUN       nmod       modifier of nominal
# Demonstrated VERB       amod       adjectival modifier
# experience NOUN       oprd       object predicate
# on         ADP        prep       prepositional modifier
# interfacing VERB       pcomp      complement of preposition
# near       SCONJ      prep       prepositional modifier
# infrared   ADJ        amod       adjectival modifier
# analyzer   PROPN      nmod       modifier of nominal
# ,          PUNCT      punct      punctuation
# nuclear    ADJ        amod       adjectival modifier
# magnetic   ADJ        amod       adjectival modifier
# resonance  NOUN       nmod       modifier of nominal
# and        CCONJ      cc         coordinating conjunction
# sample     NOUN       compound   compound
# conditioning NOUN       conj       conjunct
# systems    NOUN       pobj       object of preposition
# with       ADP        prep       prepositional modifier
# Honeywell  PROPN      compound   compound
# Experion   PROPN      pobj       object of preposition
# and        CCONJ      cc         coordinating conjunction
# TDC3000    VERB       compound   compound
# DCS        PROPN      conj       conjunct
# in         ADP        prep       prepositional modifier
# a          DET        det        determiner
# refinery   NOUN       compound   compound
# environment NOUN       pobj       object of preposition
# ;          PUNCT      punct      punctuation
# advanced   ADJ        amod       adjectival modifier
# competency NOUN       ccomp      clausal complement
# with       ADP        prep       prepositional modifier
# Triconex   PROPN      compound   compound
# PLC        PROPN      compound   compound
# programming NOUN       pobj       object of preposition
# and        CCONJ      cc         coordinating conjunction
# Unity      PROPN      compound   compound
# Pro        PROPN      conj       conjunct
# for        ADP        prep       prepositional modifier
# Modicon    PROPN      compound   compound
# PLC        PROPN      compound   compound
# Bachelor   PROPN      pobj       object of preposition
# ’s         PART       punct      punctuation
# degree     NOUN       appos      appositional modifier
# in         ADP        prep       prepositional modifier
# engineering NOUN       pobj       object of preposition
# ;          PUNCT      punct      punctuation
# post       NOUN       compound   compound
# graduate   ADJ        compound   compound
# qualifications NOUN       nsubj      nominal subject
# will       VERB       aux        auxiliary
# be         AUX        ROOT       None
# an         DET        det        determiner
# asset      NOUN       compound   compound
# Registered VERB       attr       attribute
# as         SCONJ      prep       prepositional modifier
# a          DET        det        determiner
# professional ADJ        amod       adjectival modifier
# engineer   NOUN       pobj       object of preposition
# with       ADP        prep       prepositional modifier
# the        DET        det        determiner
# Association PROPN      nmod       modifier of nominal
# of         ADP        prep       prepositional modifier
# Professional PROPN      compound   compound
# Engineers  PROPN      pobj       object of preposition
# and        CCONJ      cc         coordinating conjunction
# Geoscientists PROPN      conj       conjunct
# of         ADP        prep       prepositional modifier
# Alberta    PROPN      pobj       object of preposition
# (          PUNCT      punct      punctuation
# APEGA      PROPN      appos      appositional modifier
# )          PUNCT      punct      punctuation
# Skills     NOUN       pobj       object of preposition
# and        CCONJ      cc         coordinating conjunction
# Knowledge  NOUN       conj       conjunct
# :          PUNCT      punct      punctuation
# Hands      NOUN       nmod       modifier of nominal
# -          PUNCT      punct      punctuation
# on         ADP        prt        particle
# maintenance NOUN       nmod       modifier of nominal
# and        CCONJ      cc         coordinating conjunction
# configuration NOUN       conj       conjunct
# experience NOUN       ROOT       None
# with       ADP        prep       prepositional modifier
# distributed VERB       amod       adjectival modifier
# control    NOUN       compound   compound
# system     NOUN       pobj       object of preposition
# (          PUNCT      punct      punctuation
# Experion   PROPN      appos      appositional modifier
# ,          PUNCT      punct      punctuation
# C300       PROPN      conj       conjunct
# ,          PUNCT      punct      punctuation
# C200       PROPN      conj       conjunct
# ,          PUNCT      punct      punctuation
# TDC3000    PROPN      appos      appositional modifier
# ,          PUNCT      punct      punctuation
# SCADA      PROPN      appos      appositional modifier
# )          PUNCT      punct      punctuation
# ,          PUNCT      punct      punctuation
# safety     NOUN       npadvmod   noun phrase as adverbial modifier
# instrumented VERB       amod       adjectival modifier
# systems    NOUN       conj       conjunct
# (          PUNCT      punct      punctuation
# Triconex   PROPN      appos      appositional modifier
# )          PUNCT      punct      punctuation
# ,          PUNCT      punct      punctuation
# and        CCONJ      cc         coordinating conjunction
# programmable ADJ        amod       adjectival modifier
# logic      NOUN       compound   compound
# controllers NOUN       conj       conjunct
# (          PUNCT      punct      punctuation
# Modicon    PROPN      appos      appositional modifier
# )          PUNCT      punct      punctuation
# Strong     ADJ        amod       adjectival modifier
# technical  ADJ        amod       adjectival modifier
# knowledge  NOUN       nsubj      nominal subject
# of         ADP        prep       prepositional modifier
# applicable ADJ        amod       adjectival modifier
# automation NOUN       compound   compound
# industry   NOUN       compound   compound
# standards  NOUN       pobj       object of preposition
# ,          PUNCT      punct      punctuation
# SIL        PROPN      compound   compound
# assessment NOUN       appos      appositional modifier
# ,          PUNCT      punct      punctuation
# LOPA       PROPN      compound   compound
# methodologies NOUN       conj       conjunct
# ,          PUNCT      punct      punctuation
# and        CCONJ      cc         coordinating conjunction
# alarm      NOUN       compound   compound
# management NOUN       compound   compound
# guidelines NOUN       compound   compound
# Experience NOUN       conj       conjunct
# on         ADP        prep       prepositional modifier
# Burner     PROPN      compound   compound
# Management PROPN      compound   compound
# System     PROPN      pobj       object of preposition
# (          PUNCT      punct      punctuation
# BMS        PROPN      appos      appositional modifier
# )          PUNCT      punct      punctuation
# ,          PUNCT      punct      punctuation
# compressor NOUN       conj       conjunct
# ,          PUNCT      punct      punctuation
#            SPACE                 None
# fire       NOUN       conj       conjunct
# and        CCONJ      cc         coordinating conjunction
# gas        NOUN       compound   compound
# detection  NOUN       compound   compound
# system     NOUN       conj       conjunct
# and        CCONJ      cc         coordinating conjunction
# Triconex   PROPN      conj       conjunct
# upgrade    VERB       ROOT       None
# Strong     ADJ        amod       adjectival modifier
# interpersonal ADJ        amod       adjectival modifier
# skills     NOUN       dobj       direct object
# to         PART       aux        auxiliary
# work       VERB       advcl      adverbial clause modifier
# with       ADP        prep       prepositional modifier
# the        DET        det        determiner
# engineering NOUN       compound   compound
# contractors NOUN       pobj       object of preposition
# ,          PUNCT      punct      punctuation
# vendors    NOUN       conj       conjunct
# and        CCONJ      cc         coordinating conjunction
# project    NOUN       compound   compound
# teams      NOUN       conj       conjunct
# ,          PUNCT      punct      punctuation
# in         ADP        prep       prepositional modifier
# a          DET        det        determiner
# multi      ADJ        dep        unclassified dependent
# -          ADJ        dep        unclassified dependent
# ...
# marketing  NOUN       conj       conjunct
# operations NOUN       pobj       object of preposition
# ,          PUNCT      punct      punctuation
# natural    ADJ        amod       adjectival modifier
# gas        NOUN       conj       conjunct
# ,          PUNCT      punct      punctuation
# and        CCONJ      cc         coordinating conjunction
# conventional ADJ        amod       adjectival modifier
# oil        NOUN       compound   compound
# production NOUN       conj       conjunct
# ,          PUNCT      punct      punctuation
# internationally ADV        advmod     adverbial modifier
# and        CCONJ      cc         coordinating conjunction
# offshore   ADJ        conj       conjunct
# East       PROPN      compound   compound
# Coast      PROPN      compound   compound
# Canada     PROPN      appos      appositional modifier
# .          PUNCT      punct      punctuation
# And        CCONJ      cc         coordinating conjunction
# while      SCONJ      mark       marker
# we         PRON       nsubj      nominal subject
# are        AUX        aux        auxiliary
# working    VERB       advcl      adverbial clause modifier
# to         PART       aux        auxiliary
# responsibly ADV        advmod     adverbial modifier
# develop    VERB       xcomp      open clausal complement
# petroleum  NOUN       compound   compound
# resources  NOUN       dobj       direct object
# and        CCONJ      cc         coordinating conjunction
# contribute VERB       conj       conjunct
# to         ADP        prep       prepositional modifier
# the        DET        det        determiner
# communities NOUN       pobj       object of preposition
# where      ADV        advmod     adverbial modifier
# we         PRON       nsubj      nominal subject
# live       VERB       relcl      relative clause modifier
# and        CCONJ      cc         coordinating conjunction
# work       VERB       conj       conjunct
# ,          PUNCT      punct      punctuation
# we         PRON       nsubj      nominal subject
# are        AUX        aux        auxiliary
# also       ADV        advmod     adverbial modifier
# developing VERB       ROOT       None
# our        DET        poss       possession modifier
# renewable  ADJ        amod       adjectival modifier
# energy     NOUN       compound   compound
# portfolio  NOUN       dobj       direct object
# ,          PUNCT      punct      punctuation
# which      DET        nsubj      nominal subject
# includes   VERB       relcl      relative clause modifier
# wind       NOUN       compound   compound
# power      NOUN       dobj       direct object
# and        CCONJ      cc         coordinating conjunction
# biofuels   NOUN       conj       conjunct
# .          PUNCT      punct      punctuation
# As         SCONJ      prep       prepositional modifier
# part       NOUN       pobj       object of preposition
# of         ADP        prep       prepositional modifier
# Suncor     PROPN      poss       possession modifier
# 's         PART       case       case marking
# team       NOUN       pobj       object of preposition
# ,          PUNCT      punct      punctuation
# you        PRON       nsubj      nominal subject
# 'll        VERB       aux        auxiliary
# contribute VERB       ROOT       None
# to         ADP        prep       prepositional modifier
# the        DET        det        determiner
# ongoing    ADJ        amod       adjectival modifier
# success    NOUN       pobj       object of preposition
# of         ADP        prep       prepositional modifier
# Canada     PROPN      poss       possession modifier
# 's         PART       case       case marking
# largest    ADJ        amod       adjectival modifier
# energy     NOUN       compound   compound
# company    NOUN       pobj       object of preposition
# -          PUNCT      punct      punctuation
# one        NUM        appos      appositional modifier
# with       ADP        prep       prepositional modifier
# a          DET        det        determiner
# solid      ADJ        amod       adjectival modifier
# track      NOUN       compound   compound
# record     NOUN       pobj       object of preposition
# of         ADP        prep       prepositional modifier
# growth     NOUN       pobj       object of preposition
# ,          PUNCT      punct      punctuation
# a          DET        det        determiner
# focus      NOUN       appos      appositional modifier
# on         ADP        prep       prepositional modifier
# safety     NOUN       pobj       object of preposition
# and        CCONJ      cc         coordinating conjunction
# sustainability NOUN       conj       conjunct
# and        CCONJ      cc         coordinating conjunction
# tremendous ADJ        amod       adjectival modifier
# potential  NOUN       conj       conjunct
# for        ADP        prep       prepositional modifier
# the        DET        det        determiner
# future     NOUN       pobj       object of preposition
# .          PUNCT      punct      punctuation
# And        CCONJ      cc         coordinating conjunction
# you        PRON       nsubj      nominal subject
# 'll        VERB       aux        auxiliary
# have       AUX        ROOT       None
# the        DET        det        determiner
# opportunity NOUN       dobj       direct object
# to         PART       aux        auxiliary
# learn      VERB       acl        clausal modifier of noun (adjectival clause)
# from       ADP        prep       prepositional modifier
# experts    NOUN       pobj       object of preposition
# in         ADP        prep       prepositional modifier
# the        DET        det        determiner
# industry   NOUN       pobj       object of preposition
# and        CCONJ      cc         coordinating conjunction
# build      VERB       conj       conjunct
# on         ADP        prep       prepositional modifier
# your       DET        poss       possession modifier
# skills     NOUN       pobj       object of preposition
# every      DET        det        determiner
# day        NOUN       npadvmod   noun phrase as adverbial modifier
# .          PUNCT      punct      punctuation
# Suncor     PROPN      nsubj      nominal subject
# promotes   VERB       ROOT       None
# diversity  NOUN       dobj       direct object
# and        CCONJ      cc         coordinating conjunction
# inclusion  NOUN       conj       conjunct
# in         ADP        prep       prepositional modifier
# the        DET        det        determiner
# workplace  NOUN       pobj       object of preposition
# .          PUNCT      punct      punctuation
# Suncor     PROPN      nsubj      nominal subject
# is         AUX        ROOT       None
# an         DET        det        determiner
# equal      ADJ        amod       adjectival modifier
# opportunity NOUN       compound   compound
# employer   NOUN       attr       attribute
# and        CCONJ      cc         coordinating conjunction
# encourages VERB       conj       conjunct
# applications NOUN       dobj       direct object
# from       ADP        prep       prepositional modifier
# all        DET        det        determiner
# qualified  ADJ        amod       adjectival modifier
# individuals NOUN       pobj       object of preposition
# .          PUNCT      punct      punctuation
# At         ADP        prep       prepositional modifier
# Suncor     PROPN      pobj       object of preposition
# ,          PUNCT      punct      punctuation
# we         PRON       nsubjpass  nominal subject (passive)
# are        AUX        auxpass    auxiliary (passive)
# dedicated  ADJ        ROOT       None
# to         ADP        prep       prepositional modifier
# building   VERB       pcomp      complement of preposition
# a          DET        det        determiner
# workforce  NOUN       dobj       direct object
# that       DET        nsubj      nominal subject
# reflects   VERB       relcl      relative clause modifier
# the        DET        det        determiner
# diversity  NOUN       dobj       direct object
# of         ADP        prep       prepositional modifier
# the        DET        det        determiner
# communitities NOUN       pobj       object of preposition
# in         ADP        prep       prepositional modifier
# which      DET        pobj       object of preposition
# we         PRON       nsubj      nominal subject
# live       VERB       relcl      relative clause modifier
# ,          PUNCT      punct      punctuation
# and        CCONJ      cc         coordinating conjunction
# where      ADV        advmod     adverbial modifier
# every      DET        det        determiner
# team       NOUN       compound   compound
# member     NOUN       nsubj      nominal subject
# has        AUX        conj       conjunct
# the        DET        det        determiner
# opportunity NOUN       dobj       direct object
# to         PART       aux        auxiliary
# reach      VERB       acl        clausal modifier of noun (adjectival clause)
# their      DET        poss       possession modifier
# full       ADJ        amod       adjectival modifier
# potential  NOUN       dobj       direct object
# .          PUNCT      punct      punctuation
# Not        PART       neg        negation modifier
# sure       ADJ        ROOT       None
# if         SCONJ      mark       marker
# this       DET        det        determiner
# particular ADJ        amod       adjectival modifier
# listing    NOUN       nsubj      nominal subject
# is         AUX        ccomp      clausal complement
# the        DET        det        determiner
# right      ADJ        amod       adjectival modifier
# opportunity NOUN       attr       attribute
# for        ADP        prep       prepositional modifier
# you        PRON       pobj       object of preposition
# ?          PUNCT      punct      punctuation
# Please     INTJ       intj       interjection
# join       VERB       ROOT       None
# our        DET        poss       possession modifier
# Talent     PROPN      compound   compound
# Community  PROPN      dobj       direct object
# at         ADP        prep       prepositional modifier
# www.suncor.com X          pobj       object of preposition
# and        CCONJ      cc         coordinating conjunction
# click      VERB       conj       conjunct
# on         ADP        prep       prepositional modifier
# Careers    NOUN       pobj       object of preposition
# ,          PUNCT      punct      punctuation
# or         CCONJ      cc         coordinating conjunction
# follow     VERB       conj       conjunct
# us         PRON       dobj       direct object
# on         ADP        prep       prepositional modifier
# LinkedIn   PROPN      pobj       object of preposition
# ,          PUNCT      punct      punctuation
# Facebook   PROPN      conj       conjunct
# and        CCONJ      cc         coordinating conjunction
# Twitter    PROPN      conj       conjunct
# for        ADP        prep       prepositional modifier
# the        DET        det        determiner
# latest     ADJ        amod       adjectival modifier
# job        NOUN       compound   compound
# listings   NOUN       pobj       object of preposition
# and        CCONJ      cc         coordinating conjunction
# employment NOUN       compound   compound
# news       NOUN       conj       conjunct
# .          PUNCT      punct      punctuation
# Please     INTJ       intj       interjection
# note       VERB       ROOT       None
# that       SCONJ      mark       marker
# our        DET        poss       possession modifier
# job        NOUN       compound   compound
# postings   NOUN       nsubj      nominal subject
# are        AUX        ccomp      clausal complement
# typically  ADV        advmod     adverbial modifier
# open       ADJ        acomp      adjectival complement
# for        ADP        prep       prepositional modifier
# two        NUM        nummod     numeric modifier
# weeks      NOUN       pobj       object of preposition
# ,          PUNCT      punct      punctuation
# so         CCONJ      cc         coordinating conjunction
# if         SCONJ      mark       marker
# you        PRON       nsubj      nominal subject
# are        AUX        advcl      adverbial clause modifier
# interested ADJ        acomp      adjectival complement
# and        CCONJ      cc         coordinating conjunction
# qualified  ADJ        conj       conjunct
# ,          PUNCT      punct      punctuation
# apply      VERB       conj       conjunct
# now        ADV        advmod     adverbial modifier
# .          PUNCT      punct      punctuation
# JOB        PROPN      compound   compound
# CATEGORY   PROPN      ROOT       None
# :          PUNCT      punct      punctuation
# Engineering NOUN       compound   compound
# Job        PROPN      compound   compound
# Segment    NOUN       ROOT       None
# :          PUNCT      punct      punctuation
# Controls   PROPN      compound   compound
# Engineer   PROPN      nsubj      nominal subject
# ,          PUNCT      punct      punctuation
# Construction PROPN      conj       conjunct
# ,          PUNCT      punct      punctuation
# Instrumentation PROPN      conj       conjunct
# ,          PUNCT      punct      punctuation
# Engineer   PROPN      conj       conjunct
# ,          PUNCT      punct      punctuation
# Electrical PROPN      conj       conjunct
# ,          PUNCT      punct      punctuation
# Engineering PROPN      compound   compound
# Apply      PROPN      appos      appositional modifier
# now        ADV        advmod     adverbial modifier
# »          INTJ       punct      punctuation
# Apply      VERB       nsubj      nominal subject
# now        ADV        advmod     adverbial modifier
# Apply      VERB       ROOT       None
# Now        ADV        advmod     adverbial modifier
# Start      PROPN      nsubj      nominal subject
# apply      VERB       ccomp      clausal complement
# with       ADP        prep       prepositional modifier
# LinkedIn   PROPN      pobj       object of preposition
# Start      NOUN       aux        auxiliary
# Please     INTJ       intj       interjection
# wait       VERB       ROOT       None
# ...        PUNCT      punct      punctuation
# Find       VERB       ROOT       None
# similar    ADJ        amod       adjectival modifier
# jobs       NOUN       dobj       direct object
# :          PUNCT      punct      punctuation
# Energy     NOUN       compound   compound
# Jobs       NOUN       appos      appositional modifier
# in         ADP        prep       prepositional modifier
# Edmonton   PROPN      compound   compound
# Connect    PROPN      pobj       object of preposition
# with       ADP        prep       prepositional modifier
# Suncor     PROPN      pobj       object of preposition
# Our        DET        poss       possession modifier
# social     ADJ        amod       adjectival modifier
# media      NOUN       compound   compound
# channels   NOUN       ROOT       None
# Related    ADJ        amod       adjectival modifier
# links      NOUN       dobj       direct object
# Careers    NOUN       compound   compound
# home       ADV        compound   compound
# View       VERB       ROOT       None
# all        DET        det        determiner
# jobs       NOUN       compound   compound
# Search     NOUN       ROOT       None
# by         ADP        prep       prepositional modifier
# location   NOUN       pobj       object of preposition
# Top        ADJ        amod       adjectival modifier
# job        NOUN       compound   compound
# searches   VERB       ROOT       None
# Suncor.com PROPN      ROOT       None
# About      ADP        prep       prepositional modifier
# us         PRON       pobj       object of preposition
# Accessibility PROPN      compound   compound
# policy     NOUN       compound   compound
# Legal      PROPN      ROOT       None
# &          CCONJ      cc         coordinating conjunction
# privacy    NOUN       conj       conjunct
# Français   PROPN      compound   compound
# ©          PROPN      ROOT       None
# 2017       NUM        nummod     numeric modifier
# Suncor     PROPN      compound   compound
# Energy     PROPN      compound   compound
# Inc.       PROPN      compound   compound
# All        DET        det        determiner
# Rights     PROPN      nsubj      nominal subject
# Reserved   PROPN      ROOT       None
#            SPACE                 None
# Canada     PROPN      conj       conjunct
#                   SPACE                 None
# CA         PROPN      dobj       direct object
