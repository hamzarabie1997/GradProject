# %%
import sklearn

# %%
# synthetic classification dataset
from numpy import where
from sklearn.datasets import make_classification
from matplotlib import pyplot
# define dataset
X, y = make_classification(n_samples=1000, n_features=2, n_informative=2, n_redundant=0, n_clusters_per_class=1, random_state=4)
# create scatter plot for samples from each class
for class_value in range(2):
	# get row indexes for samples with this class
	row_ix = where(y == class_value)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %%
# affinity propagation clustering
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import AffinityPropagation
from matplotlib import pyplot
# define dataset
X, _ = make_classification(n_samples=1000, n_features=2, n_informative=2, n_redundant=0, n_clusters_per_class=1, random_state=4)
# define the model
model = AffinityPropagation(damping=0.9)
# fit the model
model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
print(pyplot)
# Out:
# <module 'matplotlib.pyplot' from 'D:\\N\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
import pandas as pd

# %%
df = pd.read_csv("../TextFiles/csv/JopDataSet.csv")
schema_df = pd.read_csv('../TextFiles/csv/JopDataSet.csv')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

df.head()
# Out:
#     type                                            pageurl  \
# 0  array  https://www.simplyhired.com/job/Ny79HQUAZet4Dy...
# 1  array  https://www.simplyhired.com/job/gNRtJ9_fyPkEsO...
# 2  array  https://www.simplyhired.com/job/N1azNM3D2VNGC_...
# 3  array  https://www.simplyhired.com/job/Cc3yCyLH80lt68...
# 4  array  https://www.simplyhired.com/job/jU07UpKLXqVCX3...
#
#                             uniq-id            crawl-timestamp  \
# 0  5a31cb0ee47e3cf1b5040e6c9fe9c0db  2019-09-30 16:12:44 +0000
# 1  1645b95dcd323b045e7e1733f775f582  2019-09-22 13:32:10 +0000
# 2  8624490c19ca05d1482f0084ccacdf59  2019-09-25 13:05:08 +0000
# 3  713d3a87025ff202027c7b5ba9d99580  2019-09-26 02:01:31 +0000
# 4  d788321e52ccae1c8ccc6228fee94edc  2019-09-19 16:45:36 +0000
#
#                                            employer  \
# 0                                         Giftcraft
# 1                                       Bento Group
# 2                     Burger King | Ghai Management
# ...

# %%
filt = (df['ad-title'] == 'Housekeeper')

# %%
filt
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 30025    False
# 30026    False
# 30027    False
# 30028    False
# 30029    False
# Name: ad-title, Length: 30030, dtype: bool

# %%
df.loc[filt]
# Out:
#         type                                            pageurl  \
# 16     array  https://www.simplyhired.com/job/XRwtaur_PstLpI...
# 328    array  https://www.simplyhired.com/job/fXm88dePnYXgG7...
# 706    array  https://www.simplyhired.com/job/EGDyXo3oUacsgs...
# 852    array  https://www.simplyhired.com/job/In7fECJaJsNQV5...
# 980    array  https://www.simplyhired.com/job/NJ93BQ_oM6C_Sa...
# 991    array  https://www.simplyhired.com/job/fKMvd7I-RASsSu...
# 1038   array  https://www.simplyhired.com/job/qr_SU4_EBBLefB...
# 1387   array  https://www.simplyhired.com/job/jg9aJpK4ZyXf_S...
# 1493   array  https://www.simplyhired.com/job/zIDEYKaKyfLrAG...
# 2271   array  https://www.simplyhired.com/job/kmKQjhmfHQYB1j...
# 2528   array  https://www.simplyhired.com/job/prd12qiK3aGsNK...
# 2562   array  https://www.simplyhired.com/job/YQGR7RmpdxBB_O...
# 2667   array  https://www.simplyhired.com/job/o4hkeNBpAWvKDA...
# 2808   array  https://www.simplyhired.com/job/FMLSa8k6uGmHZF...
# ...

# %%
# save data after filttaring in data frame  
filt = df['ad-title'].str.contains('Housekeeper', na=False)

housekeeping_df = df.loc[filt]

# %%
housekeeping_df
# Out:
#         type                                            pageurl  \
# 16     array  https://www.simplyhired.com/job/XRwtaur_PstLpI...
# 113    array  https://www.simplyhired.com/job/mzUgm7mS7Alii4...
# 328    array  https://www.simplyhired.com/job/fXm88dePnYXgG7...
# 369    array  https://www.simplyhired.com/job/w9Vw2P7zYUQrBj...
# 435    array  https://www.simplyhired.com/job/ubDJUC6FI4ImD8...
# ...      ...                                                ...
# 29353  array  https://www.simplyhired.com/job/AlWKp_H5-ouSG6...
# 29419  array  https://www.simplyhired.com/job/JGRA4wfFl28CrX...
# 29515  array  https://www.simplyhired.com/job/9ytRt6RMV0k1Bf...
# 29945  array  https://www.simplyhired.com/job/E6V77yTMEH5se1...
# 30025  array  https://www.simplyhired.com/job/bCvyw7_YnIAmCL...
#
#                                 uniq-id            crawl-timestamp  \
# 16     44ec38ab192b4a8c72f175929ee34df6  2019-09-17 16:37:07 +0000
# ...

# %%
import numpy as np
import pandas as pd
import re

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

s = df[0:1]
s=s.to_string()
    
housekeeping_df = nlp(s)

# %%
print(df.head())
# Out:
#     type                                            pageurl  \
# 0  array  https://www.simplyhired.com/job/Ny79HQUAZet4Dy...
# 1  array  https://www.simplyhired.com/job/gNRtJ9_fyPkEsO...
# 2  array  https://www.simplyhired.com/job/N1azNM3D2VNGC_...
# 3  array  https://www.simplyhired.com/job/Cc3yCyLH80lt68...
# 4  array  https://www.simplyhired.com/job/jU07UpKLXqVCX3...
#
#                             uniq-id            crawl-timestamp  \
# 0  5a31cb0ee47e3cf1b5040e6c9fe9c0db  2019-09-30 16:12:44 +0000
# 1  1645b95dcd323b045e7e1733f775f582  2019-09-22 13:32:10 +0000
# 2  8624490c19ca05d1482f0084ccacdf59  2019-09-25 13:05:08 +0000
# 3  713d3a87025ff202027c7b5ba9d99580  2019-09-26 02:01:31 +0000
# 4  d788321e52ccae1c8ccc6228fee94edc  2019-09-19 16:45:36 +0000
#
#                                            employer  \
# 0                                         Giftcraft
# 1                                       Bento Group
# 2                     Burger King | Ghai Management
# ...

# %%
s = df[0:1]
s=s.to_string()
print(s)
# Out:
#     type                                                                                    pageurl                           uniq-id            crawl-timestamp   employer                      ad-title                         salary-range  job-location job-country  job-city job-state                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          
# ...

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# Create a Doc object
housekeeping_df = nlp(s)

# Print each token separately
for token in housekeeping_df:
    print(token.text, token.pos_, token.dep_)
# Out:
#      SPACE
# type NOUN ROOT
#                                                                                     SPACE
# pageurl NOUN ROOT
#                            SPACE
# uniq PROPN amod
# - PUNCT punct
# id PROPN ROOT
#             SPACE
# crawl NOUN compound
# - PUNCT punct
# timestamp NOUN nmod
#    SPACE
# employer NOUN ROOT
#                       SPACE
# ad NOUN compound
# - PUNCT punct
# title NOUN nmod
#                          SPACE
# salary NOUN compound
# - PUNCT punct
# range NOUN nmod
#   SPACE
# job NOUN compound
# - PUNCT punct
# location NOUN compound
# job NOUN compound
# - PUNCT punct
# country NOUN intj
#   SPACE
# job NOUN compound
# - PUNCT punct
# city NOUN appos
# job NOUN compound
# - PUNCT punct
# state NOUN nmod
# ...

# %%
 # explore tokens
for token in housekeeping_df:
    print(token.text, end=' | ')
# Out:
#      | type |                                                                                     | pageurl |                            | uniq | - | id |             | crawl | - | timestamp |    | employer |                       | ad | - | title |                          | salary | - | range |   | job | - | location | job | - | country |   | job | - | city | job | - | state |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
# ...

# %%
## Visualizing the entity recognizer
from spacy import displacy

displacy.render(housekeeping_df, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">    type                                                                                    pageurl                           uniq-id            crawl-timestamp   employer                      ad-title                         salary-range  job-location job-country  job-city job-state                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              
# ...

# %%
##Function to display lemmas

for token in housekeeping_df:
    print(f'{token.text:{10}} {token.pos_:{8}} {token.tag_:{6}} {spacy.explain(token.tag_)}')
# Out:
#            SPACE    _SP    None
# type       NOUN     NN     noun, singular or mass
#                                                                                     SPACE    _SP    None
# pageurl    NOUN     NN     noun, singular or mass
#                            SPACE    _SP    None
# uniq       PROPN    NNP    noun, proper singular
# -          PUNCT    HYPH   punctuation mark, hyphen
# id         PROPN    NNP    noun, proper singular
#             SPACE    _SP    None
# crawl      NOUN     NN     noun, singular or mass
# -          PUNCT    HYPH   punctuation mark, hyphen
# timestamp  NOUN     NN     noun, singular or mass
#            SPACE    _SP    None
# employer   NOUN     NN     noun, singular or mass
#                       SPACE    _SP    None
# ad         NOUN     NN     noun, singular or mass
# -          PUNCT    HYPH   punctuation mark, hyphen
# title      NOUN     NN     noun, singular or mass
#                          SPACE    _SP    None
# ...

# %%
for token in housekeeping_df:
    print(f'{token.text:{10}} {token.pos_:{7}} {token.dep_:{7}} {spacy.explain(token.dep_)}')
# Out:
#            SPACE           None
# type       NOUN    ROOT    None
#                                                                                     SPACE           None
# pageurl    NOUN    ROOT    None
#                            SPACE           None
# uniq       PROPN   amod    adjectival modifier
# -          PUNCT   punct   punctuation
# id         PROPN   ROOT    None
#             SPACE           None
# crawl      NOUN    compound compound
# -          PUNCT   punct   punctuation
# timestamp  NOUN    nmod    modifier of nominal
#            SPACE           None
# employer   NOUN    ROOT    None
#                       SPACE           None
# ad         NOUN    compound compound
# -          PUNCT   punct   punctuation
# title      NOUN    nmod    modifier of nominal
#                          SPACE           None
# salary     NOUN    compound compound
# -          PUNCT   punct   punctuation
# range      NOUN    nmod    modifier of nominal
#            SPACE           None
# ...
